# %% [markdown]
# # 03 Correct Freeway Attribute Errors with Project Cards

# %%
import os
import sys
import yaml
import pickle
import glob

import pandas as pd

from network_wrangler import RoadwayNetwork
from network_wrangler import TransitNetwork
from network_wrangler import ProjectCard
from network_wrangler import Scenario
from network_wrangler import WranglerLogger

from lasso import ModelRoadwayNetwork
from lasso import StandardTransit
from lasso import Parameters
from lasso import mtc

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
logger = logging.getLogger("WranglerLogger")
logger.handlers[0].stream = sys.stdout
logger.setLevel(logging.INFO)

# %% [markdown]
# ## Remote I/O and Parameters

# %%
# root_dir = os.path.join('/Users', 'wsp', 'Documents', 'GitHub', 'travel-model-two-networks')
root_dir = "C:/Users/USGS667806/Documents/GitHub/travel-model-two-networks"
input_dir = os.path.join(root_dir, 'data', 'processed', 'version_03')
output_dir = os.path.join(root_dir, 'data', 'processed', 'version_04')
card_dir = os.path.join(root_dir, 'project_cards')
# lasso_dir = os.path.join('/Users', 'wsp', 'Documents', 'GitHub', 'mtc-Lasso')
lasso_dir = "C:/Users/USGS667806/Lasso"

# %%
parameters = Parameters(lasso_base_dir = lasso_dir)
# Out:
# 2021-01-20 13:10:43, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 13:10:43, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 13:10:43, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 13:10:43, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso

# %% [markdown]
# ## Read Version 00 Scenario

# %%
version_01_pickle_file_name = os.path.join(input_dir, 'working_scenario_01.pickle')
v_01_scenario = pickle.load(open(version_01_pickle_file_name, 'rb'))

# %%
v_01_scenario.road_net.links_df.shape
# Out:
# (1634769, 40)

# %%
v_01_scenario.transit_net.feed.routes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 701 entries, 0 to 700
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   route_id_original       701 non-null    object
#  1   agency_id               526 non-null    object
#  2   route_short_name        665 non-null    object
#  3   route_long_name         679 non-null    object
#  4   route_desc              14 non-null     object
#  5   route_type              701 non-null    int64
#  6   route_url               217 non-null    object
#  7   route_color             260 non-null    object
#  8   route_text_color        243 non-null    object
#  9   agency_raw_name         701 non-null    object
#  10  route_sort_order        95 non-null     object
#  11  min_headway_minutes     32 non-null     object
#  12  eligibility_restricted  4 non-null      object
#  13  continuous_pickup       4 non-null      object
#  14  continuous_drop_off     4 non-null      object
#  15  route_id                701 non-null    object
# dtypes: int64(1), object(15)
# memory usage: 87.8+ KB

# %% [markdown]
# ## Create Scenario and Apply Project Cards

# %%
v_02_scenario = Scenario.create_scenario(
    base_scenario=v_01_scenario,
    card_directory = card_dir,
    tags = ['highway review'],
    validate_project_cards=False)
# Out:
# 2021-01-20 13:11:27, INFO: Creating Scenario
# 2021-01-20 13:11:27, INFO: Creating Scenario

# %%
v_02_scenario.apply_all_projects()
# Out:
# 2021-01-20 13:11:29, INFO: Applying Year 2015 Modify Facility Type to Service
# 2021-01-20 13:11:29, INFO: Applying Year 2015 Modify Facility Type to Service
# 2021-01-20 13:11:29, INFO: Applying Year 2015 Modify Facility Type to Service
# 2021-01-20 13:11:29, INFO: Applying Year 2015 Modify Facility Type to Service
# 2021-01-20 13:11:29, INFO: Applying Project to Roadway Network: Year 2015 Modify Facility Type to Service
# 2021-01-20 13:11:29, INFO: Applying Project to Roadway Network: Year 2015 Modify Facility Type to Service
# 2021-01-20 13:11:29, INFO: Applying Year 2015 Modify Facility Type to Ramp shape incorrect
# 2021-01-20 13:11:29, INFO: Applying Year 2015 Modify Facility Type to Ramp shape incorrect
# 2021-01-20 13:11:29, INFO: Applying Year 2015 Modify Facility Type to Ramp shape incorrect
# 2021-01-20 13:11:29, INFO: Applying Year 2015 Modify Facility Type to Ramp shape incorrect
# 2021-01-20 13:11:29, INFO: Applying Project to Roadway Network: Year 2015 Modify Facility Type to Ramp shape incorrect
# 2021-01-20 13:11:29, INFO: Applying Project to Roadway Network: Year 2015 Modify Facility Type to Ramp shape incorrect
# 2021-01-20 13:11:29, INFO: Applying Year 2015 Modify Facility Type to Ramp
# 2021-01-20 13:11:29, INFO: Applying Year 2015 Modify Facility Type to Ramp
# 2021-01-20 13:11:29, INFO: Applying Year 2015 Modify Facility Type to Ramp
# 2021-01-20 13:11:29, INFO: Applying Year 2015 Modify Facility Type to Ramp
# 2021-01-20 13:11:29, INFO: Applying Project to Roadway Network: Year 2015 Modify Facility Type to Ramp
# 2021-01-20 13:11:29, INFO: Applying Project to Roadway Network: Year 2015 Modify Facility Type to Ramp
# 2021-01-20 13:11:29, INFO: Applying Year 2015 Modify Lanes to 2 Lane and Facility Type to Ramp shape incorrect
# 2021-01-20 13:11:29, INFO: Applying Year 2015 Modify Lanes to 2 Lane and Facility Type to Ramp shape incorrect
# 2021-01-20 13:11:29, INFO: Applying Year 2015 Modify Lanes to 2 Lane and Facility Type to Ramp shape incorrect
# 2021-01-20 13:11:29, INFO: Applying Year 2015 Modify Lanes to 2 Lane and Facility Type to Ramp shape incorrect
# 2021-01-20 13:11:29, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 2 Lane and Facility Type to Ramp shape incorrect
# 2021-01-20 13:11:29, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 2 Lane and Facility Type to Ramp shape incorrect
# 2021-01-20 13:11:29, INFO: Applying Year 2015 Modify Lanes to 2 Lane and Facility Type to Ramp
# 2021-01-20 13:11:29, INFO: Applying Year 2015 Modify Lanes to 2 Lane and Facility Type to Ramp
# 2021-01-20 13:11:29, INFO: Applying Year 2015 Modify Lanes to 2 Lane and Facility Type to Ramp
# 2021-01-20 13:11:29, INFO: Applying Year 2015 Modify Lanes to 2 Lane and Facility Type to Ramp
# 2021-01-20 13:11:29, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 2 Lane and Facility Type to Ramp
# 2021-01-20 13:11:29, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 2 Lane and Facility Type to Ramp
# 2021-01-20 13:11:29, INFO: Applying Year 2015 Modify Lanes to 1 Lane and Facility Type to Ramp
# 2021-01-20 13:11:29, INFO: Applying Year 2015 Modify Lanes to 1 Lane and Facility Type to Ramp
# 2021-01-20 13:11:29, INFO: Applying Year 2015 Modify Lanes to 1 Lane and Facility Type to Ramp
# 2021-01-20 13:11:29, INFO: Applying Year 2015 Modify Lanes to 1 Lane and Facility Type to Ramp
# 2021-01-20 13:11:29, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 1 Lane and Facility Type to Ramp
# 2021-01-20 13:11:29, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 1 Lane and Facility Type to Ramp
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Bus Only Segments
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Bus Only Segments
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Bus Only Segments
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Bus Only Segments
# 2021-01-20 13:11:30, INFO: Applying Project to Roadway Network: Year 2015 Bus Only Segments
# 2021-01-20 13:11:30, INFO: Applying Project to Roadway Network: Year 2015 Bus Only Segments
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Modify Lanes to 7 Lanes
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Modify Lanes to 7 Lanes
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Modify Lanes to 7 Lanes
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Modify Lanes to 7 Lanes
# 2021-01-20 13:11:30, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 7 Lanes
# 2021-01-20 13:11:30, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 7 Lanes
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Modify Lanes to 6 Lanes
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Modify Lanes to 6 Lanes
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Modify Lanes to 6 Lanes
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Modify Lanes to 6 Lanes
# 2021-01-20 13:11:30, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 6 Lanes
# 2021-01-20 13:11:30, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 6 Lanes
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Modify Lanes to 5 Lanes
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Modify Lanes to 5 Lanes
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Modify Lanes to 5 Lanes
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Modify Lanes to 5 Lanes
# 2021-01-20 13:11:30, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 5 Lanes
# 2021-01-20 13:11:30, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 5 Lanes
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Modify Lanes to 4 Lanes
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Modify Lanes to 4 Lanes
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Modify Lanes to 4 Lanes
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Modify Lanes to 4 Lanes
# 2021-01-20 13:11:30, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 4 Lanes
# 2021-01-20 13:11:30, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 4 Lanes
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Modify Lanes to 3 Lanes
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Modify Lanes to 3 Lanes
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Modify Lanes to 3 Lanes
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Modify Lanes to 3 Lanes
# 2021-01-20 13:11:30, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 3 Lanes
# 2021-01-20 13:11:30, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 3 Lanes
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Modify Lanes to 2 Lanes
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Modify Lanes to 2 Lanes
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Modify Lanes to 2 Lanes
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Modify Lanes to 2 Lanes
# 2021-01-20 13:11:30, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 2 Lanes
# 2021-01-20 13:11:30, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 2 Lanes
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Modify Lanes to 1 Lane
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Modify Lanes to 1 Lane
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Modify Lanes to 1 Lane
# 2021-01-20 13:11:30, INFO: Applying Year 2015 Modify Lanes to 1 Lane
# 2021-01-20 13:11:30, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 1 Lane
# 2021-01-20 13:11:30, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 1 Lane

# %%
v_02_scenario.applied_projects
# Out:
# ['Year 2015 Modify Facility Type to Service',
#  'Year 2015 Modify Facility Type to Ramp shape incorrect',
#  'Year 2015 Modify Facility Type to Ramp',
#  'Year 2015 Modify Lanes to 2 Lane and Facility Type to Ramp shape incorrect',
#  'Year 2015 Modify Lanes to 2 Lane and Facility Type to Ramp',
#  'Year 2015 Modify Lanes to 1 Lane and Facility Type to Ramp',
#  'Year 2015 Bus Only Segments',
#  'Year 2015 Modify Lanes to 7 Lanes',
#  'Year 2015 Modify Lanes to 6 Lanes',
#  'Year 2015 Modify Lanes to 5 Lanes',
#  'Year 2015 Modify Lanes to 4 Lanes',
#  'Year 2015 Modify Lanes to 3 Lanes',
#  'Year 2015 Modify Lanes to 2 Lanes',
#  'Year 2015 Modify Lanes to 1 Lane',
#  'Year 2015 Correct As Is',
#  'Year 2015 Modify HOV Lanes and USE on US-101 SB from South of Healdsburg to North of Petaluma',
#  'Year 2015 Modify USE and HOV Lanes on US-101 SB (Segment 02) from South of Healdsburg to North of Petaluma',
#  'Year 2015 Modify HOV Lanes and USE on US 101 SB CA-85 to Oregon Expressway',
#  'Year 2015 Modify HOV Lanes and USE on US 101 SB CA-85 to Cochrane Road',
#  'Year 2015 Modify HOV Lanes and USE on US-101 NB (Segment 02) from North of Petaluma to South of Healdsburg',
#  'Year 2015 Modify HOV Lanes and USE on US 101 NB Oregon Expressway to Whipple Road',
#  'Year 2015 Modify HOV Lanes and USE on US-101 NB from North of Petaluma to South of Healdsburg',
#  'Year 2015 Modify HOV Lanes and USE on US 101 NB Cochran Road to CA-85',
#  'Year 2015 Modify HOV Lanes and USE on San Tomas Expressway SB I-880 to Hwy 17',
#  'Year 2015 Modify HOV Lanes and USE on San Tomas Expressway NB Hwy 17 to I-880',
#  'Year 2015 Modify HOV Lanes and USE on Lawrence Expressway SB US 101 to I-280',
#  'Year 2015 Modify HOV Lanes and USE on Lawrence Expressway NB I-280 to US 101',
#  'Year 2015 Modify HOV Lanes and USE on Ramp Connecting I880 and Bay Bridge Plaza',
#  'Year 2015 Modify HOV Lanes and USE on I-880 SB from Hegenberger Road to Dixon Road',
#  'Year 2015 Modify Express Lanes and USE on I-880 SB Dixon Road to CA-237',
#  'Year 2015 Modify HOV Lanes and USE on I-880 SB CA-237 to US 101',
#  'Year 2015 Modify HOV lanes and USE on I-880 NB US 101 to CA-237',
#  'Year 2015 Modify HOV Lanes and USE on I-880 NB from Dixon Road to I-238',
#  'Year 2015 Modify Express Lanes and USE on I-880 NB CA-237 to Dixon Road',
#  'Year 2015 Modify USE on I-80 WB to Bay Bridge Toll Plaza',
#  'Year 2015 Modify HOV Lanes and USE on I-80 WB from Fairfield to I-680',
#  'Year 2015 Modify HOV Lanes and USE on I-80 WB from Carquinez Bridge to Bay Bridge Toll Plaza',
#  'Year 2015 Modify HOV Lanes and USE on I-80 EB from I-680 to Fairfield',
#  'Year 2015 Modify HOV Lanes and USE on I-80 EB from Bay Bridge to Carquinez Bridge Toll Plaza',
#  'Year 2015 Modify HOV Lanes and USE on I-680 SB from Rudgear Road to Acosta Blvd',
#  'Year 2015 Modify HOV Lanes and USE on I-680 SB from Benicia Bridge to CA-242',
#  'Year 2015 Modify HOV Lanes USE on I-680 NB CA-242 to Benicia Bridge',
#  'Year 2015 Modify HOV Lanes and USE on I-680 NB from Acosta Blvd to Rudgear Road',
#  'Year 2015 Modify HOV lanes and USE on Hwy 4 WB from Deer Valley Road to Port Chicago Highway',
#  'Year 2015 Modify HOV Lanes and USE on Hwy 4 EB from Port Chicago Highway to Deer Valley Road',
#  'Year 2015 Modify HOV Lanes and USE on E Capitol Expressway SB I-680 to US 101',
#  'Year 2015 Modify HOV Lanes and USE on E Capitol Expressway NB US101 to I-680',
#  'Year 2015 Modify HOV Lanes and USE on CA-92 WB Eden Landing Rd to San Mateo-Hayward Bridge Toll Plaza',
#  'Year 2015 Modify HOV Lanes and USE on CA-87 SB US 101 to CA-85',
#  'Year 2015 Modify HOV Lanes and USE on CA 87 NB CA-85 to US 101',
#  'Year 2015 Modify HOV Lanes and USE on CA-85 SB US101 to US101',
#  'Year 2015 Modify HOV Lanes and USE on CA-85 NB US101 to US101',
#  'Year 2015 Modify HOV Lanes and USE on CA-84 WB I-880 to Dumbarton Bridge Toll Plaza',
#  'Year 2015 Modify HOV Lanes and USE on CA-280 SB Magdalena Ave to Southwest Expressway',
#  'Year 2015 Modify HOV Lanes and USE on CA-280 NB Bascom Ave to Magdalena Ave',
#  'Year 2015 Modify HOV Lanes and USE on CA-237 WB North 1st Street to US 101',
#  'Year 2015 Modify HOV Lanes and USE on CA-237 EB US 101 to North 1st Street',
#  'Year 2015 Bus Only Segments for Transbay Terminal Ramps',
#  'Year 2015 Bus Only Segments for Golden Gate Transit on US 101',
#  'Year 2015 Exclude Trucks on SR 85',
#  'Year 2015 Exclude Trucks on I580']

# %%
v_02_scenario.road_net.links_df.columns
# Out:
# Index(['access', 'bike_access', 'drive_access', 'fromIntersectionId', 'lanes',
#        'maxspeed', 'name', 'oneWay', 'ref', 'roadway', 'shstGeometryId',
#        'shstReferenceId', 'toIntersectionId', 'u', 'v', 'walk_access', 'wayId',
#        'county', 'model_link_id', 'A', 'B', 'rail_traveltime', 'rail_only',
#        'locationReferences', 'shape_id', 'geometry', 'ft_cal', 'ft',
#        'useclass', 'assignable', 'transit', 'bus_only', 'managed', 'ML_lanes',
#        'segment_id', 'ML_useclass', 'ML_access', 'ML_egress', 'tollseg',
#        'transit_access'],
#       dtype='object')

# %%
v_02_scenario.road_net.links_df[v_02_scenario.road_net.links_df.model_link_id == 3150085] # should be ramp lanes 2
# Out:
#        access bike_access drive_access                fromIntersectionId  \
# 765904              False         True  d1b76ff92ba7a2915de8efc97c782d73
#
#        lanes maxspeed name oneWay ref        roadway  ... transit bus_only  \
# 765904     2                 True      motorway_link  ...       0      NaN
#
#        managed  ML_lanes  segment_id ML_useclass ML_access ML_egress  tollseg  \
# 765904       0       NaN         NaN         NaN       NaN       NaN      NaN
#
#         transit_access
# 765904             NaN
#
# [1 rows x 40 columns]

# %%
v_02_scenario.road_net.links_df[v_02_scenario.road_net.links_df.model_link_id == 1008942] # should be 5 lanes
# Out:
#        access bike_access drive_access                fromIntersectionId  \
# 102730    nan       False         True  c4d8a43982e5d1d33a2ec65a7b7440bd
#
#        lanes maxspeed              name oneWay     ref   roadway  ... transit  \
# 102730     5   65 mph  Bayshore Freeway   True  US 101  motorway  ...       0
#
#        bus_only managed  ML_lanes  segment_id ML_useclass ML_access ML_egress  \
# 102730      NaN       0       NaN         NaN         NaN       NaN       NaN
#
#         tollseg  transit_access
# 102730      NaN             NaN
#
# [1 rows x 40 columns]

# %%
v_02_scenario.road_net.links_df[v_02_scenario.road_net.links_df.model_link_id == 8007989] # should be bus only
# Out:
#        access bike_access drive_access                fromIntersectionId  \
# 205698                  1            0  1c480bb0cd31770def93f57e6db6c700
#
#        lanes maxspeed name oneWay ref   roadway  ... transit bus_only managed  \
# 205698     1                 True      motorway  ...       1      1.0       0
#
#         ML_lanes  segment_id ML_useclass ML_access ML_egress  tollseg  \
# 205698       NaN         NaN         NaN       NaN       NaN      NaN
#
#         transit_access
# 205698             1.0
#
# [1 rows x 40 columns]

# %%
v_02_scenario.road_net.links_df[v_01_scenario.road_net.links_df.model_link_id == 5001470] # should be service
# Out:
#       access bike_access drive_access                fromIntersectionId lanes  \
# 20336              False         True  2fbe0a60406b7e828130c61cadf7d486     1
#
#       maxspeed name oneWay ref  roadway  ... transit bus_only managed  \
# 20336                 True      service  ...       0      NaN       0
#
#        ML_lanes  segment_id ML_useclass ML_access ML_egress  tollseg  \
# 20336       NaN         NaN         NaN       NaN       NaN      NaN
#
#        transit_access
# 20336             NaN
#
# [1 rows x 40 columns]

# %% [markdown]
# ## Make Travel Model Networks

# %%
model_net = ModelRoadwayNetwork.from_RoadwayNetwork(
    roadway_network_object = v_02_scenario.road_net, 
    parameters = parameters)
# Out:
# 2021-01-20 13:15:47, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 13:15:47, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 13:15:47, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 13:15:47, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso

# %%
print(model_net.links_df.shape)
print(model_net.nodes_df.shape)
print(model_net.shapes_df.shape)
# Out:
# (1634769, 40)
# (644475, 11)
# (869970, 7)

# %%
model_net = mtc.add_centroid_and_centroid_connector(
    roadway_network = model_net,
    parameters = parameters)
# Out:
# 2021-01-20 13:15:48, INFO: Adding centroid and centroid connector to standard network
# 2021-01-20 13:15:48, INFO: Adding centroid and centroid connector to standard network
# 2021-01-20 13:15:48, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 13:15:48, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 13:15:48, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 13:15:48, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 13:15:57, INFO: Finished adding centroid and centroid connectors
# 2021-01-20 13:15:57, INFO: Finished adding centroid and centroid connectors

# %%
print(model_net.links_df.shape)
print(model_net.nodes_df.shape)
print(model_net.shapes_df.shape)
# Out:
# (2190409, 40)
# (688957, 11)
# (1147790, 7)

# %%
model_net.links_df.model_link_id.nunique()
# Out:
# 2190409

# %%
model_net = mtc.add_tap_and_tap_connector(
    roadway_network = model_net,
    parameters = parameters)
# Out:
# 2021-01-20 13:15:58, INFO: Adding tap and tap connector to standard network
# 2021-01-20 13:15:58, INFO: Adding tap and tap connector to standard network
# 2021-01-20 13:15:58, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 13:15:58, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 13:15:58, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 13:15:58, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 13:16:03, INFO: Finished adding tap and tap connectors
# 2021-01-20 13:16:03, INFO: Finished adding tap and tap connectors

# %%
print(model_net.links_df.shape)
print(model_net.nodes_df.shape)
print(model_net.shapes_df.shape)
# Out:
# (2233923, 40)
# (694957, 11)
# (1169547, 7)

# %%
model_net.links_df.model_link_id.nunique()
# Out:
# 2233923

# %%
model_net.nodes_df.model_node_id.nunique()
# Out:
# 694957

# %%
model_net.shapes_df.id.nunique()
# Out:
# 1169547

# %%
model_net = mtc.roadway_standard_to_mtc_network(model_net, parameters)
# Out:
# 2021-01-20 13:16:05, INFO: Renaming roadway attributes to be consistent with what mtc's model is expecting
# 2021-01-20 13:16:05, INFO: Renaming roadway attributes to be consistent with what mtc's model is expecting
# 2021-01-20 13:16:05, INFO: Creating managed lane network.
# 2021-01-20 13:16:05, INFO: Creating managed lane network.
# 2021-01-20 13:16:05, INFO: Creating network with duplicated managed lanes
# 2021-01-20 13:16:05, INFO: Creating network with duplicated managed lanes
# C:\Users\USGS667806\Anaconda3\envs\lasso_environment\lib\site-packages\geopandas\geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\USGS667806\Anaconda3\envs\lasso_environment\lib\site-packages\geopandas\geodataframe.py:852: UserWarning: Geometry column does not contain geometry.
#   warnings.warn("Geometry column does not contain geometry.")
# C:\Users\USGS667806\Anaconda3\envs\lasso_environment\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# 2021-01-20 13:28:34, INFO: Determining cntype
# 2021-01-20 13:28:34, INFO: Determining cntype
# 2021-01-20 13:28:34, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 13:28:34, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 13:28:34, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 13:28:34, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 13:28:34, INFO: Calculating and adding roadway network variable: cntype
# 2021-01-20 13:28:34, INFO: Calculating and adding roadway network variable: cntype
# 2021-01-20 13:29:38, INFO: Finished determining variable: cntype
# 2021-01-20 13:29:38, INFO: Finished determining variable: cntype
# 2021-01-20 13:29:38, INFO: Determining transit
# 2021-01-20 13:29:38, INFO: Determining transit
# 2021-01-20 13:29:38, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 13:29:38, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 13:29:38, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 13:29:38, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 13:29:38, INFO: Variable 'transit' updated for some links. Returning without overwriting for those links. Calculating for other links
# 2021-01-20 13:29:38, INFO: Variable 'transit' updated for some links. Returning without overwriting for those links. Calculating for other links
# 2021-01-20 13:29:38, INFO: Calculating and adding roadway network variable: transit
# 2021-01-20 13:29:38, INFO: Calculating and adding roadway network variable: transit
# 2021-01-20 13:29:39, INFO: Finished determining transit-only variable: transit
# 2021-01-20 13:29:39, INFO: Finished determining transit-only variable: transit
# 2021-01-20 13:29:39, INFO: Determining useclass
# 2021-01-20 13:29:39, INFO: Determining useclass
# 2021-01-20 13:29:39, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 13:29:39, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 13:29:39, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 13:29:39, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 13:29:39, INFO: Variable 'useclass' updated for some links. Returning without overwriting for those links. Calculating for other links
# 2021-01-20 13:29:39, INFO: Variable 'useclass' updated for some links. Returning without overwriting for those links. Calculating for other links
# 2021-01-20 13:29:39, INFO: Calculating and adding roadway network variable: useclass
# 2021-01-20 13:29:39, INFO: Calculating and adding roadway network variable: useclass
# 2021-01-20 13:29:39, INFO: Finished determining variable: useclass
# 2021-01-20 13:29:39, INFO: Finished determining variable: useclass
# 2021-01-20 13:29:39, INFO: Overwriting existing distance Variable 'distance' already in network
# 2021-01-20 13:29:39, INFO: Overwriting existing distance Variable 'distance' already in network
# 2021-01-20 13:30:44, INFO: Calculating distance for all links
# 2021-01-20 13:30:44, INFO: Calculating distance for all links
# 2021-01-20 13:30:48, INFO: Calculating distance for all links
# 2021-01-20 13:30:48, INFO: Calculating distance for all links
# 2021-01-20 13:30:57, INFO: Filling nan for network from network wrangler
# 2021-01-20 13:30:57, INFO: Filling nan for network from network wrangler
# 2021-01-20 13:31:23, INFO: Splitting variables by time period and category
# 2021-01-20 13:31:23, INFO: Splitting variables by time period and category
# 2021-01-20 13:31:31, WARNING: Specified variable to split: ML_lanes not in network variables: Index(['index', 'access', 'bike_access', 'drive_access', 'fromIntersectionId',
#        'lanes', 'maxspeed', 'name', 'oneWay', 'ref', 'roadway',
#        'shstGeometryId', 'shstReferenceId', 'toIntersectionId', 'u', 'v',
#        'walk_access', 'wayId', 'county', 'model_link_id', 'A', 'B',
#        'rail_traveltime', 'rail_only', 'locationReferences', 'shape_id',
#        'geometry', 'ft_cal', 'ft', 'useclass', 'assignable', 'transit',
#        'bus_only', 'managed', 'segment_id', 'tollseg', 'transit_access',
#        'egress', 'id', 'distance', 'cntype', 'lanes_EA', 'lanes_AM',
#        'lanes_MD', 'lanes_PM', 'lanes_EV'],
#       dtype='object'). Returning 0.
# 2021-01-20 13:31:31, WARNING: Specified variable to split: ML_lanes not in network variables: Index(['index', 'access', 'bike_access', 'drive_access', 'fromIntersectionId',
#        'lanes', 'maxspeed', 'name', 'oneWay', 'ref', 'roadway',
#        'shstGeometryId', 'shstReferenceId', 'toIntersectionId', 'u', 'v',
#        'walk_access', 'wayId', 'county', 'model_link_id', 'A', 'B',
#        'rail_traveltime', 'rail_only', 'locationReferences', 'shape_id',
#        'geometry', 'ft_cal', 'ft', 'useclass', 'assignable', 'transit',
#        'bus_only', 'managed', 'segment_id', 'tollseg', 'transit_access',
#        'egress', 'id', 'distance', 'cntype', 'lanes_EA', 'lanes_AM',
#        'lanes_MD', 'lanes_PM', 'lanes_EV'],
#       dtype='object'). Returning 0.
# 2021-01-20 13:31:39, INFO: Converting variable type to mtc standard
# 2021-01-20 13:31:39, INFO: Converting variable type to mtc standard
# 2021-01-20 13:31:45, INFO: Setting Coordinate Reference System to ESRI:102646
# 2021-01-20 13:31:45, INFO: Setting Coordinate Reference System to ESRI:102646

# %%
model_net.links_df.shape
# Out:
# (2238069, 56)

# %%
model_net.links_df.model_link_id.nunique()
# Out:
# 2238069

# %%
model_net.nodes_mtc_df.shape
# Out:
# (696375, 12)

# %%
model_net.nodes_df.model_node_id.nunique()
# Out:
# 696371

# %% [markdown]
# ## Write to Disk

# %% [markdown]
# ## As shapefile

# %%
model_net.write_roadway_as_shp(
    output_link_shp = os.path.join(output_dir, 'links.shp'),
    output_node_shp = os.path.join(output_dir, 'nodes.shp'),
    link_output_variables = ["model_link_id", "A", "B", "geometry"],
    node_output_variables = ["model_node_id", "geometry"],
    data_to_csv = False,
    data_to_dbf = True,
)
# Out:
# 2021-01-20 13:52:16, INFO: Writing Network as Shapefile
# 2021-01-20 13:52:16, INFO: Writing Network as Shapefile
# 2021-01-20 13:52:16, INFO: Renaming DBF Node Variables
# 2021-01-20 13:52:16, INFO: Renaming DBF Node Variables
# 2021-01-20 13:52:16, INFO: Renaming variables so that they are DBF-safe
# 2021-01-20 13:52:16, INFO: Renaming variables so that they are DBF-safe
# 2021-01-20 13:52:29, INFO: Renaming DBF Link Variables
# 2021-01-20 13:52:29, INFO: Renaming DBF Link Variables
# 2021-01-20 13:52:29, INFO: Renaming variables so that they are DBF-safe
# 2021-01-20 13:52:29, INFO: Renaming variables so that they are DBF-safe
# 2021-01-20 13:52:32, INFO: Writing Node Shapes:
#  - C:/Users/USGS667806/Documents/GitHub/travel-model-two-networks\data\processed\version_04\nodes.shp
# 2021-01-20 13:52:32, INFO: Writing Node Shapes:
#  - C:/Users/USGS667806/Documents/GitHub/travel-model-two-networks\data\processed\version_04\nodes.shp
# 2021-01-20 13:56:24, INFO: Writing Link Shapes:
#  - C:/Users/USGS667806/Documents/GitHub/travel-model-two-networks\data\processed\version_04\links.shp
# 2021-01-20 13:56:24, INFO: Writing Link Shapes:
#  - C:/Users/USGS667806/Documents/GitHub/travel-model-two-networks\data\processed\version_04\links.shp

# %% [markdown]
# ## As fixed width (for CUBE)

# %%
model_net.write_roadway_as_fixedwidth(
    output_link_txt = os.path.join(output_dir, 'links.txt'),
    output_node_txt = os.path.join(output_dir, 'nodes.txt'),
    output_link_header_width_txt = os.path.join(output_dir, 'links_header_width.txt'),
    output_node_header_width_txt = os.path.join(output_dir, 'nodes_header_width.txt'),
    output_cube_network_script = os.path.join(output_dir, 'make_complete_network_from_fixed_width_file.s'),
    #drive_only = True
)
# Out:
# 2021-01-20 14:07:50, INFO: Starting fixed width conversion
# 2021-01-20 14:07:50, INFO: Starting fixed width conversion
# 2021-01-20 14:24:57, INFO: Writing out link database
# 2021-01-20 14:24:57, INFO: Writing out link database
# 2021-01-20 14:25:20, INFO: Writing out link header and width ----
# 2021-01-20 14:25:20, INFO: Writing out link header and width ----
# 2021-01-20 14:25:20, INFO: Starting fixed width conversion
# 2021-01-20 14:25:20, INFO: Starting fixed width conversion
# 2021-01-20 14:26:43, INFO: Writing out node database
# 2021-01-20 14:26:43, INFO: Writing out node database
# 2021-01-20 14:26:46, INFO: Writing out node header and width
# 2021-01-20 14:26:46, INFO: Writing out node header and width

# %%
# %%capture
os.chdir(output_dir)
# !make_cube.bat
# Out:
# links.txt(1797000): 1;0;                    maz_cc170010;1;      Alameda; 333
# links.txt(1798000): 0;1;                     maz_cc39893;0;      Alameda; 333
# links.txt(1799000): 1;0;                    maz_cc186621;1;      Alameda; 333
# links.txt(1800000): 1;0;                    maz_cc175429;1;      Alameda; 333
# links.txt(1801000): 1;0;                    maz_cc177885;1;      Alameda; 333
# links.txt(1802000): 1;0;                    maz_cc167812;1;      Alameda; 333
# links.txt(1803000): 1;0;                    maz_cc183652;1;      Alameda; 333
# links.txt(1804000): 1;0;                    maz_cc187250;1;      Alameda; 333
# links.txt(1805000): 1;0;                    maz_cc161563;1;      Alameda; 334
# links.txt(1806000): 0;0;                    maz_cc172959;1;      Alameda; 334
# links.txt(1807000): 1;0;                    maz_cc167531;1;      Alameda; 334
# links.txt(1808000): 1;0;                    maz_cc190362;1;      Alameda; 334
# links.txt(1809000): 1;1;                     maz_cc82322;1;      Alameda; 334
# links.txt(1810000): 0;1;                     maz_cc33547;0;      Alameda; 334
# links.txt(1811000): 0;1;                     maz_cc83404;0;      Alameda; 334
# links.txt(1812000): 1;0;                    maz_cc172124;1;      Alameda; 334
# links.txt(1813000): 1;0;                    maz_cc167671;1;      Alameda; 334
# links.txt(1814000): 1;0;                    maz_cc181871;1;      Alameda; 334
# links.txt(1815000): 1;1;                     maz_cc37149;1;      Alameda; 335
# links.txt(1816000): 0;1;                     maz_cc29343;0;      Alameda; 335
# links.txt(1817000): 1;0;                    maz_cc179654;1;      Alameda; 335
# links.txt(1818000): 0;1;                     maz_cc33545;0;      Alameda; 335
# links.txt(1819000): 1;0;                    maz_cc184857;1;      Alameda; 335
# links.txt(1820000): 1;0;                    maz_cc190736;1;      Alameda; 335
# links.txt(1821000): 0;1;                     maz_cc33696;0;      Alameda; 335
# links.txt(1822000): 1;0;                    maz_cc175581;1;      Alameda; 335
# links.txt(1823000): 1;0;                    maz_cc192101;1;      Alameda; 335
# links.txt(1824000): 0;1;                     maz_cc27597;0;      Alameda; 335
# links.txt(1825000): 1;0;                    maz_cc162645;1;      Alameda; 336

# %%
# %%capture
# !runtpp make_simple_roadway_network.s
# !runtpp make_complete_marin_network.s
# !runtpp make_simple_transit_network.s
# !runtpp make_highway_ramps_roadway_network.s
# Out:
# links.txt(1826000): 1;0;                    maz_cc191313;1;      Alameda; 336
# links.txt(1827000): 1;0;                    maz_cc191432;1;      Alameda; 336
# links.txt(1828000): 1;0;                    maz_cc168995;1;      Alameda; 336
# links.txt(1829000): 0;1;                     maz_cc27865;0;      Alameda; 336
# links.txt(1830000): 1;0;                    maz_cc165641;1;      Alameda; 336
# links.txt(1831000): 1;0;                    maz_cc169617;1;      Alameda; 336
# links.txt(1832000): 1;0;                    maz_cc175482;1;      Alameda; 336
# links.txt(1833000): 1;0;                    maz_cc169422;1;      Alameda; 336
# links.txt(1834000): 1;0;                    maz_cc178378;1;      Alameda; 336
# links.txt(1835000): 1;0;                    maz_cc171424;1;      Alameda; 337
# links.txt(1836000): 1;1;                     maz_cc32605;1;      Alameda; 337
# links.txt(1837000): 1;0;                    maz_cc182118;1;      Alameda; 337
# links.txt(1838000): 1;0;                    maz_cc190817;1;      Alameda; 337
# links.txt(1839000): 1;0;                    maz_cc184573;1;      Alameda; 337
# links.txt(1840000): 1;0;                    maz_cc187994;1;      Alameda; 337
# links.txt(1841000): 1;0;                    maz_cc181753;1;      Alameda; 337
# links.txt(1842000): 0;1;                     maz_cc87787;0; Contra Costa; 424
# links.txt(1843000): 1;0;                    maz_cc197687;1; Contra Costa; 424
# links.txt(1844000): 0;1;                     maz_cc44505;0; Contra Costa; 424
# links.txt(1845000): 1;0;                    maz_cc212618;1; Contra Costa; 424
# links.txt(1846000): 1;0;                    maz_cc204627;1; Contra Costa; 424
# links.txt(1847000): 0;1;                     maz_cc47124;0; Contra Costa; 424
# links.txt(1848000): 0;1;                     maz_cc47069;0; Contra Costa; 424
# links.txt(1849000): 0;1;                     maz_cc48546;0; Contra Costa; 424
# links.txt(1850000): 0;1;                     maz_cc43644;0; Contra Costa; 425
# links.txt(1851000): 0;1;                     maz_cc46386;0; Contra Costa; 425
# links.txt(1852000): 1;0;                    maz_cc214829;1; Contra Costa; 425
# links.txt(1853000): 1;0;                    maz_cc214197;1; Contra Costa; 425
# links.txt(1854000): 1;0;                    maz_cc212846;1; Contra Costa; 425
# links.txt(1855000): 1;0;                    maz_cc210755;1; Contra Costa; 425
# links.txt(1856000): 1;0;                    maz_cc217256;1; Contra Costa; 425
# links.txt(1857000): 0;1;                     maz_cc50335;0; Contra Costa; 425
# links.txt(1858000): 1;0;                    maz_cc206700;1; Contra Costa; 425
# links.txt(1859000): 1;0;                    maz_cc206469;1; Contra Costa; 425
# links.txt(1860000): 1;0;                    maz_cc212621;1; Contra Costa; 426
# links.txt(1861000): 0;1;                     maz_cc48490;0; Contra Costa; 426
# links.txt(1862000): 1;0;                    maz_cc215018;1; Contra Costa; 426
# links.txt(1863000): 1;1;                     maz_cc44757;1; Contra Costa; 426
# links.txt(1864000): 0;0;                    maz_cc194459;1; Contra Costa; 426
# links.txt(1865000): 1;1;                     maz_cc27470;1; Contra Costa; 426
# links.txt(1866000): 0;0;                    maz_cc201777;1; Contra Costa; 426
# links.txt(1867000): 1;0;                    maz_cc214506;1; Contra Costa; 426
# links.txt(1868000): 1;1;                     maz_cc87412;1; Contra Costa; 426
# links.txt(1869000): 1;0;                    maz_cc197694;1; Contra Costa; 426
# links.txt(1870000): 0;1;                     maz_cc42257;0; Contra Costa; 427
# links.txt(1871000): 1;1;                     maz_cc87293;1; Contra Costa; 427
# links.txt(1872000): 1;0;                    maz_cc211216;1; Contra Costa; 427
# links.txt(1873000): 1;0;                    maz_cc199668;1; Contra Costa; 427
# links.txt(1874000): 0;1;                     maz_cc88161;0; Contra Costa; 427
# links.txt(1875000): 1;0;                    maz_cc213638;1; Contra Costa; 427
# links.txt(1876000): 1;0;                    maz_cc217520;1; Contra Costa; 427
# links.txt(1877000): 1;0;                    maz_cc200966;1; Contra Costa; 427
# links.txt(1878000): 1;0;                    maz_cc215716;1; Contra Costa; 427
# links.txt(1879000): 1;0;                    maz_cc215653;1; Contra Costa; 427
# links.txt(1880000): 0;0;                    maz_cc202438;1; Contra Costa; 428
# links.txt(1881000): 1;0;                    maz_cc225417;1;       Solano; 511
# links.txt(1882000): 1;0;                    maz_cc222952;1;       Solano; 512
# links.txt(1883000): 1;0;                    maz_cc220094;1;       Solano; 512
# links.txt(1884000): 1;0;                    maz_cc219329;1;       Solano; 512
# links.txt(1885000): 0;1;                     maz_cc55352;0;       Solano; 512
# links.txt(1886000): 1;0;                    maz_cc225032;1;       Solano; 512
# links.txt(1887000): 1;0;                    maz_cc226601;1;       Solano; 512
# links.txt(1888000): 1;1;                     maz_cc89269;1;       Solano; 512
# links.txt(1889000): 0;1;                     maz_cc54385;0;       Solano; 512
# links.txt(1890000): 1;1;                     maz_cc56450;1;       Solano; 512
# links.txt(1891000): 1;0;                    maz_cc226930;1;       Solano; 512
# links.txt(1892000): 1;0;                    maz_cc222365;1;       Solano; 513
# links.txt(1893000): 1;0;                    maz_cc225956;1;       Solano; 513
# links.txt(1894000): 0;1;                     maz_cc54857;0;       Solano; 513
# links.txt(1895000): 0;1;                     maz_cc90877;0;       Solano; 513
# links.txt(1896000): 1;0;                    maz_cc220078;1;       Solano; 513
# links.txt(1897000): 1;0;                    maz_cc227672;1;       Solano; 513
# links.txt(1898000): 1;0;                    maz_cc221158;1;       Solano; 513
# links.txt(1899000): 0;1;                     maz_cc56982;0;         Napa; 603
# links.txt(1900000): 0;1;                     maz_cc91566;0;         Napa; 603
# links.txt(1901000): 1;1;                     maz_cc57462;1;         Napa; 603
# links.txt(1902000): 0;1;                     maz_cc57420;0;         Napa; 603
# links.txt(1903000): 1;0;                    maz_cc230160;1;         Napa; 603
# links.txt(1904000): 1;0;                    maz_cc231366;1;         Napa; 603
# links.txt(1905000): 1;1;                     maz_cc91888;1;       Sonoma; 713
# links.txt(1906000): 1;0;                    maz_cc234647;1;       Sonoma; 713
# links.txt(1907000): 1;0;                    maz_cc236548;1;       Sonoma; 713
# links.txt(1908000): 1;1;                     maz_cc60894;1;       Sonoma; 714
# links.txt(1909000): 1;0;                    maz_cc242735;1;       Sonoma; 714
# links.txt(1910000): 1;0;                    maz_cc233156;1;       Sonoma; 714
# links.txt(1911000): 0;1;                     maz_cc59606;0;       Sonoma; 714
# links.txt(1912000): 1;0;                    maz_cc238529;1;       Sonoma; 714
# links.txt(1913000): 1;0;                    maz_cc244626;1;       Sonoma; 714
# links.txt(1914000): 1;0;                    maz_cc240866;1;       Sonoma; 714
# links.txt(1915000): 1;1;                     maz_cc93043;1;       Sonoma; 714
# links.txt(1916000): 1;0;                    maz_cc238746;1;       Sonoma; 714
# links.txt(1917000): 1;0;                    maz_cc261123;0;       Sonoma; 714
# links.txt(1918000): 1;0;                    maz_cc234585;1;       Sonoma; 715
# links.txt(1919000): 1;0;                    maz_cc236091;1;       Sonoma; 715
# links.txt(1920000): 1;1;                     maz_cc92236;1;       Sonoma; 715
# links.txt(1921000): 1;0;                    maz_cc244066;1;       Sonoma; 715
# links.txt(1922000): 1;0;                    maz_cc241314;1;       Sonoma; 715
# links.txt(1923000): 1;0;                    maz_cc237352;1;       Sonoma; 715
# links.txt(1924000): 1;0;                    maz_cc247065;1;        Marin; 806
# links.txt(1925000): 1;0;                    maz_cc249372;1;        Marin; 806
# links.txt(1926000): 1;1;                     maz_cc64332;1;        Marin; 806
# links.txt(1927000): 1;0;                    maz_cc248307;1;        Marin; 806
# links.txt(1928000): 0;1;                     maz_cc64589;0;        Marin; 806
# links.txt(1929000): 1;0;                    maz_cc247068;1;        Marin; 806
# links.txt(1930000): 0;1;                     maz_cc64299;0;        Marin; 807
# links.txt(1931000): 1;1;                     maz_cc63970;1;        Marin; 807
# links.txt(1932000): 1;0;                    maz_cc249599;1;        Marin; 807
# links.txt(1933000): 1;0;                    maz_cc247411;1;        Marin; 807
# links.txt(1934000): 0;0;                     maz_cc98312;1;San Francisco;  10
# links.txt(1935000): 1;0;                    maz_cc103582;1;San Francisco;  10
# links.txt(1936000): 1;1;                     maz_cc69701;1;San Francisco;  10
# links.txt(1937000): 1;0;                    maz_cc251254;0;San Francisco;  10
# links.txt(1938000): 1;0;                    maz_cc107314;1;San Francisco;  10
# links.txt(1939000): 1;0;                    maz_cc251072;0;San Francisco;  10
# links.txt(1940000): 1;1;                     maz_cc67339;1;San Francisco;  11
# links.txt(1941000): 1;1;                      maz_cc2595;1;San Francisco;  11
# links.txt(1942000): 1;0;                     maz_cc99435;1;San Francisco;  11
# links.txt(1943000): 1;0;                     maz_cc95170;1;San Francisco;  11
# links.txt(1944000): 1;1;                     maz_cc66679;1;San Francisco;  11
# links.txt(1945000): 1;0;                    maz_cc104653;1;San Francisco;  11
# links.txt(1946000): 0;1;                      maz_cc2132;0;San Francisco;  11
# links.txt(1947000): 1;1;                     maz_cc66036;1;San Francisco;  11
# links.txt(1948000): 1;0;                     maz_cc98130;1;San Francisco;  11
# links.txt(1949000): 0;1;                       maz_cc441;0;San Francisco;  11
# links.txt(1950000): 1;0;                    maz_cc100215;1;San Francisco;  12
# links.txt(1951000): 1;0;                     maz_cc98749;1;San Francisco;  12
# links.txt(1952000): 1;0;                     maz_cc94062;1;San Francisco;  12
# links.txt(1953000): 1;0;                    maz_cc103257;1;San Francisco;  12
# links.txt(1954000): 1;1;                     maz_cc65799;1;San Francisco;  12
# links.txt(1955000): 1;0;                    maz_cc105859;1;San Francisco;  12
# links.txt(1956000): 1;0;                     maz_cc97703;1;San Francisco;  12
# links.txt(1957000): 1;0;                     maz_cc97870;1;San Francisco;  12
# links.txt(1958000): 1;0;                    maz_cc121683;1;    San Mateo; 117
# links.txt(1959000): 0;1;                      maz_cc9697;0;    San Mateo; 117
# links.txt(1960000): 1;0;                    maz_cc123590;1;    San Mateo; 117
# links.txt(1961000): 1;0;                    maz_cc119869;1;    San Mateo; 117
# links.txt(1962000): 1;0;                    maz_cc121873;1;    San Mateo; 117
# links.txt(1963000): 1;0;                    maz_cc112308;1;    San Mateo; 117
# links.txt(1964000): 1;1;                     maz_cc70787;1;    San Mateo; 117
# links.txt(1965000): 1;0;                    maz_cc123026;1;    San Mateo; 117
# links.txt(1966000): 1;0;                    maz_cc109272;1;    San Mateo; 118
# links.txt(1967000): 1;1;                      maz_cc6792;1;    San Mateo; 118
# links.txt(1968000): 1;0;                    maz_cc124554;1;    San Mateo; 118
# links.txt(1969000): 0;1;                      maz_cc4837;0;    San Mateo; 118
# links.txt(1970000): 0;1;                     maz_cc74094;0;    San Mateo; 118
# links.txt(1971000): 1;0;                    maz_cc111336;1;    San Mateo; 118
# links.txt(1972000): 1;0;                    maz_cc110122;1;    San Mateo; 118
# links.txt(1973000): 1;0;                    maz_cc109696;1;    San Mateo; 118
# links.txt(1974000): 1;1;                     maz_cc74805;1;    San Mateo; 118
# links.txt(1975000): 1;0;                    maz_cc110793;1;    San Mateo; 118
# links.txt(1976000): 0;0;                    maz_cc119972;1;    San Mateo; 119
# links.txt(1977000): 1;0;                    maz_cc115544;1;    San Mateo; 119
# links.txt(1978000): 1;1;                     maz_cc70667;1;    San Mateo; 119
# links.txt(1979000): 1;1;                     maz_cc73196;1;    San Mateo; 119
# links.txt(1980000): 1;0;                    maz_cc123098;1;    San Mateo; 119
# links.txt(1981000): 1;1;                      maz_cc9779;1;    San Mateo; 119
# links.txt(1982000): 1;0;                    maz_cc123782;1;    San Mateo; 119
# links.txt(1983000): 1;0;                    maz_cc108176;1;    San Mateo; 119
# links.txt(1984000): 1;0;                    maz_cc120511;1;    San Mateo; 119
# links.txt(1985000): 1;0;                    maz_cc110213;1;    San Mateo; 119
# links.txt(1986000): 1;0;                    maz_cc143021;1;  Santa Clara; 258
# links.txt(1987000): 1;0;                    maz_cc152952;1;  Santa Clara; 258
# links.txt(1988000): 1;0;                    maz_cc252207;0;  Santa Clara; 258
# links.txt(1989000): 0;1;                     maz_cc12440;0;  Santa Clara; 259
# links.txt(1990000): 1;1;                     maz_cc24893;1;  Santa Clara; 259
# links.txt(1991000): 0;0;                    maz_cc146718;1;  Santa Clara; 259
# links.txt(1992000): 1;1;                     maz_cc22487;1;  Santa Clara; 259
# links.txt(1993000): 0;1;                     maz_cc13591;0;  Santa Clara; 259
# links.txt(1994000): 1;0;                    maz_cc141942;1;  Santa Clara; 259
# links.txt(1995000): 1;0;                    maz_cc252695;0;  Santa Clara; 259
# links.txt(1996000): 1;0;                    maz_cc254759;0;  Santa Clara; 259
# links.txt(1997000): 0;0;                    maz_cc142105;1;  Santa Clara; 259
# links.txt(1998000): 1;0;                    maz_cc159988;1;  Santa Clara; 259
# links.txt(1999000): 0;0;                    maz_cc159429;1;  Santa Clara; 260
# links.txt(2000000): 1;1;                     maz_cc77947;1;  Santa Clara; 260
# links.txt(2001000): 1;0;                    maz_cc256715;0;  Santa Clara; 260
# links.txt(2002000): 1;0;                    maz_cc127080;1;  Santa Clara; 260
# links.txt(2003000): 1;0;                    maz_cc127714;1;  Santa Clara; 260
# links.txt(2004000): 1;0;                    maz_cc254353;0;  Santa Clara; 260
# links.txt(2005000): 1;0;                    maz_cc256828;0;  Santa Clara; 260
# links.txt(2006000): 0;1;                     maz_cc19452;0;  Santa Clara; 260
# links.txt(2007000): 1;0;                    maz_cc132930;1;  Santa Clara; 260
# links.txt(2008000): 1;0;                    maz_cc160246;1;  Santa Clara; 260
# links.txt(2009000): 1;0;                    maz_cc256793;0;  Santa Clara; 261
# links.txt(2010000): 0;1;                     maz_cc14550;0;  Santa Clara; 261
# links.txt(2011000): 1;0;                    maz_cc258524;0;  Santa Clara; 261
# links.txt(2012000): 1;0;                    maz_cc158081;1;  Santa Clara; 261
# links.txt(2013000): 1;1;                     maz_cc26757;1;  Santa Clara; 261
# links.txt(2014000): 0;0;                    maz_cc128781;1;  Santa Clara; 261
# links.txt(2015000): 1;0;                    maz_cc158305;1;  Santa Clara; 261
# links.txt(2016000): 1;0;                    maz_cc158452;1;  Santa Clara; 261
# links.txt(2017000): 1;0;                    maz_cc148279;1;  Santa Clara; 261
# links.txt(2018000): 0;1;                     maz_cc23633;0;  Santa Clara; 261
# links.txt(2019000): 0;1;                     maz_cc26677;0;  Santa Clara; 262
# links.txt(2020000): 0;0;                    maz_cc154403;1;  Santa Clara; 262
# links.txt(2021000): 1;1;                     maz_cc24542;1;  Santa Clara; 262
# links.txt(2022000): 0;1;                     maz_cc13243;0;  Santa Clara; 262
# links.txt(2023000): 1;0;                    maz_cc148078;1;  Santa Clara; 262
# links.txt(2024000): 0;1;                     maz_cc26394;0;  Santa Clara; 262
# links.txt(2025000): 1;0;                    maz_cc137830;1;  Santa Clara; 262
# links.txt(2026000): 0;1;                     maz_cc16293;0;  Santa Clara; 262
# links.txt(2027000): 1;0;                    maz_cc254032;0;  Santa Clara; 262
# links.txt(2028000): 0;1;                     maz_cc24275;0;  Santa Clara; 262
# links.txt(2029000): 0;0;                    maz_cc133112;1;  Santa Clara; 263
# links.txt(2030000): 0;1;                     maz_cc11103;0;  Santa Clara; 263
# links.txt(2031000): 0;0;                    maz_cc148395;1;  Santa Clara; 263
# links.txt(2032000): 0;1;                     maz_cc15833;0;  Santa Clara; 263
# links.txt(2033000): 0;1;                     maz_cc76614;0;  Santa Clara; 263
# links.txt(2034000): 0;0;                    maz_cc150796;1;  Santa Clara; 263
# links.txt(2035000): 1;0;                    maz_cc134194;1;  Santa Clara; 263
# links.txt(2036000): 1;0;                    maz_cc155950;1;  Santa Clara; 263
# links.txt(2037000): 1;0;                    maz_cc143331;1;  Santa Clara; 263
# links.txt(2038000): 0;0;                    maz_cc130803;1;  Santa Clara; 263
# links.txt(2039000): 0;0;                    maz_cc144826;1;  Santa Clara; 264
# links.txt(2040000): 1;1;                     maz_cc16095;1;  Santa Clara; 264
# links.txt(2041000): 0;0;                    maz_cc156111;1;  Santa Clara; 264
# links.txt(2042000): 1;0;                    maz_cc134864;1;  Santa Clara; 264
# links.txt(2043000): 1;0;                    maz_cc127124;1;  Santa Clara; 264
# links.txt(2044000): 1;0;                    maz_cc155518;1;  Santa Clara; 264
# links.txt(2045000): 1;0;                    maz_cc253892;0;  Santa Clara; 264
# links.txt(2046000): 1;0;                    maz_cc140347;1;  Santa Clara; 264
# links.txt(2047000): 1;0;                    maz_cc158067;1;  Santa Clara; 264
# links.txt(2048000): 1;0;                    maz_cc132383;1;  Santa Clara; 264
# links.txt(2049000): 1;0;                    maz_cc171210;1;      Alameda; 337
# links.txt(2050000): 1;0;                    maz_cc186116;1;      Alameda; 337
# links.txt(2051000): 1;0;                    maz_cc170262;1;      Alameda; 338
# links.txt(2052000): 0;1;                     maz_cc29696;0;      Alameda; 338
# links.txt(2053000): 1;0;                    maz_cc192710;1;      Alameda; 338
# links.txt(2054000): 0;1;                     maz_cc80505;0;      Alameda; 338
# links.txt(2055000): 1;0;                    maz_cc187421;1;      Alameda; 338
# links.txt(2056000): 1;0;                    maz_cc176686;1;      Alameda; 338
# links.txt(2057000): 1;0;                    maz_cc176813;1;      Alameda; 338
# links.txt(2058000): 0;1;                     maz_cc30261;0;      Alameda; 338
# links.txt(2059000): 0;1;                     maz_cc33490;0;      Alameda; 338
# links.txt(2060000): 1;0;                    maz_cc171462;1;      Alameda; 338
# links.txt(2061000): 1;0;                    maz_cc166372;1;      Alameda; 339
# links.txt(2062000): 1;1;                     maz_cc83892;1;      Alameda; 339
# links.txt(2063000): 1;1;                     maz_cc85133;1;      Alameda; 339
# links.txt(2064000): 1;0;                    maz_cc185866;1;      Alameda; 339
# links.txt(2065000): 1;1;                     maz_cc34571;1;      Alameda; 339
# links.txt(2066000): 1;1;                     maz_cc36099;1;      Alameda; 339
# links.txt(2067000): 1;0;                    maz_cc193971;1;      Alameda; 339
# links.txt(2068000): 0;1;                     maz_cc83403;0;      Alameda; 339
# links.txt(2069000): 0;1;                     maz_cc82534;0;      Alameda; 339
# links.txt(2070000): 1;0;                    maz_cc172872;1;      Alameda; 339
# links.txt(2071000): 0;1;                     maz_cc83184;0;      Alameda; 340
# links.txt(2072000): 0;0;                    maz_cc189978;1;      Alameda; 340
# links.txt(2073000): 1;0;                    maz_cc191581;1;      Alameda; 340
# links.txt(2074000): 1;0;                    maz_cc184889;1;      Alameda; 340
# links.txt(2075000): 1;1;                     maz_cc35215;0;      Alameda; 340
# links.txt(2076000): 0;0;                    maz_cc165603;1;      Alameda; 340
# links.txt(2077000): 1;0;                    maz_cc168411;1;      Alameda; 340
# links.txt(2078000): 1;0;                    maz_cc183194;1;      Alameda; 340
# links.txt(2079000): 1;0;                    maz_cc169755;1;      Alameda; 340
# links.txt(2080000): 0;1;                     maz_cc27641;0;      Alameda; 340
# links.txt(2081000): 1;0;                    maz_cc165350;1;      Alameda; 341
# links.txt(2082000): 1;0;                    maz_cc167965;1;      Alameda; 341
# links.txt(2083000): 1;1;                     maz_cc79913;1;      Alameda; 341
# links.txt(2084000): 0;1;                     maz_cc30611;0;      Alameda; 341
# links.txt(2085000): 1;0;                    maz_cc170856;1;      Alameda; 341
# links.txt(2086000): 0;1;                     maz_cc34085;0;      Alameda; 341
# links.txt(2087000): 0;1;                     maz_cc79657;0;      Alameda; 341
# links.txt(2088000): 0;1;                     maz_cc84352;0;      Alameda; 341
# links.txt(2089000): 1;0;                    maz_cc183823;1;      Alameda; 341
# links.txt(2090000): 1;0;                    maz_cc169557;1;      Alameda; 341
# links.txt(2091000): 1;0;                    maz_cc162813;1;      Alameda; 342
# links.txt(2092000): 1;1;                     maz_cc78973;1;      Alameda; 342
# links.txt(2093000): 1;1;                     maz_cc83721;1;      Alameda; 342
# links.txt(2094000): 0;1;                     maz_cc84334;0;      Alameda; 342
# links.txt(2095000): 1;0;                    maz_cc171444;1;      Alameda; 342
# links.txt(2096000): 1;0;                    maz_cc181050;1;      Alameda; 342
# links.txt(2097000): 1;0;                    maz_cc190820;1;      Alameda; 342
# links.txt(2098000): 1;0;                    maz_cc161487;1;      Alameda; 342
# links.txt(2099000): 1;0;                    maz_cc165951;1;      Alameda; 342
# links.txt(2100000): 1;0;                    maz_cc180720;1;      Alameda; 342
# links.txt(2101000): 1;0;                    maz_cc259891;0;      Alameda; 343
# links.txt(2102000): 1;0;                    maz_cc173154;1;      Alameda; 343
# links.txt(2103000): 1;0;                    maz_cc189552;1;      Alameda; 343
# links.txt(2104000): 0;1;                     maz_cc43566;0; Contra Costa; 428
# links.txt(2105000): 1;0;                    maz_cc208317;1; Contra Costa; 428
# links.txt(2106000): 0;0;                    maz_cc197350;1; Contra Costa; 428
# links.txt(2107000): 1;0;                    maz_cc195246;1; Contra Costa; 428
# links.txt(2108000): 0;1;                     maz_cc46262;0; Contra Costa; 428
# links.txt(2109000): 1;0;                    maz_cc213645;1; Contra Costa; 428
# links.txt(2110000): 0;1;                     maz_cc41976;0; Contra Costa; 428
# links.txt(2111000): 1;0;                    maz_cc217804;1; Contra Costa; 428
# links.txt(2112000): 1;0;                    maz_cc202345;1; Contra Costa; 428
# links.txt(2113000): 0;1;                     maz_cc85485;0; Contra Costa; 429
# links.txt(2114000): 0;1;                     maz_cc49729;0; Contra Costa; 429
# links.txt(2115000): 1;0;                    maz_cc215284;1; Contra Costa; 429
# links.txt(2116000): 1;1;                     maz_cc87920;1; Contra Costa; 429
# links.txt(2117000): 0;1;                     maz_cc88197;0; Contra Costa; 429
# links.txt(2118000): 1;1;                     maz_cc44839;1; Contra Costa; 429
# links.txt(2119000): 0;1;                     maz_cc46052;0; Contra Costa; 429
# links.txt(2120000): 1;0;                    maz_cc198188;1; Contra Costa; 429
# links.txt(2121000): 1;0;                    maz_cc208395;1; Contra Costa; 429
# links.txt(2122000): 1;0;                    maz_cc198524;1; Contra Costa; 429
# links.txt(2123000): 1;1;                     maz_cc43150;1; Contra Costa; 430
# links.txt(2124000): 0;0;                    maz_cc195826;1; Contra Costa; 430
# links.txt(2125000): 1;1;                     maz_cc87250;1; Contra Costa; 430
# links.txt(2126000): 1;1;                     maz_cc87735;1; Contra Costa; 430
# links.txt(2127000): 1;0;                    maz_cc200416;1; Contra Costa; 430
# links.txt(2128000): 0;1;                     maz_cc48690;0; Contra Costa; 430
# links.txt(2129000): 1;0;                    maz_cc196630;1; Contra Costa; 430
# links.txt(2130000): 1;0;                    maz_cc216674;1; Contra Costa; 430
# links.txt(2131000): 1;0;                    maz_cc199655;1; Contra Costa; 430
# links.txt(2132000): 0;1;                     maz_cc46752;0; Contra Costa; 430
# links.txt(2133000): 0;1;                     maz_cc50788;0; Contra Costa; 431
# links.txt(2134000): 1;0;                    maz_cc207682;1; Contra Costa; 431
# links.txt(2135000): 1;0;                    maz_cc211725;1; Contra Costa; 431
# links.txt(2136000): 0;1;                     maz_cc87047;0; Contra Costa; 431
# links.txt(2137000): 1;0;                    maz_cc210089;1; Contra Costa; 431
# links.txt(2138000): 1;0;                    maz_cc198964;1; Contra Costa; 431
# links.txt(2139000): 0;0;                    maz_cc195073;1; Contra Costa; 431
# links.txt(2140000): 1;0;                    maz_cc207744;1; Contra Costa; 431
# links.txt(2141000): 1;0;                    maz_cc213432;1; Contra Costa; 431
# links.txt(2142000): 1;0;                    maz_cc194653;1; Contra Costa; 431
# links.txt(2143000): 0;1;                     maz_cc89513;0;       Solano; 513
# links.txt(2144000): 1;1;                     maz_cc89391;1;       Solano; 513
# links.txt(2145000): 0;1;                     maz_cc53237;0;       Solano; 513
# links.txt(2146000): 1;0;                    maz_cc260937;0;       Solano; 514
# links.txt(2147000): 1;0;                    maz_cc220215;1;       Solano; 514
# links.txt(2148000): 1;1;                     maz_cc89924;1;       Solano; 514
# links.txt(2149000): 0;1;                     maz_cc55798;0;       Solano; 514
# links.txt(2150000): 1;0;                    maz_cc220196;1;       Solano; 514
# links.txt(2151000): 1;0;                    maz_cc225035;1;       Solano; 514
# links.txt(2152000): 1;0;                    maz_cc224534;1;       Solano; 514
# links.txt(2153000): 1;1;                     maz_cc56146;1;       Solano; 514
# links.txt(2154000): 1;0;                    maz_cc220133;1;       Solano; 514
# links.txt(2155000): 1;0;                    maz_cc221201;1;       Solano; 514
# links.txt(2156000): 0;1;                     maz_cc90851;0;       Solano; 515
# links.txt(2157000): 1;0;                    maz_cc218462;1;       Solano; 515
# links.txt(2158000): 1;0;                    maz_cc222428;1;       Solano; 515
# links.txt(2159000): 1;0;                    maz_cc260913;0;       Solano; 515
# links.txt(2160000): 1;0;                    maz_cc218611;1;       Solano; 515
# links.txt(2161000): 1;1;                     maz_cc91282;1;         Napa; 604
# links.txt(2162000): 1;0;                    maz_cc232999;1;         Napa; 604
# links.txt(2163000): 1;1;                     maz_cc91582;1;         Napa; 604
# links.txt(2164000): 1;0;                    maz_cc230627;1;         Napa; 604
# links.txt(2165000): 1;1;                     maz_cc56882;1;         Napa; 604
# links.txt(2166000): 1;0;                    maz_cc232316;1;         Napa; 604
# links.txt(2167000): 1;0;                    maz_cc240425;1;       Sonoma; 715
# links.txt(2168000): 0;1;                     maz_cc61080;0;       Sonoma; 715
# links.txt(2169000): 1;0;                    maz_cc240382;1;       Sonoma; 715
# links.txt(2170000): 1;0;                    maz_cc239347;1;       Sonoma; 716
# links.txt(2171000): 1;1;                     maz_cc62644;1;       Sonoma; 716
# links.txt(2172000): 1;0;                    maz_cc242233;1;       Sonoma; 716
# links.txt(2173000): 0;1;                     maz_cc59005;0;       Sonoma; 716
# links.txt(2174000): 0;1;                     maz_cc58649;0;       Sonoma; 716
# links.txt(2175000): 1;1;                     maz_cc61449;1;       Sonoma; 716
# links.txt(2176000): 1;0;                    maz_cc237215;1;       Sonoma; 716
# links.txt(2177000): 0;1;                     maz_cc58153;0;       Sonoma; 716
# links.txt(2178000): 0;1;                     maz_cc62129;0;       Sonoma; 716
# links.txt(2179000): 1;0;                    maz_cc242070;1;       Sonoma; 716
# links.txt(2180000): 1;1;                     maz_cc58682;1;       Sonoma; 717
# links.txt(2181000): 1;1;                     maz_cc58144;1;       Sonoma; 717
# links.txt(2182000): 1;0;                    maz_cc234003;1;       Sonoma; 717
# links.txt(2183000): 1;0;                    maz_cc239868;1;       Sonoma; 717
# links.txt(2184000): 1;0;                    maz_cc237801;1;       Sonoma; 717
# links.txt(2185000): 1;0;                    maz_cc234903;1;       Sonoma; 717
# links.txt(2186000): 1;0;                    maz_cc249476;1;        Marin; 807
# links.txt(2187000): 1;1;                     maz_cc64469;1;        Marin; 807
# links.txt(2188000): 1;0;                    maz_cc245287;1;        Marin; 807
# links.txt(2189000): 0;1;                     maz_cc93630;0;        Marin; 807
# links.txt(2190000): 0;1;                     maz_cc64968;0;        Marin; 807
# links.txt(2191000): 1;0;                    maz_cc247294;1;        Marin; 807
# links.txt(2192000): 1;0;                    maz_cc249977;1;        Marin; 808
# links.txt(2193000): 1;0;                    maz_cc245711;1;        Marin; 808
# links.txt(2194000): 1;0;                    maz_cc250118;1;        Marin; 808
# links.txt(2195000): 0;0;                         tap_446;1; Contra Costa; 432
# links.txt(2196000): 0;0;                        tap_1446;1;       Solano; 515
# links.txt(2197000): 0;0;                        tap_2446;1;  Santa Clara; 265
# links.txt(2198000): 0;0;                        tap_3446;1;San Francisco;  12
# links.txt(2199000): 0;0;                        tap_4446;1;San Francisco;  12
# links.txt(2200000): 0;0;                        tap_5446;1;San Francisco;  13
# links.txt(2201000): 0;0;                        tap_6446;1;San Francisco;  13
# links.txt(2202000): 0;0;                        tap_7446;1;    San Mateo; 120
# links.txt(2203000): 0;0;                        tap_8446;1;       Solano; 515
# links.txt(2204000): 0;0;                        tap_9446;1;       Sonoma; 717
# links.txt(2205000): 0;0;                       tap_10446;1;  Santa Clara; 265
# links.txt(2206000): 0;0;                       tap_11446;1;  Santa Clara; 265
# links.txt(2207000): 0;0;                       tap_12446;1;  Santa Clara; 265
# links.txt(2208000): 0;0;                       tap_13446;1;  Santa Clara; 265
# links.txt(2209000): 0;0;                       tap_14446;1;         Napa; 604
# links.txt(2210000): 0;0;                       tap_15446;1;      Alameda; 343
# links.txt(2211000): 0;0;                       tap_16446;1;      Alameda; 343
# links.txt(2212000): 0;0;                       tap_17446;1;      Alameda; 343
# links.txt(2213000): 0;0;                       tap_18446;1;      Alameda; 343
# links.txt(2214000): 0;0;                       tap_19446;1;      Alameda; 343
# links.txt(2215000): 0;0;                       tap_20446;1;      Alameda; 343
# links.txt(2216000): 0;0;                       tap_21446;1;      Alameda; 343
# links.txt(2217000): 0;0;                         tap_689;1; Contra Costa; 432
# links.txt(2218000): 0;0;                        tap_1689;1;        Marin; 808
# links.txt(2219000): 0;0;                        tap_2689;1;        Marin; 808
# links.txt(2220000): 0;0;                        tap_3689;1;San Francisco;  13
# links.txt(2221000): 0;0;                        tap_4689;1;San Francisco;  13
# links.txt(2222000): 0;0;                        tap_5689;1;San Francisco;  13
# links.txt(2223000): 0;0;                        tap_6689;1;    San Mateo; 120
# links.txt(2224000): 0;0;                        tap_7689;1;    San Mateo; 120
# links.txt(2225000): 0;0;                        tap_8689;1;       Solano; 515
# links.txt(2226000): 0;0;                        tap_9689;1;       Sonoma; 717
# links.txt(2227000): 0;0;                       tap_10689;1;  Santa Clara; 265
# links.txt(2228000): 0;0;                       tap_11689;1;  Santa Clara; 265
# links.txt(2229000): 0;0;                       tap_12689;1;  Santa Clara; 265
# links.txt(2230000): 0;0;                       tap_13689;1; Contra Costa; 432
# links.txt(2231000): 0;0;                       tap_14689;1;         Napa; 604
# links.txt(2232000): 0;0;                       tap_15689;1;      Alameda; 343
# links.txt(2233000): 0;0;                       tap_16689;1;      Alameda; 343
# links.txt(2234000): 0;0;                       tap_17689;1;      Alameda; 344
# links.txt(2235000): 0;0;                       tap_18689;1;      Alameda; 344
# links.txt(2236000): 0;0;                       tap_19689;1; Contra Costa; 432
# links.txt(2237000): 0;0;                       tap_20689;1;       Sonoma; 717
# links.txt(2238000): 0;0;                       tap_21689;1;      Alameda; 344
#
#
# NODEMERGE: 10590
#
# NODEMERGE: 12288
#
# NODEMERGE: 14110
#
# NODEMERGE: 15959
#
# NODEMERGE: 90211
#
# NODEMERGE: 110444
#
# NODEMERGE: 112528
#
# NODEMERGE: 114578
#
# NODEMERGE: 116654
#
# NODEMERGE: 118758
#
# NODEMERGE: 200157
#
# NODEMERGE: 210265
#
# NODEMERGE: 212282
#
# NODEMERGE: 214390
#
# NODEMERGE: 216599
#
# NODEMERGE: 219242
#
# NODEMERGE: 222175
#
# NODEMERGE: 225041
#
# NODEMERGE: 227628
#
# NODEMERGE: 230981
#
# NODEMERGE: 290620
#
# NODEMERGE: 300382
#
# NODEMERGE: 310492
#
# NODEMERGE: 312421
#
# NODEMERGE: 314655
#
# NODEMERGE: 317059
#
# NODEMERGE: 319694
#
# NODEMERGE: 322691
#
# NODEMERGE: 325967
#
# NODEMERGE: 329488
#
# NODEMERGE: 332708
#
# NODEMERGE: 390650
#
# NODEMERGE: 400208
#
# NODEMERGE: 411257
#
# NODEMERGE: 413891
#
# NODEMERGE: 416843
#
# NODEMERGE: 419950
#
# NODEMERGE: 423478
#
# NODEMERGE: 427041
#
# NODEMERGE: 490665
#
# NODEMERGE: 511151
#
# NODEMERGE: 514398
#
# NODEMERGE: 518718
#
# NODEMERGE: 610799
#
# NODEMERGE: 700280
#
# NODEMERGE: 712714
#
# NODEMERGE: 716399
#
# NODEMERGE: 790016
#
# NODEMERGE: 810724
#
# NODEMERGE: 813895
#
# NODEMERGE: 1000517
#
# NODEMERGE: 1001517
#
# NODEMERGE: 1002517
#
# NODEMERGE: 1003517
#
# NODEMERGE: 1004517
#
# NODEMERGE: 1005517
#
# NODEMERGE: 1006517
#
# NODEMERGE: 1007517
#
# NODEMERGE: 1008517
#
# NODEMERGE: 1009517
#
# NODEMERGE: 1010517
#
# NODEMERGE: 1011517
#
# NODEMERGE: 1012517
#
# NODEMERGE: 1013517
#
# NODEMERGE: 1014517
#
# NODEMERGE: 1015517
#
# NODEMERGE: 1016517
#
# NODEMERGE: 1017517
#
# NODEMERGE: 1018517
#
# NODEMERGE: 1019517
#
# NODEMERGE: 1020517
#
# NODEMERGE: 1021517
#
# NODEMERGE: 1022517
#
# NODEMERGE: 1023517
#
# NODEMERGE: 1024517
#
# NODEMERGE: 1025517
#
# NODEMERGE: 1026517
#
# NODEMERGE: 1027517
#
# NODEMERGE: 1500476
#
# NODEMERGE: 1501476
#
# NODEMERGE: 1502476
#
# NODEMERGE: 1503476
#
# NODEMERGE: 1504476
#
# NODEMERGE: 1505476
#
# NODEMERGE: 1506476
#
# NODEMERGE: 1507476
#
# NODEMERGE: 1508476
#
# NODEMERGE: 1509476
#
# NODEMERGE: 1510476
#
# NODEMERGE: 1511476
#
# NODEMERGE: 1512476
#
# NODEMERGE: 1513476
#
# NODEMERGE: 1514476
#
# NODEMERGE: 1515476
#
# NODEMERGE: 1516476
#
# NODEMERGE: 1517476
#
# NODEMERGE: 1518476
#
# NODEMERGE: 1519476
#
# NODEMERGE: 1520476
#
# NODEMERGE: 1521476
#
# NODEMERGE: 1522476
#
# NODEMERGE: 1523476
#
# NODEMERGE: 1524476
#
# NODEMERGE: 1525476
#
# NODEMERGE: 1526476
#
# NODEMERGE: 1527476
#
# NODEMERGE: 1528476
#
# NODEMERGE: 1529476
#
# NODEMERGE: 1530476
#
# NODEMERGE: 1531476
#
# NODEMERGE: 1532476
#
# NODEMERGE: 1533476
#
# NODEMERGE: 1534476
#
# NODEMERGE: 1535476
#
# NODEMERGE: 1536476
#
# NODEMERGE: 1537476
#
# NODEMERGE: 1538476
#
# NODEMERGE: 1539476
#
# NODEMERGE: 1540476
#
# NODEMERGE: 1541476
#
# NODEMERGE: 1542476
#
# NODEMERGE: 1543476
#
# NODEMERGE: 1544476
#
# NODEMERGE: 1545476
#
# NODEMERGE: 1546476
#
# NODEMERGE: 1547476
#
# NODEMERGE: 1548476
#
# NODEMERGE: 1549476
#
# NODEMERGE: 1550476
#
# NODEMERGE: 1551476
#
# NODEMERGE: 1552476
#
# NODEMERGE: 1553476
#
# NODEMERGE: 1554476
#
# NODEMERGE: 1555476
#
# NODEMERGE: 2000084
#
# NODEMERGE: 2001084
#
# NODEMERGE: 2002084
#
# NODEMERGE: 2003084
#
# NODEMERGE: 2004084
#
# NODEMERGE: 2005084
#
# LINKMERGE: 14699-1000302
#
# LINKMERGE: 15045-1024943
#
# LINKMERGE: 15351-1010307
#
# LINKMERGE: 15657-1000751
#
# LINKMERGE: 15972-1016971
#
# LINKMERGE: 16303-1014160
#
# LINKMERGE: 16603-1003756
#
# LINKMERGE: 16886-1004409
#
# LINKMERGE: 17194-1011423
#
# LINKMERGE: 90093-1009509
#
# LINKMERGE: 90295-1008583
#
# LINKMERGE: 90534-1023932
#
# LINKMERGE: 100264-1523423
#
# LINKMERGE: 110126-1505773
#
# LINKMERGE: 110451-1516388
#
# LINKMERGE: 110722-1524443
#
# LINKMERGE: 111060-1529585
#
# LINKMERGE: 111372-1513777
#
# LINKMERGE: 111730-1501459
#
# LINKMERGE: 112055-1511198
#
# LINKMERGE: 112410-1521089
#
# LINKMERGE: 112741-1531273
#
# LINKMERGE: 113082-1535219
#
# LINKMERGE: 113404-1531683
#
# LINKMERGE: 113723-1507238
#
# LINKMERGE: 114055-1523209
#
# LINKMERGE: 114399-1541235
#
# LINKMERGE: 114687-1543213
#
# LINKMERGE: 115020-1542962
#
# LINKMERGE: 115343-1554026
#
# LINKMERGE: 115705-1553133
#
# LINKMERGE: 116045-1515224
#
# LINKMERGE: 116378-1529158
#
# LINKMERGE: 116723-1522914
#
# LINKMERGE: 117059-1523187
#
# LINKMERGE: 117410-1544560
#
# LINKMERGE: 117731-1525596
#
# LINKMERGE: 118048-1533917
#
# LINKMERGE: 118398-1531851
#
# ...
#
# LINKMERGE: 3064865-414805
#
# LINKMERGE: 3065193-411724
#
# LINKMERGE: 3065513-3060953
#
# LINKMERGE: 3065839-3071468
#
# LINKMERGE: 3066168-3033738
#
# LINKMERGE: 3066497-3058133
#
# LINKMERGE: 3066821-3004023
#
# LINKMERGE: 3067150-3033770
#
# LINKMERGE: 3067478-419470
#
# LINKMERGE: 3067811-3059919
#
# LINKMERGE: 3068141-3024135
#
# LINKMERGE: 3068456-3055402
#
# LINKMERGE: 3068775-3006780
#
# LINKMERGE: 3069115-422871
#
# LINKMERGE: 3069443-3093260
#
# LINKMERGE: 3069765-3033159
#
# LINKMERGE: 3070096-3079346
#
# LINKMERGE: 3070438-3007051
#
# LINKMERGE: 3070763-3036494
#
# LINKMERGE: 3071099-3027781
#
# LINKMERGE: 3071427-418450
#
# LINKMERGE: 3071760-3018407
#
# LINKMERGE: 3072096-3058817
#
# LINKMERGE: 3072428-3043703
#
# LINKMERGE: 3072775-3037960
#
# LINKMERGE: 3073099-3082834
#
# LINKMERGE: 3073430-3011935
#
# LINKMERGE: 3073761-3017180
#
# LINKMERGE: 3074105-3022860
#
# LINKMERGE: 3074440-427558
#
# LINKMERGE: 3074779-3057802
#
# LINKMERGE: 3075127-3002143
#
# LINKMERGE: 3075469-3039895
#
# LINKMERGE: 3075805-3000374
#
# LINKMERGE: 3076148-3014021
#
# LINKMERGE: 3076501-3039623
#
# LINKMERGE: 3076840-3038781
#
# LINKMERGE: 3077184-3034863
#
# LINKMERGE: 3077523-3072860
#
# LINKMERGE: 3077880-3007909
#
# LINKMERGE: 3538625-3522951
#
# LINKMERGE: 3538969-3537758
#
# LINKMERGE: 3539327-3531021
#
# LINKMERGE: 3539988-3504455
#
# LINKMERGE: 3540666-3509441
#
# LINKMERGE: 3541356-511850
#
# LINKMERGE: 3542052-511294
#
# LINKMERGE: 3542747-3520433
#
# LINKMERGE: 3543454-3508845
#
# LINKMERGE: 3544169-3516699
#
# LINKMERGE: 3544894-3522463
#
# LINKMERGE: 3545663-3516358
#
# LINKMERGE: 3546385-510106
#
# LINKMERGE: 3547129-3516428
#
# LINKMERGE: 4000220-4007082
#
# LINKMERGE: 4000517-4007711
#
# LINKMERGE: 4000811-4003780
#
# LINKMERGE: 4001104-4001071
#
# LINKMERGE: 4001394-4001972
#
# LINKMERGE: 4001691-4007982
#
# LINKMERGE: 4001986-4007038
#
# LINKMERGE: 4002288-4000326
#
# LINKMERGE: 4002590-4000350
#
# LINKMERGE: 4002879-4008510
#
# LINKMERGE: 4003169-4006766
#
# LINKMERGE: 4003474-4001120
#
# LINKMERGE: 4003765-4003687
#
# LINKMERGE: 4004063-4008795
#
# LINKMERGE: 4004360-4001970
#
# LINKMERGE: 4004667-4007542
#
# LINKMERGE: 4004960-4006846
#
# LINKMERGE: 4005265-4002716
#
# LINKMERGE: 4005561-4001547
#
# LINKMERGE: 4005849-4004844
#
# LINKMERGE: 4006155-4005578
#
# LINKMERGE: 4006449-4008705
#
# LINKMERGE: 4006758-4005270
#
# LINKMERGE: 4007055-4012402
#
# LINKMERGE: 4007353-611172
#
# LINKMERGE: 4007664-4001575
#
# LINKMERGE: 4007969-600028
#
# LINKMERGE: 4008283-4002511
#
# LINKMERGE: 4008592-4013098
#
# LINKMERGE: 4008906-4000849
#
# LINKMERGE: 4009230-4000460
#
# LINKMERGE: 4009542-4003488
#
# LINKMERGE: 4009857-4002584
#
# LINKMERGE: 4010179-4001939
#
# LINKMERGE: 4010518-4003702
#
# LINKMERGE: 4010856-4007320
#
# LINKMERGE: 4011424-4002490
#
# LINKMERGE: 4012089-612300
#
# LINKMERGE: 4012784-4006305
#
# LINKMERGE: 4013489-4001593
#
# LINKMERGE: 4500158-717840
#
# LINKMERGE: 4500452-4530212
#
# LINKMERGE: 4500759-710956
#
# LINKMERGE: 4501068-4511656
#
# LINKMERGE: 4501371-4521242
#
# LINKMERGE: 4501669-4543789
#
# LINKMERGE: 4501978-719597
#
# LINKMERGE: 4502279-4533417
#
# LINKMERGE: 4502585-4534144
#
# LINKMERGE: 4502883-4539823
#
# LINKMERGE: 4503185-4525041
#
# LINKMERGE: 4503488-4537007
#
# LINKMERGE: 4503793-4533408
#
# LINKMERGE: 4504100-4544263
#
# LINKMERGE: 4504402-4508582
#
# LINKMERGE: 4504711-4514363
#
# LINKMERGE: 4505013-4510750
#
# LINKMERGE: 4505310-4515165
#
# LINKMERGE: 4505603-4540118
#
# LINKMERGE: 4505905-4508450
#
# LINKMERGE: 4506206-790547
#
# LINKMERGE: 4506515-4544731
#
# LINKMERGE: 4506817-4521675
#
# LINKMERGE: 4507123-4519317
#
# LINKMERGE: 4507436-4511043
#
# LINKMERGE: 4507748-4534104
#
# LINKMERGE: 4508053-4523819
#
# LINKMERGE: 4508353-4506772
#
# LINKMERGE: 4508657-4537020
#
# LINKMERGE: 4508963-720157
#
# LINKMERGE: 4509270-4530923
#
# LINKMERGE: 4509576-4553174
#
# LINKMERGE: 4509879-4521020
#
# LINKMERGE: 4510181-4534640
#
# LINKMERGE: 4510481-710906
#
# LINKMERGE: 4510782-4514460
#
# LINKMERGE: 4511085-4517432
#
# LINKMERGE: 4511388-4529519
#
# LINKMERGE: 4511697-4539348
#
# LINKMERGE: 4512000-4513216
#
# LINKMERGE: 4512303-4505949
#
# LINKMERGE: 4512612-4532776
#
# LINKMERGE: 4512910-4524574
#
# LINKMERGE: 4513219-4535956
#
# LINKMERGE: 4513532-4508180
#
# LINKMERGE: 4513837-718502
#
# LINKMERGE: 4514137-4537451
#
# LINKMERGE: 4514434-711501
#
# LINKMERGE: 4514741-4516798
#
# LINKMERGE: 4515049-4516499
#
# LINKMERGE: 4515353-4519202
#
# LINKMERGE: 4515648-4552083
#
# LINKMERGE: 4515960-4528030
#
# LINKMERGE: 4516270-4538978
#
# LINKMERGE: 4516578-4524819
#
# LINKMERGE: 4516878-4521965
#
# LINKMERGE: 4517179-4543049
#
# LINKMERGE: 4517484-4543366
#
# LINKMERGE: 4517786-4537049
#
# LINKMERGE: 4518088-4518890
#
# LINKMERGE: 4518392-4532132
#
# LINKMERGE: 4518701-4501810
#
# LINKMERGE: 4519010-4533322
#
# LINKMERGE: 4519315-4522965
#
# LINKMERGE: 4519624-4520984
#
# LINKMERGE: 4519935-4529149
#
# LINKMERGE: 4520238-4529672
#
# LINKMERGE: 4520543-700182
#
# LINKMERGE: 4520846-716087
#
# LINKMERGE: 4521152-4556145
#
# LINKMERGE: 4521460-4525597
#
# LINKMERGE: 4521762-790057
#
# LINKMERGE: 4522057-4529103
#
# LINKMERGE: 4522357-4501495
#
# LINKMERGE: 4522675-4504840
#
# LINKMERGE: 4522978-4515674
#
# LINKMERGE: 4523284-4524540
#
# LINKMERGE: 4523596-4534566
#
# LINKMERGE: 4523911-718618
#
# LINKMERGE: 4524225-4501030
#
# LINKMERGE: 4524539-700307
#
# LINKMERGE: 4524843-4531707
#
# LINKMERGE: 4525149-4533604
#
# LINKMERGE: 4525458-4525736
#
# LINKMERGE: 4525779-4550364
#
# LINKMERGE: 4526090-714360
#
# LINKMERGE: 4526405-4528484
#
# LINKMERGE: 4526714-4521331
#
# LINKMERGE: 4527026-4549511
#
# LINKMERGE: 4527336-4524960
#
# LINKMERGE: 4527648-4519448
#
# LINKMERGE: 4527963-4517379
#
# LINKMERGE: 4528280-4550043
#
# LINKMERGE: 4528591-4502517
#
# LINKMERGE: 4528903-4505479
#
# LINKMERGE: 4529214-4532488
#
# LINKMERGE: 4529528-4505686
#
# LINKMERGE: 4529832-4536732
#
# LINKMERGE: 4530144-4540319
#
# LINKMERGE: 4530446-4507649
#
# LINKMERGE: 4530762-4550638
#
# LINKMERGE: 4531078-4507562
#
# LINKMERGE: 4531388-4539164
#
# LINKMERGE: 4531705-714278
#
# LINKMERGE: 4532015-4516768
#
# LINKMERGE: 4532329-4503305
#
# LINKMERGE: 4532643-4522350
#
# LINKMERGE: 4532966-4540232
#
# LINKMERGE: 4533277-4530696
#
# LINKMERGE: 4533588-4538230
#
# LINKMERGE: 4533910-4552422
#
# LINKMERGE: 4534230-4536016
#
# LINKMERGE: 4534546-4537801
#
# LINKMERGE: 4534871-4532172
#
# LINKMERGE: 4535186-700296
#
# LINKMERGE: 4535508-4533527
#
# LINKMERGE: 4535825-4533970
#
# LINKMERGE: 4536143-4511315
#
# LINKMERGE: 4536455-4535302
#
# LINKMERGE: 4536764-4528679
#
# LINKMERGE: 4537081-4517568
#
# LINKMERGE: 4537401-4552964
#
# LINKMERGE: 4537729-4523062
#
# LINKMERGE: 4538049-4533810
#
# LINKMERGE: 4538376-714675
#
# LINKMERGE: 4538713-4511497
#
# LINKMERGE: 4539044-4511867
#
# LINKMERGE: 4539361-4527441
#
# LINKMERGE: 4539676-4515610
#
# LINKMERGE: 4540010-4509374
#
# LINKMERGE: 4540343-4516960
#
# LINKMERGE: 4540677-716331
#
# LINKMERGE: 4541021-4511278
#
# LINKMERGE: 4541352-716202
#
# LINKMERGE: 4541699-720218
#
# LINKMERGE: 4542042-4527932
#
# LINKMERGE: 4542384-4525011
#
# LINKMERGE: 4542727-4505911
#
# LINKMERGE: 4543083-4555838
#
# LINKMERGE: 4543422-4519787
#
# LINKMERGE: 4544086-4503238
#
# LINKMERGE: 4544801-716322
#
# LINKMERGE: 4545541-720036
#
# LINKMERGE: 4546269-4514034
#
# LINKMERGE: 4546996-710687
#
# LINKMERGE: 4547733-4520169
#
# LINKMERGE: 4548471-712855
#
# LINKMERGE: 4549242-4526038
#
# LINKMERGE: 4549990-4528647
#
# LINKMERGE: 4550727-4523500
#
# LINKMERGE: 4551477-4533450
#
# LINKMERGE: 4552227-4535503
#
# LINKMERGE: 4552971-719807
#
# LINKMERGE: 4553732-710940
#
# LINKMERGE: 4554505-4518196
#
# LINKMERGE: 4555268-4530984
#
# LINKMERGE: 4556056-713891
#
# LINKMERGE: 5000275-5007409
#
# LINKMERGE: 5000586-5021236
#
# LINKMERGE: 5000895-810876
#
# LINKMERGE: 5001202-5016533
#
# LINKMERGE: 5001506-5006314
#
# LINKMERGE: 5001816-800154
#
# LINKMERGE: 5002126-5004158
#
# LINKMERGE: 5002431-813205
#
# LINKMERGE: 5002742-5011587
#
# LINKMERGE: 5003057-5008607
#
# LINKMERGE: 5003370-5002977
#
# LINKMERGE: 5003686-5008469
#
# LINKMERGE: 5003994-5015210
#
# LINKMERGE: 5004304-810869
#
# LINKMERGE: 5004621-5011661
#
# LINKMERGE: 5004922-5020424
#
# LINKMERGE: 5005235-5011888
#
# LINKMERGE: 5005549-5004185
#
# LINKMERGE: 5005859-5003041
#
# LINKMERGE: 5006176-5003294
#
# LINKMERGE: 5006484-5008995
#
# LINKMERGE: 5006797-814351
#
# LINKMERGE: 5007099-5016580
#
# LINKMERGE: 5007403-5025175
#
# LINKMERGE: 5007717-5026004
#
# LINKMERGE: 5008029-5008180
#
# LINKMERGE: 5008340-5016539
#
# LINKMERGE: 5008646-5010670
#
# LINKMERGE: 5008962-5002465
#
# LINKMERGE: 5009280-5017595
#
# LINKMERGE: 5009594-5008746
#
# LINKMERGE: 5009911-5016387
#
# LINKMERGE: 5010213-5019245
#
# LINKMERGE: 5010523-5010252
#
# LINKMERGE: 5010843-5017873
#
# LINKMERGE: 5011161-5009167
#
# LINKMERGE: 5011488-5008905
#
# LINKMERGE: 5011800-5012197
#
# LINKMERGE: 5012114-5003395
#
# LINKMERGE: 5012434-5007672
#
# LINKMERGE: 5012755-5025429
#
# LINKMERGE: 5013073-5009463
#
# LINKMERGE: 5013397-5005116
#
# LINKMERGE: 5013723-5010159
#
# LINKMERGE: 5014048-5020767
#
# LINKMERGE: 5014364-5007368
#
# LINKMERGE: 5014691-5001435
#
# LINKMERGE: 5015012-5011723
#
# LINKMERGE: 5015330-5019587
#
# LINKMERGE: 5015667-5010570
#
# LINKMERGE: 5015999-5010275
#
# LINKMERGE: 5016327-5003263
#
# LINKMERGE: 5016648-5011630
#
# LINKMERGE: 5016966-5024807
#
# LINKMERGE: 5017290-5006224
#
# LINKMERGE: 5017617-5004104
#
# LINKMERGE: 5017946-812617
#
# LINKMERGE: 5018277-5015876
#
# LINKMERGE: 5018614-5004549
#
# LINKMERGE: 5018954-5009716
#
# LINKMERGE: 5019288-5020666
#
# LINKMERGE: 5019633-5000976
#
# LINKMERGE: 5019976-5006048
#
# LINKMERGE: 5020314-5010179
#
# LINKMERGE: 5020675-5014536
#
# LINKMERGE: 5021022-5000658
#
# LINKMERGE: 5021501-5001485
#
# LINKMERGE: 5022178-5005318
#
# LINKMERGE: 5022873-5005492
#
# LINKMERGE: 5023569-810859
#
# LINKMERGE: 5024298-5015144
#
# LINKMERGE: 5025029-5013124
#
# LINKMERGE: 5025760-813558
#
# LINKMERGE: 5026518-5019527
#
# LINKMERGE: 6595990-6512163
#
# LINKMERGE: 7089160-2589160
#
#
#
# NETWORK  ReturnCode = 0  Elapsed Time = 00:01:49
# VOYAGER  ReturnCode = 0  Elapsed Time = 00:01:52

# %% [markdown]
# ## As transit line file (for CUBE)

# %%
standard_transit_net = StandardTransit.fromTransitNetwork(v_02_scenario.transit_net, parameters = parameters)
mtc.write_as_cube_lin(standard_transit_net, parameters, outpath = os.path.join(output_dir, "transit.lin"))
# Out:
# 2021-01-20 14:28:56, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 14:28:56, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 14:28:56, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 14:28:56, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2021-01-20 14:28:56, INFO: Converting GTFS Standard Properties to MTC's Cube Standard
# 2021-01-20 14:28:56, INFO: Converting GTFS Standard Properties to MTC's Cube Standard

# %% [markdown]
# ## As pickle

# %%
working_scenario_filename = os.path.join(output_dir, 'working_scenario_02.pickle')
pickle.dump(v_02_scenario, open(working_scenario_filename, 'wb'))

# %% [markdown]
# ## As standard network

# %%
model_net.write(path = output_dir, filename = "v02")
