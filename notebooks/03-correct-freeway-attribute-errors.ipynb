# %% [markdown]
# # 03 Correct Freeway Attribute Errors with Project Cards

# %%
import os
import sys
import yaml
import pickle
import glob

import pandas as pd

from network_wrangler import RoadwayNetwork
from network_wrangler import TransitNetwork
from network_wrangler import ProjectCard
from network_wrangler import Scenario
from network_wrangler import WranglerLogger

from lasso import ModelRoadwayNetwork
from lasso import StandardTransit
from lasso import Parameters
from lasso import mtc

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
logger = logging.getLogger("WranglerLogger")
logger.handlers[0].stream = sys.stdout
logger.setLevel(logging.INFO)

# %% [markdown]
# ## Remote I/O and Parameters

# %%
# root_dir = os.path.join('/Users', 'wsp', 'Documents', 'GitHub', 'travel-model-two-networks')
root_dir = "C:/Users/USGS667806/Documents/GitHub/travel-model-two-networks"
input_dir = os.path.join(root_dir, 'data', 'processed', 'version_03')
output_dir = os.path.join(root_dir, 'data', 'processed', 'version_04')
card_dir = os.path.join(root_dir, 'project_cards')
# lasso_dir = os.path.join('/Users', 'wsp', 'Documents', 'GitHub', 'mtc-Lasso')
lasso_dir = "C:/Users/USGS667806/Lasso"

# %%
parameters = Parameters(lasso_base_dir = lasso_dir)
# Out:
# 2020-12-22 19:36:45, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-22 19:36:45, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-22 19:36:45, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-22 19:36:45, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso

# %% [markdown]
# ## Read Version 00 Scenario

# %%
version_01_pickle_file_name = os.path.join(input_dir, 'working_scenario_01.pickle')
v_01_scenario = pickle.load(open(version_01_pickle_file_name, 'rb'))

# %%
v_01_scenario.road_net.links_df.shape
# Out:
# (1634769, 42)

# %%
v_01_scenario.transit_net.feed.routes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 701 entries, 0 to 700
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   route_id_original       701 non-null    object
#  1   agency_id               526 non-null    object
#  2   route_short_name        665 non-null    object
#  3   route_long_name         679 non-null    object
#  4   route_desc              14 non-null     object
#  5   route_type              701 non-null    int64
#  6   route_url               217 non-null    object
#  7   route_color             260 non-null    object
#  8   route_text_color        243 non-null    object
#  9   agency_raw_name         701 non-null    object
#  10  route_sort_order        95 non-null     object
#  11  min_headway_minutes     32 non-null     object
#  12  eligibility_restricted  4 non-null      object
#  13  continuous_pickup       4 non-null      object
#  14  continuous_drop_off     4 non-null      object
#  15  route_id                701 non-null    object
# dtypes: int64(1), object(15)
# memory usage: 87.8+ KB

# %% [markdown]
# ## Create Scenario and Apply Project Cards

# %%
v_02_scenario = Scenario.create_scenario(
    base_scenario=v_01_scenario,
    card_directory = card_dir,
    tags = ['highway review'],
    validate_project_cards=False)
# Out:
# 2020-12-22 19:38:22, INFO: Creating Scenario
# 2020-12-22 19:38:22, INFO: Creating Scenario

# %%
v_02_scenario.apply_all_projects()
# Out:
# 2020-12-22 19:38:25, INFO: Applying Year 2015 Modify Facility Type to Service
# 2020-12-22 19:38:25, INFO: Applying Year 2015 Modify Facility Type to Service
# 2020-12-22 19:38:25, INFO: Applying Year 2015 Modify Facility Type to Service
# 2020-12-22 19:38:25, INFO: Applying Year 2015 Modify Facility Type to Service
# 2020-12-22 19:38:25, INFO: Applying Project to Roadway Network: Year 2015 Modify Facility Type to Service
# 2020-12-22 19:38:25, INFO: Applying Project to Roadway Network: Year 2015 Modify Facility Type to Service
# 2020-12-22 19:38:25, INFO: Applying Year 2015 Modify Facility Type to Ramp shape incorrect
# 2020-12-22 19:38:25, INFO: Applying Year 2015 Modify Facility Type to Ramp shape incorrect
# 2020-12-22 19:38:25, INFO: Applying Year 2015 Modify Facility Type to Ramp shape incorrect
# 2020-12-22 19:38:25, INFO: Applying Year 2015 Modify Facility Type to Ramp shape incorrect
# 2020-12-22 19:38:25, INFO: Applying Project to Roadway Network: Year 2015 Modify Facility Type to Ramp shape incorrect
# 2020-12-22 19:38:25, INFO: Applying Project to Roadway Network: Year 2015 Modify Facility Type to Ramp shape incorrect
# C:\Users\USGS667806\Anaconda3\envs\lasso_environment\lib\site-packages\geopandas\geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\USGS667806\Anaconda3\envs\lasso_environment\lib\site-packages\geopandas\geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# 2020-12-22 19:38:26, INFO: Applying Year 2015 Modify Facility Type to Ramp
# 2020-12-22 19:38:26, INFO: Applying Year 2015 Modify Facility Type to Ramp
# 2020-12-22 19:38:26, INFO: Applying Year 2015 Modify Facility Type to Ramp
# 2020-12-22 19:38:26, INFO: Applying Year 2015 Modify Facility Type to Ramp
# 2020-12-22 19:38:26, INFO: Applying Project to Roadway Network: Year 2015 Modify Facility Type to Ramp
# 2020-12-22 19:38:26, INFO: Applying Project to Roadway Network: Year 2015 Modify Facility Type to Ramp
# 2020-12-22 19:38:26, INFO: Applying Year 2015 Modify Lanes to 2 Lane and Facility Type to Ramp shape incorrect
# 2020-12-22 19:38:26, INFO: Applying Year 2015 Modify Lanes to 2 Lane and Facility Type to Ramp shape incorrect
# 2020-12-22 19:38:26, INFO: Applying Year 2015 Modify Lanes to 2 Lane and Facility Type to Ramp shape incorrect
# 2020-12-22 19:38:26, INFO: Applying Year 2015 Modify Lanes to 2 Lane and Facility Type to Ramp shape incorrect
# 2020-12-22 19:38:26, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 2 Lane and Facility Type to Ramp shape incorrect
# 2020-12-22 19:38:26, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 2 Lane and Facility Type to Ramp shape incorrect
# C:\Users\USGS667806\Anaconda3\envs\lasso_environment\lib\site-packages\geopandas\geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\USGS667806\Anaconda3\envs\lasso_environment\lib\site-packages\geopandas\geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# 2020-12-22 19:38:26, INFO: Applying Year 2015 Modify Lanes to 2 Lane and Facility Type to Ramp
# 2020-12-22 19:38:26, INFO: Applying Year 2015 Modify Lanes to 2 Lane and Facility Type to Ramp
# 2020-12-22 19:38:26, INFO: Applying Year 2015 Modify Lanes to 2 Lane and Facility Type to Ramp
# 2020-12-22 19:38:26, INFO: Applying Year 2015 Modify Lanes to 2 Lane and Facility Type to Ramp
# 2020-12-22 19:38:26, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 2 Lane and Facility Type to Ramp
# 2020-12-22 19:38:26, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 2 Lane and Facility Type to Ramp
# 2020-12-22 19:38:26, INFO: Applying Year 2015 Modify Lanes to 1 Lane and Facility Type to Ramp
# 2020-12-22 19:38:26, INFO: Applying Year 2015 Modify Lanes to 1 Lane and Facility Type to Ramp
# 2020-12-22 19:38:26, INFO: Applying Year 2015 Modify Lanes to 1 Lane and Facility Type to Ramp
# 2020-12-22 19:38:26, INFO: Applying Year 2015 Modify Lanes to 1 Lane and Facility Type to Ramp
# 2020-12-22 19:38:26, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 1 Lane and Facility Type to Ramp
# 2020-12-22 19:38:26, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 1 Lane and Facility Type to Ramp
# C:\Users\USGS667806\Anaconda3\envs\lasso_environment\lib\site-packages\geopandas\geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Bus Only Segments
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Bus Only Segments
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Bus Only Segments
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Bus Only Segments
# 2020-12-22 19:38:27, INFO: Applying Project to Roadway Network: Year 2015 Bus Only Segments
# 2020-12-22 19:38:27, INFO: Applying Project to Roadway Network: Year 2015 Bus Only Segments
# C:\Users\USGS667806\Anaconda3\envs\lasso_environment\lib\site-packages\geopandas\geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Modify Lanes to 7 Lanes
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Modify Lanes to 7 Lanes
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Modify Lanes to 7 Lanes
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Modify Lanes to 7 Lanes
# 2020-12-22 19:38:27, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 7 Lanes
# 2020-12-22 19:38:27, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 7 Lanes
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Modify Lanes to 6 Lanes
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Modify Lanes to 6 Lanes
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Modify Lanes to 6 Lanes
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Modify Lanes to 6 Lanes
# 2020-12-22 19:38:27, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 6 Lanes
# 2020-12-22 19:38:27, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 6 Lanes
# C:\Users\USGS667806\Anaconda3\envs\lasso_environment\lib\site-packages\geopandas\geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\USGS667806\Anaconda3\envs\lasso_environment\lib\site-packages\geopandas\geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Modify Lanes to 5 Lanes
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Modify Lanes to 5 Lanes
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Modify Lanes to 5 Lanes
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Modify Lanes to 5 Lanes
# 2020-12-22 19:38:27, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 5 Lanes
# 2020-12-22 19:38:27, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 5 Lanes
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Modify Lanes to 4 Lanes
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Modify Lanes to 4 Lanes
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Modify Lanes to 4 Lanes
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Modify Lanes to 4 Lanes
# 2020-12-22 19:38:27, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 4 Lanes
# 2020-12-22 19:38:27, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 4 Lanes
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Modify Lanes to 3 Lanes
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Modify Lanes to 3 Lanes
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Modify Lanes to 3 Lanes
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Modify Lanes to 3 Lanes
# 2020-12-22 19:38:27, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 3 Lanes
# 2020-12-22 19:38:27, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 3 Lanes
# C:\Users\USGS667806\Anaconda3\envs\lasso_environment\lib\site-packages\geopandas\geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\USGS667806\Anaconda3\envs\lasso_environment\lib\site-packages\geopandas\geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\USGS667806\Anaconda3\envs\lasso_environment\lib\site-packages\geopandas\geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Modify Lanes to 2 Lanes
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Modify Lanes to 2 Lanes
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Modify Lanes to 2 Lanes
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Modify Lanes to 2 Lanes
# 2020-12-22 19:38:27, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 2 Lanes
# 2020-12-22 19:38:27, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 2 Lanes
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Modify Lanes to 1 Lane
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Modify Lanes to 1 Lane
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Modify Lanes to 1 Lane
# 2020-12-22 19:38:27, INFO: Applying Year 2015 Modify Lanes to 1 Lane
# 2020-12-22 19:38:27, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 1 Lane
# 2020-12-22 19:38:27, INFO: Applying Project to Roadway Network: Year 2015 Modify Lanes to 1 Lane
# C:\Users\USGS667806\Anaconda3\envs\lasso_environment\lib\site-packages\geopandas\geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\USGS667806\Anaconda3\envs\lasso_environment\lib\site-packages\geopandas\geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
v_02_scenario.applied_projects
# Out:
# ['Year 2015 Modify HOV Lanes and USE on San Mateo Bridge Toll Plaza Toll Plaza on CA-92 WB - Bridge Pass',
#  'Year 2015 Modify HOV Lanes and USE on Richmond-San Rafael Bridge Toll Plaza - Bridge Pass',
#  'Year 2015 Modify HOV Lanes and USE on US-101 SB from South of Healdsburg to North of Petaluma',
#  'Year 2015 Modify USE and HOV Lanes on US-101 SB (Segment 02) from South of Healdsburg to North of Petaluma',
#  'Year 2015 Modify HOV Lanes and USE on US 101 SB CA-85 to Oregon Expressway',
#  'Year 2015 Modify HOV Lanes and USE on US 101 SB CA-85 to Cochrane Road',
#  'Year 2015 Modify HOV Lanes and USE on US-101 NB (Segment 02) from North of Petaluma to South of Healdsburg',
#  'Year 2015 Modify HOV Lanes and USE on US 101 NB Oregon Expressway to Whipple Road',
#  'Year 2015 Modify HOV Lanes and USE on US-101 NB from North of Petaluma to South of Healdsburg',
#  'Year 2015 Modify HOV Lanes and USE on US 101 NB Cochran Road to CA-85',
#  'Year 2015 Modify HOV Lanes and USE on San Tomas Expressway SB I-880 to Hwy 17',
#  'Year 2015 Modify HOV Lanes and USE on San Tomas Expressway NB Hwy 17 to I-880',
#  'Year 2015 Modify HOV Lanes and USE on Lawrence Expressway SB US 101 to I-280',
#  'Year 2015 Modify HOV Lanes and USE on Lawrence Expressway NB I-280 to US 101',
#  'Year 2015 Modify HOV Lanes and USE on Ramp Connecting I880 and Bay Bridge Plaza',
#  'Year 2015 Modify HOV Lanes and USE on I-880 SB from Hegenberger Road to Dixon Road',
#  'Year 2015 Modify Express Lanes and USE on I-880 SB Dixon Road to CA-237',
#  'Year 2015 Modify HOV Lanes and USE on I-880 SB CA-237 to US 101',
#  'Year 2015 Modify HOV lanes and USE on I-880 NB US 101 to CA-237',
#  'Year 2015 Modify HOV Lanes and USE on I-880 NB from Dixon Road to I-238',
#  'Year 2015 Modify Express Lanes and USE on I-880 NB CA-237 to Dixon Road',
#  'Year 2015 Modify USE on I-80 WB to Bay Bridge Toll Plaza',
#  'Year 2015 Modify HOV Lanes and USE on I-80 WB from Fairfield to I-680',
#  'Year 2015 Modify HOV Lanes and USE on I-80 WB from Carquinez Bridge to Bay Bridge Toll Plaza',
#  'Year 2015 Modify HOV Lanes and USE on I-80 EB from I-680 to Fairfield',
#  'Year 2015 Modify HOV Lanes and USE on I-80 EB from Bay Bridge to Carquinez Bridge Toll Plaza',
#  'Year 2015 Modify HOV Lanes and USE on I-680 SB from Rudgear Road to Acosta Blvd',
#  'Year 2015 Modify HOV Lanes and USE on I-680 SB from Benicia Bridge to CA-242',
#  'Year 2015 Modify Express Lanes and USE on I-680 SB Alameda/Santa Clara County Line to SR-84',
#  'Year 2015 Modify HOV Lanes USE on I-680 NB CA-242 to Benicia Bridge',
#  'Year 2015 Modify HOV Lanes and USE on I-680 NB from Acosta Blvd to Rudgear Road',
#  'Year 2015 Modify USE on I-580 WB Greenville Road to I-680',
#  'Year 2015 Modify Express Lanes and USE on I-580 EB (segment 02) Hacienda Drive to Greenville Road',
#  'Year 2015 Modify Express Lanes and USE on I-580 EB Hacienda Drive to Greenville Road',
#  'Year 2015 Modify HOV lanes and USE on Hwy 4 WB from Deer Valley Road to Port Chicago Highway',
#  'Year 2015 Modify HOV Lanes and USE on Hwy 4 EB from Port Chicago Highway to Deer Valley Road',
#  'Year 2015 Modify HOV Lanes and USE on E Capitol Expressway SB I-680 to US 101',
#  'Year 2015 Modify HOV Lanes and USE on E Capitol Expressway NB US101 to I-680',
#  'Year 2015 Modify HOV Lanes and USE on CA-92 WB Eden Landing Rd to San Mateo-Hayward Bridge Toll Plaza',
#  'Year 2015 Modify HOV Lanes and USE on CA-87 SB US 101 to CA-85',
#  'Year 2015 Modify HOV Lanes and USE on CA 87 NB CA-85 to US 101',
#  'Year 2015 Modify HOV Lanes and USE on CA-85 SB US101 to US101',
#  'Year 2015 Modify HOV Lanes and USE on CA-85 NB US101 to US101',
#  'Year 2015 Modify HOV Lanes and USE on CA-84 WB I-880 to Dumbarton Bridge Toll Plaza',
#  'Year 2015 Modify HOV Lanes and USE on CA-280 SB Magdalena Ave to Southwest Expressway',
#  'Year 2015 Modify HOV Lanes and USE on CA-280 NB Bascom Ave to Magdalena Ave',
#  'Year 2015 Modify HOV Lanes and USE on CA-237 WB North 1st Street to US 101',
#  'Year 2015 Modify Express Lanes and USE on CA-237 WB I-880 to CA-262 Mission Blvd',
#  'Year 2015 Modify HOV Lanes and USE on CA-237 EB US 101 to North 1st Street',
#  'Year 2015 Modify Express Lanes and USE on CA-237 EB SR-262 Mission Blvd to I-880',
#  'Year 2015 Modify HOV Lanes and USE on Benicia Bridge Toll Plaza - Bridge Pass',
#  'Year 2015 Modify HOV Lanes-Fastrak Lanes and USE on San Francisco-Oakland Bay Bridge WB Toll Plaza - Bridge Pass',
#  'Year 2015 Modify HOV Lanes and USE on Golden Gate Bridge Toll Plaza on US101 SB - Bridge Pass',
#  'Year 2015 Modify HOV Lanes and USE on Dumbarton Bridge Toll Plaza Toll Plaza on CA-84 WB - Bridge Pass',
#  'Year 2015 Modify HOV Lanes and USE on Carquinez Bridge Toll Plaza on I-80 NB - Bridge Pass',
#  'Year 2015 Bus Only Segments for Transbay Terminal Ramps',
#  'Year 2015 Bus Only Segments for Golden Gate Transit on US 101',
#  'Year 2015 Exclude Trucks on SR 85',
#  'Year 2015 Exclude Trucks on I580',
#  'Year 2015 Modify HOV Lanes-Fastrak Lanes and USE on Antioch Bridge NB on Route 160 - Bridge Pass',
#  'Year 2015 Modify Facility Type to Service',
#  'Year 2015 Modify Facility Type to Ramp shape incorrect',
#  'Year 2015 Modify Facility Type to Ramp',
#  'Year 2015 Modify Lanes to 2 Lane and Facility Type to Ramp shape incorrect',
#  'Year 2015 Modify Lanes to 2 Lane and Facility Type to Ramp',
#  'Year 2015 Modify Lanes to 1 Lane and Facility Type to Ramp',
#  'Year 2015 Bus Only Segments',
#  'Year 2015 Modify Lanes to 7 Lanes',
#  'Year 2015 Modify Lanes to 6 Lanes',
#  'Year 2015 Modify Lanes to 5 Lanes',
#  'Year 2015 Modify Lanes to 4 Lanes',
#  'Year 2015 Modify Lanes to 3 Lanes',
#  'Year 2015 Modify Lanes to 2 Lanes',
#  'Year 2015 Modify Lanes to 1 Lane']

# %%
v_02_scenario.road_net.links_df.columns
# Out:
# Index(['access', 'bike_access', 'drive_access', 'fromIntersectionId', 'lanes',
#        'maxspeed', 'name', 'oneWay', 'ref', 'roadway', 'shstGeometryId',
#        'shstReferenceId', 'toIntersectionId', 'u', 'v', 'walk_access', 'wayId',
#        'county', 'model_link_id', 'A', 'B', 'rail_traveltime', 'rail_only',
#        'locationReferences', 'shape_id', 'geometry', 'ft_cal', 'ft',
#        'useclass', 'assignable', 'transit', 'managed', 'ML_lanes',
#        'segment_id', 'tollbooth', 'ML_useclass', 'ML_access', 'ML_egress',
#        'tollseg', 'tollboth', 'bus_only', 'transit_access'],
#       dtype='object')

# %%
v_02_scenario.road_net.links_df[v_02_scenario.road_net.links_df.model_link_id == 3150085] # should be ramp lanes 2
# Out:
#        access bike_access drive_access                fromIntersectionId  \
# 765904              False         True  d1b76ff92ba7a2915de8efc97c782d73
#
#        lanes maxspeed name oneWay ref        roadway  ... ML_lanes segment_id  \
# 765904     2                 True      motorway_link  ...      NaN        NaN
#
#        tollbooth  ML_useclass  ML_access ML_egress tollseg tollboth  bus_only  \
# 765904       NaN          NaN        NaN       NaN     NaN      NaN       NaN
#
#         transit_access
# 765904             NaN
#
# [1 rows x 42 columns]

# %%
v_02_scenario.road_net.links_df[v_02_scenario.road_net.links_df.model_link_id == 1008942] # should be 5 lanes
# Out:
#        access bike_access drive_access                fromIntersectionId  \
# 102730    nan       False         True  c4d8a43982e5d1d33a2ec65a7b7440bd
#
#        lanes maxspeed              name oneWay     ref   roadway  ...  \
# 102730     5   65 mph  Bayshore Freeway   True  US 101  motorway  ...
#
#        ML_lanes segment_id tollbooth  ML_useclass  ML_access ML_egress  \
# 102730      NaN        NaN       NaN          NaN        NaN       NaN
#
#        tollseg tollboth  bus_only  transit_access
# 102730     NaN      NaN       NaN             NaN
#
# [1 rows x 42 columns]

# %%
v_02_scenario.road_net.links_df[v_02_scenario.road_net.links_df.model_link_id == 8007989] # should be bus only
# Out:
#        access bike_access drive_access                fromIntersectionId  \
# 205698                  1            0  1c480bb0cd31770def93f57e6db6c700
#
#        lanes maxspeed name oneWay ref   roadway  ... ML_lanes segment_id  \
# 205698     1                 True      motorway  ...      NaN        NaN
#
#        tollbooth  ML_useclass  ML_access ML_egress tollseg tollboth  bus_only  \
# 205698       NaN          NaN        NaN       NaN     NaN      NaN       1.0
#
#         transit_access
# 205698             1.0
#
# [1 rows x 42 columns]

# %%
v_02_scenario.road_net.links_df[v_01_scenario.road_net.links_df.model_link_id == 5001470] # should be service
# Out:
#       access bike_access drive_access                fromIntersectionId lanes  \
# 20336              False         True  2fbe0a60406b7e828130c61cadf7d486     1
#
#       maxspeed name oneWay ref  roadway  ... ML_lanes segment_id tollbooth  \
# 20336                 True      service  ...      NaN        NaN       NaN
#
#        ML_useclass  ML_access ML_egress tollseg tollboth  bus_only  \
# 20336          NaN        NaN       NaN     NaN      NaN       NaN
#
#        transit_access
# 20336             NaN
#
# [1 rows x 42 columns]

# %% [markdown]
# ## Make Travel Model Networks

# %%
model_net = ModelRoadwayNetwork.from_RoadwayNetwork(
    roadway_network_object = v_02_scenario.road_net, 
    parameters = parameters)
# Out:
# 2020-12-22 19:45:01, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-22 19:45:01, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-22 19:45:01, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-22 19:45:01, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso

# %%
print(model_net.links_df.shape)
print(model_net.nodes_df.shape)
print(model_net.shapes_df.shape)
# Out:
# (1634769, 42)
# (644475, 11)
# (869970, 7)

# %%
model_net = mtc.add_centroid_and_centroid_connector(
    roadway_network = model_net,
    parameters = parameters)
# Out:
# 2020-12-22 19:45:27, INFO: Adding centroid and centroid connector to standard network
# 2020-12-22 19:45:27, INFO: Adding centroid and centroid connector to standard network
# 2020-12-22 19:45:27, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-22 19:45:27, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-22 19:45:27, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-22 19:45:27, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-22 19:45:37, INFO: Finished adding centroid and centroid connectors
# 2020-12-22 19:45:37, INFO: Finished adding centroid and centroid connectors

# %%
print(model_net.links_df.shape)
print(model_net.nodes_df.shape)
print(model_net.shapes_df.shape)
# Out:
# (2190409, 42)
# (688957, 11)
# (1147790, 7)

# %%
model_net.links_df.model_link_id.nunique()
# Out:
# 2190409

# %%
model_net = mtc.add_tap_and_tap_connector(
    roadway_network = model_net,
    parameters = parameters)
# Out:
# 2020-12-22 19:47:31, INFO: Adding tap and tap connector to standard network
# 2020-12-22 19:47:31, INFO: Adding tap and tap connector to standard network
# 2020-12-22 19:47:31, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-22 19:47:31, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-22 19:47:31, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-22 19:47:31, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-22 19:47:37, INFO: Finished adding tap and tap connectors
# 2020-12-22 19:47:37, INFO: Finished adding tap and tap connectors

# %%
print(model_net.links_df.shape)
print(model_net.nodes_df.shape)
print(model_net.shapes_df.shape)
# Out:
# (2233923, 42)
# (694957, 11)
# (1169547, 7)

# %%
model_net.links_df.model_link_id.nunique()
# Out:
# 2233923

# %%
model_net.nodes_df.model_node_id.nunique()
# Out:
# 694957

# %%
model_net.shapes_df.id.nunique()
# Out:
# 1169547

# %%
model_net = mtc.roadway_standard_to_mtc_network(model_net, parameters)
# Out:
# 2020-12-22 19:49:50, INFO: Renaming roadway attributes to be consistent with what mtc's model is expecting
# 2020-12-22 19:49:50, INFO: Renaming roadway attributes to be consistent with what mtc's model is expecting
# 2020-12-22 19:49:50, INFO: Creating managed lane network.
# 2020-12-22 19:49:50, INFO: Creating managed lane network.
# 2020-12-22 19:49:50, INFO: Creating network with duplicated managed lanes
# 2020-12-22 19:49:50, INFO: Creating network with duplicated managed lanes
# C:\Users\USGS667806\Anaconda3\envs\lasso_environment\lib\site-packages\geopandas\geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\USGS667806\Anaconda3\envs\lasso_environment\lib\site-packages\geopandas\geodataframe.py:852: UserWarning: Geometry column does not contain geometry.
#   warnings.warn("Geometry column does not contain geometry.")
# C:\Users\USGS667806\Anaconda3\envs\lasso_environment\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# 2020-12-22 20:03:05, INFO: Determining cntype
# 2020-12-22 20:03:05, INFO: Determining cntype
# 2020-12-22 20:03:05, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-22 20:03:05, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-22 20:03:05, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-22 20:03:05, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-22 20:03:05, INFO: Calculating and adding roadway network variable: cntype
# 2020-12-22 20:03:05, INFO: Calculating and adding roadway network variable: cntype
# 2020-12-22 20:04:09, INFO: Finished determining variable: cntype
# 2020-12-22 20:04:09, INFO: Finished determining variable: cntype
# 2020-12-22 20:04:09, INFO: Determining transit
# 2020-12-22 20:04:09, INFO: Determining transit
# 2020-12-22 20:04:09, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-22 20:04:09, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-22 20:04:09, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-22 20:04:09, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-22 20:04:10, INFO: Variable 'transit' updated for some links. Returning without overwriting for those links. Calculating for other links
# 2020-12-22 20:04:10, INFO: Variable 'transit' updated for some links. Returning without overwriting for those links. Calculating for other links
# 2020-12-22 20:04:10, INFO: Calculating and adding roadway network variable: transit
# 2020-12-22 20:04:10, INFO: Calculating and adding roadway network variable: transit
# 2020-12-22 20:04:11, INFO: Finished determining transit-only variable: transit
# 2020-12-22 20:04:11, INFO: Finished determining transit-only variable: transit
# 2020-12-22 20:04:11, INFO: Determining useclass
# 2020-12-22 20:04:11, INFO: Determining useclass
# 2020-12-22 20:04:11, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-22 20:04:11, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-22 20:04:11, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-22 20:04:11, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-22 20:04:11, INFO: Variable 'useclass' updated for some links. Returning without overwriting for those links. Calculating for other links
# 2020-12-22 20:04:11, INFO: Variable 'useclass' updated for some links. Returning without overwriting for those links. Calculating for other links
# 2020-12-22 20:04:11, INFO: Calculating and adding roadway network variable: useclass
# 2020-12-22 20:04:11, INFO: Calculating and adding roadway network variable: useclass
# 2020-12-22 20:04:11, INFO: Finished determining variable: useclass
# 2020-12-22 20:04:11, INFO: Finished determining variable: useclass
# 2020-12-22 20:04:11, INFO: Overwriting existing distance Variable 'distance' already in network
# 2020-12-22 20:04:11, INFO: Overwriting existing distance Variable 'distance' already in network
# 2020-12-22 20:05:15, INFO: Calculating distance for all links
# 2020-12-22 20:05:15, INFO: Calculating distance for all links
# 2020-12-22 20:05:20, INFO: Calculating distance for all links
# 2020-12-22 20:05:20, INFO: Calculating distance for all links
# 2020-12-22 20:05:28, INFO: Filling nan for network from network wrangler
# 2020-12-22 20:05:28, INFO: Filling nan for network from network wrangler
# 2020-12-22 20:05:58, INFO: Splitting variables by time period and category
# 2020-12-22 20:05:58, INFO: Splitting variables by time period and category
# 2020-12-22 20:06:06, WARNING: Specified variable to split: ML_lanes not in network variables: Index(['index', 'access', 'bike_access', 'drive_access', 'fromIntersectionId',
#        'lanes', 'maxspeed', 'name', 'oneWay', 'ref', 'roadway',
#        'shstGeometryId', 'shstReferenceId', 'toIntersectionId', 'u', 'v',
#        'walk_access', 'wayId', 'county', 'model_link_id', 'A', 'B',
#        'rail_traveltime', 'rail_only', 'locationReferences', 'shape_id',
#        'geometry', 'ft_cal', 'ft', 'useclass', 'assignable', 'transit',
#        'managed', 'segment_id', 'tollbooth', 'tollseg', 'tollboth', 'bus_only',
#        'transit_access', 'egress', 'id', 'distance', 'cntype', 'lanes_EA',
#        'lanes_AM', 'lanes_MD', 'lanes_PM', 'lanes_EV'],
#       dtype='object'). Returning 0.
# 2020-12-22 20:06:06, WARNING: Specified variable to split: ML_lanes not in network variables: Index(['index', 'access', 'bike_access', 'drive_access', 'fromIntersectionId',
#        'lanes', 'maxspeed', 'name', 'oneWay', 'ref', 'roadway',
#        'shstGeometryId', 'shstReferenceId', 'toIntersectionId', 'u', 'v',
#        'walk_access', 'wayId', 'county', 'model_link_id', 'A', 'B',
#        'rail_traveltime', 'rail_only', 'locationReferences', 'shape_id',
#        'geometry', 'ft_cal', 'ft', 'useclass', 'assignable', 'transit',
#        'managed', 'segment_id', 'tollbooth', 'tollseg', 'tollboth', 'bus_only',
#        'transit_access', 'egress', 'id', 'distance', 'cntype', 'lanes_EA',
#        'lanes_AM', 'lanes_MD', 'lanes_PM', 'lanes_EV'],
#       dtype='object'). Returning 0.
# 2020-12-22 20:06:14, INFO: Converting variable type to mtc standard
# 2020-12-22 20:06:14, INFO: Converting variable type to mtc standard
# 2020-12-22 20:06:20, INFO: Setting Coordinate Reference System to ESRI:102646
# 2020-12-22 20:06:20, INFO: Setting Coordinate Reference System to ESRI:102646

# %%
model_net.links_df.shape
# Out:
# (2238330, 58)

# %%
model_net.links_df.model_link_id.nunique()
# Out:
# 2238330

# %%
model_net.nodes_mtc_df.shape
# Out:
# (696465, 13)

# %%
model_net.nodes_df.model_node_id.nunique()
# Out:
# 696461

# %% [markdown]
# ## Write to Disk

# %% [markdown]
# ## As shapefile

# %%
model_net.write_roadway_as_shp(
    output_link_shp = os.path.join(output_dir, 'links.shp'),
    output_node_shp = os.path.join(output_dir, 'nodes.shp'),
    link_output_variables = ["model_link_id", "A", "B", "geometry"],
    node_output_variables = ["model_node_id", "geometry"],
    data_to_csv = False,
    data_to_dbf = True,
)
# Out:
# 2020-12-22 20:09:54, INFO: Writing Network as Shapefile
# 2020-12-22 20:09:54, INFO: Writing Network as Shapefile
# 2020-12-22 20:09:54, INFO: Renaming DBF Node Variables
# 2020-12-22 20:09:54, INFO: Renaming DBF Node Variables
# 2020-12-22 20:09:54, INFO: Renaming variables so that they are DBF-safe
# 2020-12-22 20:09:54, INFO: Renaming variables so that they are DBF-safe
# 2020-12-22 20:10:07, INFO: Renaming DBF Link Variables
# 2020-12-22 20:10:07, INFO: Renaming DBF Link Variables
# 2020-12-22 20:10:07, INFO: Renaming variables so that they are DBF-safe
# 2020-12-22 20:10:07, INFO: Renaming variables so that they are DBF-safe
# 2020-12-22 20:10:10, INFO: Writing Node Shapes:
#  - C:/Users/USGS667806/Documents/GitHub/travel-model-two-networks\data\processed\version_04\nodes.shp
# 2020-12-22 20:10:10, INFO: Writing Node Shapes:
#  - C:/Users/USGS667806/Documents/GitHub/travel-model-two-networks\data\processed\version_04\nodes.shp
# 2020-12-22 20:13:06, INFO: Writing Link Shapes:
#  - C:/Users/USGS667806/Documents/GitHub/travel-model-two-networks\data\processed\version_04\links.shp
# 2020-12-22 20:13:06, INFO: Writing Link Shapes:
#  - C:/Users/USGS667806/Documents/GitHub/travel-model-two-networks\data\processed\version_04\links.shp

# %% [markdown]
# ## As fixed width (for CUBE)

# %%
model_net.write_roadway_as_fixedwidth(
    output_link_txt = os.path.join(output_dir, 'links.txt'),
    output_node_txt = os.path.join(output_dir, 'nodes.txt'),
    output_link_header_width_txt = os.path.join(output_dir, 'links_header_width.txt'),
    output_node_header_width_txt = os.path.join(output_dir, 'nodes_header_width.txt'),
    output_cube_network_script = os.path.join(output_dir, 'make_complete_network_from_fixed_width_file.s'),
    #drive_only = True
)
# Out:
# 2020-12-23 11:18:45, INFO: Starting fixed width conversion
# 2020-12-23 11:18:45, INFO: Starting fixed width conversion
# 2020-12-23 11:35:29, INFO: Writing out link database
# 2020-12-23 11:35:29, INFO: Writing out link database
# 2020-12-23 11:35:46, INFO: Writing out link header and width ----
# 2020-12-23 11:35:46, INFO: Writing out link header and width ----
# 2020-12-23 11:35:46, INFO: Starting fixed width conversion
# 2020-12-23 11:35:46, INFO: Starting fixed width conversion
# 2020-12-23 11:37:06, INFO: Writing out node database
# 2020-12-23 11:37:06, INFO: Writing out node database
# 2020-12-23 11:37:09, INFO: Writing out node header and width
# 2020-12-23 11:37:09, INFO: Writing out node header and width

# %%
# %%capture
os.chdir(output_dir)
# !make_cube.bat
# Out:
# links.txt(1656000): 0;1;                      taz_cc1227;0;San Francisco;   7
# links.txt(1657000): 0;1;                     taz_cc15950;0;San Francisco;   7
# links.txt(1658000): 0;1;                      taz_cc2526;0;    San Mateo; 114
# links.txt(1659000): 0;1;                      taz_cc2569;0;    San Mateo; 114
# links.txt(1660000): 0;1;                      taz_cc5700;0;  Santa Clara; 252
# links.txt(1661000): 0;1;                      taz_cc5399;0;  Santa Clara; 252
# links.txt(1662000): 0;1;                      taz_cc6543;0;  Santa Clara; 252
# links.txt(1663000): 0;1;                     taz_cc10482;0;      Alameda; 331
# links.txt(1664000): 0;1;                     taz_cc10149;0;      Alameda; 332
# links.txt(1665000): 0;1;                      taz_cc7850;0;      Alameda; 332
# links.txt(1666000): 0;1;                      taz_cc9852;0;      Alameda; 332
# links.txt(1667000): 0;1;                     taz_cc12534;0; Contra Costa; 423
# links.txt(1668000): 0;1;                     taz_cc11588;0; Contra Costa; 424
# links.txt(1669000): 0;1;                     taz_cc13193;0;       Solano; 511
# links.txt(1670000): 0;1;                     taz_cc13987;0;         Napa; 603
# links.txt(1671000): 0;1;                     taz_cc15097;0;       Sonoma; 713
# links.txt(1672000): 0;1;                     taz_cc15604;0;        Marin; 806
# links.txt(1673000): 1;0;                    maz_cc106064;1;San Francisco;   8
# links.txt(1674000): 1;1;                     maz_cc66665;1;San Francisco;   8
# links.txt(1675000): 1;0;                     maz_cc96494;1;San Francisco;   8
# links.txt(1676000): 1;0;                    maz_cc102042;1;San Francisco;   8
# links.txt(1677000): 1;0;                     maz_cc99398;1;San Francisco;   8
# links.txt(1678000): 1;0;                    maz_cc103415;1;San Francisco;   8
# links.txt(1679000): 0;0;                     maz_cc96889;1;San Francisco;   8
# links.txt(1680000): 1;0;                    maz_cc103278;1;San Francisco;   8
# links.txt(1681000): 1;1;                     maz_cc70150;1;San Francisco;   8
# links.txt(1682000): 1;1;                     maz_cc68679;1;San Francisco;   8
# links.txt(1683000): 1;0;                    maz_cc102389;1;San Francisco;   9
# links.txt(1684000): 1;1;                     maz_cc66097;1;San Francisco;   9
# links.txt(1685000): 1;0;                     maz_cc99508;1;San Francisco;   9
# links.txt(1686000): 1;0;                    maz_cc103016;1;San Francisco;   9
# links.txt(1687000): 0;1;                     maz_cc68764;0;San Francisco;   9
# links.txt(1688000): 0;1;                      maz_cc2226;0;San Francisco;   9
# links.txt(1689000): 1;1;                     maz_cc70027;1;San Francisco;   9
# links.txt(1690000): 1;0;                    maz_cc101309;1;San Francisco;   9
# links.txt(1691000): 1;0;                     maz_cc96072;1;San Francisco;   9
# links.txt(1692000): 0;1;                       maz_cc347;0;San Francisco;   9
# links.txt(1693000): 1;0;                    maz_cc103750;1;San Francisco;  10
# links.txt(1694000): 1;1;                      maz_cc2812;1;San Francisco;  10
# links.txt(1695000): 1;0;                    maz_cc103550;1;San Francisco;  10
# links.txt(1696000): 1;0;                     maz_cc98403;1;San Francisco;  10
# links.txt(1697000): 1;0;                    maz_cc122985;1;    San Mateo; 114
# links.txt(1698000): 1;0;                    maz_cc116864;1;    San Mateo; 114
# links.txt(1699000): 0;1;                     maz_cc70774;0;    San Mateo; 114
# links.txt(1700000): 1;0;                    maz_cc112803;1;    San Mateo; 114
# links.txt(1701000): 1;1;                      maz_cc7908;1;    San Mateo; 114
# links.txt(1702000): 0;1;                      maz_cc8445;0;    San Mateo; 114
# links.txt(1703000): 0;0;                    maz_cc117398;1;    San Mateo; 115
# links.txt(1704000): 0;1;                      maz_cc5147;0;    San Mateo; 115
# links.txt(1705000): 1;0;                    maz_cc120045;1;    San Mateo; 115
# links.txt(1706000): 1;0;                    maz_cc115241;1;    San Mateo; 115
# links.txt(1707000): 1;1;                     maz_cc73248;1;    San Mateo; 115
# links.txt(1708000): 1;1;                     maz_cc73483;1;    San Mateo; 115
# links.txt(1709000): 1;0;                    maz_cc118217;1;    San Mateo; 115
# links.txt(1710000): 0;1;                     maz_cc10850;0;    San Mateo; 115
# links.txt(1711000): 1;1;                      maz_cc6039;1;    San Mateo; 115
# links.txt(1712000): 1;0;                    maz_cc251882;0;    San Mateo; 115
# links.txt(1713000): 0;1;                      maz_cc8106;0;    San Mateo; 116
# links.txt(1714000): 0;1;                      maz_cc6148;0;    San Mateo; 116
# links.txt(1715000): 1;1;                      maz_cc9936;1;    San Mateo; 116
# links.txt(1716000): 1;0;                    maz_cc121603;1;    San Mateo; 116
# links.txt(1717000): 1;1;                      maz_cc8531;1;    San Mateo; 116
# links.txt(1718000): 1;0;                    maz_cc117888;1;    San Mateo; 116
# links.txt(1719000): 1;0;                    maz_cc123250;1;    San Mateo; 116
# links.txt(1720000): 1;1;                     maz_cc70922;1;    San Mateo; 116
# links.txt(1721000): 1;0;                    maz_cc116030;1;    San Mateo; 116
# links.txt(1722000): 1;0;                    maz_cc119209;1;    San Mateo; 116
# links.txt(1723000): 1;0;                    maz_cc115323;1;    San Mateo; 117
# links.txt(1724000): 1;0;                    maz_cc112369;1;    San Mateo; 117
# links.txt(1725000): 0;1;                     maz_cc13683;0;  Santa Clara; 252
# links.txt(1726000): 0;0;                    maz_cc135672;1;  Santa Clara; 252
# links.txt(1727000): 1;0;                    maz_cc153555;1;  Santa Clara; 252
# links.txt(1728000): 1;1;                     maz_cc75211;1;  Santa Clara; 252
# links.txt(1729000): 0;0;                    maz_cc157141;1;  Santa Clara; 252
# links.txt(1730000): 0;1;                     maz_cc15097;0;  Santa Clara; 252
# links.txt(1731000): 0;0;                    maz_cc140498;1;  Santa Clara; 253
# links.txt(1732000): 0;1;                     maz_cc13767;0;  Santa Clara; 253
# links.txt(1733000): 0;1;                     maz_cc22647;0;  Santa Clara; 253
# links.txt(1734000): 1;0;                    maz_cc156115;1;  Santa Clara; 253
# links.txt(1735000): 0;1;                     maz_cc18938;0;  Santa Clara; 253
# links.txt(1736000): 1;0;                    maz_cc152358;1;  Santa Clara; 253
# links.txt(1737000): 0;0;                    maz_cc129293;1;  Santa Clara; 253
# links.txt(1738000): 1;0;                    maz_cc130214;1;  Santa Clara; 253
# links.txt(1739000): 0;1;                     maz_cc11582;0;  Santa Clara; 253
# links.txt(1740000): 0;1;                     maz_cc26610;0;  Santa Clara; 253
# links.txt(1741000): 0;1;                     maz_cc16244;0;  Santa Clara; 254
# links.txt(1742000): 0;1;                     maz_cc12977;0;  Santa Clara; 254
# links.txt(1743000): 1;1;                     maz_cc21517;1;  Santa Clara; 254
# links.txt(1744000): 1;0;                    maz_cc252663;0;  Santa Clara; 254
# links.txt(1745000): 0;0;                    maz_cc146875;1;  Santa Clara; 254
# links.txt(1746000): 1;0;                    maz_cc256483;0;  Santa Clara; 254
# links.txt(1747000): 0;0;                    maz_cc150246;1;  Santa Clara; 254
# links.txt(1748000): 0;0;                    maz_cc156775;1;  Santa Clara; 254
# links.txt(1749000): 0;0;                    maz_cc157334;1;  Santa Clara; 254
# links.txt(1750000): 0;1;                     maz_cc12078;0;  Santa Clara; 254
# links.txt(1751000): 1;0;                    maz_cc134448;1;  Santa Clara; 255
# links.txt(1752000): 0;0;                    maz_cc139634;1;  Santa Clara; 255
# links.txt(1753000): 0;0;                    maz_cc153737;1;  Santa Clara; 255
# links.txt(1754000): 0;0;                    maz_cc126243;1;  Santa Clara; 255
# links.txt(1755000): 1;0;                    maz_cc159760;1;  Santa Clara; 255
# links.txt(1756000): 1;0;                    maz_cc135187;1;  Santa Clara; 255
# links.txt(1757000): 1;0;                    maz_cc136227;1;  Santa Clara; 255
# links.txt(1758000): 0;0;                    maz_cc136864;1;  Santa Clara; 255
# links.txt(1759000): 1;0;                    maz_cc253652;0;  Santa Clara; 255
# links.txt(1760000): 1;0;                    maz_cc137079;1;  Santa Clara; 255
# links.txt(1761000): 0;1;                     maz_cc25586;0;  Santa Clara; 256
# links.txt(1762000): 0;1;                     maz_cc16852;0;  Santa Clara; 256
# links.txt(1763000): 1;1;                     maz_cc18900;0;  Santa Clara; 256
# links.txt(1764000): 1;0;                    maz_cc152244;1;  Santa Clara; 256
# links.txt(1765000): 0;0;                    maz_cc148086;1;  Santa Clara; 256
# links.txt(1766000): 1;0;                    maz_cc135563;1;  Santa Clara; 256
# links.txt(1767000): 1;1;                     maz_cc76478;1;  Santa Clara; 256
# links.txt(1768000): 1;0;                    maz_cc156736;1;  Santa Clara; 256
# links.txt(1769000): 1;0;                    maz_cc129673;1;  Santa Clara; 256
# links.txt(1770000): 0;0;                    maz_cc144547;1;  Santa Clara; 256
# links.txt(1771000): 1;1;                     maz_cc23471;1;  Santa Clara; 257
# links.txt(1772000): 1;0;                    maz_cc143998;1;  Santa Clara; 257
# links.txt(1773000): 1;1;                     maz_cc12441;1;  Santa Clara; 257
# links.txt(1774000): 0;0;                    maz_cc159687;1;  Santa Clara; 257
# links.txt(1775000): 1;1;                     maz_cc76323;1;  Santa Clara; 257
# links.txt(1776000): 1;1;                     maz_cc75109;1;  Santa Clara; 257
# links.txt(1777000): 0;1;                     maz_cc19194;0;  Santa Clara; 257
# links.txt(1778000): 0;1;                     maz_cc19872;0;  Santa Clara; 257
# links.txt(1779000): 0;0;                    maz_cc137233;1;  Santa Clara; 257
# links.txt(1780000): 1;1;                     maz_cc76664;1;  Santa Clara; 257
# links.txt(1781000): 1;0;                    maz_cc131457;1;  Santa Clara; 258
# links.txt(1782000): 1;0;                    maz_cc159879;1;  Santa Clara; 258
# links.txt(1783000): 1;0;                    maz_cc141997;1;  Santa Clara; 258
# links.txt(1784000): 1;0;                    maz_cc125478;1;  Santa Clara; 258
# links.txt(1785000): 1;0;                    maz_cc155178;1;  Santa Clara; 258
# links.txt(1786000): 1;0;                    maz_cc152671;1;  Santa Clara; 258
# links.txt(1787000): 1;0;                    maz_cc155519;1;  Santa Clara; 258
# links.txt(1788000): 1;0;                    maz_cc193542;1;      Alameda; 332
# links.txt(1789000): 1;0;                    maz_cc175986;1;      Alameda; 332
# links.txt(1790000): 1;0;                    maz_cc181760;1;      Alameda; 332
# links.txt(1791000): 1;0;                    maz_cc175840;1;      Alameda; 332
# links.txt(1792000): 1;0;                    maz_cc173507;1;      Alameda; 332
# links.txt(1793000): 1;0;                    maz_cc161613;1;      Alameda; 332
# links.txt(1794000): 1;1;                     maz_cc36392;1;      Alameda; 332
# links.txt(1795000): 1;1;                     maz_cc81676;1;      Alameda; 333
# links.txt(1796000): 0;1;                     maz_cc37919;0;      Alameda; 333
# links.txt(1797000): 1;0;                    maz_cc192543;1;      Alameda; 333
# links.txt(1798000): 1;0;                    maz_cc188519;1;      Alameda; 333
# links.txt(1799000): 1;1;                     maz_cc39791;1;      Alameda; 333
# links.txt(1800000): 0;1;                     maz_cc85083;0;      Alameda; 333
# links.txt(1801000): 1;0;                    maz_cc162529;1;      Alameda; 333
# links.txt(1802000): 1;1;                     maz_cc81912;1;      Alameda; 333
# links.txt(1803000): 1;0;                    maz_cc173775;1;      Alameda; 333
# links.txt(1804000): 1;0;                    maz_cc191798;1;      Alameda; 333
# links.txt(1805000): 0;1;                     maz_cc84897;0;      Alameda; 334
# links.txt(1806000): 0;1;                     maz_cc79264;0;      Alameda; 334
# links.txt(1807000): 0;1;                     maz_cc83397;0;      Alameda; 334
# links.txt(1808000): 0;1;                     maz_cc80726;0;      Alameda; 334
# links.txt(1809000): 1;0;                    maz_cc191390;1;      Alameda; 334
# links.txt(1810000): 0;0;                    maz_cc169921;1;      Alameda; 334
# links.txt(1811000): 1;0;                    maz_cc181156;1;      Alameda; 334
# links.txt(1812000): 0;0;                    maz_cc169924;1;      Alameda; 334
# links.txt(1813000): 1;0;                    maz_cc190494;1;      Alameda; 334
# links.txt(1814000): 1;1;                     maz_cc32673;1;      Alameda; 334
# links.txt(1815000): 1;0;                    maz_cc188231;1;      Alameda; 335
# links.txt(1816000): 1;0;                    maz_cc172332;1;      Alameda; 335
# links.txt(1817000): 1;0;                    maz_cc173191;1;      Alameda; 335
# links.txt(1818000): 1;0;                    maz_cc185037;1;      Alameda; 335
# links.txt(1819000): 0;1;                     maz_cc31476;0;      Alameda; 335
# links.txt(1820000): 1;0;                    maz_cc184296;1;      Alameda; 335
# links.txt(1821000): 0;1;                     maz_cc27756;0;      Alameda; 335
# links.txt(1822000): 1;0;                    maz_cc192801;1;      Alameda; 335
# links.txt(1823000): 1;1;                     maz_cc37889;1;      Alameda; 335
# links.txt(1824000): 1;0;                    maz_cc180886;1;      Alameda; 335
# links.txt(1825000): 1;0;                    maz_cc163267;1;      Alameda; 336
# links.txt(1826000): 1;0;                    maz_cc165912;1;      Alameda; 336
# links.txt(1827000): 1;0;                    maz_cc168224;1;      Alameda; 336
# links.txt(1828000): 1;1;                     maz_cc82601;1;      Alameda; 336
# links.txt(1829000): 1;0;                    maz_cc194351;1;      Alameda; 336
# links.txt(1830000): 1;0;                    maz_cc162487;1;      Alameda; 336
# links.txt(1831000): 1;0;                    maz_cc171837;1;      Alameda; 336
# links.txt(1832000): 1;0;                    maz_cc179569;1;      Alameda; 336
# links.txt(1833000): 1;0;                    maz_cc176360;1;      Alameda; 336
# links.txt(1834000): 1;0;                    maz_cc183941;1;      Alameda; 336
# links.txt(1835000): 1;0;                    maz_cc168729;1;      Alameda; 337
# links.txt(1836000): 0;1;                     maz_cc37094;0;      Alameda; 337
# links.txt(1837000): 1;0;                    maz_cc175930;1;      Alameda; 337
# links.txt(1838000): 1;0;                    maz_cc168123;1;      Alameda; 337
# links.txt(1839000): 1;0;                    maz_cc165234;1;      Alameda; 337
# links.txt(1840000): 1;0;                    maz_cc163565;1;      Alameda; 337
# links.txt(1841000): 1;0;                    maz_cc170118;1;      Alameda; 337
# links.txt(1842000): 1;0;                    maz_cc162496;1;      Alameda; 337
# links.txt(1843000): 1;0;                    maz_cc198477;1; Contra Costa; 424
# links.txt(1844000): 0;1;                     maz_cc48464;0; Contra Costa; 424
# links.txt(1845000): 1;0;                    maz_cc206144;1; Contra Costa; 424
# links.txt(1846000): 1;1;                     maz_cc87057;1; Contra Costa; 424
# links.txt(1847000): 1;1;                     maz_cc86824;1; Contra Costa; 424
# links.txt(1848000): 1;0;                    maz_cc208501;1; Contra Costa; 424
# links.txt(1849000): 0;1;                     maz_cc41109;0; Contra Costa; 424
# links.txt(1850000): 1;0;                    maz_cc205694;1; Contra Costa; 424
# links.txt(1851000): 1;0;                    maz_cc204418;1; Contra Costa; 425
# links.txt(1852000): 1;0;                    maz_cc202076;1; Contra Costa; 425
# links.txt(1853000): 1;1;                     maz_cc86442;1; Contra Costa; 425
# links.txt(1854000): 1;1;                     maz_cc88360;1; Contra Costa; 425
# links.txt(1855000): 1;1;                     maz_cc45674;1; Contra Costa; 425
# links.txt(1856000): 1;0;                    maz_cc200606;1; Contra Costa; 425
# links.txt(1857000): 1;0;                    maz_cc216225;1; Contra Costa; 425
# links.txt(1858000): 1;0;                    maz_cc211733;1; Contra Costa; 425
# links.txt(1859000): 0;1;                     maz_cc50095;0; Contra Costa; 425
# links.txt(1860000): 0;1;                     maz_cc42318;0; Contra Costa; 425
# links.txt(1861000): 1;1;                     maz_cc85839;1; Contra Costa; 426
# links.txt(1862000): 1;0;                    maz_cc206190;1; Contra Costa; 426
# links.txt(1863000): 1;1;                     maz_cc88541;1; Contra Costa; 426
# links.txt(1864000): 1;0;                    maz_cc206694;1; Contra Costa; 426
# links.txt(1865000): 0;1;                     maz_cc85815;0; Contra Costa; 426
# links.txt(1866000): 1;0;                    maz_cc207125;1; Contra Costa; 426
# links.txt(1867000): 0;1;                     maz_cc46768;0; Contra Costa; 426
# links.txt(1868000): 0;0;                    maz_cc215622;1; Contra Costa; 426
# links.txt(1869000): 0;1;                     maz_cc48223;0; Contra Costa; 426
# links.txt(1870000): 0;1;                     maz_cc46605;0; Contra Costa; 426
# links.txt(1871000): 1;0;                    maz_cc216709;1; Contra Costa; 427
# links.txt(1872000): 1;0;                    maz_cc208351;1; Contra Costa; 427
# links.txt(1873000): 1;1;                     maz_cc46815;1; Contra Costa; 427
# links.txt(1874000): 1;1;                     maz_cc43621;1; Contra Costa; 427
# links.txt(1875000): 0;1;                     maz_cc51116;0; Contra Costa; 427
# links.txt(1876000): 1;0;                    maz_cc205550;1; Contra Costa; 427
# links.txt(1877000): 1;0;                    maz_cc217481;1; Contra Costa; 427
# links.txt(1878000): 1;0;                    maz_cc206086;1; Contra Costa; 427
# links.txt(1879000): 1;0;                    maz_cc202950;1; Contra Costa; 427
# links.txt(1880000): 1;0;                    maz_cc202628;1; Contra Costa; 427
# links.txt(1881000): 1;0;                    maz_cc213840;1; Contra Costa; 428
# links.txt(1882000): 0;1;                     maz_cc89615;0;       Solano; 511
# links.txt(1883000): 0;1;                     maz_cc52343;0;       Solano; 512
# links.txt(1884000): 0;1;                     maz_cc89772;0;       Solano; 512
# links.txt(1885000): 1;1;                     maz_cc89976;1;       Solano; 512
# links.txt(1886000): 1;0;                    maz_cc224372;1;       Solano; 512
# links.txt(1887000): 0;0;                    maz_cc228220;1;       Solano; 512
# links.txt(1888000): 1;0;                    maz_cc222682;1;       Solano; 512
# links.txt(1889000): 1;0;                    maz_cc220443;1;       Solano; 512
# links.txt(1890000): 1;0;                    maz_cc220665;1;       Solano; 512
# links.txt(1891000): 1;0;                    maz_cc221312;1;       Solano; 512
# links.txt(1892000): 1;1;                     maz_cc89671;1;       Solano; 512
# links.txt(1893000): 1;0;                    maz_cc229268;1;       Solano; 513
# links.txt(1894000): 1;1;                     maz_cc55469;1;       Solano; 513
# links.txt(1895000): 1;0;                    maz_cc218412;1;       Solano; 513
# links.txt(1896000): 1;0;                    maz_cc220326;1;       Solano; 513
# links.txt(1897000): 1;0;                    maz_cc227173;1;       Solano; 513
# links.txt(1898000): 0;0;                    maz_cc228409;1;       Solano; 513
# links.txt(1899000): 1;0;                    maz_cc223306;1;       Solano; 513
# links.txt(1900000): 1;0;                    maz_cc231917;1;         Napa; 603
# links.txt(1901000): 1;0;                    maz_cc232671;1;         Napa; 603
# links.txt(1902000): 1;0;                    maz_cc230508;1;         Napa; 603
# links.txt(1903000): 0;1;                     maz_cc56876;0;         Napa; 603
# links.txt(1904000): 1;0;                    maz_cc231775;1;         Napa; 603
# links.txt(1905000): 1;0;                    maz_cc232353;1;         Napa; 604
# links.txt(1906000): 1;1;                     maz_cc92941;1;       Sonoma; 713
# links.txt(1907000): 1;0;                    maz_cc242309;1;       Sonoma; 713
# links.txt(1908000): 1;0;                    maz_cc238429;1;       Sonoma; 714
# links.txt(1909000): 1;0;                    maz_cc243667;1;       Sonoma; 714
# links.txt(1910000): 1;0;                    maz_cc243843;1;       Sonoma; 714
# links.txt(1911000): 1;0;                    maz_cc237709;1;       Sonoma; 714
# links.txt(1912000): 1;0;                    maz_cc240326;1;       Sonoma; 714
# links.txt(1913000): 0;1;                     maz_cc60298;0;       Sonoma; 714
# links.txt(1914000): 1;0;                    maz_cc233493;1;       Sonoma; 714
# links.txt(1915000): 1;0;                    maz_cc240950;1;       Sonoma; 714
# links.txt(1916000): 0;1;                     maz_cc61895;0;       Sonoma; 714
# links.txt(1917000): 1;0;                    maz_cc237084;1;       Sonoma; 714
# links.txt(1918000): 1;0;                    maz_cc239623;1;       Sonoma; 715
# links.txt(1919000): 1;0;                    maz_cc239744;1;       Sonoma; 715
# links.txt(1920000): 1;0;                    maz_cc233768;1;       Sonoma; 715
# links.txt(1921000): 1;0;                    maz_cc241018;1;       Sonoma; 715
# links.txt(1922000): 1;0;                    maz_cc235899;1;       Sonoma; 715
# links.txt(1923000): 1;0;                    maz_cc234920;1;       Sonoma; 715
# links.txt(1924000): 1;0;                    maz_cc236671;1;       Sonoma; 715
# links.txt(1925000): 0;1;                     maz_cc64006;0;        Marin; 806
# links.txt(1926000): 0;1;                     maz_cc64891;0;        Marin; 806
# links.txt(1927000): 1;0;                    maz_cc248595;1;        Marin; 806
# links.txt(1928000): 1;0;                    maz_cc250407;1;        Marin; 806
# links.txt(1929000): 1;0;                    maz_cc248251;1;        Marin; 806
# links.txt(1930000): 1;0;                    maz_cc249169;1;        Marin; 807
# links.txt(1931000): 0;1;                     maz_cc64486;0;        Marin; 807
# links.txt(1932000): 1;0;                    maz_cc250851;1;        Marin; 807
# links.txt(1933000): 1;0;                    maz_cc245501;1;        Marin; 807
# links.txt(1934000): 1;0;                    maz_cc251104;0;San Francisco;  10
# links.txt(1935000): 1;0;                    maz_cc104971;1;San Francisco;  10
# links.txt(1936000): 1;0;                     maz_cc95277;1;San Francisco;  10
# links.txt(1937000): 1;0;                    maz_cc106360;1;San Francisco;  10
# links.txt(1938000): 1;0;                     maz_cc98425;1;San Francisco;  10
# links.txt(1939000): 0;1;                      maz_cc2062;0;San Francisco;  10
# links.txt(1940000): 1;0;                    maz_cc103961;1;San Francisco;  11
# links.txt(1941000): 1;1;                      maz_cc3321;1;San Francisco;  11
# links.txt(1942000): 1;0;                    maz_cc106598;1;San Francisco;  11
# links.txt(1943000): 1;0;                    maz_cc251425;0;San Francisco;  11
# links.txt(1944000): 1;1;                     maz_cc65906;1;San Francisco;  11
# links.txt(1945000): 1;1;                     maz_cc69852;1;San Francisco;  11
# links.txt(1946000): 1;1;                     maz_cc67376;1;San Francisco;  11
# links.txt(1947000): 1;0;                     maz_cc95674;1;San Francisco;  11
# links.txt(1948000): 1;1;                      maz_cc3692;1;San Francisco;  11
# links.txt(1949000): 0;1;                     maz_cc67465;0;San Francisco;  11
# links.txt(1950000): 1;0;                    maz_cc106047;1;San Francisco;  12
# links.txt(1951000): 1;1;                      maz_cc2316;1;San Francisco;  12
# links.txt(1952000): 1;0;                     maz_cc95876;1;San Francisco;  12
# links.txt(1953000): 1;1;                     maz_cc69804;1;San Francisco;  12
# links.txt(1954000): 1;1;                      maz_cc4016;1;San Francisco;  12
# links.txt(1955000): 1;1;                     maz_cc67160;1;San Francisco;  12
# links.txt(1956000): 1;0;                    maz_cc101587;1;San Francisco;  12
# links.txt(1957000): 1;0;                     maz_cc96569;1;San Francisco;  12
# links.txt(1958000): 1;0;                    maz_cc118721;1;    San Mateo; 117
# links.txt(1959000): 1;1;                     maz_cc72809;1;    San Mateo; 117
# links.txt(1960000): 0;1;                     maz_cc73762;0;    San Mateo; 117
# links.txt(1961000): 1;0;                    maz_cc119374;1;    San Mateo; 117
# links.txt(1962000): 1;0;                    maz_cc119903;1;    San Mateo; 117
# links.txt(1963000): 1;0;                    maz_cc116361;1;    San Mateo; 117
# links.txt(1964000): 0;1;                     maz_cc74425;0;    San Mateo; 117
# links.txt(1965000): 1;0;                    maz_cc116286;1;    San Mateo; 117
# links.txt(1966000): 1;0;                    maz_cc113454;1;    San Mateo; 118
# links.txt(1967000): 1;0;                    maz_cc118788;1;    San Mateo; 118
# links.txt(1968000): 1;0;                    maz_cc108555;1;    San Mateo; 118
# links.txt(1969000): 1;0;                    maz_cc109721;1;    San Mateo; 118
# links.txt(1970000): 0;1;                     maz_cc72020;0;    San Mateo; 118
# links.txt(1971000): 1;0;                    maz_cc120888;1;    San Mateo; 118
# links.txt(1972000): 1;0;                    maz_cc109685;1;    San Mateo; 118
# links.txt(1973000): 0;1;                      maz_cc6880;0;    San Mateo; 118
# links.txt(1974000): 1;0;                    maz_cc110860;1;    San Mateo; 118
# links.txt(1975000): 1;0;                    maz_cc119923;1;    San Mateo; 118
# links.txt(1976000): 0;1;                      maz_cc8223;0;    San Mateo; 119
# links.txt(1977000): 1;1;                     maz_cc74573;1;    San Mateo; 119
# links.txt(1978000): 1;0;                    maz_cc109913;1;    San Mateo; 119
# links.txt(1979000): 1;0;                    maz_cc115350;1;    San Mateo; 119
# links.txt(1980000): 1;0;                    maz_cc122005;1;    San Mateo; 119
# links.txt(1981000): 0;1;                     maz_cc10285;0;    San Mateo; 119
# links.txt(1982000): 1;1;                     maz_cc71154;1;    San Mateo; 119
# links.txt(1983000): 1;0;                    maz_cc118521;1;    San Mateo; 119
# links.txt(1984000): 1;0;                    maz_cc116847;1;    San Mateo; 119
# links.txt(1985000): 1;0;                    maz_cc112875;1;    San Mateo; 119
# links.txt(1986000): 1;0;                    maz_cc129788;1;  Santa Clara; 258
# links.txt(1987000): 1;0;                    maz_cc144083;1;  Santa Clara; 258
# links.txt(1988000): 1;1;                     maz_cc26762;1;  Santa Clara; 258
# links.txt(1989000): 0;1;                     maz_cc12651;0;  Santa Clara; 259
# links.txt(1990000): 0;0;                    maz_cc127602;1;  Santa Clara; 259
# links.txt(1991000): 1;0;                    maz_cc126236;1;  Santa Clara; 259
# links.txt(1992000): 0;1;                     maz_cc26179;0;  Santa Clara; 259
# links.txt(1993000): 1;1;                     maz_cc12750;1;  Santa Clara; 259
# links.txt(1994000): 0;1;                     maz_cc12062;0;  Santa Clara; 259
# links.txt(1995000): 1;1;                     maz_cc21766;0;  Santa Clara; 259
# links.txt(1996000): 0;0;                    maz_cc135479;1;  Santa Clara; 259
# links.txt(1997000): 1;0;                    maz_cc158364;1;  Santa Clara; 259
# links.txt(1998000): 1;0;                    maz_cc157275;1;  Santa Clara; 259
# links.txt(1999000): 1;0;                    maz_cc131301;1;  Santa Clara; 260
# links.txt(2000000): 0;0;                    maz_cc128329;1;  Santa Clara; 260
# links.txt(2001000): 1;0;                    maz_cc133581;1;  Santa Clara; 260
# links.txt(2002000): 1;1;                     maz_cc16573;1;  Santa Clara; 260
# links.txt(2003000): 1;0;                    maz_cc145423;1;  Santa Clara; 260
# links.txt(2004000): 1;1;                     maz_cc16300;1;  Santa Clara; 260
# links.txt(2005000): 0;0;                    maz_cc136297;1;  Santa Clara; 260
# links.txt(2006000): 0;1;                     maz_cc11439;0;  Santa Clara; 260
# links.txt(2007000): 1;0;                    maz_cc131750;1;  Santa Clara; 260
# links.txt(2008000): 1;0;                    maz_cc159643;1;  Santa Clara; 260
# links.txt(2009000): 0;0;                    maz_cc152820;1;  Santa Clara; 261
# links.txt(2010000): 1;0;                    maz_cc257338;0;  Santa Clara; 261
# links.txt(2011000): 1;0;                    maz_cc156164;1;  Santa Clara; 261
# links.txt(2012000): 0;0;                    maz_cc157223;1;  Santa Clara; 261
# links.txt(2013000): 1;0;                    maz_cc253344;0;  Santa Clara; 261
# links.txt(2014000): 1;0;                    maz_cc145492;1;  Santa Clara; 261
# links.txt(2015000): 0;1;                     maz_cc11032;0;  Santa Clara; 261
# links.txt(2016000): 1;0;                    maz_cc126490;1;  Santa Clara; 261
# links.txt(2017000): 1;0;                    maz_cc152538;1;  Santa Clara; 261
# links.txt(2018000): 1;0;                    maz_cc160209;1;  Santa Clara; 261
# links.txt(2019000): 1;0;                    maz_cc130163;1;  Santa Clara; 262
# links.txt(2020000): 0;1;                     maz_cc20423;0;  Santa Clara; 262
# links.txt(2021000): 1;0;                    maz_cc132754;1;  Santa Clara; 262
# links.txt(2022000): 1;0;                    maz_cc156165;1;  Santa Clara; 262
# links.txt(2023000): 1;0;                    maz_cc156805;1;  Santa Clara; 262
# links.txt(2024000): 1;0;                    maz_cc126437;1;  Santa Clara; 262
# links.txt(2025000): 1;0;                    maz_cc252393;0;  Santa Clara; 262
# links.txt(2026000): 1;0;                    maz_cc258076;0;  Santa Clara; 262
# links.txt(2027000): 0;1;                     maz_cc24072;0;  Santa Clara; 262
# links.txt(2028000): 0;0;                    maz_cc158533;1;  Santa Clara; 262
# links.txt(2029000): 0;0;                    maz_cc130288;1;  Santa Clara; 263
# links.txt(2030000): 1;1;                     maz_cc75912;1;  Santa Clara; 263
# links.txt(2031000): 1;1;                     maz_cc12228;1;  Santa Clara; 263
# links.txt(2032000): 1;0;                    maz_cc154130;1;  Santa Clara; 263
# links.txt(2033000): 1;0;                    maz_cc148275;1;  Santa Clara; 263
# links.txt(2034000): 1;0;                    maz_cc126509;1;  Santa Clara; 263
# links.txt(2035000): 1;1;                     maz_cc76746;1;  Santa Clara; 263
# links.txt(2036000): 1;0;                    maz_cc259396;0;  Santa Clara; 263
# links.txt(2037000): 1;0;                    maz_cc139586;1;  Santa Clara; 263
# links.txt(2038000): 1;1;                     maz_cc15450;1;  Santa Clara; 263
# links.txt(2039000): 1;1;                     maz_cc75937;1;  Santa Clara; 264
# links.txt(2040000): 1;0;                    maz_cc256724;0;  Santa Clara; 264
# links.txt(2041000): 0;1;                     maz_cc13502;0;  Santa Clara; 264
# links.txt(2042000): 1;0;                    maz_cc125336;1;  Santa Clara; 264
# links.txt(2043000): 0;1;                     maz_cc76646;0;  Santa Clara; 264
# links.txt(2044000): 1;0;                    maz_cc125627;1;  Santa Clara; 264
# links.txt(2045000): 1;0;                    maz_cc144582;1;  Santa Clara; 264
# links.txt(2046000): 1;0;                    maz_cc132040;1;  Santa Clara; 264
# links.txt(2047000): 1;0;                    maz_cc155202;1;  Santa Clara; 264
# links.txt(2048000): 1;0;                    maz_cc153027;1;  Santa Clara; 264
# links.txt(2049000): 0;1;                     maz_cc79986;0;      Alameda; 337
# links.txt(2050000): 1;0;                    maz_cc163753;1;      Alameda; 337
# links.txt(2051000): 1;1;                     maz_cc39960;1;      Alameda; 338
# links.txt(2052000): 1;0;                    maz_cc175299;1;      Alameda; 338
# links.txt(2053000): 1;0;                    maz_cc186388;1;      Alameda; 338
# links.txt(2054000): 0;1;                     maz_cc78924;0;      Alameda; 338
# links.txt(2055000): 1;0;                    maz_cc163483;1;      Alameda; 338
# links.txt(2056000): 1;1;                     maz_cc30320;1;      Alameda; 338
# links.txt(2057000): 1;0;                    maz_cc193574;1;      Alameda; 338
# links.txt(2058000): 1;0;                    maz_cc185217;1;      Alameda; 338
# links.txt(2059000): 1;1;                     maz_cc83046;1;      Alameda; 338
# links.txt(2060000): 1;1;                     maz_cc27566;1;      Alameda; 338
# links.txt(2061000): 1;0;                    maz_cc179001;1;      Alameda; 339
# links.txt(2062000): 1;0;                    maz_cc166925;1;      Alameda; 339
# links.txt(2063000): 1;0;                    maz_cc173088;1;      Alameda; 339
# links.txt(2064000): 1;0;                    maz_cc161291;1;      Alameda; 339
# links.txt(2065000): 1;0;                    maz_cc189780;1;      Alameda; 339
# links.txt(2066000): 1;0;                    maz_cc166535;1;      Alameda; 339
# links.txt(2067000): 1;0;                    maz_cc162233;1;      Alameda; 339
# links.txt(2068000): 1;0;                    maz_cc178017;1;      Alameda; 339
# links.txt(2069000): 1;0;                    maz_cc188825;1;      Alameda; 339
# links.txt(2070000): 1;0;                    maz_cc163790;1;      Alameda; 339
# links.txt(2071000): 1;1;                     maz_cc80399;1;      Alameda; 340
# links.txt(2072000): 1;0;                    maz_cc165351;1;      Alameda; 340
# links.txt(2073000): 1;0;                    maz_cc171569;1;      Alameda; 340
# links.txt(2074000): 1;0;                    maz_cc169185;1;      Alameda; 340
# links.txt(2075000): 0;1;                     maz_cc36626;0;      Alameda; 340
# links.txt(2076000): 1;0;                    maz_cc185730;1;      Alameda; 340
# links.txt(2077000): 1;0;                    maz_cc172204;1;      Alameda; 340
# links.txt(2078000): 1;0;                    maz_cc190154;1;      Alameda; 340
# links.txt(2079000): 1;1;                     maz_cc34618;0;      Alameda; 340
# links.txt(2080000): 1;0;                    maz_cc180152;1;      Alameda; 340
# links.txt(2081000): 1;1;                     maz_cc81397;1;      Alameda; 341
# links.txt(2082000): 1;0;                    maz_cc181699;1;      Alameda; 341
# links.txt(2083000): 1;0;                    maz_cc180281;1;      Alameda; 341
# links.txt(2084000): 0;1;                     maz_cc34464;0;      Alameda; 341
# links.txt(2085000): 1;0;                    maz_cc165531;1;      Alameda; 341
# links.txt(2086000): 1;0;                    maz_cc183559;1;      Alameda; 341
# links.txt(2087000): 1;0;                    maz_cc191504;1;      Alameda; 341
# links.txt(2088000): 1;1;                     maz_cc34396;1;      Alameda; 341
# links.txt(2089000): 1;0;                    maz_cc178045;1;      Alameda; 341
# links.txt(2090000): 1;0;                    maz_cc177568;1;      Alameda; 341
# links.txt(2091000): 1;0;                    maz_cc179371;1;      Alameda; 342
# links.txt(2092000): 1;0;                    maz_cc161786;1;      Alameda; 342
# links.txt(2093000): 0;1;                     maz_cc30857;0;      Alameda; 342
# links.txt(2094000): 1;1;                     maz_cc80949;1;      Alameda; 342
# links.txt(2095000): 1;1;                     maz_cc83478;1;      Alameda; 342
# links.txt(2096000): 1;1;                     maz_cc37060;1;      Alameda; 342
# links.txt(2097000): 1;0;                    maz_cc187705;1;      Alameda; 342
# links.txt(2098000): 1;0;                    maz_cc182074;1;      Alameda; 342
# links.txt(2099000): 1;0;                    maz_cc169457;1;      Alameda; 342
# links.txt(2100000): 1;0;                    maz_cc179175;1;      Alameda; 342
# links.txt(2101000): 1;0;                    maz_cc184522;1;      Alameda; 343
# links.txt(2102000): 1;0;                    maz_cc175931;1;      Alameda; 343
# links.txt(2103000): 1;0;                    maz_cc167252;1;      Alameda; 343
# links.txt(2104000): 0;1;                     maz_cc43269;0; Contra Costa; 428
# links.txt(2105000): 1;0;                    maz_cc202667;1; Contra Costa; 428
# links.txt(2106000): 1;0;                    maz_cc196179;1; Contra Costa; 428
# links.txt(2107000): 1;0;                    maz_cc217813;1; Contra Costa; 428
# links.txt(2108000): 0;1;                     maz_cc44115;0; Contra Costa; 428
# links.txt(2109000): 1;0;                    maz_cc216861;1; Contra Costa; 428
# links.txt(2110000): 0;1;                     maz_cc49487;0; Contra Costa; 428
# links.txt(2111000): 0;1;                     maz_cc85172;0; Contra Costa; 428
# links.txt(2112000): 1;1;                     maz_cc47671;1; Contra Costa; 428
# links.txt(2113000): 1;1;                     maz_cc47058;1; Contra Costa; 429
# links.txt(2114000): 1;0;                    maz_cc194906;1; Contra Costa; 429
# links.txt(2115000): 1;1;                     maz_cc48277;1; Contra Costa; 429
# links.txt(2116000): 0;1;                     maz_cc87721;0; Contra Costa; 429
# links.txt(2117000): 0;1;                     maz_cc44948;0; Contra Costa; 429
# links.txt(2118000): 1;0;                    maz_cc214111;1; Contra Costa; 429
# links.txt(2119000): 0;1;                     maz_cc47761;0; Contra Costa; 429
# links.txt(2120000): 1;0;                    maz_cc197538;1; Contra Costa; 429
# links.txt(2121000): 1;0;                    maz_cc208945;1; Contra Costa; 429
# links.txt(2122000): 1;0;                    maz_cc195436;1; Contra Costa; 429
# links.txt(2123000): 1;0;                    maz_cc216936;1; Contra Costa; 430
# links.txt(2124000): 1;0;                    maz_cc212760;1; Contra Costa; 430
# links.txt(2125000): 1;0;                    maz_cc206765;1; Contra Costa; 430
# links.txt(2126000): 1;0;                    maz_cc200708;1; Contra Costa; 430
# links.txt(2127000): 1;0;                    maz_cc211821;1; Contra Costa; 430
# links.txt(2128000): 0;1;                     maz_cc47849;0; Contra Costa; 430
# links.txt(2129000): 1;0;                    maz_cc209388;1; Contra Costa; 430
# links.txt(2130000): 1;1;                     maz_cc42924;1; Contra Costa; 430
# links.txt(2131000): 1;0;                    maz_cc203916;1; Contra Costa; 430
# links.txt(2132000): 1;0;                    maz_cc202541;1; Contra Costa; 430
# links.txt(2133000): 1;0;                    maz_cc215448;1; Contra Costa; 431
# links.txt(2134000): 1;0;                    maz_cc196654;1; Contra Costa; 431
# links.txt(2135000): 0;1;                     maz_cc47434;0; Contra Costa; 431
# links.txt(2136000): 1;0;                    maz_cc211898;1; Contra Costa; 431
# links.txt(2137000): 0;0;                    maz_cc211803;1; Contra Costa; 431
# links.txt(2138000): 1;0;                    maz_cc218077;1; Contra Costa; 431
# links.txt(2139000): 1;0;                    maz_cc204851;1; Contra Costa; 431
# links.txt(2140000): 1;0;                    maz_cc208768;1; Contra Costa; 431
# links.txt(2141000): 1;0;                    maz_cc202651;1; Contra Costa; 431
# links.txt(2142000): 0;0;                    maz_cc202606;1; Contra Costa; 431
# links.txt(2143000): 1;0;                    maz_cc224026;1;       Solano; 513
# links.txt(2144000): 1;1;                     maz_cc52504;1;       Solano; 513
# links.txt(2145000): 0;1;                     maz_cc52541;0;       Solano; 513
# links.txt(2146000): 1;1;                     maz_cc54337;1;       Solano; 514
# links.txt(2147000): 0;1;                     maz_cc52878;0;       Solano; 514
# links.txt(2148000): 0;1;                     maz_cc55901;0;       Solano; 514
# links.txt(2149000): 0;1;                     maz_cc55444;0;       Solano; 514
# links.txt(2150000): 0;1;                     maz_cc52534;0;       Solano; 514
# links.txt(2151000): 1;0;                    maz_cc223462;1;       Solano; 514
# links.txt(2152000): 1;0;                    maz_cc223044;1;       Solano; 514
# links.txt(2153000): 1;0;                    maz_cc220641;1;       Solano; 514
# links.txt(2154000): 1;0;                    maz_cc222739;1;       Solano; 514
# links.txt(2155000): 0;1;                     maz_cc56185;0;       Solano; 514
# links.txt(2156000): 1;0;                    maz_cc220829;1;       Solano; 515
# links.txt(2157000): 0;1;                     maz_cc54452;0;       Solano; 515
# links.txt(2158000): 1;0;                    maz_cc224326;1;       Solano; 515
# links.txt(2159000): 1;0;                    maz_cc222067;1;       Solano; 515
# links.txt(2160000): 1;0;                    maz_cc225151;1;       Solano; 515
# links.txt(2161000): 0;1;                     maz_cc57996;0;         Napa; 604
# links.txt(2162000): 1;0;                    maz_cc232582;1;         Napa; 604
# links.txt(2163000): 1;1;                     maz_cc57469;1;         Napa; 604
# links.txt(2164000): 1;0;                    maz_cc231206;1;         Napa; 604
# links.txt(2165000): 1;0;                    maz_cc231958;1;         Napa; 604
# links.txt(2166000): 1;0;                    maz_cc232216;1;         Napa; 604
# links.txt(2167000): 1;0;                    maz_cc238796;1;       Sonoma; 715
# links.txt(2168000): 1;0;                    maz_cc236916;1;       Sonoma; 715
# links.txt(2169000): 0;1;                     maz_cc61258;0;       Sonoma; 715
# links.txt(2170000): 0;1;                     maz_cc59551;0;       Sonoma; 715
# links.txt(2171000): 1;0;                    maz_cc235408;1;       Sonoma; 716
# links.txt(2172000): 0;1;                     maz_cc92812;0;       Sonoma; 716
# links.txt(2173000): 0;1;                     maz_cc59110;0;       Sonoma; 716
# links.txt(2174000): 1;0;                    maz_cc245006;1;       Sonoma; 716
# links.txt(2175000): 1;0;                    maz_cc239870;1;       Sonoma; 716
# links.txt(2176000): 1;1;                     maz_cc58556;1;       Sonoma; 716
# links.txt(2177000): 0;1;                     maz_cc58814;0;       Sonoma; 716
# links.txt(2178000): 1;0;                    maz_cc240500;1;       Sonoma; 716
# links.txt(2179000): 1;0;                    maz_cc243862;1;       Sonoma; 716
# links.txt(2180000): 1;0;                    maz_cc234618;1;       Sonoma; 716
# links.txt(2181000): 0;1;                     maz_cc58498;0;       Sonoma; 717
# links.txt(2182000): 1;0;                    maz_cc236926;1;       Sonoma; 717
# links.txt(2183000): 1;0;                    maz_cc235677;1;       Sonoma; 717
# links.txt(2184000): 1;0;                    maz_cc244505;1;       Sonoma; 717
# links.txt(2185000): 1;0;                    maz_cc233651;1;       Sonoma; 717
# links.txt(2186000): 1;0;                    maz_cc249757;1;        Marin; 807
# links.txt(2187000): 0;1;                     maz_cc64917;0;        Marin; 807
# links.txt(2188000): 1;1;                     maz_cc63278;1;        Marin; 807
# links.txt(2189000): 1;1;                     maz_cc63288;1;        Marin; 807
# links.txt(2190000): 1;0;                    maz_cc250794;1;        Marin; 807
# links.txt(2191000): 1;0;                    maz_cc249371;1;        Marin; 807
# links.txt(2192000): 0;1;                     maz_cc63864;0;        Marin; 808
# links.txt(2193000): 1;0;                    maz_cc250864;1;        Marin; 808
# links.txt(2194000): 1;0;                    maz_cc248770;1;        Marin; 808
# links.txt(2195000): 0;0;                         tap_185;1; Contra Costa; 432
# links.txt(2196000): 0;0;                        tap_1185;1; Contra Costa; 432
# links.txt(2197000): 0;0;                        tap_2185;1;       Sonoma; 717
# links.txt(2198000): 0;0;                        tap_3185;1;San Francisco;  12
# links.txt(2199000): 0;0;                        tap_4185;1;San Francisco;  12
# links.txt(2200000): 0;0;                        tap_5185;1;San Francisco;  13
# links.txt(2201000): 0;0;                        tap_6185;1;San Francisco;  13
# links.txt(2202000): 0;0;                        tap_7185;1;    San Mateo; 120
# links.txt(2203000): 0;0;                        tap_8185;1;  Santa Clara; 265
# links.txt(2204000): 0;0;                        tap_9185;1;       Sonoma; 717
# links.txt(2205000): 0;0;                       tap_10185;1;  Santa Clara; 265
# links.txt(2206000): 0;0;                       tap_11185;1;  Santa Clara; 265
# links.txt(2207000): 0;0;                       tap_12185;1;  Santa Clara; 265
# links.txt(2208000): 0;0;                       tap_13185;1;  Santa Clara; 265
# links.txt(2209000): 0;0;                       tap_14185;1; Contra Costa; 432
# links.txt(2210000): 0;0;                       tap_15185;1; Contra Costa; 432
# links.txt(2211000): 0;0;                       tap_16185;1;      Alameda; 343
# links.txt(2212000): 0;0;                       tap_17185;1;      Alameda; 343
# links.txt(2213000): 0;0;                       tap_18185;1;      Alameda; 343
# links.txt(2214000): 0;0;                       tap_19185;1; Contra Costa; 432
# links.txt(2215000): 0;0;                       tap_20185;1;      Alameda; 343
# links.txt(2216000): 0;0;                       tap_21185;1;      Alameda; 343
# links.txt(2217000): 0;0;                         tap_428;1; Contra Costa; 432
# links.txt(2218000): 0;0;                        tap_1428;1;       Solano; 515
# links.txt(2219000): 0;0;                        tap_2428;1;  Santa Clara; 265
# links.txt(2220000): 0;0;                        tap_3428;1;San Francisco;  13
# links.txt(2221000): 0;0;                        tap_4428;1;San Francisco;  13
# links.txt(2222000): 0;0;                        tap_5428;1;San Francisco;  13
# links.txt(2223000): 0;0;                        tap_6428;1;San Francisco;  13
# links.txt(2224000): 0;0;                        tap_7428;1;    San Mateo; 120
# links.txt(2225000): 0;0;                        tap_8428;1;       Solano; 515
# links.txt(2226000): 0;0;                        tap_9428;1;       Sonoma; 717
# links.txt(2227000): 0;0;                       tap_10428;1;  Santa Clara; 265
# links.txt(2228000): 0;0;                       tap_11428;1;  Santa Clara; 265
# links.txt(2229000): 0;0;                       tap_12428;1;  Santa Clara; 265
# links.txt(2230000): 0;0;                       tap_13428;1;  Santa Clara; 265
# links.txt(2231000): 0;0;                       tap_14428;1;      Alameda; 343
# links.txt(2232000): 0;0;                       tap_15428;1;      Alameda; 343
# links.txt(2233000): 0;0;                       tap_16428;1;      Alameda; 343
# links.txt(2234000): 0;0;                       tap_17428;1;      Alameda; 344
# links.txt(2235000): 0;0;                       tap_18428;1;      Alameda; 344
# links.txt(2236000): 0;0;                       tap_19428;1;      Alameda; 344
# links.txt(2237000): 0;0;                       tap_20428;1;      Alameda; 344
# links.txt(2238000): 0;0;                       tap_21428;1;      Alameda; 344
#
#
# NODEMERGE: 10590
#
# NODEMERGE: 12288
#
# NODEMERGE: 14110
#
# NODEMERGE: 15959
#
# NODEMERGE: 90211
#
# NODEMERGE: 110444
#
# NODEMERGE: 112528
#
# NODEMERGE: 114578
#
# NODEMERGE: 116654
#
# NODEMERGE: 118758
#
# NODEMERGE: 200157
#
# NODEMERGE: 210265
#
# NODEMERGE: 212282
#
# NODEMERGE: 214390
#
# NODEMERGE: 216599
#
# NODEMERGE: 219242
#
# NODEMERGE: 222175
#
# NODEMERGE: 225041
#
# NODEMERGE: 227628
#
# NODEMERGE: 230981
#
# NODEMERGE: 290620
#
# NODEMERGE: 300382
#
# NODEMERGE: 310492
#
# NODEMERGE: 312421
#
# NODEMERGE: 314655
#
# NODEMERGE: 317059
#
# NODEMERGE: 319694
#
# NODEMERGE: 322691
#
# NODEMERGE: 325967
#
# NODEMERGE: 329488
#
# NODEMERGE: 332708
#
# NODEMERGE: 390650
#
# NODEMERGE: 400208
#
# NODEMERGE: 411257
#
# NODEMERGE: 413891
#
# NODEMERGE: 416843
#
# NODEMERGE: 419950
#
# NODEMERGE: 423478
#
# NODEMERGE: 427041
#
# NODEMERGE: 490665
#
# NODEMERGE: 511151
#
# NODEMERGE: 514398
#
# NODEMERGE: 518718
#
# NODEMERGE: 610799
#
# NODEMERGE: 700280
#
# NODEMERGE: 712714
#
# NODEMERGE: 716399
#
# NODEMERGE: 790016
#
# NODEMERGE: 810724
#
# NODEMERGE: 813895
#
# NODEMERGE: 1000517
#
# NODEMERGE: 1001517
#
# NODEMERGE: 1002517
#
# NODEMERGE: 1003517
#
# NODEMERGE: 1004517
#
# NODEMERGE: 1005517
#
# NODEMERGE: 1006517
#
# NODEMERGE: 1007517
#
# NODEMERGE: 1008517
#
# NODEMERGE: 1009517
#
# NODEMERGE: 1010517
#
# NODEMERGE: 1011517
#
# NODEMERGE: 1012517
#
# NODEMERGE: 1013517
#
# NODEMERGE: 1014517
#
# NODEMERGE: 1015517
#
# NODEMERGE: 1016517
#
# NODEMERGE: 1017517
#
# NODEMERGE: 1018517
#
# NODEMERGE: 1019517
#
# NODEMERGE: 1020517
#
# NODEMERGE: 1021517
#
# NODEMERGE: 1022517
#
# NODEMERGE: 1023517
#
# NODEMERGE: 1024517
#
# NODEMERGE: 1025517
#
# NODEMERGE: 1026517
#
# NODEMERGE: 1027517
#
# NODEMERGE: 1500476
#
# NODEMERGE: 1501476
#
# NODEMERGE: 1502476
#
# NODEMERGE: 1503476
#
# NODEMERGE: 1504476
#
# NODEMERGE: 1505476
#
# NODEMERGE: 1506476
#
# NODEMERGE: 1507476
#
# NODEMERGE: 1508476
#
# NODEMERGE: 1509476
#
# NODEMERGE: 1510476
#
# NODEMERGE: 1511476
#
# NODEMERGE: 1512476
#
# NODEMERGE: 1513476
#
# NODEMERGE: 1514476
#
# NODEMERGE: 1515476
#
# NODEMERGE: 1516476
#
# NODEMERGE: 1517476
#
# NODEMERGE: 1518476
#
# NODEMERGE: 1519476
#
# NODEMERGE: 1520476
#
# NODEMERGE: 1521476
#
# NODEMERGE: 1522476
#
# NODEMERGE: 1523476
#
# NODEMERGE: 1524476
#
# NODEMERGE: 1525476
#
# NODEMERGE: 1526476
#
# NODEMERGE: 1527476
#
# NODEMERGE: 1528476
#
# NODEMERGE: 1529476
#
# NODEMERGE: 1530476
#
# NODEMERGE: 1531476
#
# NODEMERGE: 1532476
#
# NODEMERGE: 1533476
#
# NODEMERGE: 1534476
#
# NODEMERGE: 1535476
#
# NODEMERGE: 1536476
#
# NODEMERGE: 1537476
#
# NODEMERGE: 1538476
#
# NODEMERGE: 1539476
#
# NODEMERGE: 1540476
#
# NODEMERGE: 1541476
#
# NODEMERGE: 1542476
#
# NODEMERGE: 1543476
#
# NODEMERGE: 1544476
#
# NODEMERGE: 1545476
#
# NODEMERGE: 1546476
#
# ...
#
# LINKMERGE: 3065485-413832
#
# LINKMERGE: 3065809-3075157
#
# LINKMERGE: 3066139-3071867
#
# LINKMERGE: 3066468-3032062
#
# LINKMERGE: 3066793-3065805
#
# LINKMERGE: 3067123-3031779
#
# LINKMERGE: 3067452-3034882
#
# LINKMERGE: 3067782-3079585
#
# LINKMERGE: 3068116-417681
#
# LINKMERGE: 3068431-3026677
#
# LINKMERGE: 3068748-3065983
#
# LINKMERGE: 3069088-3011317
#
# LINKMERGE: 3069416-3007747
#
# LINKMERGE: 3069738-3003866
#
# LINKMERGE: 3070068-3062271
#
# LINKMERGE: 3070409-3025588
#
# LINKMERGE: 3070736-3029892
#
# LINKMERGE: 3071076-3093743
#
# LINKMERGE: 3071400-413313
#
# LINKMERGE: 3071732-3093933
#
# LINKMERGE: 3072069-3064981
#
# LINKMERGE: 3072405-3022737
#
# LINKMERGE: 3072748-3074810
#
# LINKMERGE: 3073071-3025497
#
# LINKMERGE: 3073405-3075042
#
# LINKMERGE: 3073733-3039771
#
# LINKMERGE: 3074076-3076903
#
# LINKMERGE: 3074413-3025965
#
# LINKMERGE: 3074751-3017116
#
# LINKMERGE: 3075096-3078067
#
# LINKMERGE: 3075438-410957
#
# LINKMERGE: 3075775-3035445
#
# LINKMERGE: 3076118-3021268
#
# LINKMERGE: 3076471-3006923
#
# LINKMERGE: 3076812-3076638
#
# LINKMERGE: 3077154-3001451
#
# LINKMERGE: 3077494-3001092
#
# LINKMERGE: 3077849-3077841
#
# LINKMERGE: 3078192-3053843
#
# LINKMERGE: 3078556-3032993
#
# LINKMERGE: 3078911-3018669
#
# LINKMERGE: 3079252-3063356
#
# LINKMERGE: 3079598-400634
#
# LINKMERGE: 3079958-3079210
#
# LINKMERGE: 3080326-3047874
#
# LINKMERGE: 3080679-3041400
#
# LINKMERGE: 3081060-3000217
#
# LINKMERGE: 3081739-3005009
#
# LINKMERGE: 3082397-414783
#
# LINKMERGE: 3083046-3014437
#
# LINKMERGE: 3083706-3018934
#
# LINKMERGE: 3084378-417734
#
# LINKMERGE: 3085058-3027587
#
# LINKMERGE: 3085746-3032043
#
# LINKMERGE: 3086429-3018976
#
# LINKMERGE: 3087126-417289
#
# LINKMERGE: 3087804-3044198
#
# LINKMERGE: 3088507-3046235
#
# LINKMERGE: 3089206-3041642
#
# LINKMERGE: 3089904-3055199
#
# LINKMERGE: 3090594-3008952
#
# LINKMERGE: 3091302-411574
#
# LINKMERGE: 3091977-3032639
#
# LINKMERGE: 3092688-3067212
#
# LINKMERGE: 3093416-3011491
#
# LINKMERGE: 3094128-3040163
#
# LINKMERGE: 3094844-3026404
#
# LINKMERGE: 3095558-426160
#
# LINKMERGE: 3096262-3069225
#
# LINKMERGE: 3096989-3061950
#
# LINKMERGE: 3500164-3513301
#
# LINKMERGE: 3500469-3514593
#
# LINKMERGE: 3500775-3515821
#
# LINKMERGE: 3501077-3538941
#
# LINKMERGE: 3501377-3531717
#
# LINKMERGE: 3501677-3521741
#
# LINKMERGE: 3501982-3527087
#
# LINKMERGE: 3502281-3529178
#
# LINKMERGE: 3502592-511474
#
# LINKMERGE: 3502897-3500046
#
# LINKMERGE: 3503193-511380
#
# LINKMERGE: 3503504-3507441
#
# LINKMERGE: 3503802-3504082
#
# LINKMERGE: 3504102-3503699
#
# LINKMERGE: 3504407-3506620
#
# LINKMERGE: 3504706-3503973
#
# LINKMERGE: 3505002-3512448
#
# LINKMERGE: 3505305-3511664
#
# LINKMERGE: 3505602-3533223
#
# LINKMERGE: 3505917-3503765
#
# LINKMERGE: 3506227-3528144
#
# LINKMERGE: 3506531-3536123
#
# LINKMERGE: 3506840-3505254
#
# LINKMERGE: 3507149-3540321
#
# LINKMERGE: 3507455-3500940
#
# LINKMERGE: 3507753-3524920
#
# LINKMERGE: 3508061-3522693
#
# LINKMERGE: 3508375-3528895
#
# LINKMERGE: 3508687-3505020
#
# LINKMERGE: 3508988-3506339
#
# LINKMERGE: 3509302-3511181
#
# LINKMERGE: 3509591-3544636
#
# LINKMERGE: 3509911-3502641
#
# LINKMERGE: 3510218-518402
#
# LINKMERGE: 3510522-3508837
#
# LINKMERGE: 3510837-512734
#
# LINKMERGE: 3511137-3502418
#
# LINKMERGE: 3511455-3538459
#
# LINKMERGE: 3511761-3503539
#
# LINKMERGE: 3512064-3504439
#
# LINKMERGE: 3512362-3542263
#
# LINKMERGE: 3512668-3530449
#
# LINKMERGE: 3512983-514828
#
# LINKMERGE: 3513282-3500914
#
# LINKMERGE: 3513574-3501278
#
# LINKMERGE: 3513884-3518287
#
# LINKMERGE: 3514185-3507788
#
# LINKMERGE: 3514488-3518110
#
# LINKMERGE: 3514789-3503105
#
# LINKMERGE: 3515090-3526749
#
# LINKMERGE: 3515407-3526472
#
# LINKMERGE: 3515709-3500401
#
# LINKMERGE: 3516015-3514185
#
# LINKMERGE: 3516329-514627
#
# LINKMERGE: 3516654-514845
#
# LINKMERGE: 3516972-3507573
#
# LINKMERGE: 3517271-3508642
#
# LINKMERGE: 3517578-3539127
#
# LINKMERGE: 3517883-3538873
#
# LINKMERGE: 3518190-512566
#
# LINKMERGE: 3518502-517373
#
# LINKMERGE: 3518815-3514472
#
# LINKMERGE: 3519123-3507967
#
# LINKMERGE: 3519439-3538871
#
# LINKMERGE: 3519742-3532217
#
# LINKMERGE: 3520053-3520200
#
# LINKMERGE: 3520373-3520678
#
# LINKMERGE: 3520677-3511266
#
# LINKMERGE: 3520990-3542566
#
# LINKMERGE: 3521290-518576
#
# LINKMERGE: 3521601-520256
#
# LINKMERGE: 3521910-3513639
#
# LINKMERGE: 3522221-3507091
#
# LINKMERGE: 3522535-3502508
#
# LINKMERGE: 3522839-3526420
#
# LINKMERGE: 3523159-3546269
#
# LINKMERGE: 3523463-3522365
#
# LINKMERGE: 3523770-3545326
#
# LINKMERGE: 3524084-3509347
#
# LINKMERGE: 3524400-512944
#
# LINKMERGE: 3524703-3527014
#
# LINKMERGE: 3525023-3519636
#
# LINKMERGE: 3525334-3515828
#
# LINKMERGE: 3525643-3508781
#
# LINKMERGE: 3525957-512125
#
# LINKMERGE: 3526270-3520293
#
# LINKMERGE: 3526574-3531888
#
# LINKMERGE: 3526893-3502726
#
# LINKMERGE: 3527219-518047
#
# LINKMERGE: 3527541-3504321
#
# LINKMERGE: 3527853-3508583
#
# LINKMERGE: 3528167-3515199
#
# LINKMERGE: 3528479-3507033
#
# LINKMERGE: 3528788-3528396
#
# LINKMERGE: 3529109-590188
#
# LINKMERGE: 3529427-3500351
#
# LINKMERGE: 3529731-3545083
#
# LINKMERGE: 3530058-3509056
#
# LINKMERGE: 3530377-3529558
#
# LINKMERGE: 3530693-3517219
#
# LINKMERGE: 3531014-3534493
#
# LINKMERGE: 3531333-3534847
#
# LINKMERGE: 3531642-3530303
#
# LINKMERGE: 3531958-513255
#
# LINKMERGE: 3532288-3538491
#
# LINKMERGE: 3532611-3534623
#
# LINKMERGE: 3532931-3503375
#
# LINKMERGE: 3533253-3504063
#
# LINKMERGE: 3533592-3537304
#
# LINKMERGE: 3533918-3535904
#
# LINKMERGE: 3534246-3537852
#
# LINKMERGE: 3534573-3519556
#
# LINKMERGE: 3534896-3511536
#
# LINKMERGE: 3535224-3522723
#
# LINKMERGE: 3535553-511209
#
# LINKMERGE: 3535888-519389
#
# LINKMERGE: 3536220-510058
#
# LINKMERGE: 3536555-3537527
#
# LINKMERGE: 3536888-3527374
#
# LINKMERGE: 3537227-3517044
#
# LINKMERGE: 3537569-3514896
#
# LINKMERGE: 3537896-3512472
#
# LINKMERGE: 3538249-3502976
#
# LINKMERGE: 3538596-3536133
#
# LINKMERGE: 3538941-518349
#
# LINKMERGE: 3539297-3529534
#
# LINKMERGE: 3539930-3504003
#
# LINKMERGE: 3540613-514653
#
# LINKMERGE: 3541294-520143
#
# LINKMERGE: 3541988-3534622
#
# LINKMERGE: 3542689-510373
#
# LINKMERGE: 3543398-513972
#
# LINKMERGE: 3544108-3528736
#
# LINKMERGE: 3544830-3531721
#
# LINKMERGE: 3545602-3514299
#
# LINKMERGE: 3546328-3535417
#
# LINKMERGE: 3547064-516994
#
# LINKMERGE: 4000196-4007143
#
# LINKMERGE: 4000494-4007579
#
# LINKMERGE: 4000786-4000990
#
# LINKMERGE: 4001079-4008080
#
# LINKMERGE: 4001368-4006491
#
# LINKMERGE: 4001665-4006343
#
# LINKMERGE: 4001965-610491
#
# LINKMERGE: 4002262-4001265
#
# LINKMERGE: 4002565-4004850
#
# LINKMERGE: 4002856-4005400
#
# LINKMERGE: 4003145-4006487
#
# LINKMERGE: 4003447-4001916
#
# LINKMERGE: 4003739-4002589
#
# LINKMERGE: 4004037-4010014
#
# LINKMERGE: 4004334-4009575
#
# LINKMERGE: 4004641-4002800
#
# LINKMERGE: 4004936-600078
#
# LINKMERGE: 4005235-4003622
#
# LINKMERGE: 4005538-4006748
#
# LINKMERGE: 4005823-4012097
#
# LINKMERGE: 4006128-4005530
#
# LINKMERGE: 4006427-612461
#
# LINKMERGE: 4006730-4000473
#
# LINKMERGE: 4007028-4004601
#
# LINKMERGE: 4007325-4013262
#
# LINKMERGE: 4007637-4001469
#
# LINKMERGE: 4007943-4009900
#
# LINKMERGE: 4008257-4003384
#
# LINKMERGE: 4008567-4009311
#
# LINKMERGE: 4008883-4013326
#
# LINKMERGE: 4009203-690028
#
# LINKMERGE: 4009515-4001406
#
# LINKMERGE: 4009830-4000637
#
# LINKMERGE: 4010152-4006918
#
# LINKMERGE: 4010488-4005164
#
# LINKMERGE: 4010823-4006090
#
# LINKMERGE: 4011373-611565
#
# LINKMERGE: 4012029-4001928
#
# LINKMERGE: 4012719-4007806
#
# LINKMERGE: 4013428-611627
#
# LINKMERGE: 4500130-4543494
#
# LINKMERGE: 4500426-4540096
#
# LINKMERGE: 4500734-4501437
#
# LINKMERGE: 4501041-4506936
#
# LINKMERGE: 4501346-4503271
#
# LINKMERGE: 4501643-713246
#
# LINKMERGE: 4501950-4521756
#
# LINKMERGE: 4502253-4536892
#
# LINKMERGE: 4502561-4535305
#
# LINKMERGE: 4502856-4514064
#
# LINKMERGE: 4503159-4513265
#
# LINKMERGE: 4503464-4504304
#
# LINKMERGE: 4503768-4533772
#
# LINKMERGE: 4504075-4528001
#
# LINKMERGE: 4504378-4501227
#
# LINKMERGE: 4504685-4518338
#
# LINKMERGE: 4504987-4541473
#
# LINKMERGE: 4505284-4525974
#
# LINKMERGE: 4505580-4535620
#
# LINKMERGE: 4505878-4534554
#
# LINKMERGE: 4506178-4544664
#
# LINKMERGE: 4506488-4534805
#
# LINKMERGE: 4506791-4508997
#
# LINKMERGE: 4507094-4543081
#
# LINKMERGE: 4507407-4550967
#
# LINKMERGE: 4507724-4508048
#
# LINKMERGE: 4508025-4524275
#
# LINKMERGE: 4508326-4524232
#
# LINKMERGE: 4508634-711637
#
# LINKMERGE: 4508936-4508794
#
# LINKMERGE: 4509243-4548021
#
# LINKMERGE: 4509550-4553551
#
# LINKMERGE: 4509852-4537778
#
# LINKMERGE: 4510155-700139
#
# LINKMERGE: 4510455-4550100
#
# LINKMERGE: 4510756-4533786
#
# LINKMERGE: 4511060-700046
#
# LINKMERGE: 4511362-4532410
#
# LINKMERGE: 4511670-4521154
#
# LINKMERGE: 4511973-4529066
#
# LINKMERGE: 4512279-4527615
#
# LINKMERGE: 4512587-4545964
#
# LINKMERGE: 4512887-4510497
#
# LINKMERGE: 4513196-4555031
#
# LINKMERGE: 4513505-4546160
#
# LINKMERGE: 4513810-4542120
#
# LINKMERGE: 4514109-4518954
#
# LINKMERGE: 4514406-4532639
#
# LINKMERGE: 4514717-4554728
#
# LINKMERGE: 4515020-4500343
#
# LINKMERGE: 4515328-4519970
#
# LINKMERGE: 4515623-4519369
#
# LINKMERGE: 4515932-4537722
#
# LINKMERGE: 4516244-4534840
#
# LINKMERGE: 4516553-4532462
#
# LINKMERGE: 4516849-4546925
#
# LINKMERGE: 4517153-717065
#
# LINKMERGE: 4517459-4520473
#
# LINKMERGE: 4517761-719984
#
# LINKMERGE: 4518062-4537203
#
# LINKMERGE: 4518367-4508342
#
# LINKMERGE: 4518676-4503466
#
# LINKMERGE: 4518984-4534775
#
# LINKMERGE: 4519291-4504589
#
# LINKMERGE: 4519600-4520576
#
# LINKMERGE: 4519909-4501314
#
# LINKMERGE: 4520214-4503101
#
# LINKMERGE: 4520517-4517591
#
# LINKMERGE: 4520819-4541982
#
# LINKMERGE: 4521125-4500905
#
# LINKMERGE: 4521432-4535483
#
# LINKMERGE: 4521737-4518062
#
# LINKMERGE: 4522028-4534418
#
# LINKMERGE: 4522330-4505497
#
# LINKMERGE: 4522647-4529987
#
# LINKMERGE: 4522952-4512678
#
# LINKMERGE: 4523257-4529069
#
# LINKMERGE: 4523569-4532105
#
# LINKMERGE: 4523883-4551800
#
# LINKMERGE: 4524197-4505436
#
# LINKMERGE: 4524513-4507881
#
# LINKMERGE: 4524816-4548898
#
# LINKMERGE: 4525123-4507609
#
# LINKMERGE: 4525434-4549064
#
# LINKMERGE: 4525751-4534899
#
# LINKMERGE: 4526062-4511023
#
# LINKMERGE: 4526381-4505442
#
# LINKMERGE: 4526686-4530656
#
# LINKMERGE: 4526999-4505032
#
# LINKMERGE: 4527309-4520035
#
# LINKMERGE: 4527619-4526376
#
# LINKMERGE: 4527938-4501160
#
# LINKMERGE: 4528254-4500778
#
# LINKMERGE: 4528563-4538349
#
# LINKMERGE: 4528877-790123
#
# LINKMERGE: 4529186-4501307
#
# LINKMERGE: 4529502-4513123
#
# LINKMERGE: 4529807-710384
#
# LINKMERGE: 4530117-4518549
#
# LINKMERGE: 4530417-4541616
#
# LINKMERGE: 4530736-4537345
#
# LINKMERGE: 4531051-4522339
#
# LINKMERGE: 4531360-4513607
#
# LINKMERGE: 4531677-710372
#
# LINKMERGE: 4531986-4552463
#
# LINKMERGE: 4532300-4532765
#
# LINKMERGE: 4532619-4520610
#
# LINKMERGE: 4532938-4523238
#
# LINKMERGE: 4533251-4552095
#
# LINKMERGE: 4533563-712591
#
# LINKMERGE: 4533878-4521951
#
# LINKMERGE: 4534206-4526200
#
# LINKMERGE: 4534520-4536720
#
# LINKMERGE: 4534839-4551963
#
# LINKMERGE: 4535156-4553093
#
# LINKMERGE: 4535482-719509
#
# LINKMERGE: 4535800-4503792
#
# LINKMERGE: 4536115-4533360
#
# LINKMERGE: 4536428-4520469
#
# LINKMERGE: 4536740-4552710
#
# LINKMERGE: 4537058-4528806
#
# LINKMERGE: 4537373-4540491
#
# LINKMERGE: 4537703-4502836
#
# LINKMERGE: 4538019-4508844
#
# LINKMERGE: 4538346-4515083
#
# LINKMERGE: 4538683-4500143
#
# LINKMERGE: 4539018-4509201
#
# LINKMERGE: 4539333-4530404
#
# LINKMERGE: 4539649-4523150
#
# LINKMERGE: 4539983-4541791
#
# LINKMERGE: 4540312-4554549
#
# LINKMERGE: 4540649-4505795
#
# LINKMERGE: 4540991-790001
#
# LINKMERGE: 4541325-716493
#
# LINKMERGE: 4541669-4533430
#
# LINKMERGE: 4542010-4507325
#
# LINKMERGE: 4542355-4522153
#
# LINKMERGE: 4542696-4517715
#
# LINKMERGE: 4543054-4526184
#
# LINKMERGE: 4543391-4514550
#
# LINKMERGE: 4544029-4502808
#
# LINKMERGE: 4544741-718461
#
# LINKMERGE: 4545476-4504714
#
# LINKMERGE: 4546203-4513718
#
# LINKMERGE: 4546930-4516868
#
# LINKMERGE: 4547671-4519964
#
# LINKMERGE: 4548409-4518408
#
# LINKMERGE: 4549179-4525823
#
# LINKMERGE: 4549923-719265
#
# LINKMERGE: 4550659-4522825
#
# LINKMERGE: 4551415-4506726
#
# LINKMERGE: 4552161-4535332
#
# LINKMERGE: 4552905-4533807
#
# LINKMERGE: 4553668-4535249
#
# LINKMERGE: 4554438-715546
#
# LINKMERGE: 4555201-4518814
#
# LINKMERGE: 4555996-4506539
#
# LINKMERGE: 5000248-5009282
#
# LINKMERGE: 5000560-5026354
#
# LINKMERGE: 5000868-5004979
#
# LINKMERGE: 5001179-5013595
#
# LINKMERGE: 5001478-813555
#
# LINKMERGE: 5001790-5009763
#
# LINKMERGE: 5002101-5014605
#
# LINKMERGE: 5002405-5006718
#
# LINKMERGE: 5002712-5014612
#
# LINKMERGE: 5003032-5018275
#
# LINKMERGE: 5003343-5021821
#
# LINKMERGE: 5003660-5001463
#
# LINKMERGE: 5003968-5019149
#
# LINKMERGE: 5004276-5003876
#
# LINKMERGE: 5004593-5012688
#
# LINKMERGE: 5004894-5006615
#
# LINKMERGE: 5005206-5011617
#
# LINKMERGE: 5005522-5016320
#
# LINKMERGE: 5005835-5014989
#
# LINKMERGE: 5006147-5016823
#
# LINKMERGE: 5006457-5017409
#
# LINKMERGE: 5006772-811180
#
# LINKMERGE: 5007073-5000247
#
# LINKMERGE: 5007379-5022568
#
# LINKMERGE: 5007688-5018897
#
# LINKMERGE: 5008003-5019751
#
# LINKMERGE: 5008314-5013142
#
# LINKMERGE: 5008619-5022814
#
# LINKMERGE: 5008935-811090
#
# LINKMERGE: 5009253-812896
#
# LINKMERGE: 5009567-5001519
#
# LINKMERGE: 5009884-5014157
#
# LINKMERGE: 5010188-5003936
#
# LINKMERGE: 5010497-5016317
#
# LINKMERGE: 5010816-5018520
#
# LINKMERGE: 5011133-5004698
#
# LINKMERGE: 5011460-890264
#
# LINKMERGE: 5011774-811899
#
# LINKMERGE: 5012086-5006971
#
# LINKMERGE: 5012405-5017560
#
# LINKMERGE: 5012725-5004407
#
# LINKMERGE: 5013045-5011203
#
# LINKMERGE: 5013367-5003228
#
# LINKMERGE: 5013695-5008542
#
# LINKMERGE: 5014023-811290
#
# LINKMERGE: 5014334-5007460
#
# LINKMERGE: 5014663-5008249
#
# LINKMERGE: 5014984-5024117
#
# LINKMERGE: 5015303-5012235
#
# LINKMERGE: 5015638-5017092
#
# LINKMERGE: 5015973-5005576
#
# LINKMERGE: 5016300-5015855
#
# LINKMERGE: 5016622-5020561
#
# LINKMERGE: 5016940-813685
#
# LINKMERGE: 5017263-811549
#
# LINKMERGE: 5017590-5004560
#
# LINKMERGE: 5017916-5025098
#
# LINKMERGE: 5018247-5016458
#
# LINKMERGE: 5018589-5011348
#
# LINKMERGE: 5018926-810313
#
# LINKMERGE: 5019261-5005934
#
# LINKMERGE: 5019601-5007031
#
# LINKMERGE: 5019945-5026312
#
# LINKMERGE: 5020283-5015329
#
# LINKMERGE: 5020644-5012293
#
# LINKMERGE: 5020991-5002874
#
# LINKMERGE: 5021438-5004714
#
# LINKMERGE: 5022120-5005001
#
# LINKMERGE: 5022811-5008599
#
# LINKMERGE: 5023506-810217
#
# LINKMERGE: 5024237-5014926
#
# LINKMERGE: 5024963-812044
#
# LINKMERGE: 5025694-5017817
#
# LINKMERGE: 5026451-5017297
#
# LINKMERGE: 6584718-6629522
#
# LINKMERGE: 7035389-2535389
#
# LINKMERGE: 9515359-5015359
#
#
#
# NETWORK  ReturnCode = 0  Elapsed Time = 00:01:45
# VOYAGER  ReturnCode = 0  Elapsed Time = 00:01:45

# %%
# %%capture
# !runtpp make_simple_roadway_network.s
# !runtpp make_complete_marin_network.s
# !runtpp make_simple_transit_network.s
# !runtpp make_highway_ramps_roadway_network.s

# %% [markdown]
# ## As transit line file (for CUBE)

# %%
standard_transit_net = StandardTransit.fromTransitNetwork(v_02_scenario.transit_net, parameters = parameters)
mtc.write_as_cube_lin(standard_transit_net, parameters, outpath = os.path.join(output_dir, "transit.lin"))
# Out:
# 2020-12-23 11:39:16, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-23 11:39:16, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-23 11:39:16, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-23 11:39:16, INFO: Lasso base directory set as: C:/Users/USGS667806/Lasso
# 2020-12-23 11:39:16, INFO: Converting GTFS Standard Properties to MTC's Cube Standard
# 2020-12-23 11:39:16, INFO: Converting GTFS Standard Properties to MTC's Cube Standard

# %% [markdown]
# ## As pickle

# %%
working_scenario_filename = os.path.join(output_dir, 'working_scenario_02.pickle')
pickle.dump(v_02_scenario, open(working_scenario_filename, 'wb'))

# %% [markdown]
# ## As standard network

# %%
model_net.write(path = output_dir, filename = "v02")
