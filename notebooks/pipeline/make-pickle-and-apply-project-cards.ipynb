# %%
import os
import sys
import yaml
from subprocess import Popen
import pickle

import pandas as pd
import geopandas as gpd
import numpy as np

from network_wrangler import RoadwayNetwork
from network_wrangler import TransitNetwork
from network_wrangler import WranglerLogger
from network_wrangler import ProjectCard

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import logging
logger = logging.getLogger("WranglerLogger")
logger.handlers[0].stream = sys.stdout
logger.setLevel(logging.INFO)

# %%
input_dir = os.path.join(os.getcwd(),'../','examples','mtc') # change path to Github
pickle_dir = os.path.join(input_dir, 'network_standard')
output_dir = os.path.join(input_dir, 'network_standard')
card_dir = os.path.join(input_dir, 'project_cards')

# %%
link_file = os.path.join(input_dir, 'link.json')
node_file = os.path.join(input_dir, 'node.geojson')
shape_file = os.path.join(input_dir, 'shape.geojson')

# %%
roadway_net = RoadwayNetwork.read(link_file = link_file, node_file = node_file, shape_file = shape_file)
# Out:
# 2020-09-28 16:43:21, INFO: Reading from following files:
# -C:\Users\USGS667806\network_wrangler\notebook\../examples\mtc\link.json
# -C:\Users\USGS667806\network_wrangler\notebook\../examples\mtc\node.geojson
# -C:\Users\USGS667806\network_wrangler\notebook\../examples\mtc\shape.geojson.
# 2020-09-28 16:43:21, INFO: Reading from following files:
# -C:\Users\USGS667806\network_wrangler\notebook\../examples\mtc\link.json
# -C:\Users\USGS667806\network_wrangler\notebook\../examples\mtc\node.geojson
# -C:\Users\USGS667806\network_wrangler\notebook\../examples\mtc\shape.geojson.
# 2020-09-28 16:46:40, INFO: Read 1639690 links from C:\Users\USGS667806\network_wrangler\notebook\../examples\mtc\link.json
# 2020-09-28 16:46:40, INFO: Read 1639690 links from C:\Users\USGS667806\network_wrangler\notebook\../examples\mtc\link.json
# 2020-09-28 16:46:40, INFO: Read 645282 nodes from C:\Users\USGS667806\network_wrangler\notebook\../examples\mtc\node.geojson
# 2020-09-28 16:46:40, INFO: Read 645282 nodes from C:\Users\USGS667806\network_wrangler\notebook\../examples\mtc\node.geojson
# 2020-09-28 16:46:40, INFO: Read 874890 shapes from C:\Users\USGS667806\network_wrangler\notebook\../examples\mtc\shape.geojson
# 2020-09-28 16:46:40, INFO: Read 874890 shapes from C:\Users\USGS667806\network_wrangler\notebook\../examples\mtc\shape.geojson

# %%
roadway_net.links_df = roadway_net.links_df[roadway_net.links_df['drive_access'] == 1]

# %%
base_scenario = {"road_net": roadway_net}

# %%
working_scenario = Scenario.create_scenario(base_scenario = base_scenario)
# Out:
# 2020-09-28 16:51:54, INFO: Creating Scenario
# 2020-09-28 16:51:54, INFO: Creating Scenario

# %%
working_scenario_filename = os.path.join(output_dir, 'working_scenario_00.pickle')
pickle.dump(working_scenario, open(working_scenario_filename, 'wb'))

# %%
roadway_net_filename = os.path.join(output_dir, 'roadway_network_00.pickle')
pickle.dump(roadway_net, open(roadway_net_filename, 'wb'))

# %%
working_scenario_filename = os.path.join(pickle_dir, 'working_scenario_00.pickle')
v_01_scenario = pickle.load(open(working_scenario_filename, 'rb'))

# %%
card_01_file_name = os.path.join(card_dir, 'year_2015_managed_lane_us101n_segment_02_north_petaluma_to_south_healdsburg.yml')
card = ProjectCard.read(card_01_file_name, validate = False) # search for list of file with yaml

# %%
v_01_scenario.apply_project(card)
# Out:
# 2020-09-28 17:19:16, INFO: Applying Year 2015 Modify HOV Lanes and USE on US-101 NB from North of Petaluma to South of Healdsburg
# 2020-09-28 17:19:16, INFO: Applying Year 2015 Modify HOV Lanes and USE on US-101 NB from North of Petaluma to South of Healdsburg
# 2020-09-28 17:19:16, INFO: Applying Year 2015 Modify HOV Lanes and USE on US-101 NB from North of Petaluma to South of Healdsburg
# 2020-09-28 17:19:16, INFO: Applying Year 2015 Modify HOV Lanes and USE on US-101 NB from North of Petaluma to South of Healdsburg
# 2020-09-28 17:19:16, INFO: Applying Project to Roadway Network: Year 2015 Modify HOV Lanes and USE on US-101 NB from North of Petaluma to South of Healdsburg
# 2020-09-28 17:19:16, INFO: Applying Project to Roadway Network: Year 2015 Modify HOV Lanes and USE on US-101 NB from North of Petaluma to South of Healdsburg

# %%
v_01_scenario.applied_projects
# Out:
# ['Year 2015 Modify HOV Lanes and USE on US-101 NB from North of Petaluma to South of Healdsburg']

# %%
roadway_net_filename = os.path.join(output_dir, 'roadway_network_with_projects.pickle')
pickle.dump(v_01_scenario.road_net, open(roadway_net_filename, 'wb'))

# %%
v_01_scenario.road_net.links_df
# Out:
#                  access            area  bike_access          bridge  \
# 0                   nan             nan         True             nan
# 1                   nan             nan         True             nan
# 2                   nan             nan         True             nan
# 3                   nan             nan         True             nan
# 4                   nan             nan         True             nan
# ...                 ...             ...          ...             ...
# 1637610  ['nan', 'nan']  ['nan', 'nan']        False  ['nan', 'nan']
# 1637613             nan             nan         True             nan
# 1637614             nan             nan         True             nan
# 1637615             nan             nan         True             nan
# 1637616             nan             nan         True             nan
#
#          drive_access                fromIntersectionId             highway  \
# 0                True  505d64eb98f1da8d812a3b3801034308             service
# 1                True  473979c78435732f01ca5a168afb62e0         residential
# 2                True  fc7b575d5d8c961d4a70fca846ae7f80            tertiary
# 3                True  6c60cf34e9dc3e123eefb829fe80c76a         residential
# 4                True  013e1f994fd86c1f226098f8364f7286             service
# ...               ...                               ...                 ...
# 1637610          True  b0dd83b3ce0708cb3226d18749bffb0d  ['trunk', 'trunk']
# 1637613          True  0c54753b3b0f8d97ecabc7499764e575            tertiary
# 1637614          True  0a9a48e970accba2a5212f8d7425277e             service
# 1637615          True  9b6c746de0e1dab9a705fbc1d56bc801             service
# 1637616          True  24308eef488227a8422185d847baf615             service
#
#               lanes              maxspeed  \
# 0               nan                   nan
# 1               nan                   nan
# 2               nan                25 mph
# 3               nan                   nan
# 4               nan                   nan
# ...             ...                   ...
# 1637610  ['2', '2']  ['55 mph', '55 mph']
# 1637613         nan                   nan
# 1637614         nan                   nan
# 1637615         nan                   nan
# 1637616         nan                   nan
#
#                                              name  ...        county  \
# 0                                             nan  ...  Contra Costa
# 1                                  Yolanda Circle  ...  Contra Costa
# 2                                   Molino Avenue  ...         Marin
# 3                                        Mina Way  ...   Santa Clara
# 4                                             nan  ...   Santa Clara
# ...                                           ...  ...           ...
# 1637610  ['Cabrillo Highway', 'Cabrillo Highway']  ...     San Mateo
# 1637613                              Aston Avenue  ...        Sonoma
# 1637614                                       nan  ...       Alameda
# 1637615                                       nan  ...   Santa Clara
# 1637616                                       nan  ...  Contra Costa
#
#              length model_link_id        A        B rail_traveltime rail_only  \
# 0         84.645250       4000000  3000000  3007839             NaN     False
# 1        509.283331       4000001  3000001  3077548             NaN     False
# 2        128.106786       8000000  5000000  5014587             NaN     False
# 3         15.740142       2000000  2000000  2104322             NaN     False
# 4        122.421225       2000001  2000001  2106125             NaN     False
# ...             ...           ...      ...      ...             ...       ...
# 1637610  194.642204       1144180  1525712  1523868             NaN     False
# 1637613  174.646375       7138806  4536665  4515692             NaN     False
# 1637614   31.448143       3321920  2546439  2572336             NaN     False
# 1637615   62.881009       2524819  2111589  2138203             NaN     False
# 1637616   12.171989       4243347  3012183  3054085             NaN     False
#
#                                         locationReferences  \
# 0        [{'sequence': 1, 'point': [-122.3315542, 37.98...
# 1        [{'sequence': 1, 'point': [-121.94477, 37.9533...
# 2        [{'sequence': 1, 'point': [-122.5398278, 37.89...
# 3        [{'sequence': 1, 'point': [-122.031897, 37.267...
# 4        [{'sequence': 1, 'point': [-122.0118628, 37.37...
# ...                                                    ...
# 1637610  [{'sequence': 1, 'point': [-122.4035134, 37.20...
# 1637613  [{'sequence': 1, 'point': [-122.6984225, 38.42...
# 1637614  [{'sequence': 1, 'point': [-121.8895829, 37.69...
# 1637615  [{'sequence': 1, 'point': [-121.8520898, 37.29...
# 1637616  [{'sequence': 1, 'point': [-121.9458459, 38.01...
#
#                                  shape_id  \
# 0        208e093f10a62dcc6646a8efa0bde136
# 1        5fe3056a5583474c0c898983cd6a638b
# 2        38e962038ecf17c6c7394ba88bc3b4c1
# 3        f3558c6d4c7e3d48742ea3755186c20d
# 4        550ef74674d67256659c5ab80d35d7a7
# ...                                   ...
# 1637610  4efe90a8fcd018e39df23d6748e04d23
# 1637613  c1e7e6909d4820269cdb5cd5a7068bcd
# 1637614  1783aa72a5c9c7289c647853a37d7f12
# 1637615  75bbb8e86cfdea477614c27bb3e2e4e0
# 1637616  9acfb0c65ed5c0bca33577d95d3e4634
#
#                                                   geometry
# 0        LINESTRING (-122.33155 37.98120, -122.33200 37...
# 1        LINESTRING (-121.94477 37.95332, -121.94253 37...
# 2        LINESTRING (-122.53983 37.89800, -122.54023 37...
# 3        LINESTRING (-122.03190 37.26739, -122.03206 37...
# 4        LINESTRING (-122.01186 37.37845, -122.01076 37...
# ...                                                    ...
# 1637610  LINESTRING (-122.40351 37.20811, -122.40282 37...
# 1637613  LINESTRING (-122.69842 38.42619, -122.70011 38...
# 1637614  LINESTRING (-121.88958 37.69903, -121.88987 37...
# 1637615  LINESTRING (-121.85209 37.29526, -121.85255 37...
# 1637616  LINESTRING (-121.94585 38.01728, -121.94583 38...
#
# [1015954 rows x 32 columns]

# %%
v_01_scenario.road_net.links_df[v_01_scenario.road_net.links_df.model_link_id == 7000783]
# Out:
#               access            area  bike_access          bridge  \
# 9150  ['nan', 'nan']  ['nan', 'nan']        False  ['nan', 'nan']
#
#       drive_access                fromIntersectionId  \
# 9150          True  44c5845da27c94b7c42fc405040e012a
#
#                        highway  \
# 9150  ['motorway', 'motorway']
#
#                                                   lanes              maxspeed  \
# 9150  {'default': 3, 'timeofday': [{'time': (10800, ...  ['65 mph', '65 mph']
#
#                                         name  ... rail_only  \
# 9150  ['Redwood Highway', 'Redwood Highway']  ...     False
#
#                                      locationReferences  \
# 9150  [{'sequence': 1, 'point': [-122.7128306, 38.34...
#
#                               shape_id  \
# 9150  08cbff319608e9108b3dbc1bb06965f8
#
#                                                geometry managed  \
# 9150  LINESTRING (-122.71283 38.34427, -122.71295 38...       1
#
#                                                ML_lanes segment_id  \
# 9150  {'default': 0, 'timeofday': [{'time': (10800, ...       9994
#
#                                                     USE  ML_access  ML_egress
# 9150  {'default': 2, 'timeofday': [{'time': (10800, ...        all        all
#
# [1 rows x 38 columns]
