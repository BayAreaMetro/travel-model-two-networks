# %% [markdown]
# # This notebook processes SHST extraction data to network standard, and conflates with OSM, TomTom

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import glob
import json
import geojson
from shapely.geometry import Point
import osmnx as ox
import networkx as nx
import fiona

# %%
from methods import extract_osm_link_from_shst_shape
from methods import osm_link_with_shst_info
from methods import add_two_way_osm
from methods import consolidate_osm_way_to_shst_link
from methods import create_node_gdf
from methods import link_df_to_geojson
from methods import point_df_to_geojson
from methods import fill_na
from methods import ox_graph
from methods import identify_dead_end_nodes
from methods import highway_attribute_list_to_value
from methods import read_shst_extract

# %%
pd.options.display.max_columns = None

# %% [markdown]
# # I/O

# %%
data_external_dir = "../../data/external/"
osm_link_file = data_external_dir + "osmnx_extract/link.geojson"
osm_node_file = data_external_dir + "osmnx_extract/node.geojson"
shst_extract_dir = data_external_dir + "sharedstreets_extract/"

# %% [markdown]
# # read OSM data

# %%
# input osm data
print("-------reading osmnx data---------")

osmnx_link_gdf = gpd.read_file(osm_link_file)
osmnx_node_gdf = gpd.read_file(osm_node_file)
    
    
print("-------finished reading osmnx data---------")
# Out:
# -------reading osmnx data---------
# -------finished reading osmnx data---------

# %%
osmnx_link_gdf[(osmnx_link_gdf.u == 4075004794) | (osmnx_link_gdf.v == 4075001784)]
# Out:
#         access area bridge est_width  highway junction  key landuse lanes  \
# 4604480    nan  nan    nan       nan  service      nan    0     nan   nan
# 4604485    nan  nan    nan       nan    track      nan    0     nan   nan
# 4604494    nan  nan    nan       nan    track      nan    0     nan   nan
# 4604499    nan  nan    nan       nan  service      nan    0     nan   nan
# 4605846    nan  nan    nan       nan    track      nan    0     nan   nan
# 4605847    nan  nan    nan       nan    track      nan    0     nan   nan
# 4605848    nan  nan    nan       nan    track      nan    0     nan   nan
#
#          length maxspeed name  oneway      osmid  ref service tunnel  \
# 4604480  36.179      nan  nan   False  405292128  nan     nan    nan
# 4604485  39.105      nan  nan   False  405292130  nan     nan    nan
# 4604494  16.779      nan  nan   False  405292130  nan     nan    nan
# 4604499  52.015      nan  nan   False  405292128  nan     nan    nan
# 4605846  63.956      nan  nan   False  405292129  nan     nan    nan
# 4605847   5.078      nan  nan   False  405292129  nan     nan    nan
# 4605848  15.519      nan  nan   False  405292130  nan     nan    nan
#
#                   u           v width  \
# 4604480  4075001779  4075001784   nan
# 4604485  4075001782  4075001784   nan
# 4604494  4075001786  4075001784   nan
# 4604499  4075001788  4075001784   nan
# 4605846  4075004794  4075004790   nan
# 4605847  4075004794  4075004796   nan
# 4605848  4075004794  4075004797   nan
#
#                                                   geometry
# 4604480  LINESTRING (-122.2364831 37.4187938, -122.2364...
# 4604485  LINESTRING (-122.2369042 37.418976, -122.23649...
# 4604494  LINESTRING (-122.2363597 37.419221, -122.23649...
# 4604499  LINESTRING (-122.2365233 37.4195863, -122.2364...
# 4605846  LINESTRING (-122.2339452 37.4206079, -122.2339...
# 4605847  LINESTRING (-122.2339452 37.4206079, -122.2339...
# 4605848  LINESTRING (-122.2339452 37.4206079, -122.2341...

# %%
osmnx_link_gdf.head(3)
# Out:
#   access area bridge est_width  highway junction  key landuse lanes  length  \
# 0    nan  nan    nan       nan  footway      nan    0     nan   nan  65.712
# 1    nan  nan    nan       nan  footway      nan    0     nan   nan   5.205
# 2    nan  nan    nan       nan  footway      nan    0     nan   nan   5.379
#
#   maxspeed name  oneway      osmid  ref service tunnel           u  \
# 0      nan  nan   False  527154489  nan     nan    nan  5125439488
# 1      nan  nan   False  527154489  nan     nan    nan  5125439488
# 2      nan  nan   False  564139731  nan     nan    nan  5125439488
#
#             v width                                           geometry
# 0  5125439539   nan  LINESTRING (-121.9597182 37.4128493, -121.9590...
# 1  5436098947   nan  LINESTRING (-121.9597182 37.4128493, -121.9597...
# 2  5436093519   nan  LINESTRING (-121.9597182 37.4128493, -121.9596...

# %% [markdown]
# # read SHST extraction output, and process it to standard network

# %%
# %%time
shst_link_gdf = read_shst_extract(shst_extract_dir, "*.out.geojson")
# Out:
# ----------start reading shst extraction data-------------
# reading shst extraction data :  ../../data/external/sharedstreets_extract\mtc_1.out.geojson
# reading shst extraction data :  ../../data/external/sharedstreets_extract\mtc_11.out.geojson
# reading shst extraction data :  ../../data/external/sharedstreets_extract\mtc_2.out.geojson
# reading shst extraction data :  ../../data/external/sharedstreets_extract\mtc_3.out.geojson
# reading shst extraction data :  ../../data/external/sharedstreets_extract\mtc_4.out.geojson
# reading shst extraction data :  ../../data/external/sharedstreets_extract\mtc_5.out.geojson
# reading shst extraction data :  ../../data/external/sharedstreets_extract\mtc_6.out.geojson
# reading shst extraction data :  ../../data/external/sharedstreets_extract\mtc_8.out.geojson
# reading shst extraction data :  ../../data/external/sharedstreets_extract\mtc_9.out.geojson
# reading shst extraction data :  ../../data/external/sharedstreets_extract\mtc_7.out.geojson
# reading shst extraction data :  ../../data/external/sharedstreets_extract\mtc_10.out.geojson
# reading shst extraction data :  ../../data/external/sharedstreets_extract\mtc_12.out.geojson
# reading shst extraction data :  ../../data/external/sharedstreets_extract\mtc_13.out.geojson
# reading shst extraction data :  ../../data/external/sharedstreets_extract\mtc_14.out.geojson
# ----------finished reading shst extraction data-------------
# Wall time: 5min 28s

# %%
print(shst_link_gdf.columns)
# Out:
# Index(['id', 'fromIntersectionId', 'toIntersectionId', 'forwardReferenceId',
#        'backReferenceId', 'roadClass', 'metadata', 'geometry', 'source'],
#       dtype='object')

# %%
shst_link_gdf.head(3)
# Out:
#                                  id                fromIntersectionId  \
# 0  89d807e34d7630c619bbc23a64e1313e  fc62d018be0236d6b9e43536ebc51830
# 1  95451c235af17ca9cde815dfc3f4b6ce  1bf4572e933b7f6d81535ff217053926
# 2  6c28c78ee3ac710cf40194e2cac3730d  fc62d018be0236d6b9e43536ebc51830
#
#                    toIntersectionId                forwardReferenceId  \
# 0  61c9208c38c5d942c222859cb7073e30  1f25555f0c2f4a6c1205f4f0079c818f
# 1  d60ae663adb14804616d2ca06c3ff8fb  89dd7cf0f842c091241b9a139a5e9506
# 2  d60ae663adb14804616d2ca06c3ff8fb  31529c3bf7a3c1a1aa9f76a607762487
#
#                     backReferenceId    roadClass  \
# 0  d0e1dddc808772de514b913b8f6875c7  Residential
# 1  f38e31579534d3a5abb518ef31bb0517  Residential
# 2  80c4235b61bd0fe1b1538b8b36b40958  Residential
#
#                                             metadata  \
# 0  {'gisMetadata': [], 'geometryId': '89d807e34d7...
# 1  {'gisMetadata': [], 'geometryId': '95451c235af...
# 2  {'gisMetadata': [], 'geometryId': '6c28c78ee3a...
#
#                                             geometry  \
# 0  LINESTRING (-121.8172415 38.00969540000001, -1...
# 1  LINESTRING (-121.8171988 38.0083948, -121.8172...
# 2  LINESTRING (-121.8172415 38.00969540000001, -1...
#
#                                               source
# 0  ../../data/external/sharedstreets_extract\mtc_...
# 1  ../../data/external/sharedstreets_extract\mtc_...
# 2  ../../data/external/sharedstreets_extract\mtc_...

# %%
shst_link_gdf.metadata.iloc[0]
# Out:
# {'gisMetadata': [],
#  'geometryId': '89d807e34d7630c619bbc23a64e1313e',
#  'osmMetadata': {'waySections': [{'nodeIds': ['57927258',
#      '2565726730',
#      '57927260',
#      '2565726729',
#      '2450165486',
#      '57825297'],
#     'wayId': '7874755',
#     'roadClass': 'Residential',
#     'oneWay': False,
#     'roundabout': False,
#     'link': False,
#     'name': ''}],
#   'name': 'Macaulay Street'}}

# %%
shst_link_gdf.metadata.iloc[9]
# Out:
# {'gisMetadata': [],
#  'geometryId': 'c78d00321ccbb0f1d4e6ef465d5854d8',
#  'osmMetadata': {'waySections': [{'nodeIds': ['4932441355', '4932505268'],
#     'wayId': '7880774',
#     'roadClass': 'Residential',
#     'oneWay': False,
#     'roundabout': False,
#     'link': False,
#     'name': ''}],
#   'name': 'West 18th Street'}}

# %%
shst_link_gdf[shst_link_gdf.id == "b5a13d71332300baf271a3dde50dd06d"].metadata.iloc[0]
# Out:
# {'gisMetadata': [],
#  'geometryId': 'b5a13d71332300baf271a3dde50dd06d',
#  'osmMetadata': {'waySections': [{'nodeIds': ['4075004794',
#      '4075004797',
#      '4075004795',
#      '4075004793',
#      '4075004791',
#      '4075001786',
#      '4075001784'],
#     'wayId': '405292130',
#     'roadClass': 'Other',
#     'oneWay': False,
#     'roundabout': False,
#     'link': False,
#     'name': ''}],
#   'name': ''}}

# %%
shst_link_gdf[shst_link_gdf.id == "b6f6f29894314a39e1b7069bd4f53d96"].metadata.iloc[0]
# Out:
# {'gisMetadata': [],
#  'geometryId': 'b6f6f29894314a39e1b7069bd4f53d96',
#  'osmMetadata': {'waySections': [{'nodeIds': ['4075001784',
#      '4075001788',
#      '4075004792',
#      '4075004798',
#      '4075004801',
#      '4075004803',
#      '4075004805',
#      '4075004808',
#      '4075004809',
#      '4075004811'],
#     'wayId': '405292128',
#     'roadClass': 'Service',
#     'oneWay': False,
#     'roundabout': False,
#     'link': False,
#     'name': ''},
#    {'nodeIds': ['4075004811',
#      '4075004810',
#      '4075004806',
#      '4075004804',
#      '4075004802',
#      '4075004800',
#      '4075004799',
#      '4075004796',
#      '4075004794'],
#     'wayId': '405292129',
#     'roadClass': 'Other',
#     'oneWay': False,
#     'roundabout': False,
#     'link': False,
#     'name': ''}],
#   'name': ''}}

# %%
# shst geometry file has duplicates, due to the buffer area along polygon boundries
# drop duplicates

print("--------removing duplicated shst extraction data---------")
print("before removing duplicates, shst extraction has geometry # : ", shst_link_gdf.shape[0])

shst_link_non_dup_gdf = shst_link_gdf.drop_duplicates(
    subset = ['id', 'fromIntersectionId', 'toIntersectionId', 'forwardReferenceId', 'backReferenceId'])

print("after removing duplicates, shst extraction has geometry # : ", shst_link_non_dup_gdf.shape[0])
# Out:
# --------removing duplicated shst extraction data---------
# before removing duplicates, shst extraction has geometry # :  1237008
# after removing duplicates, shst extraction has geometry # :  908281

# %%
# %%time

# this step is needed for obtaining OSM data for SHST links

print("-------extracting single osm ways by every shst geometry----------")

shst_link_df_list = []

temp = shst_link_non_dup_gdf.apply(lambda x: extract_osm_link_from_shst_shape(x, shst_link_df_list),
                            axis = 1)

osm_link_df = pd.concat(shst_link_df_list)
# Out:
# -------extracting single osm ways by every shst geometry----------
# Wall time: 32min 18s

# %%
len(shst_link_df_list)
# Out:
# 908281

# %%
osm_link_df
# Out:
#      link              name  \
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 1   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False       Aster Drive
# 1   False       Tulip Drive
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# ..    ...               ...
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False  Polvorosa Avenue
# 1   False      Aurora Drive
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
# 0   False
#
#                                               nodeIds  oneWay    roadClass  \
# 0   [57927258, 2565726730, 57927260, 2565726729, 2...   False  Residential
# 0                              [4932505296, 57825298]   False  Residential
# 0                                [57927258, 57825298]   False  Residential
# 0                                [57825300, 57825302]   False  Residential
# 0                   [2450165485, 351884044, 57825302]   False  Residential
# 0                                [57872518, 57825300]   False  Residential
# 0                                [57825298, 57825300]   False  Residential
# 0                              [57825297, 4932505296]   False  Residential
# 0                            [4932441355, 4932441353]   False      Service
# 0                            [4932441355, 4932505268]   False  Residential
# 0                              [5353257586, 57900090]   False  Residential
# 0                              [4932505268, 57899212]   False  Residential
# 0   [4932505272, 4932505266, 4932505271, 493250527...   False      Service
# 1                            [4932505267, 4932505268]   False      Service
# 0   [57955137, 352689833, 5353257583, 352689851, 3...   False  Residential
# 0                            [4932441353, 4932441352]   False      Service
# 0                [4932441353, 4932441357, 4932441361]   False      Service
# 0                            [4932441362, 4932441361]   False      Service
# 0                              [4932441362, 57899212]   False     Tertiary
# 0                                [57900090, 57887820]   False  Residential
# 0                              [57825304, 2565675352]   False     Tertiary
# 0                            [4932441352, 4932441351]   False      Service
# 0                                [57825302, 57825304]   False  Residential
# 0                    [57818203, 3545721111, 57834407]   False  Residential
# 1   [57834407, 3545721110, 2328668670, 351886273, ...   False  Residential
# 0                [4932441389, 4932441383, 4932441382]   False        Other
# 0                            [4932441386, 4932441371]   False      Service
# 0                            [4932441386, 4932441381]   False      Service
# 0                            [4932441389, 4932441380]   False      Service
# 0                            [4932441381, 4932441380]   False        Other
# ..                                                ...     ...          ...
# 0   [4919411149, 4919411147, 4919411146, 491941114...   False      Service
# 0                            [4919411140, 4919411144]   False      Service
# 0    [4919411143, 4919411142, 4919411141, 4919411140]   False      Service
# 0                            [4919411143, 4919411155]   False      Service
# 0                            [4919411006, 4919411005]   False      Service
# 0   [4919411154, 4919411159, 4919411158, 491941115...   False      Service
# 0                            [4919411144, 4919411143]   False      Service
# 0    [4919411016, 4919411015, 4919411014, 4919411013]   False      Service
# 0                            [4919411003, 4919411005]   False      Service
# 0                            [4919411163, 4919411162]   False      Service
# 0                            [4919411163, 4919411139]   False     Tertiary
# 0                            [4919411130, 4919411163]   False     Tertiary
# 0                            [4919411130, 4919411125]   False      Service
# 0                            [4919411148, 4919411130]   False     Tertiary
# 0    [4919411125, 4919411129, 4919411128, 4919411127]   False      Service
# 0                            [5669673504, 4919411148]   False     Tertiary
# 0                            [4919411148, 4919411149]   False      Service
# 0                            [4919411155, 4919411149]   False      Service
# 0                            [4919411161, 4919411162]   False      Service
# 0                              [4919411166, 53082691]   False     Tertiary
# 1      [53082691, 3123445465, 3123445464, 4919411164]   False     Tertiary
# 0                            [4919411012, 4919411007]   False      Service
# 0   [4919411126, 4919411138, 4919411137, 491941113...   False      Service
# 0   [4919411139, 310887362, 3123445468, 3123445466...   False     Tertiary
# 0    [4919411005, 4919411009, 4919411008, 4919411007]   False      Service
# 0    [4919411124, 4919411123, 4919411122, 4919411131]   False      Service
# 0   [4919411124, 4919411135, 4919411134, 491941113...   False      Service
# 0                            [4919411139, 4919411126]   False      Service
# 0                            [4919411126, 4919411125]   False      Service
# 0                [4919411166, 4918913813, 4918913812]   False      Service
#
#     roundabout      wayId                        geometryId
# 0        False    7874755  89d807e34d7630c619bbc23a64e1313e
# 0        False    7857892  95451c235af17ca9cde815dfc3f4b6ce
# 0        False    7879092  6c28c78ee3ac710cf40194e2cac3730d
# 0        False    7857892  bcf240fee04a590969705fdaeea814ea
# 0        False    7864815  2172fcefdf21e39f6810c4deaf9f89ee
# 0        False  454841378  ca69fa9f3760f10ab6f6fae09fbd4bc1
# 0        False    7857892  2477e97f737bcc11c2ba86d4eeef8ce1
# 0        False    7857892  fee066c4040395bc6b25667e12e073fd
# 0        False  502893079  a4ea005b4d92189d670e4cdfdd5b1e30
# 0        False    7880774  c78d00321ccbb0f1d4e6ef465d5854d8
# 0        False  502902339  2544320fa25c12820ac1bdf9f51e7565
# 0        False    7880774  bd8a14aaefd38391ca8270ebd89b0bdd
# 0        False  502902301  f69f3a63c1cd55f2437e238fbe2bfc5b
# 1        False  502902300  f69f3a63c1cd55f2437e238fbe2bfc5b
# 0        False    7880774  c75362150c899f6105d05993efa4e319
# 0        False  502893078  9c5b4ad2e0cb7d0afd32f85619cab90f
# 0        False  502893080  a39105f937f050006bb837c0568d894f
# 0        False  502893083  cb401dc9080381ab6aa99fe13e5db387
# 0        False  393481409  4e995b41f2c84346db185ed2eba4a0c0
# 0        False  502902339  7005a9cc2c01fcf2c3cba427d55ea5b3
# 0        False  393487978  06860cf4a7b5bdaeeb1326a9d9629196
# 0        False  502893077  814e7f01881a474e328ffba51e9e7558
# 0        False    7857892  283f74c801e7d112fa73f12b480be1fd
# 0        False    7859318  c7fcc9045e8dd7ae34897c45837a0e62
# 1        False    7880243  c7fcc9045e8dd7ae34897c45837a0e62
# 0        False  554568064  faaebb75fcd6476af241ce7a2e797644
# 0        False  502893095  c587910d75455b9710ed2cdb70029484
# 0        False  502893095  b4f6571a2c6f22bcea6b52e2cd42df19
# 0        False  502893097  e9d9d2abb845db0e27737580139d783f
# 0        False  502893092  5806486990038aedc3f5accdb49ec852
# ..         ...        ...                               ...
# 0        False  501037359  6599c930d77f678e7dc844352d37fd31
# 0        False  501037359  a14f93c841e0088eded724688964b205
# 0        False  501037357  7e90b0e4105dd3b7f997c60e206922f8
# 0        False  501037363  cc90af1574b1ced4aa36fd1ae5d55dde
# 0        False  501037338  ebf490c5f56bf7779bed49de62948a1c
# 0        False  501037363  c34f7fe8e6249a878325d8ceeaa79d4c
# 0        False  501037363  ca961659fc060f4ff066c279d7b1dc42
# 0        False  501037344  286a34a4a158599dca68420d851de5e7
# 0        False  501037340  320c5955764da0a16d4a7eeaa92b6ac0
# 0        False  501037367  320c93a80150617b7d9a21d1fda12d3b
# 0        False    6360809  c794d9ffdab922baa9cc5e69469c38cb
# 0        False    6360809  0411442871446f0e8fafe152660c86ec
# 0        False  501037352  51569bf54c49d42e480df9a6994954de
# 0        False    6360809  3bda0fc5fe2fe128a32aa5f1df8f9e89
# 0        False  501037352  bdc3ecc86a836991c2c56926f018351e
# 0        False    6360809  fa0c8c57bf6d4bb1b1c0d326700aaa66
# 0        False  501037359  caf7ccfb8293ab7252225d829c9c3954
# 0        False  501037361  21ccb94e4abdb215c6128953fe7a9c89
# 0        False  501037365  e7fc7a2adb30d7d3249d1af3edc4056b
# 0        False    6360809  d1d2ff3cc75442778a4631d15226082c
# 1        False  307250547  d1d2ff3cc75442778a4631d15226082c
# 0        False  501037342  502b1539d6dfc89268e1e6aa44ebc2cf
# 0        False  501037355  03e7116200d5d8f37e2af054ab21bed9
# 0        False    6360809  d1e582e44af9f5bd118a9748dc8b38f5
# 0        False  501037340  d11bdf5b7a35aa1875be35161e03c170
# 0        False  501037348  478b214c24fe04c4bd8140ca4d362bb5
# 0        False  501037355  71b91ed17546f238dd2f3634149d7e92
# 0        False  501037355  c9040be5b4952b2cfe6f44445c1a3180
# 0        False  501037350  0af0522a64f003526c57aeeeb102fe0b
# 0        False  500970080  441d8d0eaec8cde88fe1ab6a1442197c
#
# [974897 rows x 8 columns]

# %%
osm_link_df[osm_link_df.geometryId.isin(["b5a13d71332300baf271a3dde50dd06d",
                                   "b6f6f29894314a39e1b7069bd4f53d96"])]
# Out:
#     link name                                            nodeIds  oneWay  \
# 0  False       [4075001784, 4075001788, 4075004792, 407500479...   False
# 1  False       [4075004811, 4075004810, 4075004806, 407500480...   False
# 0  False       [4075004794, 4075004797, 4075004795, 407500479...   False
#
#   roadClass  roundabout      wayId                        geometryId
# 0   Service       False  405292128  b6f6f29894314a39e1b7069bd4f53d96
# 1     Other       False  405292129  b6f6f29894314a39e1b7069bd4f53d96
# 0     Other       False  405292130  b5a13d71332300baf271a3dde50dd06d

# %%
osm_link_gdf = osm_link_with_shst_info(osm_link_df,
                                      shst_link_non_dup_gdf)

# %%
osm_link_gdf[osm_link_gdf.geometryId == "959d4c59605650229d66d14423d971d0"]
# Out:
#          link name                   nodeIds  oneWay roadClass  roundabout  \
# 483384  False       [1750865944, 5991260810]   False  Tertiary       False
# 483385  False       [5991260810, 4177955847]   False  Tertiary       False
#
#             wayId                        geometryId  \
# 483384  417198045  959d4c59605650229d66d14423d971d0
# 483385  635006789  959d4c59605650229d66d14423d971d0
#
#                                       id                fromIntersectionId  \
# 483384  959d4c59605650229d66d14423d971d0  1c03d41f12ec25a8d6667c30302c9eb5
# 483385  959d4c59605650229d66d14423d971d0  1c03d41f12ec25a8d6667c30302c9eb5
#
#                         toIntersectionId                forwardReferenceId  \
# 483384  f9f6b56abd6f30436d529bfcb8d68f4d  74f674b6d6ee32ef61d99d0cdb6afa56
# 483385  f9f6b56abd6f30436d529bfcb8d68f4d  74f674b6d6ee32ef61d99d0cdb6afa56
#
#                          backReferenceId  \
# 483384  043ac564db0dd88710d588714f68fcba
# 483385  043ac564db0dd88710d588714f68fcba
#
#                                                  geometry
# 483384  LINESTRING (-122.1450835 37.4116109, -122.1451...
# 483385  LINESTRING (-122.1450835 37.4116109, -122.1451...

# %%
osmnx_link_gdf[osmnx_link_gdf.osmid == 635006789]
# Out:
#         access area bridge est_width   highway junction  key landuse lanes  \
# 190377     nan  nan    nan       nan  tertiary      nan    0     nan   nan
# 190378     nan  nan    nan       nan  tertiary      nan    0     nan   nan
# 639047     nan  nan    nan       nan  tertiary      nan    0     nan   nan
# 1209463    nan  nan    nan       nan  tertiary      nan    0     nan   nan
# 3328098    nan  nan    nan       nan  tertiary      nan    0     nan   nan
#
#          length maxspeed            name  oneway      osmid  ref service  \
# 190377    4.637   30 mph  Hanover Street    True  635006789  nan     nan
# 190378   60.788   30 mph  Hanover Street    True  635006789  nan     nan
# 639047    5.853   30 mph  Hanover Street    True  635006789  nan     nan
# 1209463   3.737   30 mph  Hanover Street    True  635006789  nan     nan
# 3328098   2.434   30 mph  Hanover Street    True  635006789  nan     nan
#
#         tunnel           u           v width  \
# 190377     nan  7055083815  4177955847   nan
# 190378     nan  7055083816  6732375482   nan
# 639047     nan  6208518527  7055083815   nan
# 1209463    nan  5991260810  7055083816   nan
# 3328098    nan  6732375482  6208518527   nan
#
#                                                   geometry
# 190377   LINESTRING (-122.1457079 37.4109288, -122.1457...
# 190378   LINESTRING (-122.1452791 37.4114483, -122.1456...
# 639047   LINESTRING (-122.1456725 37.4109733, -122.1457...
# 1209463  LINESTRING (-122.1452373 37.4114535, -122.1452...
# 3328098  LINESTRING (-122.145657 37.4109914, -122.14567...

# %%
osm_link_df[osm_link_df.wayId == "635006789"]
# Out:
#     link name                   nodeIds  oneWay roadClass  roundabout  \
# 1  False       [5991260810, 4177955847]   False  Tertiary       False
#
#        wayId                        geometryId
# 1  635006789  959d4c59605650229d66d14423d971d0

# %%
osm_link_gdf[osm_link_gdf.geometryId.isin(["b5a13d71332300baf271a3dde50dd06d",
                                   "b6f6f29894314a39e1b7069bd4f53d96"])]
# Out:
#          link name                                            nodeIds  oneWay  \
# 516313  False       [4075001784, 4075001788, 4075004792, 407500479...   False
# 516314  False       [4075004811, 4075004810, 4075004806, 407500480...   False
# 516317  False       [4075004794, 4075004797, 4075004795, 407500479...   False
#
#        roadClass  roundabout      wayId                        geometryId  \
# 516313   Service       False  405292128  b6f6f29894314a39e1b7069bd4f53d96
# 516314     Other       False  405292129  b6f6f29894314a39e1b7069bd4f53d96
# 516317     Other       False  405292130  b5a13d71332300baf271a3dde50dd06d
#
#                                       id                fromIntersectionId  \
# 516313  b6f6f29894314a39e1b7069bd4f53d96  7da9cd62c681f3425ba9b2e28d702fc9
# 516314  b6f6f29894314a39e1b7069bd4f53d96  7da9cd62c681f3425ba9b2e28d702fc9
# 516317  b5a13d71332300baf271a3dde50dd06d  f407efc156163c556b516200a966187e
#
#                         toIntersectionId                forwardReferenceId  \
# 516313  f407efc156163c556b516200a966187e  3a4ecbf4a5e97c0d71a89db621957a79
# 516314  f407efc156163c556b516200a966187e  3a4ecbf4a5e97c0d71a89db621957a79
# 516317  7da9cd62c681f3425ba9b2e28d702fc9  6233a20ff0d9dc29be597a06ffd19727
#
#                          backReferenceId  \
# 516313  4715d32ebbf18e592af26b06ce167ac0
# 516314  4715d32ebbf18e592af26b06ce167ac0
# 516317  239f1586cff1f2116ad5e26df9375927
#
#                                                  geometry
# 516313  LINESTRING (-122.2364996 37.4191189, -122.2365...
# 516314  LINESTRING (-122.2364996 37.4191189, -122.2365...
# 516317  LINESTRING (-122.2339452 37.4206079, -122.2341...

# %%
# note, the sharedstreets extraction using default tile osm/planet 181224

# 1. join SHST with OSM
# 2. add two way links

osm_link_gdf = osm_link_with_shst_info(osm_link_df,
                                      shst_link_non_dup_gdf)

osm_link_gdf = add_two_way_osm(osm_link_gdf,osmnx_link_gdf)
# Out:
# shst extraction has geometry:  908281
# osm links from shst extraction:  974897
# ---joining osm shst with osmnx data---
# which includes two way links: 843159
# and they are geometrys:  798093
# after join, osm links from shst extraction:  1818056  out of which there are  151836  links that do not have osm info, due to shst extraction (default tile 181224) contains  42539  osm ids that are not included in latest OSM extraction, e.g. private streets, closed streets.
# after join, there are shst geometry # :  1706374

# %%
osm_link_gdf[osm_link_gdf.shstGeometryId == "959d4c59605650229d66d14423d971d0"]
# Out:
#           link                   nodeIds  oneWay roadClass  roundabout  \
# 483384   False  [1750865944, 5991260810]   False  Tertiary       False
# 483385   False  [5991260810, 4177955847]   False  Tertiary       False
# 1396831  False  [1750865944, 5991260810]   False  Tertiary       False
# 1396832  False  [5991260810, 4177955847]   False  Tertiary       False
#
#              wayId                    shstGeometryId  \
# 483384   417198045  959d4c59605650229d66d14423d971d0
# 483385   635006789  959d4c59605650229d66d14423d971d0
# 1396831  417198045  959d4c59605650229d66d14423d971d0
# 1396832  635006789  959d4c59605650229d66d14423d971d0
#
#                                        id                fromIntersectionId  \
# 483384   959d4c59605650229d66d14423d971d0  1c03d41f12ec25a8d6667c30302c9eb5
# 483385   959d4c59605650229d66d14423d971d0  1c03d41f12ec25a8d6667c30302c9eb5
# 1396831  959d4c59605650229d66d14423d971d0  f9f6b56abd6f30436d529bfcb8d68f4d
# 1396832  959d4c59605650229d66d14423d971d0  f9f6b56abd6f30436d529bfcb8d68f4d
#
#                          toIntersectionId                   shstReferenceId  \
# 483384   f9f6b56abd6f30436d529bfcb8d68f4d  74f674b6d6ee32ef61d99d0cdb6afa56
# 483385   f9f6b56abd6f30436d529bfcb8d68f4d  74f674b6d6ee32ef61d99d0cdb6afa56
# 1396831  1c03d41f12ec25a8d6667c30302c9eb5  043ac564db0dd88710d588714f68fcba
# 1396832  1c03d41f12ec25a8d6667c30302c9eb5  043ac564db0dd88710d588714f68fcba
#
#                                                   geometry           u  \
# 483384   LINESTRING (-122.1450835 37.4116109, -122.1451...  1750865944
# 483385   LINESTRING (-122.1450835 37.4116109, -122.1451...  5991260810
# 1396831  LINESTRING (-122.1450835 37.4116109, -122.1451...  5991260810
# 1396832  LINESTRING (-122.1450835 37.4116109, -122.1451...  4177955847
#
#                   v access area bridge est_width   highway junction  key  \
# 483384   5991260810    NaN  NaN    NaN       NaN       NaN      NaN  NaN
# 483385   4177955847    nan  nan    nan       nan  tertiary      nan  0.0
# 1396831  1750865944    NaN  NaN    NaN       NaN       NaN      NaN  NaN
# 1396832  5991260810    nan  nan    nan       nan  tertiary      nan  0.0
#
#         landuse lanes maxspeed            name oneway        osmid  ref  \
# 483384      NaN   NaN      NaN             NaN    NaN          NaN  NaN
# 483385      nan   nan   30 mph  Hanover Street   True  635006789.0  nan
# 1396831     NaN   NaN      NaN             NaN    NaN          NaN  NaN
# 1396832     nan   nan   30 mph  Hanover Street   True  635006789.0  nan
#
#         service tunnel width  reverse_out
# 483384      NaN    NaN   NaN          NaN
# 483385      nan    nan   nan          NaN
# 1396831     NaN    NaN   NaN          1.0
# 1396832     nan    nan   nan          1.0

# %%
# fill NAs
# for shst links that do not have complete osm info 

osm_link_non_na_gdf = fill_na(osm_link_gdf)
# Out:
# numeric columns:  ['wayId', 'u', 'v', 'key', 'osmid', 'reverse_out']
# str columns:  ['nodeIds', 'roadClass', 'shstGeometryId', 'id', 'fromIntersectionId', 'toIntersectionId', 'shstReferenceId', 'geometry', 'access', 'area', 'bridge', 'est_width', 'highway', 'junction', 'landuse', 'lanes', 'maxspeed', 'name', 'oneway', 'ref', 'service', 'tunnel', 'width']

# %%
# %%time

# aggregate osm data back to shst geometry based links

link_gdf = consolidate_osm_way_to_shst_link(osm_link_non_na_gdf)

print("after joining back to shst geometry, network has ", len(link_gdf), " links, which are based on ", 
      link_gdf.shstGeometryId.nunique(), " geometries")
# Out:
# -----start aggregating osm segments to one shst link for forward links----------
# -----start aggregating osm segments to one shst link for backward links----------
# all
# after joining back to shst geometry, network has  1706374  links, which are based on  908281  geometries
# Wall time: 15min 2s

# %%
# simplify highway
highway_to_roadway_df = pd.read_csv("../../data/interim/highway_to_roadway.csv").fillna("")

highway_to_roadway_dict = pd.Series(highway_to_roadway_df.roadway.values, 
                                    index = highway_to_roadway_df.highway).to_dict()

roadway_hierarchy_dict = pd.Series(highway_to_roadway_df.hierarchy.values, 
                                   index = highway_to_roadway_df.roadway).to_dict()
    
link_gdf["roadway"] = link_gdf.apply(lambda x: highway_attribute_list_to_value(x, 
                                                                              highway_to_roadway_dict,
                                                                              roadway_hierarchy_dict),
                                    axis = 1)

# %%
print(link_gdf.roadway.value_counts())
print(link_gdf[link_gdf.highway == ""].roadway.value_counts())
# Out:
# service           567900
# residential       558684
# footway           251136
# cycleway          118781
# tertiary           95320
# secondary          69775
# primary            27601
# motorway_link       4988
# trunk               4249
# motorway            2871
# secondary_link      1567
# primary_link        1506
# trunk_link          1384
# tertiary_link        612
# Name: roadway, dtype: int64
# cycleway       56190
# service        38015
# residential    32902
# tertiary        3463
# secondary       2628
# primary         1426
# motorway         135
# trunk            118
# Name: roadway, dtype: int64

# %%
link_gdf.roadway.value_counts()
# Out:
# service           567900
# residential       558684
# footway           251136
# cycleway          118781
# tertiary           95320
# secondary          69775
# primary            27601
# motorway_link       4988
# trunk               4249
# motorway            2871
# secondary_link      1567
# primary_link        1506
# trunk_link          1384
# tertiary_link        612
# Name: roadway, dtype: int64

# %%
# there are links with different shstgeomid, but same shstrefid, to/from nodes

shst_refid_counts_df = pd.DataFrame(link_gdf.shstReferenceId.value_counts())
shst_refid_counts_df = shst_refid_counts_df[shst_refid_counts_df.shstReferenceId == 2]

links_with_diff_geomid_same_refid_df = link_gdf[link_gdf.shstReferenceId.isin(shst_refid_counts_df.index.values)]

links_with_diff_geomid_same_refid_df.sort_values(by = ["shstReferenceId"])

links_with_diff_geomid_same_refid_df.highway.value_counts()

links_with_diff_geomid_same_refid_df[links_with_diff_geomid_same_refid_df.highway == "tertiary"].sort_values(by = ["shstReferenceId"])

links_with_diff_geomid_same_refid_df[links_with_diff_geomid_same_refid_df.shstReferenceId == "18b6ce8eeb59e96413ede8e115ac2aa1"]

links_with_diff_geomid_same_refid_df.groupby("shstReferenceId")['roadway'].apply(list).value_counts()

# drop one of the links that have two shstGeomId

link_gdf.drop_duplicates(subset = ["shstReferenceId"],
                        inplace = True)

link_gdf.shape
# Out:
# (1705772, 32)

# %%
print("In the end, network has ", len(link_gdf), " links, which are based on ", 
      link_gdf.shstGeometryId.nunique(), " geometries")
# Out:
# In the end, network has  1705772  links, which are based on  908267  geometries

# %%
# add network type variables

network_type_df = pd.read_csv("../../data/interim/network_type_indicator.csv")

link_gdf = pd.merge(link_gdf,
                    network_type_df,
                    how = "left",
                    on = "roadway")

# %%
# %%time

# create node gdf

node_gdf = create_node_gdf(link_gdf)

print("In the end, network has ", len(node_gdf), " nodes")
# Out:
# -------start creating shst nodes--------
# In the end, network has  661159  nodes
# Wall time: 1min 43s

# %%
# add network type variable for node

A_B_df = pd.concat([link_gdf[["u", "drive_access", "walk_access", "bike_access"]].rename(columns = {"u":"osm_node_id"}),
                  link_gdf[["v", "drive_access", "walk_access", "bike_access"]].rename(columns = {"v":"osm_node_id"})],
                  sort = False,
                  ignore_index = True)

A_B_df.drop_duplicates(inplace = True)

A_B_df = A_B_df.groupby("osm_node_id").max().reset_index()

node_gdf = pd.merge(node_gdf,
                      A_B_df,
                      how = "left",
                      on = "osm_node_id")

# %%
osm_link_gdf[osm_link_gdf.shstGeometryId == "959d4c59605650229d66d14423d971d0"]
# Out:
#           link                   nodeIds  oneWay roadClass  roundabout  \
# 483384   False  [1750865944, 5991260810]   False  Tertiary       False
# 483385   False  [5991260810, 4177955847]   False  Tertiary       False
# 1396831  False  [1750865944, 5991260810]   False  Tertiary       False
# 1396832  False  [5991260810, 4177955847]   False  Tertiary       False
#
#              wayId                    shstGeometryId  \
# 483384   417198045  959d4c59605650229d66d14423d971d0
# 483385   635006789  959d4c59605650229d66d14423d971d0
# 1396831  417198045  959d4c59605650229d66d14423d971d0
# 1396832  635006789  959d4c59605650229d66d14423d971d0
#
#                                        id                fromIntersectionId  \
# 483384   959d4c59605650229d66d14423d971d0  1c03d41f12ec25a8d6667c30302c9eb5
# 483385   959d4c59605650229d66d14423d971d0  1c03d41f12ec25a8d6667c30302c9eb5
# 1396831  959d4c59605650229d66d14423d971d0  f9f6b56abd6f30436d529bfcb8d68f4d
# 1396832  959d4c59605650229d66d14423d971d0  f9f6b56abd6f30436d529bfcb8d68f4d
#
#                          toIntersectionId                   shstReferenceId  \
# 483384   f9f6b56abd6f30436d529bfcb8d68f4d  74f674b6d6ee32ef61d99d0cdb6afa56
# 483385   f9f6b56abd6f30436d529bfcb8d68f4d  74f674b6d6ee32ef61d99d0cdb6afa56
# 1396831  1c03d41f12ec25a8d6667c30302c9eb5  043ac564db0dd88710d588714f68fcba
# 1396832  1c03d41f12ec25a8d6667c30302c9eb5  043ac564db0dd88710d588714f68fcba
#
#                                                   geometry           u  \
# 483384   LINESTRING (-122.1450835 37.4116109, -122.1451...  1750865944
# 483385   LINESTRING (-122.1450835 37.4116109, -122.1451...  5991260810
# 1396831  LINESTRING (-122.1450835 37.4116109, -122.1451...  5991260810
# 1396832  LINESTRING (-122.1450835 37.4116109, -122.1451...  4177955847
#
#                   v access area bridge est_width   highway junction  key  \
# 483384   5991260810    NaN  NaN    NaN       NaN       NaN      NaN  NaN
# 483385   4177955847    nan  nan    nan       nan  tertiary      nan  0.0
# 1396831  1750865944    NaN  NaN    NaN       NaN       NaN      NaN  NaN
# 1396832  5991260810    nan  nan    nan       nan  tertiary      nan  0.0
#
#         landuse lanes maxspeed            name oneway        osmid  ref  \
# 483384      NaN   NaN      NaN             NaN    NaN          NaN  NaN
# 483385      nan   nan   30 mph  Hanover Street   True  635006789.0  nan
# 1396831     NaN   NaN      NaN             NaN    NaN          NaN  NaN
# 1396832     nan   nan   30 mph  Hanover Street   True  635006789.0  nan
#
#         service tunnel width  reverse_out
# 483384      NaN    NaN   NaN          NaN
# 483385      nan    nan   nan          NaN
# 1396831     NaN    NaN   NaN          1.0
# 1396832     nan    nan   nan          1.0

# %%
link_gdf[link_gdf.shstGeometryId == "959d4c59605650229d66d14423d971d0"]
# Out:
#                          shstReferenceId                                id  \
# 415003  74f674b6d6ee32ef61d99d0cdb6afa56  959d4c59605650229d66d14423d971d0
# 921376  043ac564db0dd88710d588714f68fcba  959d4c59605650229d66d14423d971d0
#
#                           shstGeometryId                fromIntersectionId  \
# 415003  959d4c59605650229d66d14423d971d0  1c03d41f12ec25a8d6667c30302c9eb5
# 921376  959d4c59605650229d66d14423d971d0  f9f6b56abd6f30436d529bfcb8d68f4d
#
#                         toIntersectionId  \
# 415003  f9f6b56abd6f30436d529bfcb8d68f4d
# 921376  1c03d41f12ec25a8d6667c30302c9eb5
#
#                                                  geometry           u  \
# 415003  LINESTRING (-122.1450835 37.4116109, -122.1451...  1750865944
# 921376  LINESTRING (-122.1450835 37.4116109, -122.1451...  4177955847
#
#                  v            link  \
# 415003  4177955847  [False, False]
# 921376  1750865944  [False, False]
#
#                                                   nodeIds          oneWay  \
# 415003  [[1750865944, 5991260810], [5991260810, 417795...  [False, False]
# 921376  [[1750865944, 5991260810], [5991260810, 417795...  [False, False]
#
#                    roadClass      roundabout                   wayId   access  \
# 415003  [Tertiary, Tertiary]  [False, False]  [417198045, 635006789]  [, nan]
# 921376  [Tertiary, Tertiary]  [False, False]  [417198045, 635006789]  [, nan]
#
#            area   bridge est_width       highway junction         key  \
# 415003  [, nan]  [, nan]   [, nan]  [, tertiary]  [, nan]  [0.0, 0.0]
# 921376  [, nan]  [, nan]   [, nan]  [, tertiary]  [, nan]  [0.0, 0.0]
#
#         landuse    lanes    maxspeed                name    oneway      ref  \
# 415003  [, nan]  [, nan]  [, 30 mph]  [, Hanover Street]  [, True]  [, nan]
# 921376  [, nan]  [, nan]  [, 30 mph]  [, Hanover Street]  [, True]  [, nan]
#
#         service   tunnel    width  forward   roadway  drive_access  \
# 415003  [, nan]  [, nan]  [, nan]      1.0  tertiary             1
# 921376  [, nan]  [, nan]  [, nan]      NaN  tertiary             1
#
#         walk_access  bike_access
# 415003            1            1
# 921376            1            1

# %%
node_gdf.osm_node_id.nunique()
# Out:
# 661159

# %%
len(set(link_gdf.u.tolist() + link_gdf.v.tolist()))
# Out:
# 661159

# %%
link_gdf[~link_gdf.v.isin(node_gdf.osm_node_id.tolist())]
# Out:
# Empty GeoDataFrame
# Columns: [shstReferenceId, id, shstGeometryId, fromIntersectionId, toIntersectionId, geometry, u, v, link, nodeIds, oneWay, roadClass, roundabout, wayId, access, area, bridge, est_width, highway, junction, key, landuse, lanes, maxspeed, name, oneway, ref, service, tunnel, width, forward, roadway, drive_access, walk_access, bike_access]
# Index: []

# %%
print(shst_link_non_dup_gdf.columns)
print(shst_link_non_dup_gdf.shape)
print(shst_link_non_dup_gdf.id.nunique())
# Out:
# Index(['id', 'fromIntersectionId', 'toIntersectionId', 'forwardReferenceId',
#        'backReferenceId', 'roadClass', 'metadata', 'geometry', 'source'],
#       dtype='object')
# (908281, 9)
# 908281

# %%
shape_gdf = shst_link_non_dup_gdf[shst_link_non_dup_gdf.id.isin(link_gdf.shstGeometryId.tolist())].copy()
print(" In the end, there are " + str(len(shape_gdf)) + " geometries.")
# Out:
#  In the end, there are 908267 geometries.

# %%
# %%time

print("-------write out link shape geojson---------")

shape_prop = ['id', 'fromIntersectionId', 'toIntersectionId', 'forwardReferenceId', 'backReferenceId']
shape_geojson = link_df_to_geojson(shape_gdf, shape_prop)

with open("../../data/interim/step3_join_shst_extraction_with_osm/shape.geojson", "w") as f:
    json.dump(shape_geojson, f)
# Out:
# -------write out link shape geojson---------
# Wall time: 5min 23s

# %%
# %%time

# write out link variable json
# link unique handle "shstReferenceId" + "shstGeometryId"

print("-------write out link json---------")
#["id", "link", "nodeIds", "roadClass", "forward", "oneway"]
link_prop = link_gdf.drop(["geometry", "nodeIds", "forward", "roadClass", "oneway"], 
                          axis = 1).columns.tolist()

out = link_gdf[link_prop].to_json(orient = "records")

with open('../../data/interim/step3_join_shst_extraction_with_osm/link.json', 'w') as f:
    f.write(out)
# Out:
# -------write out link json---------
# Wall time: 36.7 s

# %%
link_gdf.drive_access.value_counts()
# Out:
# 1    1336384
# 0     369388
# Name: drive_access, dtype: int64

# %%
link_gdf.drive_access.value_counts()
# Out:
# 1    1336380
# 0     369392
# Name: drive_access, dtype: int64

# %%
# %%time

print("-------write out node geojson---------")

node_prop = node_gdf.drop("geometry", axis = 1).columns.tolist()
node_geojson = point_df_to_geojson(node_gdf, node_prop)

with open("../../data/interim/step3_join_shst_extraction_with_osm/node.geojson", "w") as f:
    json.dump(node_geojson, f)
# Out:
# -------write out node geojson---------
# Wall time: 2min 48s
