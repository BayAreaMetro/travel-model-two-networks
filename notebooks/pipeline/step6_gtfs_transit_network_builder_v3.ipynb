# %% [markdown]
# # This notebook goes through building transit network from gtfs to network standard
#
# 1. extract represetative trips
# 2. snap stops to roadway nodes
# 3. route bus on roadway via osmnx routing
# 4. route bus on roadway via shst routing
# 5. build non-bus/rail links and nodes
# 6. complete network node list that each transit path traverses
# 7. frequence based stop time
# 8. write out to transit network standard
# 9. write out quick QA/QC transit route true shape
# 10. write out network standard with rail nodes and links
# 11. write out travel model transit network

# %%
import partridge as ptg
import peartree as pt
#%matplotlib inline
import requests
from urllib.request import urlopen
from zipfile import ZipFile
from io import BytesIO
import pandas as pd
import numpy as np
import geopandas as gpd
from shapely.geometry import Point, LineString
import networkx as nx
from shapely import wkt
from scipy.spatial import cKDTree
import osmnx as ox
from dbfread import DBF
from osgeo import ogr
import glob
import time
import json
import os

# %%
from methods import link_df_to_geojson
from methods import point_df_to_geojson

# %%
data_interim_dir = "../../data/interim/"

# %%
output_folder = "../../data/interim/step6_gtfs/"
output_folder = "../../data/processed/version_12/"

# %% [markdown]
# #  Read Network

# %%
link_file = data_interim_dir + "step5_tidy_roadway/link.feather"
link_df = pd.read_feather(link_file)

node_file = data_interim_dir + "step5_tidy_roadway/node.geojson"
node_gdf = gpd.read_file(node_file)

shape_file = data_interim_dir + "step5_tidy_roadway/shape.geojson"
shape_gdf = gpd.read_file(shape_file)

# %%
link_df.shape
# Out:
# (1632702, 36)

# %%
link_df[link_df.shstReferenceId == "02b0be7186de823a19b1bbd0ae45ddec"].model_link_id
# Out:
# 9112    7000765
# Name: model_link_id, dtype: int64

# %%
# network type correction at Transbay temporary terminal:

link_df[link_df.shstReferenceId.isin(["feab62cc90650bfc45dc453816782f9c", "9ab364b22d6b33ec158d8bc4008c1be7"])][
    ["roadway", "drive_access", "walk_access", "bike_access"]]
# Out:
#          roadway  drive_access  walk_access  bike_access
# 524671  cycleway             0            1            1
# 863713   service             0            1            1

# %%
link_df.loc[link_df.shstReferenceId.isin(["feab62cc90650bfc45dc453816782f9c", "9ab364b22d6b33ec158d8bc4008c1be7"]), 
            "roadway"] = "service"
link_df.loc[link_df.shstReferenceId.isin(["feab62cc90650bfc45dc453816782f9c", "9ab364b22d6b33ec158d8bc4008c1be7"]), 
            "drive_access"] = 1

link_df[link_df.shstReferenceId.isin(["feab62cc90650bfc45dc453816782f9c", "9ab364b22d6b33ec158d8bc4008c1be7"])][
    ["roadway", "drive_access", "walk_access", "bike_access"]]
# Out:
#         roadway  drive_access  walk_access  bike_access
# 524671  service             1            1            1
# 863713  service             1            1            1

# %%
node_gdf[node_gdf.osm_node_id.isin([890045140, 5372055804, 890045129])]
# Out:
#         osm_node_id                      shst_node_id         county  \
# 130712   5372055804  3291f7c2f15101c22abf554ce230343e  San Francisco
# 215684    890045140  4c0619714744bed10b7de965adc7048d  San Francisco
# 244341    890045129  490be8656a6428c6fc871a1f0e6432eb  San Francisco
#
#         drive_access  walk_access  bike_access  model_node_id  \
# 130712             0            1            1        1006138
# 215684             1            1            1        1010031
# 244341             1            1            1        1011380
#
#         county_numbering_start                     geometry
# 130712                 1000000  POINT (-122.39210 37.78934)
# 215684                 1000000  POINT (-122.39263 37.78966)
# 244341                 1000000  POINT (-122.39203 37.78925)

# %%
# network type correction at Transbay temporary terminal:

node_gdf.loc[node_gdf.osm_node_id.isin([890045140, 5372055804, 890045129]), "drive_access"] = 1

node_gdf[node_gdf.osm_node_id.isin([890045140, 5372055804, 890045129])]
# Out:
#         osm_node_id                      shst_node_id         county  \
# 130712   5372055804  3291f7c2f15101c22abf554ce230343e  San Francisco
# 215684    890045140  4c0619714744bed10b7de965adc7048d  San Francisco
# 244341    890045129  490be8656a6428c6fc871a1f0e6432eb  San Francisco
#
#         drive_access  walk_access  bike_access  model_node_id  \
# 130712             1            1            1        1006138
# 215684             1            1            1        1010031
# 244341             1            1            1        1011380
#
#         county_numbering_start                     geometry
# 130712                 1000000  POINT (-122.39210 37.78934)
# 215684                 1000000  POINT (-122.39263 37.78966)
# 244341                 1000000  POINT (-122.39203 37.78925)

# %%
link_df.info()
node_gdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1632702 entries, 0 to 1632701
# Data columns (total 36 columns):
# access                    1632702 non-null object
# area                      1632702 non-null object
# bike_access               1632702 non-null int64
# bridge                    1632702 non-null object
# drive_access              1632702 non-null int64
# est_width                 1632702 non-null object
# fromIntersectionId        1632702 non-null object
# highway                   1632702 non-null object
# id                        1632702 non-null object
# junction                  1632702 non-null object
# key                       1632702 non-null object
# landuse                   1632702 non-null object
# lanes                     1632702 non-null object
# link                      1632702 non-null object
# maxspeed                  1632702 non-null object
# name                      1632702 non-null object
# oneWay                    1632702 non-null object
# ref                       1632702 non-null object
# roadway                   1632702 non-null object
# roundabout                1632702 non-null object
# service                   1632702 non-null object
# shstGeometryId            1632702 non-null object
# shstReferenceId           1632702 non-null object
# toIntersectionId          1632702 non-null object
# tunnel                    1632702 non-null object
# u                         1632702 non-null int64
# v                         1632702 non-null int64
# walk_access               1632702 non-null int64
# wayId                     1632702 non-null object
# width                     1632702 non-null object
# county                    1632702 non-null object
# length                    1632702 non-null float64
# model_link_id             1632702 non-null int64
# county_numbering_start    1632702 non-null int64
# A                         1632702 non-null int64
# B                         1632702 non-null int64
# dtypes: float64(1), int64(9), object(26)
# memory usage: 448.4+ MB
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 643811 entries, 0 to 643810
# Data columns (total 9 columns):
# osm_node_id               643811 non-null int64
# shst_node_id              643811 non-null object
# county                    643811 non-null object
# drive_access              643811 non-null int64
# walk_access               643811 non-null int64
# bike_access               643811 non-null int64
# model_node_id             643811 non-null int64
# county_numbering_start    643811 non-null int64
# geometry                  643811 non-null geometry
# dtypes: geometry(1), int64(6), object(2)
# memory usage: 44.2+ MB

# %%
print(node_gdf.crs)
print(node_gdf.columns)
# Out:
# epsg:4326
# Index(['osm_node_id', 'shst_node_id', 'county', 'drive_access', 'walk_access',
#        'bike_access', 'model_node_id', 'county_numbering_start', 'geometry'],
#       dtype='object')

# %%
bus_only_link_list = [
     "0c246e7620f35085a744138ded98bcc0",
     "0d18dfb09f3fade6e2ff628c5a687b11",
     "2aa3575c0c2e3ca0641cd4cb1e72948b",
     "2c2ea4bd3246004fa11069cb1efb840b",
def ox_graph(nodes_df, links_df):
    """
        create an osmnx-flavored network graph
        osmnx doesn't like values that are arrays, so remove the variables
        that have arrays.  osmnx also requires that certain variables
        be filled in, so do that too.
        Parameters
        ----------
        nodes_df : GeoDataFrame
        link_df : GeoDataFrame
        Returns
        -------
        networkx multidigraph
    """
    try:
        graph_nodes = nodes_df.drop(
                ["inboundReferenceId", "outboundReferenceId"], axis=1
            )
    except:
        graph_nodes = nodes_df.copy()

    graph_nodes.gdf_name = "network_nodes"
    graph_nodes['id'] = graph_nodes['shst_node_id']

    graph_links = links_df.copy()
    graph_links['id'] = graph_links['shstReferenceId']
    graph_links['key'] = graph_links['shstReferenceId']

    G = ox.gdfs_to_graph(graph_nodes, graph_links)

    return G

# %%
# build network routing file for osmnx routing

G_drive = ox_graph(drive_node_gdf,
                  drive_link_df)

# %% [markdown]
# # Consolidate all gtfs into one

# %%
gtfs_agencies_list = os.listdir("../../data/external/gtfs/2015")

gtfs_agencies_list.remove("Petaluma_2016_5_22")
gtfs_agencies_list.remove("WestCAT_2016_5_26")
gtfs_agencies_list.remove("GGFerries_2017_3_18")
gtfs_agencies_list.remove("commuteDOTorg_GTFSImportExport_20160127_final_mj")

gtfs_agencies_list = gtfs_agencies_list + ["commuteDOTorg_GTFSImportExport_20160127_final_mj"]

# %%
gtfs_agencies_list
# Out:
# ['ACE_2017_3_20',
#  'ACTransit_2015_8_14',
#  'BART_2015_8_3',
#  'Blue&Gold_gtfs_10_4_2017',
#  'Caltrain_2015_5_13',
#  'Capitol_2017_3_20',
#  'CCTA_2015_8_11',
#  'Emeryville_2016_10_26',
#  'Fairfield_2015_10_14',
#  'GGTransit_2015_9_3',
#  'Marguerite_2016_10_10',
#  'MarinTransit_2015_8_31',
#  'MVGo_2016_10_26',
#  'petalumatransit-petaluma-ca-us__11_12_15',
#  'RioVista_2015_8_20',
#  'SamTrans_2015_8_20',
#  'SantaRosa_google_transit_08_28_15',
#  'SFMTA_2015_8_11',
#  'SF_Bay_Ferry2016_07_01',
#  'Soltrans_2016_5_20',
#  'SonomaCounty_2015_8_18',
#  'TriDelta-GTFS-2018-05-24_21-43-17',
#  'Union_City_Transit_Aug-01-2015 to Jun-30-2017',
#  'vacavillecitycoach-2020-ca-us',
#  'Vine_GTFS_PLUS_2015',
#  'VTA_2015_8_27',
#  'westcat-ca-us_9_17_2015',
#  'Wheels_2016_7_13',
#  'commuteDOTorg_GTFSImportExport_20160127_final_mj']

# %%
all_routes_df = pd.DataFrame()
all_trips_df = pd.DataFrame()
all_stops_df = pd.DataFrame()
all_shapes_df = pd.DataFrame()
all_stop_times_df = pd.DataFrame()
all_agency_df = pd.DataFrame()
all_fare_attributes_df = pd.DataFrame()
all_fare_rules_df = pd.DataFrame()

def get_representative_feed_from_gtfs(work_dir, in_url = "", fetch = False):
    
    print('getting representative feed...')
    
    if fetch == True:
        #read and save zip from url
        resp = urlopen(in_url)
        zipfile = ZipFile(BytesIO(resp.read()))
    
    if fetch == True:
        zipfile.extractall(work_dir + "muni")
    
    file_loc = work_dir
    
    # get feed for the busiest day
    feed = pt.get_representative_feed(file_loc)
    
    return feed

for name in gtfs_agencies_list:
    
    # exclude weekend only services
    if "calendar_orig.txt" in os.listdir("../../data/external/gtfs/2015/" + name):
        calendar_df = pd.read_csv("../../data/external/gtfs/2015/" + name + "/calendar.txt")
        
    elif "calendar.txt" in os.listdir("../../data/external/gtfs/2015/" + name):
        calendar_df = pd.read_csv("../../data/external/gtfs/2015/" + name + "/calendar.txt")
        calendar_df.to_csv("../../data/external/gtfs/2015/" + name + "/calendar_orig.txt",
                                                 index = False,
                                                 sep = ",")
    
        calendar_df["weekdays"] = calendar_df.apply(lambda x: x.monday + x.tuesday + x.wednesday + x.thursday + x.friday,
                                               axis = 1)
        calendar_df = calendar_df[calendar_df.weekdays > 0]
    
        calendar_df.drop("weekdays", axis = 1).to_csv("../../data/external/gtfs/2015/" + name + "/calendar.txt",
                                                 index = False,
                                                 sep = ",")
    
    feed = get_representative_feed_from_gtfs("../../data/external/gtfs/2015/" + name)
    
    routes_df = feed.routes.copy()
    routes_df["agency_raw_name"] = name
    
    stops_df = feed.stops.copy()
    stops_df["agency_raw_name"] = name
    
    trips_df = feed.trips.copy()
    trips_df["agency_raw_name"] = name
    
    if "direction_id" not in trips_df.columns: # Marguerita
        trips_df["direction_id"] = 0
    
    trips_df["direction_id"].fillna(0, inplace = True)
   
    shapes_df = feed.shapes.copy()
    shapes_df["agency_raw_name"] = name
    
    stop_times_df = feed.stop_times.copy()
    stop_times_df["agency_raw_name"] = name
    
    agency_df = feed.agency.copy()
    agency_df["agency_raw_name"] = name
    
    # gtfs cannot read fare tables for all agencies
        
    if "fare_attributes.txt" in os.listdir("../../data/external/gtfs/2015/" + name):
        
        fare_attributes_df = pd.read_csv("../../data/external/gtfs/2015/" + name + "/fare_attributes.txt",
                                         dtype = {"fare_id" : str})
        fare_attributes_df["agency_raw_name"] = name
    
    else:
        
        fare_attributes_df = pd.DataFrame()
    
    if "fare_rules.txt" in os.listdir("../../data/external/gtfs/2015/" + name):
        
        fare_rules_df = pd.read_csv("../../data/external/gtfs/2015/" + name + "/fare_rules.txt",
                                    dtype = {"fare_id" : str, "route_id" : str, "origin_id" : str, "destination_id" : str,
                                             " route_id" : str, " origin_id" : str, " destination_id" : str,})
        fare_rules_df["agency_raw_name"] = name
        
    else:
        
        fare_rules_df = pd.DataFrame()
        
    # add agency_id in routes.txt if missing
    if "agency_id" not in routes_df.columns:
        if "agency_id" in agency_df.columns:
            routes_df["agency_id"] = agency_df.agency_id.iloc[0]
    
    if len(shapes_df) == 0: # ACE, CCTA, VINE
        print("missing shapes.txt for {}".format(name))
        group_df = trips_df.groupby(["route_id", "direction_id"])["trip_id"].first().reset_index().drop("trip_id", axis = 1)
        group_df["shape_id"] = range(1, len(group_df) + 1)
        if "shape_id" in trips_df.columns:
            trips_df.drop("shape_id", axis = 1, inplace = True)
        trips_df = pd.merge(trips_df, group_df, how = "left", on = ["route_id", "direction_id"])
        
    if len(trips_df[trips_df.shape_id.isnull()]) > 0:
        print("partial complete shape_id for {}".format(name))
        trips_missing_shape_df = trips_df[trips_df.shape_id.isnull()].copy()
        group_df = trips_missing_shape_df.groupby(["route_id", "direction_id"])["trip_id"].first().reset_index().drop("trip_id", axis = 1)
        group_df["shape_id"] = range(1, len(group_df) + 1)
        group_df["shape_id"] = group_df["shape_id"].apply(lambda x: "psudo" + str(x))
        trips_missing_shape_df = pd.merge(trips_missing_shape_df.drop("shape_id", axis = 1), 
                                          group_df, how = "left", on = ["route_id", "direction_id"])
        trips_df = pd.concat([trips_df[trips_df.shape_id.notnull()], trips_missing_shape_df],
                             ignore_index = True,
                             sort = False)
        
    all_routes_df = all_routes_df.append(routes_df, sort = False, ignore_index = True)
    all_trips_df = all_trips_df.append(trips_df, sort = False, ignore_index = True)
    all_stops_df = all_stops_df.append(stops_df, sort = False, ignore_index = True)
    all_shapes_df = all_shapes_df.append(shapes_df, sort = False, ignore_index = True)
    all_stop_times_df = all_stop_times_df.append(stop_times_df, sort = False, ignore_index = True)
    all_agency_df = all_agency_df.append(agency_df, sort = False, ignore_index = True)
    all_fare_attributes_df = all_fare_attributes_df.append(fare_attributes_df, sort = False, ignore_index = True)
    all_fare_rules_df = all_fare_rules_df.append(fare_rules_df, sort = False, ignore_index = True)
# Out:
# getting representative feed...
# missing shapes.txt for ACE_2017_3_20
# getting representative feed...
# getting representative feed...
# getting representative feed...
# getting representative feed...
# getting representative feed...
# partial complete shape_id for Capitol_2017_3_20
# getting representative feed...
# missing shapes.txt for CCTA_2015_8_11
# getting representative feed...
# getting representative feed...
# getting representative feed...
# getting representative feed...
# getting representative feed...
# getting representative feed...
# getting representative feed...
# getting representative feed...
# getting representative feed...
# partial complete shape_id for SamTrans_2015_8_20
# getting representative feed...
# getting representative feed...
# getting representative feed...
# partial complete shape_id for SF_Bay_Ferry2016_07_01
# getting representative feed...
# getting representative feed...
# getting representative feed...
# getting representative feed...
# getting representative feed...
# getting representative feed...
# missing shapes.txt for Vine_GTFS_PLUS_2015
# getting representative feed...
# getting representative feed...
# getting representative feed...
# getting representative feed...

# %%
all_routes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 723 entries, 0 to 722
# Data columns (total 15 columns):
# route_id                  723 non-null object
# agency_id                 626 non-null object
# route_short_name          668 non-null object
# route_long_name           701 non-null object
# route_type                723 non-null int64
# route_color               340 non-null object
# route_text_color          322 non-null object
# agency_raw_name           723 non-null object
# route_desc                102 non-null object
# route_url                 316 non-null object
# route_sort_order          95 non-null object
# min_headway_minutes       32 non-null object
# eligibility_restricted    4 non-null object
# continuous_pickup         4 non-null object
# continuous_drop_off       4 non-null object
# dtypes: int64(1), object(14)
# memory usage: 84.8+ KB

# %%
all_fare_attributes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 743 entries, 0 to 742
# Data columns (total 8 columns):
# fare_id              743 non-null object
# price                743 non-null float64
# currency_type        743 non-null object
# payment_method       743 non-null object
# transfers            44 non-null object
# transfer_duration    264 non-null float64
# agency_raw_name      743 non-null object
# agency_id            251 non-null object
# dtypes: float64(2), object(6)
# memory usage: 46.5+ KB

# %%
all_fare_rules_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3269 entries, 0 to 3268
# Data columns (total 9 columns):
# fare_id            3269 non-null object
# route_id           665 non-null object
#  origin_id         307 non-null object
#  destination_id    307 non-null object
#  contains_id       0 non-null float64
# agency_raw_name    3269 non-null object
# origin_id          2511 non-null object
# destination_id     2511 non-null object
# contains_id        19 non-null object
# dtypes: float64(1), object(8)
# memory usage: 229.9+ KB

# %%
all_fare_rules_df["origin_id"] = np.where(all_fare_rules_df["origin_id"].isnull(),
                                          all_fare_rules_df[" origin_id"],
                                          all_fare_rules_df["origin_id"])

all_fare_rules_df["destination_id"] = np.where(all_fare_rules_df["destination_id"].isnull(),
                                          all_fare_rules_df[" destination_id"],
                                          all_fare_rules_df["destination_id"])

all_fare_rules_df["contains_id"] = np.where(all_fare_rules_df["contains_id"].isnull(),
                                          all_fare_rules_df[" contains_id"],
                                          all_fare_rules_df["contains_id"])

all_fare_rules_df.drop(columns = [" origin_id", " destination_id", " contains_id"], inplace = True)

# %%
all_fare_rules_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3269 entries, 0 to 3268
# Data columns (total 6 columns):
# fare_id            3269 non-null object
# route_id           665 non-null object
# agency_raw_name    3269 non-null object
# origin_id          2818 non-null object
# destination_id     2818 non-null object
# contains_id        19 non-null object
# dtypes: object(6)
# memory usage: 153.3+ KB

# %%
all_trips_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33747 entries, 0 to 33746
# Data columns (total 21 columns):
# route_id                       33747 non-null object
# service_id                     33747 non-null object
# trip_id                        33747 non-null object
# trip_headsign                  31601 non-null object
# direction_id                   33747 non-null float64
# block_id                       25830 non-null object
# trip_short_name                2037 non-null object
# agency_raw_name                33747 non-null object
# shape_id                       33747 non-null object
# wheelchair_accessible          1318 non-null float64
# bikes_allowed                  4332 non-null float64
# original_trip_id               668 non-null object
# trip_bikes_allowed             10 non-null object
# trip_type                      0 non-null object
# drt_max_travel_time            48 non-null object
# drt_avg_travel_time            48 non-null object
# drt_advance_book_min           48 non-null object
# drt_pickup_message             0 non-null object
# drt_drop_off_message           0 non-null object
# continuous_pickup_message      0 non-null object
# continuous_drop_off_message    0 non-null object
# dtypes: float64(3), object(18)
# memory usage: 5.4+ MB

# %%
all_routes_df[(all_routes_df.agency_raw_name == "ACTransit_2015_8_14") & (all_routes_df.route_short_name == "H")]
# Out:
#     route_id   agency_id route_short_name           route_long_name  \
# 131    H-118  AC Transit                H  San Francisco - Richmond
#
#      route_type route_color route_text_color      agency_raw_name route_desc  \
# 131           3         NaN              NaN  ACTransit_2015_8_14        NaN
#
#     route_url route_sort_order min_headway_minutes eligibility_restricted  \
# 131       NaN              NaN                 NaN                    NaN
#
#     continuous_pickup continuous_drop_off
# 131               NaN                 NaN

# %%
all_stops_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22153 entries, 0 to 22152
# Data columns (total 17 columns):
# stop_id                22153 non-null object
# stop_name              22153 non-null object
# stop_lat               22153 non-null float64
# stop_lon               22153 non-null float64
# zone_id                12267 non-null object
# agency_raw_name        22153 non-null object
# stop_code              15488 non-null object
# location_type          5558 non-null float64
# parent_station         620 non-null object
# stop_desc              4319 non-null object
# stop_url               4168 non-null object
# stop_timezone          137 non-null object
# wheelchair_boarding    388 non-null float64
# platform_code          58 non-null object
# position               0 non-null object
# direction              0 non-null object
# * used by routes       125 non-null object
# dtypes: float64(4), object(13)
# memory usage: 2.9+ MB

# %%
all_agency_df[all_agency_df.agency_raw_name == "Marguerite_2016_10_10"]
# Out:
#    agency_id                  agency_name                      agency_url  \
# 10       NaN  Stanford Marguerite Shuttle  http://marguerite.stanford.edu
#
#         agency_timezone agency_lang  agency_phone        agency_raw_name  \
# 10  America/Los_Angeles          en  650-723-9362  Marguerite_2016_10_10
#
#    agency_fare_url agency_email
# 10             NaN          NaN

# %%
all_agency_df.astype(str).groupby(["agency_raw_name", "agency_name", "agency_id"]).count()
# Out:
#                                                                                                                   agency_url  \
# agency_raw_name                                  agency_name                                   agency_id
# ACE_2017_3_20                                    ACE Altamont Corridor Express                 CE                          1
# ACTransit_2015_8_14                              AC Transit                                    AC Transit                  1
# BART_2015_8_3                                    Bay Area Rapid Transit                        BART                        1
# Blue&Gold_gtfs_10_4_2017                         Blue & Gold Fleet                             BG                          1
# CCTA_2015_8_11                                   County Connection                             nan                         1
# Caltrain_2015_5_13                               Caltrain                                      caltrain-ca-us              1
# Capitol_2017_3_20                                Capitol Corridor                              AM                          1
# Emeryville_2016_10_26                            Emery Go-Round                                573                         1
# Fairfield_2015_10_14                             Fairfield and Suisun Transit                  36                          1
# GGTransit_2015_9_3                               Golden Gate Transit                           nan                         1
# MVGo_2016_10_26                                  MVgo Mountain View                            533                         1
# Marguerite_2016_10_10                            Stanford Marguerite Shuttle                   nan                         1
# MarinTransit_2015_8_31                           Marin Transit                                 MCTD                        1
# RioVista_2015_8_20                               Rio Vista Delta Breeze                        5                           1
# SFMTA_2015_8_11                                  San Francisco Municipal Transportation Agency SFMTA                       1
# SF_Bay_Ferry2016_07_01                           San Francisco Bay Ferry                       SB                          1
# SamTrans_2015_8_20                               SamTrans                                      samtrans-ca-us              1
# SantaRosa_google_transit_08_28_15                Santa Rosa CityBus                            SRCityBus                   1
# Soltrans_2016_5_20                               SolTrans                                      247                         1
# SonomaCounty_2015_8_18                           Cloverdale Transit                            183                         1
#                                                  Sonoma County Transit                         175                         1
# TriDelta-GTFS-2018-05-24_21-43-17                Tri Delta Transit                             tri-delta-transit           1
# Union_City_Transit_Aug-01-2015 to Jun-30-2017    Union City Transit                            UCT                         1
# VTA_2015_8_27                                    VTA                                           VTA                         1
# Vine_GTFS_PLUS_2015                              Vine (Napa County)                            362                         1
# Wheels_2016_7_13                                 Wheels Bus                                    LAVTA                       1
# commuteDOTorg_GTFSImportExport_20160127_final_mj Commute.org Shuttle                           alliance                    1
# petalumatransit-petaluma-ca-us__11_12_15         Petaluma Transit                              267                         1
# vacavillecitycoach-2020-ca-us                    Vacaville City Coach                          869                         1
# westcat-ca-us_9_17_2015                          WestCat (Western Contra Costa)                392                         1
#
#                                                                                                                   agency_timezone  \
# agency_raw_name                                  agency_name                                   agency_id
# ACE_2017_3_20                                    ACE Altamont Corridor Express                 CE                               1
# ACTransit_2015_8_14                              AC Transit                                    AC Transit                       1
# BART_2015_8_3                                    Bay Area Rapid Transit                        BART                             1
# Blue&Gold_gtfs_10_4_2017                         Blue & Gold Fleet                             BG                               1
# CCTA_2015_8_11                                   County Connection                             nan                              1
# Caltrain_2015_5_13                               Caltrain                                      caltrain-ca-us                   1
# Capitol_2017_3_20                                Capitol Corridor                              AM                               1
# Emeryville_2016_10_26                            Emery Go-Round                                573                              1
# Fairfield_2015_10_14                             Fairfield and Suisun Transit                  36                               1
# GGTransit_2015_9_3                               Golden Gate Transit                           nan                              1
# MVGo_2016_10_26                                  MVgo Mountain View                            533                              1
# Marguerite_2016_10_10                            Stanford Marguerite Shuttle                   nan                              1
# MarinTransit_2015_8_31                           Marin Transit                                 MCTD                             1
# RioVista_2015_8_20                               Rio Vista Delta Breeze                        5                                1
# SFMTA_2015_8_11                                  San Francisco Municipal Transportation Agency SFMTA                            1
# SF_Bay_Ferry2016_07_01                           San Francisco Bay Ferry                       SB                               1
# SamTrans_2015_8_20                               SamTrans                                      samtrans-ca-us                   1
# SantaRosa_google_transit_08_28_15                Santa Rosa CityBus                            SRCityBus                        1
# Soltrans_2016_5_20                               SolTrans                                      247                              1
# SonomaCounty_2015_8_18                           Cloverdale Transit                            183                              1
#                                                  Sonoma County Transit                         175                              1
# TriDelta-GTFS-2018-05-24_21-43-17                Tri Delta Transit                             tri-delta-transit                1
# Union_City_Transit_Aug-01-2015 to Jun-30-2017    Union City Transit                            UCT                              1
# VTA_2015_8_27                                    VTA                                           VTA                              1
# Vine_GTFS_PLUS_2015                              Vine (Napa County)                            362                              1
# Wheels_2016_7_13                                 Wheels Bus                                    LAVTA                            1
# commuteDOTorg_GTFSImportExport_20160127_final_mj Commute.org Shuttle                           alliance                         1
# petalumatransit-petaluma-ca-us__11_12_15         Petaluma Transit                              267                              1
# vacavillecitycoach-2020-ca-us                    Vacaville City Coach                          869                              1
# westcat-ca-us_9_17_2015                          WestCat (Western Contra Costa)                392                              1
#
#                                                                                                                   agency_lang  \
# agency_raw_name                                  agency_name                                   agency_id
# ACE_2017_3_20                                    ACE Altamont Corridor Express                 CE                           1
# ACTransit_2015_8_14                              AC Transit                                    AC Transit                   1
# BART_2015_8_3                                    Bay Area Rapid Transit                        BART                         1
# Blue&Gold_gtfs_10_4_2017                         Blue & Gold Fleet                             BG                           1
# CCTA_2015_8_11                                   County Connection                             nan                          1
# Caltrain_2015_5_13                               Caltrain                                      caltrain-ca-us               1
# Capitol_2017_3_20                                Capitol Corridor                              AM                           1
# Emeryville_2016_10_26                            Emery Go-Round                                573                          1
# Fairfield_2015_10_14                             Fairfield and Suisun Transit                  36                           1
# GGTransit_2015_9_3                               Golden Gate Transit                           nan                          1
# MVGo_2016_10_26                                  MVgo Mountain View                            533                          1
# Marguerite_2016_10_10                            Stanford Marguerite Shuttle                   nan                          1
# MarinTransit_2015_8_31                           Marin Transit                                 MCTD                         1
# RioVista_2015_8_20                               Rio Vista Delta Breeze                        5                            1
# SFMTA_2015_8_11                                  San Francisco Municipal Transportation Agency SFMTA                        1
# SF_Bay_Ferry2016_07_01                           San Francisco Bay Ferry                       SB                           1
# SamTrans_2015_8_20                               SamTrans                                      samtrans-ca-us               1
# SantaRosa_google_transit_08_28_15                Santa Rosa CityBus                            SRCityBus                    1
# Soltrans_2016_5_20                               SolTrans                                      247                          1
# SonomaCounty_2015_8_18                           Cloverdale Transit                            183                          1
#                                                  Sonoma County Transit                         175                          1
# TriDelta-GTFS-2018-05-24_21-43-17                Tri Delta Transit                             tri-delta-transit            1
# Union_City_Transit_Aug-01-2015 to Jun-30-2017    Union City Transit                            UCT                          1
# VTA_2015_8_27                                    VTA                                           VTA                          1
# Vine_GTFS_PLUS_2015                              Vine (Napa County)                            362                          1
# Wheels_2016_7_13                                 Wheels Bus                                    LAVTA                        1
# commuteDOTorg_GTFSImportExport_20160127_final_mj Commute.org Shuttle                           alliance                     1
# petalumatransit-petaluma-ca-us__11_12_15         Petaluma Transit                              267                          1
# vacavillecitycoach-2020-ca-us                    Vacaville City Coach                          869                          1
# westcat-ca-us_9_17_2015                          WestCat (Western Contra Costa)                392                          1
#
#                                                                                                                   agency_phone  \
# agency_raw_name                                  agency_name                                   agency_id
# ACE_2017_3_20                                    ACE Altamont Corridor Express                 CE                            1
# ACTransit_2015_8_14                              AC Transit                                    AC Transit                    1
# BART_2015_8_3                                    Bay Area Rapid Transit                        BART                          1
# Blue&Gold_gtfs_10_4_2017                         Blue & Gold Fleet                             BG                            1
# CCTA_2015_8_11                                   County Connection                             nan                           1
# Caltrain_2015_5_13                               Caltrain                                      caltrain-ca-us                1
# Capitol_2017_3_20                                Capitol Corridor                              AM                            1
# Emeryville_2016_10_26                            Emery Go-Round                                573                           1
# Fairfield_2015_10_14                             Fairfield and Suisun Transit                  36                            1
# GGTransit_2015_9_3                               Golden Gate Transit                           nan                           1
# MVGo_2016_10_26                                  MVgo Mountain View                            533                           1
# Marguerite_2016_10_10                            Stanford Marguerite Shuttle                   nan                           1
# MarinTransit_2015_8_31                           Marin Transit                                 MCTD                          1
# RioVista_2015_8_20                               Rio Vista Delta Breeze                        5                             1
# SFMTA_2015_8_11                                  San Francisco Municipal Transportation Agency SFMTA                         1
# SF_Bay_Ferry2016_07_01                           San Francisco Bay Ferry                       SB                            1
# SamTrans_2015_8_20                               SamTrans                                      samtrans-ca-us                1
# SantaRosa_google_transit_08_28_15                Santa Rosa CityBus                            SRCityBus                     1
# Soltrans_2016_5_20                               SolTrans                                      247                           1
# SonomaCounty_2015_8_18                           Cloverdale Transit                            183                           1
#                                                  Sonoma County Transit                         175                           1
# TriDelta-GTFS-2018-05-24_21-43-17                Tri Delta Transit                             tri-delta-transit             1
# Union_City_Transit_Aug-01-2015 to Jun-30-2017    Union City Transit                            UCT                           1
# VTA_2015_8_27                                    VTA                                           VTA                           1
# Vine_GTFS_PLUS_2015                              Vine (Napa County)                            362                           1
# Wheels_2016_7_13                                 Wheels Bus                                    LAVTA                         1
# commuteDOTorg_GTFSImportExport_20160127_final_mj Commute.org Shuttle                           alliance                      1
# petalumatransit-petaluma-ca-us__11_12_15         Petaluma Transit                              267                           1
# vacavillecitycoach-2020-ca-us                    Vacaville City Coach                          869                           1
# westcat-ca-us_9_17_2015                          WestCat (Western Contra Costa)                392                           1
#
#                                                                                                                   agency_fare_url  \
# agency_raw_name                                  agency_name                                   agency_id
# ACE_2017_3_20                                    ACE Altamont Corridor Express                 CE                               1
# ACTransit_2015_8_14                              AC Transit                                    AC Transit                       1
# BART_2015_8_3                                    Bay Area Rapid Transit                        BART                             1
# Blue&Gold_gtfs_10_4_2017                         Blue & Gold Fleet                             BG                               1
# CCTA_2015_8_11                                   County Connection                             nan                              1
# Caltrain_2015_5_13                               Caltrain                                      caltrain-ca-us                   1
# Capitol_2017_3_20                                Capitol Corridor                              AM                               1
# Emeryville_2016_10_26                            Emery Go-Round                                573                              1
# Fairfield_2015_10_14                             Fairfield and Suisun Transit                  36                               1
# GGTransit_2015_9_3                               Golden Gate Transit                           nan                              1
# MVGo_2016_10_26                                  MVgo Mountain View                            533                              1
# Marguerite_2016_10_10                            Stanford Marguerite Shuttle                   nan                              1
# MarinTransit_2015_8_31                           Marin Transit                                 MCTD                             1
# RioVista_2015_8_20                               Rio Vista Delta Breeze                        5                                1
# SFMTA_2015_8_11                                  San Francisco Municipal Transportation Agency SFMTA                            1
# SF_Bay_Ferry2016_07_01                           San Francisco Bay Ferry                       SB                               1
# SamTrans_2015_8_20                               SamTrans                                      samtrans-ca-us                   1
# SantaRosa_google_transit_08_28_15                Santa Rosa CityBus                            SRCityBus                        1
# Soltrans_2016_5_20                               SolTrans                                      247                              1
# SonomaCounty_2015_8_18                           Cloverdale Transit                            183                              1
#                                                  Sonoma County Transit                         175                              1
# TriDelta-GTFS-2018-05-24_21-43-17                Tri Delta Transit                             tri-delta-transit                1
# Union_City_Transit_Aug-01-2015 to Jun-30-2017    Union City Transit                            UCT                              1
# VTA_2015_8_27                                    VTA                                           VTA                              1
# Vine_GTFS_PLUS_2015                              Vine (Napa County)                            362                              1
# Wheels_2016_7_13                                 Wheels Bus                                    LAVTA                            1
# commuteDOTorg_GTFSImportExport_20160127_final_mj Commute.org Shuttle                           alliance                         1
# petalumatransit-petaluma-ca-us__11_12_15         Petaluma Transit                              267                              1
# vacavillecitycoach-2020-ca-us                    Vacaville City Coach                          869                              1
# westcat-ca-us_9_17_2015                          WestCat (Western Contra Costa)                392                              1
#
#                                                                                                                   agency_email
# agency_raw_name                                  agency_name                                   agency_id
# ACE_2017_3_20                                    ACE Altamont Corridor Express                 CE                            1
# ACTransit_2015_8_14                              AC Transit                                    AC Transit                    1
# BART_2015_8_3                                    Bay Area Rapid Transit                        BART                          1
# Blue&Gold_gtfs_10_4_2017                         Blue & Gold Fleet                             BG                            1
# CCTA_2015_8_11                                   County Connection                             nan                           1
# Caltrain_2015_5_13                               Caltrain                                      caltrain-ca-us                1
# Capitol_2017_3_20                                Capitol Corridor                              AM                            1
# Emeryville_2016_10_26                            Emery Go-Round                                573                           1
# Fairfield_2015_10_14                             Fairfield and Suisun Transit                  36                            1
# GGTransit_2015_9_3                               Golden Gate Transit                           nan                           1
# MVGo_2016_10_26                                  MVgo Mountain View                            533                           1
# Marguerite_2016_10_10                            Stanford Marguerite Shuttle                   nan                           1
# MarinTransit_2015_8_31                           Marin Transit                                 MCTD                          1
# RioVista_2015_8_20                               Rio Vista Delta Breeze                        5                             1
# SFMTA_2015_8_11                                  San Francisco Municipal Transportation Agency SFMTA                         1
# SF_Bay_Ferry2016_07_01                           San Francisco Bay Ferry                       SB                            1
# SamTrans_2015_8_20                               SamTrans                                      samtrans-ca-us                1
# SantaRosa_google_transit_08_28_15                Santa Rosa CityBus                            SRCityBus                     1
# Soltrans_2016_5_20                               SolTrans                                      247                           1
# SonomaCounty_2015_8_18                           Cloverdale Transit                            183                           1
#                                                  Sonoma County Transit                         175                           1
# TriDelta-GTFS-2018-05-24_21-43-17                Tri Delta Transit                             tri-delta-transit             1
# Union_City_Transit_Aug-01-2015 to Jun-30-2017    Union City Transit                            UCT                           1
# VTA_2015_8_27                                    VTA                                           VTA                           1
# Vine_GTFS_PLUS_2015                              Vine (Napa County)                            362                           1
# Wheels_2016_7_13                                 Wheels Bus                                    LAVTA                         1
# commuteDOTorg_GTFSImportExport_20160127_final_mj Commute.org Shuttle                           alliance                      1
# petalumatransit-petaluma-ca-us__11_12_15         Petaluma Transit                              267                           1
# vacavillecitycoach-2020-ca-us                    Vacaville City Coach                          869                           1
# westcat-ca-us_9_17_2015                          WestCat (Western Contra Costa)                392                           1

# %% [markdown]
# # Re-ID the consolidated gtfs

# %%
# route_id, shape_id, trip_id, stop_id, 

unique_route_id_df = all_routes_df[
    all_routes_df.agency_raw_name != "commuteDOTorg_GTFSImportExport_20160127_final_mj"].copy()
unique_route_id_df = unique_route_id_df.groupby(
    ["agency_raw_name", "route_id"])["agency_id"].count().reset_index().drop(["agency_id"], axis = 1)
unique_route_id_df["route_id_original"] = unique_route_id_df["route_id"]
unique_route_id_df["route_id"] = range(1,  len(unique_route_id_df) + 1)

unique_trip_id_df = all_trips_df[
    all_trips_df.agency_raw_name != "commuteDOTorg_GTFSImportExport_20160127_final_mj"].copy()
unique_trip_id_df = unique_trip_id_df.groupby(
    ["agency_raw_name", "trip_id"])["route_id"].count().reset_index().drop(["route_id"], axis = 1)
unique_trip_id_df["trip_id_original"] = unique_trip_id_df["trip_id"]
unique_trip_id_df["trip_id"] = range(1,  len(unique_trip_id_df) + 1)

unique_shape_id_df = all_trips_df[
    all_trips_df.agency_raw_name != "commuteDOTorg_GTFSImportExport_20160127_final_mj"].copy()
unique_shape_id_df = unique_shape_id_df.groupby(
    ["agency_raw_name", "shape_id"])["trip_id"].count().reset_index().drop(["trip_id"], axis = 1)
unique_shape_id_df["shape_id_original"] = unique_shape_id_df["shape_id"]
unique_shape_id_df["shape_id"] = range(1,  len(unique_shape_id_df) + 1)

unique_stop_id_df = all_stops_df[
    all_stops_df.agency_raw_name != "commuteDOTorg_GTFSImportExport_20160127_final_mj"].copy()
unique_stop_id_df = unique_stop_id_df.groupby(
    ["agency_raw_name", "stop_id"])["stop_lat"].count().reset_index().drop(["stop_lat"], axis = 1)
unique_stop_id_df["stop_id_original"] = unique_stop_id_df["stop_id"]
unique_stop_id_df["stop_id"] = range(1,  len(unique_stop_id_df) + 1)

## caltrain shuttle June 11th, 2021
# appending caltrain data without renumbering the existing transit

cs_unique_route_id_df = all_routes_df[
    all_routes_df.agency_raw_name == "commuteDOTorg_GTFSImportExport_20160127_final_mj"].copy()
cs_unique_route_id_df = cs_unique_route_id_df.groupby(
    ["agency_raw_name", "route_id"])["agency_id"].count().reset_index().drop(["agency_id"], axis = 1)
cs_unique_route_id_df["route_id_original"] = cs_unique_route_id_df["route_id"]
cs_unique_route_id_df["route_id"] = range(1 + max(unique_route_id_df.route_id),  
                                          len(cs_unique_route_id_df) + 1 + max(unique_route_id_df.route_id))

unique_route_id_df = pd.concat([unique_route_id_df, cs_unique_route_id_df], sort = False, ignore_index = True)

cs_unique_trip_id_df = all_trips_df[
    all_trips_df.agency_raw_name == "commuteDOTorg_GTFSImportExport_20160127_final_mj"].copy()
cs_unique_trip_id_df = cs_unique_trip_id_df.groupby(
    ["agency_raw_name", "trip_id"])["route_id"].count().reset_index().drop(["route_id"], axis = 1)
cs_unique_trip_id_df["trip_id_original"] = cs_unique_trip_id_df["trip_id"]
cs_unique_trip_id_df["trip_id"] = range(1 + max(unique_trip_id_df.trip_id),  
                                        len(cs_unique_trip_id_df) + 1 + max(unique_trip_id_df.trip_id))

unique_trip_id_df = pd.concat([unique_trip_id_df, cs_unique_trip_id_df], sort = False, ignore_index = True)

cs_unique_shape_id_df = all_trips_df[
    all_trips_df.agency_raw_name == "commuteDOTorg_GTFSImportExport_20160127_final_mj"].copy()
cs_unique_shape_id_df = cs_unique_shape_id_df.groupby(
    ["agency_raw_name", "shape_id"])["trip_id"].count().reset_index().drop(["trip_id"], axis = 1)
cs_unique_shape_id_df["shape_id_original"] = cs_unique_shape_id_df["shape_id"]
cs_unique_shape_id_df["shape_id"] = range(1 + max(unique_shape_id_df.shape_id),  
                                          len(cs_unique_shape_id_df) + 1 + max(unique_shape_id_df.shape_id))

unique_shape_id_df = pd.concat([unique_shape_id_df, cs_unique_shape_id_df], sort = False, ignore_index = True)

cs_unique_stop_id_df = all_stops_df[
    all_stops_df.agency_raw_name == "commuteDOTorg_GTFSImportExport_20160127_final_mj"].copy()
cs_unique_stop_id_df = cs_unique_stop_id_df.groupby(
    ["agency_raw_name", "stop_id"])["stop_lat"].count().reset_index().drop(["stop_lat"], axis = 1)
cs_unique_stop_id_df["stop_id_original"] = cs_unique_stop_id_df["stop_id"]
cs_unique_stop_id_df["stop_id"] = range(1 + max(unique_stop_id_df.stop_id),  
                                        len(cs_unique_stop_id_df) + 1 + max(unique_stop_id_df.stop_id))

unique_stop_id_df = pd.concat([unique_stop_id_df, cs_unique_stop_id_df], sort = False, ignore_index = True)

# %%
unique_route_id_df[unique_route_id_df.route_id_original == "1031"]
# Out:
#             agency_raw_name  route_id route_id_original
# 310         SFMTA_2015_8_11       311              1031
# 499  SonomaCounty_2015_8_18       500              1031

# %%
unique_stop_id_df[unique_stop_id_df.stop_id_original.isin(["3042", "3071"])]
# Out:
#        agency_raw_name  stop_id stop_id_original
# 8420   SFMTA_2015_8_11     8421             3042
# 8447   SFMTA_2015_8_11     8448             3071
# 18153    VTA_2015_8_27    18154             3042
# 18174    VTA_2015_8_27    18175             3071

# %%
unique_shape_id_df[unique_shape_id_df.agency_raw_name == "Vine_GTFS_PLUS_2015"]
# Out:
#           agency_raw_name  shape_id shape_id_original
# 1933  Vine_GTFS_PLUS_2015      1934                 1
# 1934  Vine_GTFS_PLUS_2015      1935                 2
# 1935  Vine_GTFS_PLUS_2015      1936                 3
# 1936  Vine_GTFS_PLUS_2015      1937                 4
# 1937  Vine_GTFS_PLUS_2015      1938                 5
# 1938  Vine_GTFS_PLUS_2015      1939                 6
# 1939  Vine_GTFS_PLUS_2015      1940                 7
# 1940  Vine_GTFS_PLUS_2015      1941                 8
# 1941  Vine_GTFS_PLUS_2015      1942                 9
# 1942  Vine_GTFS_PLUS_2015      1943                10
# 1943  Vine_GTFS_PLUS_2015      1944                11
# 1944  Vine_GTFS_PLUS_2015      1945                12
# 1945  Vine_GTFS_PLUS_2015      1946                13
# 1946  Vine_GTFS_PLUS_2015      1947                14
# 1947  Vine_GTFS_PLUS_2015      1948                15
# 1948  Vine_GTFS_PLUS_2015      1949                16
# 1949  Vine_GTFS_PLUS_2015      1950                17
# 1950  Vine_GTFS_PLUS_2015      1951                18
# 1951  Vine_GTFS_PLUS_2015      1952                19

# %%
all_fare_attributes_df.columns
# Out:
# Index(['fare_id', 'price', 'currency_type', 'payment_method', 'transfers',
#        'transfer_duration', 'agency_raw_name', 'agency_id'],
#       dtype='object')

# %%
all_fare_rules_df.columns
# Out:
# Index(['fare_id', 'route_id', 'agency_raw_name', 'origin_id', 'destination_id',
#        'contains_id'],
#       dtype='object')

# %%
unique_route_id_df[(unique_route_id_df.agency_raw_name == 'westcat-ca-us_9_17_2015') & (unique_route_id_df.route_id_original == "2676")]
# Out:
#              agency_raw_name  route_id route_id_original
# 698  westcat-ca-us_9_17_2015       699              2676

# %%
all_fare_rules_df[all_fare_rules_df.route_id == "2676"]
# Out:
#      fare_id route_id          agency_raw_name origin_id destination_id  \
# 3249    1382     2676  westcat-ca-us_9_17_2015       NaN            NaN
#
#      contains_id
# 3249         NaN

# %%
all_fare_rules_df[all_fare_rules_df.origin_id == "55448"]
# Out:
#   fare_id route_id agency_raw_name origin_id destination_id contains_id
# 0  178837      NaN   ACE_2017_3_20     55448          55449         NaN
# 1  178838      NaN   ACE_2017_3_20     55448          55450         NaN
# 2  178839      NaN   ACE_2017_3_20     55448          55643         NaN
# 3  178840      NaN   ACE_2017_3_20     55448          55644         NaN
# 4  178841      NaN   ACE_2017_3_20     55448          55645         NaN

# %%
all_fare_rules_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3269 entries, 0 to 3268
# Data columns (total 6 columns):
# fare_id            3269 non-null object
# route_id           665 non-null object
# agency_raw_name    3269 non-null object
# origin_id          2818 non-null object
# destination_id     2818 non-null object
# contains_id        19 non-null object
# dtypes: object(6)
# memory usage: 153.3+ KB

# %%
all_routes_df = pd.merge(
    all_routes_df.rename(columns = {"route_id" : "route_id_original"}),
    unique_route_id_df,
    how = "left",
    on = ["agency_raw_name", "route_id_original"]
)

all_trips_df = pd.merge(
    all_trips_df.rename(columns = {"route_id" : "route_id_original", "trip_id" : "trip_id_original",
                                 "shape_id" : "shape_id_original"}),
    unique_route_id_df,
    how = "left",
    on = ["agency_raw_name", "route_id_original"]
)
all_trips_df = pd.merge(
    all_trips_df,
    unique_trip_id_df,
    how = "left",
    on = ["agency_raw_name", "trip_id_original"]
)
all_trips_df = pd.merge(
    all_trips_df,
    unique_shape_id_df,
    how = "left",
    on = ["agency_raw_name", "shape_id_original"]
)

all_stops_df = pd.merge(
    all_stops_df.rename(columns = {"stop_id" : "stop_id_original"}),
    unique_stop_id_df,
    how = "left",
    on = ["agency_raw_name", "stop_id_original"]
)

all_shapes_df = pd.merge(
    all_shapes_df.rename(columns = {"shape_id" : "shape_id_original"}),
    unique_shape_id_df,
    how = "left",
    on = ["agency_raw_name", "shape_id_original"]
)


all_stop_times_df = pd.merge(
    all_stop_times_df.rename(columns = {"trip_id" : "trip_id_original", "stop_id" : "stop_id_original"}),
    unique_trip_id_df,
    how = "left",
    on = ["agency_raw_name", "trip_id_original"]
)
all_stop_times_df = pd.merge(
    all_stop_times_df,
    unique_stop_id_df,
    how = "left",
    on = ["agency_raw_name", "stop_id_original"]
)

all_fare_rules_df["route_id"] = all_fare_rules_df["route_id"].astype(str)
all_fare_rules_df = pd.merge(
    all_fare_rules_df.rename(columns = {"route_id" : "route_id_original"}),
    unique_route_id_df,
    how = "left",
    on = ["agency_raw_name", "route_id_original"]
)

all_routes_df.to_csv('../../data/interim/step6_gtfs/consolidated_gtfs_input/routes.txt', index = False, sep = ',')
all_trips_df.to_csv('../../data/interim/step6_gtfs/consolidated_gtfs_input/trips.txt', index = False, sep = ',')
all_stops_df.to_csv('../../data/interim/step6_gtfs/consolidated_gtfs_input/stops.txt', index = False, sep = ',')
all_shapes_df.to_csv('../../data/interim/step6_gtfs/consolidated_gtfs_input/shapes.txt', index = False, sep = ',')
all_stop_times_df.to_csv('../../data/interim/step6_gtfs/consolidated_gtfs_input/stop_times.txt', index = False, sep = ',')
all_agency_df.to_csv('../../data/interim/step6_gtfs/consolidated_gtfs_input/agency.txt', index = False, sep = ',')
all_fare_attributes_df.to_csv('../../data/interim/step6_gtfs/consolidated_gtfs_input/fare_attributes.txt', index = False, sep = ',')
all_fare_rules_df.to_csv('../../data/interim/step6_gtfs/consolidated_gtfs_input/fare_rules.txt', index = False, sep = ',')

all_trips_df.drop(["route_id_original", "trip_id_original", "shape_id_original"], axis = 1, inplace = True)
all_stops_df.drop(["stop_id_original"], axis = 1, inplace = True)
all_shapes_df.drop(["agency_raw_name", "shape_id_original"], axis = 1, inplace = True)
all_stop_times_df.drop(["agency_raw_name", "trip_id_original", "stop_id_original"], axis = 1, inplace = True)

# %%
all_trips_df[all_trips_df.direction_id.isnull()].agency_raw_name.unique()
# Out:
# array([], dtype=object)

# %%
all_fare_rules_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3269 entries, 0 to 3268
# Data columns (total 7 columns):
# fare_id              3269 non-null object
# route_id_original    3269 non-null object
# agency_raw_name      3269 non-null object
# origin_id            2818 non-null object
# destination_id       2818 non-null object
# contains_id          19 non-null object
# route_id             557 non-null float64
# dtypes: float64(1), object(6)
# memory usage: 204.3+ KB

# %%
all_fare_rules_df[all_fare_rules_df.origin_id.notnull()].agency_raw_name.unique()
# Out:
# array(['ACE_2017_3_20', 'BART_2015_8_3', 'Caltrain_2015_5_13',
#        'Capitol_2017_3_20', 'Fairfield_2015_10_14',
#        'MarinTransit_2015_8_31', 'RioVista_2015_8_20',
#        'SamTrans_2015_8_20', 'SonomaCounty_2015_8_18'], dtype=object)

# %%
all_fare_rules_df.agency_raw_name.unique()
# Out:
# array(['ACE_2017_3_20', 'BART_2015_8_3', 'Blue&Gold_gtfs_10_4_2017',
#        'Caltrain_2015_5_13', 'Capitol_2017_3_20', 'CCTA_2015_8_11',
#        'Fairfield_2015_10_14', 'MarinTransit_2015_8_31',
#        'petalumatransit-petaluma-ca-us__11_12_15', 'RioVista_2015_8_20',
#        'SamTrans_2015_8_20', 'SFMTA_2015_8_11', 'Soltrans_2016_5_20',
#        'SonomaCounty_2015_8_18', 'VTA_2015_8_27',
#        'westcat-ca-us_9_17_2015',
#        'commuteDOTorg_GTFSImportExport_20160127_final_mj'], dtype=object)

# %%
all_routes_df[(all_routes_df.agency_raw_name == "westcat-ca-us_9_17_2015") & (all_routes_df.route_id_original == "2676")]
# Out:
#     route_id_original agency_id route_short_name  \
# 667              2676       392             Lynx
#
#                                     route_long_name  route_type route_color  \
# 667  Rodeo/Hercules/San Francisco Transbay Terminal           3      74262B
#
#     route_text_color          agency_raw_name route_desc  \
# 667           FFFFFF  westcat-ca-us_9_17_2015        NaN
#
#                                              route_url route_sort_order  \
# 667  http://www.westcat.org/schedules/routeLYNXcs.html                0
#
#     min_headway_minutes eligibility_restricted continuous_pickup  \
# 667                 NaN                    NaN               NaN
#
#     continuous_drop_off  route_id
# 667                 NaN       699

# %% [markdown]
# # Processing

# %%
# pick representatives for each route by direction, with most number of trip 
def get_representative_trip_for_route(trips, stop_times):
    
    """
    get the representative trips for each route, by direction, tod
    
    """
    
    print('getting representative trip...')
    
    # get the first stop of each trip to determine the time period for each trip
    # process time
    stop_times_df = stop_times.copy()
    stop_times_df['arrival_h'] = pd.to_datetime(stop_times_df['arrival_time'], unit = 's').dt.hour
    stop_times_df['arrival_m'] = pd.to_datetime(stop_times_df['arrival_time'], unit = 's').dt.minute
    stop_times_df['departure_h'] = pd.to_datetime(stop_times_df['departure_time'], unit = 's').dt.hour
    stop_times_df['departure_m'] = pd.to_datetime(stop_times_df['departure_time'], unit = 's').dt.minute
    
    # according to the gtfs reference, the stop sequence does not have to be consecutive, but has to always increase
    # so we can get the fisrt stop by the smallest stop sequence on the trip
    stop_times_df.sort_values(by = ["trip_id", "stop_sequence"], 
                              ascending = True, 
                              inplace = True)
    first_stop_df = stop_times_df.drop_duplicates(subset = ["trip_id"])
    
    ## identify peak, offpeak trips, based on the arrival time of first stop
    trip_df = trips.copy()
    trip_df = pd.merge(trip_df, 
                       first_stop_df,
                       how = 'left',
                       on = 'trip_id')
    
    ## AM: 6-10am, MD: 10am-3pm, PM: 3-7pm, NT 7pm-3am, EA 3-6am
    trip_df['tod'] = np.where((trip_df['arrival_h'] >= 6) & (trip_df['arrival_h'] < 10),
                                 'AM',
                                 np.where((trip_df['arrival_h'] >= 10) & (trip_df['arrival_h'] < 15),
                                     'MD',
                                    np.where((trip_df['arrival_h'] >= 15) & (trip_df['arrival_h'] < 19),
                                         'PM',
                                        np.where((trip_df['arrival_h'] >= 3) & (trip_df['arrival_h'] < 6),
                                             'EA',
                                                 'NT'))))
  
    # calculate frequency for EA and NT period using 5-6am, and 7-10pm
    trip_EA_NT_df = trip_df.copy()
    trip_EA_NT_df["tod"] = np.where((trip_df['arrival_h'] >= 5) & (trip_df['arrival_h'] < 6),
                                  "EA",
                                  np.where((trip_df['arrival_h'] >= 19) & (trip_df['arrival_h'] < 22),
                                          "NT",
                                          "NA")
                                  )
    
    # get the most frequent trip for each route, by direction, by time of day
    ## trips share the same shape_id is considered being the same
    ## first get the trip count for each shape_id
    trip_freq_df = trip_df.groupby(['route_id', 'tod', 'direction_id', 'shape_id'])['trip_id'].count().\
                            to_frame().\
                            drop(index = 'other', level = 1).\
                            reset_index()
    
    ## then choose the most frequent shape_id for each route, frequency use the total number of trips
    def agg(x):
        m = x.shape_id.iloc[np.argmax(x.trip_id.values)]
        return pd.Series({'trip_num' : x.trip_id.sum(), 'shape_id' : m})
   
    trip_freq_df = trip_freq_df.reset_index().groupby(['route_id', 'tod', 'direction_id']).apply(agg)
    
    # retain the complete trip info of represent trip only
    trip_df = pd.merge(trip_df, trip_freq_df.reset_index(),
                      how = 'inner',
                      on = ['route_id', 'tod', 'direction_id', 'shape_id']).\
                drop_duplicates(['route_id', 'direction_id', 'tod'])
        
    trip_EA_NT_df = pd.merge(trip_EA_NT_df, trip_freq_df.reset_index(),
                      how = 'inner',
                      on = ['route_id', 'tod', 'direction_id', 'shape_id'])
    
    trip_EA_NT_df = trip_EA_NT_df[trip_EA_NT_df.tod.isin(["EA", "NT"])].groupby(
        ["route_id", "tod", "direction_id", "shape_id"])["trip_id"].count().reset_index()
    
    trip_EA_NT_df.rename(columns = {"trip_id" : "trip_num"}, inplace = True)
    
    trip_df = pd.merge(
        trip_df,
        trip_EA_NT_df,
        how = "left",
        on = ["route_id", "tod", "direction_id", "shape_id"]
    )
    
    trip_df["trip_num"] = np.where(trip_df.trip_num_y.isnull(),
                                  trip_df.trip_num_x,
                                  trip_df.trip_num_y)
    
    return trip_df

# %%
trip_df = get_representative_trip_for_route(all_trips_df, all_stop_times_df)
# Out:
# getting representative trip...

# %%
all_routes_df.agency_raw_name.value_counts()
# Out:
# ACTransit_2015_8_14                                 152
# SFMTA_2015_8_11                                      81
# VTA_2015_8_27                                        80
# SamTrans_2015_8_20                                   75
# GGTransit_2015_9_3                                   38
# Wheels_2016_7_13                                     36
# CCTA_2015_8_11                                       30
# SonomaCounty_2015_8_18                               29
# Marguerite_2016_10_10                                29
# commuteDOTorg_GTFSImportExport_20160127_final_mj     19
# SantaRosa_google_transit_08_28_15                    17
# Fairfield_2015_10_14                                 16
# TriDelta-GTFS-2018-05-24_21-43-17                    14
# westcat-ca-us_9_17_2015                              14
# Soltrans_2016_5_20                                   14
# Vine_GTFS_PLUS_2015                                  13
# petalumatransit-petaluma-ca-us__11_12_15             11
# Union_City_Transit_Aug-01-2015 to Jun-30-2017         9
# MarinTransit_2015_8_31                                8
# Emeryville_2016_10_26                                 7
# SF_Bay_Ferry2016_07_01                                6
# BART_2015_8_3                                         6
# MVGo_2016_10_26                                       4
# vacavillecitycoach-2020-ca-us                         4
# Caltrain_2015_5_13                                    3
# Blue&Gold_gtfs_10_4_2017                              3
# RioVista_2015_8_20                                    2
# Capitol_2017_3_20                                     2
# ACE_2017_3_20                                         1
# Name: agency_raw_name, dtype: int64

# %%
all_routes_df[all_routes_df.agency_raw_name.isin(["CCTA_2015_8_11"])]
# Out:
#        route_id_original agency_id route_short_name  \
# 167  34_merged_381003112       NaN              93X
# 168  28_merged_381003096       NaN                5
# 169  26_merged_381003090       NaN               36
# 170  13_merged_381003100       NaN               21
# 171  15_merged_381003102       NaN               28
# 172  11_merged_381003098       NaN                2
# 173                    1       NaN                1
# 174                    3       NaN               11
# 175                    2       NaN               10
# 176                    5       NaN               15
# 177                    4       NaN               14
# 178                    7       NaN               17
# 179                    6       NaN               16
# 180                    9       NaN               19
# 181                    8       NaN               18
# 182  36_merged_381003110       NaN              96X
# 183  12_merged_381003101       NaN               20
# 184  14_merged_381003103       NaN               25
# 185  16_merged_381003105       NaN                3
# 186  31_merged_381003108       NaN                9
# 187                   38       NaN              98X
# 188  27_merged_381003091       NaN                4
# 189  10_merged_381003099       NaN               1M
# 190  25_merged_381003089       NaN               35
# 191  33_merged_381003113       NaN              92X
# 192  30_merged_381003109       NaN                7
# 193  29_merged_381003097       NaN                6
# 194                   37       NaN              97X
# 195  32_merged_381003114       NaN              91X
# 196  35_merged_381003111       NaN              95X
#
#                          route_long_name  route_type route_color  \
# 167                  Kirker Pass Express           3         NaN
# 168          Creekside/BART Walnut Creek           3         NaN
# 169                San Ramon/BART Dublin           3         NaN
# 170          BART Walnut Creek/San Ramon           3         NaN
# 171          BART North Concord/Martinez           3         NaN
# 172            Rudgear/BART Walnut Creek           3         NaN
# 173                  Rossmoor/Shadelands           3         NaN
# 174        BART Concord/BART Pleasant Hi           3         NaN
# 175                 BART Concord/Clayton           3         NaN
# 176                           Treat Blvd           3         NaN
# 177                        Monument Blvd           3         NaN
# 178           BART Concord/North Concord           3         NaN
# 179                  AMTRAK/BART Concord           3         NaN
# 180                  AMTRAK/BART Concord           3         NaN
# 181            AMTRAK/BART Pleasant Hill           3         NaN
# 182       BART Walnut Creek/Bishop Ranch           3         NaN
# 183                     DVC/BART Concord           3         NaN
# 184     BART Lafayette/BART Walnut Creek           3         NaN
# 185                   Martinez Community           3         NaN
# 186                DVC/BART Walnut Creek           3         NaN
# 187           Martinez/BART Walnut Creek           3         NaN
# 188     Broadway Plaza/BART Walnut Creek           3         NaN
# 189  BART WALNUT CREEK/JOHN MUIR MED CTR           3         NaN
# 190                BART Dublin/San Ramon           3         NaN
# 191                          ACE Express           3         NaN
# 192                   Shadelands/BART PH           3         NaN
# 193              Lafayette/Moraga/Orinda           3         NaN
# 194             BART Dublin/Bishop Ranch           3         NaN
# 195             Concord Commuter Express           3         NaN
# 196          San Ramon/BART Walnut Creek           3         NaN
#
#     route_text_color agency_raw_name route_desc route_url route_sort_order  \
# 167              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 168              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 169              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 170              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 171              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 172              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 173              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 174              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 175              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 176              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 177              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 178              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 179              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 180              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 181              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 182              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 183              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 184              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 185              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 186              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 187              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 188              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 189              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 190              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 191              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 192              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 193              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 194              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 195              NaN  CCTA_2015_8_11        NaN       NaN              NaN
# 196              NaN  CCTA_2015_8_11        NaN       NaN              NaN
#
#     min_headway_minutes eligibility_restricted continuous_pickup  \
# 167                 NaN                    NaN               NaN
# 168                 NaN                    NaN               NaN
# 169                 NaN                    NaN               NaN
# 170                 NaN                    NaN               NaN
# 171                 NaN                    NaN               NaN
# 172                 NaN                    NaN               NaN
# 173                 NaN                    NaN               NaN
# 174                 NaN                    NaN               NaN
# 175                 NaN                    NaN               NaN
# 176                 NaN                    NaN               NaN
# 177                 NaN                    NaN               NaN
# 178                 NaN                    NaN               NaN
# 179                 NaN                    NaN               NaN
# 180                 NaN                    NaN               NaN
# 181                 NaN                    NaN               NaN
# 182                 NaN                    NaN               NaN
# 183                 NaN                    NaN               NaN
# 184                 NaN                    NaN               NaN
# 185                 NaN                    NaN               NaN
# 186                 NaN                    NaN               NaN
# 187                 NaN                    NaN               NaN
# 188                 NaN                    NaN               NaN
# 189                 NaN                    NaN               NaN
# 190                 NaN                    NaN               NaN
# 191                 NaN                    NaN               NaN
# 192                 NaN                    NaN               NaN
# 193                 NaN                    NaN               NaN
# 194                 NaN                    NaN               NaN
# 195                 NaN                    NaN               NaN
# 196                 NaN                    NaN               NaN
#
#     continuous_drop_off  route_id
# 167                 NaN       182
# 168                 NaN       175
# 169                 NaN       173
# 170                 NaN       167
# 171                 NaN       169
# 172                 NaN       165
# 173                 NaN       163
# 174                 NaN       177
# 175                 NaN       171
# 176                 NaN       188
# 177                 NaN       187
# 178                 NaN       190
# 179                 NaN       189
# 180                 NaN       192
# 181                 NaN       191
# 182                 NaN       184
# 183                 NaN       166
# 184                 NaN       168
# 185                 NaN       170
# 186                 NaN       179
# 187                 NaN       186
# 188                 NaN       174
# 189                 NaN       164
# 190                 NaN       172
# 191                 NaN       181
# 192                 NaN       178
# 193                 NaN       176
# 194                 NaN       185
# 195                 NaN       180
# 196                 NaN       183

# %%
all_trips_df[all_trips_df.trip_id == 4384]
# Out:
#                 service_id     trip_headsign  direction_id block_id  \
# 4383  1508FA-D6-Weekday-02  232 FREMONT BART           1.0   611281
#
#      trip_short_name      agency_raw_name  wheelchair_accessible  \
# 4383             NaN  ACTransit_2015_8_14                    NaN
#
#       bikes_allowed original_trip_id trip_bikes_allowed  ...  \
# 4383            NaN              NaN                NaN  ...
#
#      drt_max_travel_time drt_avg_travel_time drt_advance_book_min  \
# 4383                 NaN                 NaN                  NaN
#
#      drt_pickup_message drt_drop_off_message continuous_pickup_message  \
# 4383                NaN                  NaN                       NaN
#
#      continuous_drop_off_message route_id  trip_id  shape_id
# 4383                         NaN       17     4384        47
#
# [1 rows x 21 columns]

# %%
print(trip_df.info())
trip_df[trip_df.agency_raw_name == "Caltrain_2015_5_13"]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3980 entries, 0 to 3979
# Data columns (total 53 columns):
# service_id                      3980 non-null object
# trip_headsign                   3605 non-null object
# direction_id                    3980 non-null float64
# block_id                        2780 non-null object
# trip_short_name                 363 non-null object
# agency_raw_name                 3980 non-null object
# wheelchair_accessible           125 non-null float64
# bikes_allowed                   634 non-null float64
# original_trip_id                147 non-null object
# trip_bikes_allowed              8 non-null object
# trip_type                       0 non-null object
# drt_max_travel_time             18 non-null object
# drt_avg_travel_time             18 non-null object
# drt_advance_book_min            18 non-null object
# drt_pickup_message              0 non-null object
# drt_drop_off_message            0 non-null object
# continuous_pickup_message       0 non-null object
# continuous_drop_off_message     0 non-null object
# route_id                        3980 non-null int32
# trip_id                         3980 non-null int32
# shape_id                        3980 non-null int32
# arrival_time                    3979 non-null float64
# departure_time                  3979 non-null float64
# stop_sequence                   3980 non-null int64
# pickup_type                     1208 non-null float64
# drop_off_type                   1794 non-null object
# stop_headsign                   944 non-null object
# shape_dist_traveled             845 non-null float64
# timepoint                       352 non-null float64
# last_stop_on_trip               0 non-null object
# start_service_area_id           0 non-null object
# end_service_area_id             0 non-null object
# start_service_area_radius       0 non-null object
# end_service_area_radius         0 non-null object
# continuous_pickup               18 non-null object
# continuous_drop_off             18 non-null object
# pickup_area_id                  0 non-null object
# drop_off_area_id                0 non-null object
# pickup_service_area_radius      0 non-null object
# drop_off_service_area_radius    0 non-null object
# *shape_id                       49 non-null object
# *seq#                           49 non-null object
# *Dist(m)                        49 non-null object
# *Comment                        0 non-null object
# stop_id                         3980 non-null int32
# arrival_h                       3979 non-null float64
# arrival_m                       3979 non-null float64
# departure_h                     3979 non-null float64
# departure_m                     3979 non-null float64
# tod                             3980 non-null object
# trip_num_x                      3980 non-null int64
# trip_num_y                      1026 non-null float64
# trip_num                        3980 non-null float64
# dtypes: float64(14), int32(4), int64(2), object(33)
# memory usage: 1.6+ MB
# None
#                     service_id                   trip_headsign  direction_id  \
# 938  CT-14OCT-Combo-Weekday-01       San Jose Caltrain Station           1.0
# 939  CT-14OCT-Combo-Weekday-01  San Francisco Caltrain Station           0.0
# 940  CT-14OCT-Combo-Weekday-01  San Francisco Caltrain Station           0.0
# 941  CT-14OCT-Combo-Weekday-01  San Francisco Caltrain Station           0.0
# 942  CT-14OCT-Combo-Weekday-01       San Jose Caltrain Station           1.0
# 943  CT-14OCT-Combo-Weekday-01         Tamien Caltrain Station           1.0
# 944  CT-14OCT-Combo-Weekday-01         Tamien Caltrain Station           1.0
# 945  CT-14OCT-Combo-Weekday-01       San Jose Caltrain Station           1.0
# 946  CT-14OCT-Combo-Weekday-01  San Francisco Caltrain Station           0.0
# 947  CT-14OCT-Combo-Weekday-01  San Francisco Caltrain Station           0.0
# 948  CT-14OCT-Combo-Weekday-01  San Francisco Caltrain Station           0.0
# 949  CT-14OCT-Combo-Weekday-01  San Francisco Caltrain Station           0.0
# 950  CT-14OCT-Combo-Weekday-01  San Francisco Caltrain Station           0.0
# 951  CT-14OCT-Combo-Weekday-01       San Jose Caltrain Station           1.0
# 952  CT-14OCT-Combo-Weekday-01  San Francisco Caltrain Station           0.0
# 953  CT-14OCT-Combo-Weekday-01  San Francisco Caltrain Station           0.0
# 954  CT-14OCT-Combo-Weekday-01  San Francisco Caltrain Station           0.0
# 955  CT-14OCT-Combo-Weekday-01  San Francisco Caltrain Station           0.0
# 956  CT-14OCT-Combo-Weekday-01       San Jose Caltrain Station           1.0
# 957  CT-14OCT-Combo-Weekday-01       San Jose Caltrain Station           1.0
# 958  CT-14OCT-Combo-Weekday-01       San Jose Caltrain Station           1.0
# 959  CT-14OCT-Combo-Weekday-01         Gilroy Caltrain Station           1.0
#
#     block_id trip_short_name     agency_raw_name  wheelchair_accessible  \
# 938      NaN             312  Caltrain_2015_5_13                    NaN
# 939      NaN             365  Caltrain_2015_5_13                    NaN
# 940      NaN             305  Caltrain_2015_5_13                    NaN
# 941      NaN             313  Caltrain_2015_5_13                    NaN
# 942      NaN             360  Caltrain_2015_5_13                    NaN
# 943      NaN             208  Caltrain_2015_5_13                    NaN
# 944      NaN             254  Caltrain_2015_5_13                    NaN
# 945      NaN             262  Caltrain_2015_5_13                    NaN
# 946      NaN             211  Caltrain_2015_5_13                    NaN
# 947      NaN             257  Caltrain_2015_5_13                    NaN
# 948      NaN             261  Caltrain_2015_5_13                    NaN
# 949      NaN             207  Caltrain_2015_5_13                    NaN
# 950      NaN             143  Caltrain_2015_5_13                    NaN
# 951      NaN             196  Caltrain_2015_5_13                    NaN
# 952      NaN             101  Caltrain_2015_5_13                    NaN
# 953      NaN             135  Caltrain_2015_5_13                    NaN
# 954      NaN             191  Caltrain_2015_5_13                    NaN
# 955      NaN             193  Caltrain_2015_5_13                    NaN
# 956      NaN             102  Caltrain_2015_5_13                    NaN
# 957      NaN             134  Caltrain_2015_5_13                    NaN
# 958      NaN             138  Caltrain_2015_5_13                    NaN
# 959      NaN             156  Caltrain_2015_5_13                    NaN
#
#      bikes_allowed original_trip_id trip_bikes_allowed  ... *Comment stop_id  \
# 938            NaN              NaN                NaN  ...      NaN    6607
# 939            NaN              NaN                NaN  ...      NaN    6650
# 940            NaN              NaN                NaN  ...      NaN    6650
# 941            NaN              NaN                NaN  ...      NaN    6650
# 942            NaN              NaN                NaN  ...      NaN    6607
# 943            NaN              NaN                NaN  ...      NaN    6607
# 944            NaN              NaN                NaN  ...      NaN    6607
# 945            NaN              NaN                NaN  ...      NaN    6607
# 946            NaN              NaN                NaN  ...      NaN    6650
# 947            NaN              NaN                NaN  ...      NaN    6652
# 948            NaN              NaN                NaN  ...      NaN    6652
# 949            NaN              NaN                NaN  ...      NaN    6652
# 950            NaN              NaN                NaN  ...      NaN    6650
# 951            NaN              NaN                NaN  ...      NaN    6607
# 952            NaN              NaN                NaN  ...      NaN    6650
# 953            NaN              NaN                NaN  ...      NaN    6650
# 954            NaN              NaN                NaN  ...      NaN    6650
# 955            NaN              NaN                NaN  ...      NaN    6650
# 956            NaN              NaN                NaN  ...      NaN    6607
# 957            NaN              NaN                NaN  ...      NaN    6607
# 958            NaN              NaN                NaN  ...      NaN    6607
# 959            NaN              NaN                NaN  ...      NaN    6607
#
#     arrival_h arrival_m departure_h departure_m tod trip_num_x  trip_num_y  \
# 938       6.0      57.0         6.0        57.0  AM          5         NaN
# 939      16.0      23.0        16.0        23.0  PM          5         NaN
# 940       5.0      45.0         5.0        45.0  EA          2         1.0
# 941       6.0      45.0         6.0        45.0  AM          4         NaN
# 942      16.0       9.0        16.0         9.0  PM          6         NaN
# 943       6.0      24.0         6.0        24.0  AM         10         NaN
# 944      14.0      37.0        14.0        37.0  MD          1         NaN
# 945      16.0      19.0        16.0        19.0  PM         10         NaN
# 946       6.0      20.0         6.0        20.0  AM          9         NaN
# 947      14.0      33.0        14.0        33.0  MD          1         NaN
# 948      15.0      37.0        15.0        37.0  PM         10         NaN
# 949       5.0      50.0         5.0        50.0  EA          1         1.0
# 950      11.0      10.0        11.0        10.0  MD          5         NaN
# 951      22.0      40.0        22.0        40.0  NT          5         1.0
# 952       4.0      30.0         4.0        30.0  EA          2         NaN
# 953       9.0      15.0         9.0        15.0  AM          1         NaN
# 954      18.0      50.0        18.0        50.0  PM          2         NaN
# 955      19.0      30.0        19.0        30.0  NT          4         1.0
# 956       4.0      55.0         4.0        55.0  EA          2         NaN
# 957       9.0       7.0         9.0         7.0  AM          1         NaN
# 958      10.0       7.0        10.0         7.0  MD          5         NaN
# 959      15.0       7.0        15.0         7.0  PM          1         NaN
#
#      trip_num
# 938       5.0
# 939       5.0
# 940       1.0
# 941       4.0
# 942       6.0
# 943      10.0
# 944       1.0
# 945      10.0
# 946       9.0
# 947       1.0
# 948      10.0
# 949       1.0
# 950       5.0
# 951       1.0
# 952       2.0
# 953       1.0
# 954       2.0
# 955       1.0
# 956       2.0
# 957       1.0
# 958       5.0
# 959       1.0
#
# [22 rows x 53 columns]

# %%
trip_df[trip_df.trip_headsign == "22 EASTRIDGE"].trip_id
# Out:
# 3229    27543
# 3230    27582
# 3231    27537
# 3232    27551
# 3233    27592
# Name: trip_id, dtype: int32

# %%
all_shapes_df[all_shapes_df.shape_id == 1691]
all_stop_times_df[all_stop_times_df.trip_id == 27543]
# Out:
#         arrival_time  departure_time  stop_sequence  pickup_type  \
# 986522                          NaN       NaN   NaN      NaN      NaN   27543
# 986523                          NaN       NaN   NaN      NaN      NaN   27543
# 986524                          NaN       NaN   NaN      NaN      NaN   27543
# 986525                          NaN       NaN   NaN      NaN      NaN   27543
# 986526                          NaN       NaN   NaN      NaN      NaN   27543
# 986527                          NaN       NaN   NaN      NaN      NaN   27543
# 986528                          NaN       NaN   NaN      NaN      NaN   27543
# 986529                          NaN       NaN   NaN      NaN      NaN   27543
# 986530                          NaN       NaN   NaN      NaN      NaN   27543
# 986531                          NaN       NaN   NaN      NaN      NaN   27543
# 986532                          NaN       NaN   NaN      NaN      NaN   27543
# 986533                          NaN       NaN   NaN      NaN      NaN   27543
# 986534                          NaN       NaN   NaN      NaN      NaN   27543
# 986535                          NaN       NaN   NaN      NaN      NaN   27543
#
#        stop_id
# 961473   18542
# 961474   16621
# 969728   18370
# 969729   18412
# 969730   18716
# 969731   18776
# 969732   19000
# 969733   18569
# 969734   18999
# 969735   20048
# 970957   18617
# 970958   18857
# 972067   19106
# 986440   18381
# 986441   18393
# 986442   18401
# 986443   18402
# 986444   18404
# 986445   18405
# 986446   18420
# 986447   18431
# 986448   18442
# 986449   18453
# 986450   18465
# 986451   18476
# 986452   18487
# 986453   18498
# 986454   18509
# 986455   18520
# 986456   18531
# ...        ...
# 986506   19061
# 986507   19072
# 986508   19084
# 986509   19095
# 986510   19117
# 986511   19120
# 986512   19121
# 986513   19122
# 986514   19127
# 986515   19138
# 986516   19148
# 986517   19160
# 986518   19163
# 986519   19170
# 986520   19171
# 986521   18671
# 986522   18775
# 986523   18879
# 986524   18923
# 986525   19083
# 986526   19159
# 986527   19186
# 986528   19250
# 986529   19345
# 986530   19417
# 986531   19471
# 986532   19549
# 986533   19582
# 986534   19604
# 986535   19966
#
# [109 rows x 25 columns]

# %%
def snap_stop_to_node(stops, node_gdf):
    
    """
    map gtfs stops to roadway nodes
    
    Parameters:
    ------------
    feed
    drive nodes
    
    return
    ------------
    stops with drive nodes id
    """
    
    print('snapping gtfs stops to roadway node osmid...')
    
    node_non_c_gdf = node_gdf.copy()
    node_non_c_gdf = node_non_c_gdf.to_crs({'init' : 'epsg:26915'})
    node_non_c_gdf['X'] = node_non_c_gdf.geometry.map(lambda g:g.x)
    node_non_c_gdf['Y'] = node_non_c_gdf.geometry.map(lambda g:g.y)
    inventory_node_ref = node_non_c_gdf[['X', 'Y']].values
    tree = cKDTree(inventory_node_ref)
    
    stop_df = stops.copy()
    stop_df['geometry'] = [Point(xy) for xy in zip(stop_df['stop_lon'], stop_df['stop_lat'])]
    stop_df = gpd.GeoDataFrame(stop_df)
    stop_df.crs = {'init' : 'epsg:4326'}
    stop_df = stop_df.to_crs({'init' : 'epsg:26915'})
    stop_df['X'] = stop_df['geometry'].apply(lambda p: p.x)
    stop_df['Y'] = stop_df['geometry'].apply(lambda p: p.y)
   
    for i in range(len(stop_df)):
        point = stop_df.iloc[i][['X', 'Y']].values
        dd, ii = tree.query(point, k = 1)
        add_snap_gdf = gpd.GeoDataFrame(node_non_c_gdf.iloc[ii]).transpose().reset_index(drop = True)
        add_snap_gdf['stop_id'] = stop_df.iloc[i]['stop_id']
        if i == 0:
            stop_to_node_gdf = add_snap_gdf.copy()
        else:
            stop_to_node_gdf = stop_to_node_gdf.append(add_snap_gdf, ignore_index=True, sort=False)
    
    stop_df.drop(['X','Y'], axis = 1, inplace = True)
    stop_to_node_gdf = pd.merge(stop_df, stop_to_node_gdf, how = 'left', on = 'stop_id')
    
    column_list = stops.columns.values.tolist() + ['osm_node_id', 'shst_node_id', "model_node_id"]
    
    return stop_to_node_gdf[column_list]

# %%
# get rid of motorway nodes
non_motorway_links_df = drive_link_df[~drive_link_df.roadway.isin(["motorway", "motorway_link"])].copy()

nodes_for_stops_df = drive_node_gdf[drive_node_gdf.model_node_id.isin(non_motorway_links_df.A.tolist() + 
                                                                     non_motorway_links_df.B.tolist())].copy()

# %%
stop_df = snap_stop_to_node(all_stops_df, nodes_for_stops_df)
# Out:
# snapping gtfs stops to roadway node osmid...
# C:\Users\wangs1\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:68: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\wangs1\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:68: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
stop_df.info()
stop_df.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22153 entries, 0 to 22152
# Data columns (total 20 columns):
# stop_name              22153 non-null object
# stop_lat               22153 non-null float64
# stop_lon               22153 non-null float64
# zone_id                12267 non-null object
# agency_raw_name        22153 non-null object
# stop_code              15488 non-null object
# location_type          5558 non-null float64
# parent_station         620 non-null object
# stop_desc              4319 non-null object
# stop_url               4168 non-null object
# stop_timezone          137 non-null object
# wheelchair_boarding    388 non-null float64
# platform_code          58 non-null object
# position               0 non-null object
# direction              0 non-null object
# * used by routes       125 non-null object
# stop_id                22153 non-null int32
# osm_node_id            22153 non-null object
# shst_node_id           22153 non-null object
# model_node_id          22153 non-null object
# dtypes: float64(4), int32(1), object(15)
# memory usage: 3.5+ MB
#                      stop_name   stop_lat    stop_lon zone_id agency_raw_name  \
# 0          FMT FREMONT STATION  37.558559 -122.007598   55644   ACE_2017_3_20
# 1    GAC GREAT AMERICA STATION  37.406398 -121.966671   55645   ACE_2017_3_20
# 2  LAT LATHROP/MANTECA STATION  37.797908 -121.263664   55449   ACE_2017_3_20
#
#   stop_code  location_type parent_station stop_desc stop_url stop_timezone  \
# 0       NaN            NaN            NaN       NaN      NaN           NaN
# 1       NaN            NaN            NaN       NaN      NaN           NaN
# 2       NaN            NaN            NaN       NaN      NaN           NaN
#
#    wheelchair_boarding platform_code position direction * used by routes  \
# 0                  NaN           NaN      NaN       NaN              NaN
# 1                  NaN           NaN      NaN       NaN              NaN
# 2                  NaN           NaN      NaN       NaN              NaN
#
#    stop_id osm_node_id                      shst_node_id model_node_id
# 0        7    53026824  0d6e8c51d77d4cbf23cf1150a4c73d22       2582218
# 1        8   312418202  4cfcb17d2cf046c6f55ce459194ebc0e       2019349
# 2        2  1832575219  584a0ca93779f09a42595e3d094b8151       2551601

# %%
all_routes_df[all_routes_df.route_type==5]
# Out:
#     route_id_original agency_id route_short_name route_long_name  route_type  \
# 451              1059     SFMTA     Powell-Mason             NaN           5
# 452              1060     SFMTA      Powell-Hyde             NaN           5
# 453             10807     SFMTA       CALIFORNIA             NaN           5
#
#     route_color route_text_color  agency_raw_name route_desc route_url  \
# 451                               SFMTA_2015_8_11
# 452                               SFMTA_2015_8_11
# 453                               SFMTA_2015_8_11
#
#     route_sort_order min_headway_minutes eligibility_restricted  \
# 451              NaN                 NaN                    NaN
# 452              NaN                 NaN                    NaN
# 453              NaN                 NaN                    NaN
#
#     continuous_pickup continuous_drop_off  route_id
# 451               NaN                 NaN       319
# 452               NaN                 NaN       320
# 453               NaN                 NaN       352

# %%
all_routes_df.route_type.value_counts()
# Out:
# 3    687
# 0     10
# 4      9
# 2      8
# 1      6
# 5      3
# Name: route_type, dtype: int64

# %%
def route_bus_link_osmnx(roadway_gdf, node_gdf, G, stop_times, routes, trip, stop):
    
    """
    route bus with OSMNX routing
    
    Parameters
    ----------
    drive link
    drive node
    drive graph
    feed
    trip 
    stop
    
    return
    ----------
    dataframe of drive links bus trips traverses
    list of trips that could not be routed by OSMNX
    """
    
    trip_df = trip.copy()
    stop_df = stop.copy()
    stop_time_df = stop_times.copy()
    
    chained_stop_df = stop_time_df[stop_time_df['trip_id'].isin(trip_df.trip_id.tolist())]
    chained_stop_to_node_df = pd.merge(chained_stop_df, 
                                       stop_df,
                                        how = 'left',
                                        on = 'stop_id')
    
    print('routing bus on roadway network with osmnx...')
    
    #osm_node_dict = dict(zip(node_gdf.osmid, node_gdf.N))
    
    trip_df = pd.merge(trip_df, routes, how = 'left', on = 'route_id')
    bus_trip_df = trip_df[trip_df['route_type'] == 3]
    
    # to track trips that osmnx failed to route
    broken_shape_trip_list = []
    
    # output dataframe for osmnx success
    trip_link_shape_df = pd.DataFrame()
    
    # loop through for bus trips
    for trip_id in bus_trip_df.trip_id.unique():
        
        # get the stops on the trip
        trip_stop_df = chained_stop_to_node_df[chained_stop_to_node_df['trip_id'] == trip_id].copy()
        
        trip_stop_df.sort_values(by = ["stop_sequence"], inplace = True)
        """
        print("routing" + str(trip_id))
        for s in range(len(trip_stop_df)-1):
                # from stop node OSM id
            closest_node_to_stop1 = int(trip_stop_df.osm_node_id.iloc[s])
            print("from {}".format(closest_node_to_stop1))
                
                # to stop node OSM id
            closest_node_to_stop2 = int(trip_stop_df.osm_node_id.iloc[s+1])
            print("to {}".format(closest_node_to_stop2))
                
                # osmnx routing btw from and to stops, return the list of nodes
            node_osmid_list = nx.shortest_path(G, closest_node_to_stop1, closest_node_to_stop2)
            print("path {}".format(node_osmid_list))
                
                # get the links
            if len(node_osmid_list) > 1:
                osm_link_gdf = pd.DataFrame({'u' : node_osmid_list[:len(node_osmid_list)-1], 
                                            'v' : node_osmid_list[1:len(node_osmid_list)],
                                            'trip_id' : trip_id},
                                               )
            else:
                continue
                
            trip_link_shape_df = trip_link_shape_df.append(osm_link_gdf, ignore_index = True, sort = False)
                     
        """
        try:
            print("routing" + str(trip_id))
            for s in range(len(trip_stop_df)-1):
                # from stop node OSM id
                closest_node_to_stop1 = int(trip_stop_df.osm_node_id.iloc[s])
                
                # to stop node OSM id
                closest_node_to_stop2 = int(trip_stop_df.osm_node_id.iloc[s+1])
                
                # osmnx routing btw from and to stops, return the list of nodes
                node_osmid_list = nx.shortest_path(G, closest_node_to_stop1, closest_node_to_stop2, weight = "length")
                
                # get the links
                if len(node_osmid_list) > 1:
                    osm_link_gdf = pd.DataFrame({'u' : node_osmid_list[:len(node_osmid_list)-1], 
                                            'v' : node_osmid_list[1:len(node_osmid_list)],
                                            'trip_id' : trip_id},
                                               )
                else:
                    continue
                
                trip_link_shape_df = trip_link_shape_df.append(osm_link_gdf, ignore_index = True, sort = False)
                
        

        except:
            broken_shape_trip_list = broken_shape_trip_list + [trip_id]
            print('  warning: cannot route bus: ' + str(trip_id))
            continue      
       #"""        
    trip_link_shape_df = pd.merge(trip_link_shape_df, trip_df[['trip_id', 'shape_id']], how = 'left', on = 'trip_id')

    trip_link_shape_df = pd.merge(trip_link_shape_df,
                                  drive_link_df[["u", "v", "wayId", "shstReferenceId", "shstGeometryId", "A", "B"]].\
                                      drop_duplicates(subset = ["u", "v"]),
                                  how = "left",
                                  on = ["u", "v"])
    
    
    return trip_link_shape_df, broken_shape_trip_list

# %%
stop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22153 entries, 0 to 22152
# Data columns (total 20 columns):
# stop_name              22153 non-null object
# stop_lat               22153 non-null float64
# stop_lon               22153 non-null float64
# zone_id                12267 non-null object
# agency_raw_name        22153 non-null object
# stop_code              15488 non-null object
# location_type          5558 non-null float64
# parent_station         620 non-null object
# stop_desc              4319 non-null object
# stop_url               4168 non-null object
# stop_timezone          137 non-null object
# wheelchair_boarding    388 non-null float64
# platform_code          58 non-null object
# position               0 non-null object
# direction              0 non-null object
# * used by routes       125 non-null object
# stop_id                22153 non-null int32
# osm_node_id            22153 non-null object
# shst_node_id           22153 non-null object
# model_node_id          22153 non-null object
# dtypes: float64(4), int32(1), object(15)
# memory usage: 3.5+ MB

# %%
bus_route_list = all_routes_df[all_routes_df.route_type ==3].route_id.tolist()

# %%
trip_df.shape
# Out:
# (3980, 53)

# %%
trip_df[trip_df.route_id.isin(bus_route_list)]
# Out:
#                 service_id                            trip_headsign  \
# 3     1508FA-D2-Weekday-01                          G SAN FRANCISCO
# 4     1508FA-D2-Weekday-01                          G SAN FRANCISCO
# 5     1508FA-D2-Weekday-01                         LA HILLTOP P & R
# 6     1508FA-D2-Weekday-01                         LA SAN FRANCISCO
# 7     1508FA-D2-Weekday-01                          Z WEST BERKELEY
# 8     1508FA-D2-Weekday-01                          Z SAN FRANCISCO
# 9     1508FA-D2-Weekday-01                         12 BERKELEY BART
# 10    1508FA-D2-Weekday-01                         12 BERKELEY BART
# 11    1508FA-D2-Weekday-01                         12 BERKELEY BART
# 12    1508FA-D2-Weekday-01                       669 CRESPI MDL SCL
# 13    1508FA-D2-Weekday-01                         671 DE ANZA HIGH
# 14    1508FA-D2-Weekday-01                         676 DE ANZA HIGH
# 15    1508FA-D2-Weekday-01                       667 NORTH RICHMOND
# 16    1508FA-D2-Weekday-01                        607 RICHMOND HIGH
# 17    1508FA-D2-Weekday-01                     668 MACDONALD & 21ST
# 18    1508FA-D2-Weekday-01                        672 LEROY HEIGHTS
# 19    1508FA-D2-Weekday-01                     668 MACDONALD & 21ST
# 20    1508FA-D2-Weekday-01                          669 TO MAY ROAD
# 21    1508FA-D2-Weekday-01                          671 C C COLLEGE
# 22    1508FA-D2-Weekday-01                          676 C C COLLEGE
# 23    1508FA-D2-Weekday-01                     675 MACDONALD & 21ST
# 24    1508FA-D2-Weekday-01                          679 C C COLLEGE
# 25    1508FA-D2-Weekday-01                     675 MACDONALD & 21ST
# 26    1508FA-D2-Weekday-01                          671 C C COLLEGE
# 27    1508FA-D2-Weekday-01                       667 NORTH RICHMOND
# 28    1508FA-D2-Weekday-01                    668 KOREMATSU MDL SCL
# 29    1508FA-D2-Weekday-01                       679 CRESPI MDL SCL
# 30    1508FA-D2-Weekday-01                          676 C C COLLEGE
# 31    1508FA-D2-Weekday-01                      681 DE JEAN MDL SCl
# 32    1508FA-D2-Weekday-01                    681 MACD & RICH. PKWY
# ...                    ...                                      ...
# 3950                 mtwtf                                  Seaport
# 3951                 mtwtf                               Laurelwood
# 3952                 mtwtf                               Laurelwood
# 3953                 mtwtf                       Hillsdale Caltrain
# 3954                 mtwtf                       Hillsdale Caltrain
# 3955                 mtwtf                       Hillsdale Caltrain
# 3956                 mtwtf                       Hillsdale Caltrain
# 3957                 mtwtf                      South San Francisco
# 3958                 mtwtf                      South San Francisco
# 3959                 mtwtf               So. San Francisco B.A.R.T.
# 3960                 mtwtf               So. San Francisco B.A.R.T.
# 3961                 mtwtf               So. San Francisco Caltrain
# 3962                 mtwtf               So. San Francisco Caltrain
# 3963                 mtwtf               So. San Francisco Caltrain
# 3964                 mtwtf               So. San Francisco Caltrain
# 3965                 mtwtf         So. San Francisco Caltrain/Ferry
# 3966                 mtwtf                  So. San Francisco Ferry
# 3967                 mtwtf               So. San Francisco B.A.R.T.
# 3968                 mtwtf               So. San Francisco B.A.R.T.
# 3969                 mtwtf               So. San Francisco Caltrain
# 3970                 mtwtf               So. San Francisco Caltrain
# 3971                 mtwtf               So. San Francisco Caltrain
# 3972                 mtwtf               So. San Francisco Caltrain
# 3973                 mtwtf               So. San Francisco Caltrain
# 3974                 mtwtf  So. San Francisco Ferry at Oyster Point
# 3975                 mtwtf  So. San Francisco Ferry at Oyster Point
# 3976                 mtwtf                           Bridge Parkway
# 3977                 mtwtf                           Bridge Parkway
# 3978                 mtwtf                           Bridge Parkway
# 3979                 mtwtf                           Bridge Parkway
#
#       direction_id block_id trip_short_name  \
# 3              1.0   601820             NaN
# 4              1.0   601804             NaN
# 5              0.0   601870             NaN
# 6              1.0   601827             NaN
# 7              0.0   601804             NaN
# 8              1.0   601825             NaN
# 9              0.0   601759             NaN
# 10             0.0   601755             NaN
# 11             0.0   601893             NaN
# 12             0.0   601867             NaN
# 13             0.0   601847             NaN
# 14             0.0   601849             NaN
# 15             1.0   601817             NaN
# 16             0.0   601851             NaN
# 17             1.0   601816             NaN
# 18             1.0   601819             NaN
# 19             1.0   601924             NaN
# 20             1.0   601809             NaN
# 21             1.0   601802             NaN
# 22             1.0   601817             NaN
# 23             1.0   607787             NaN
# 24             1.0   601799             NaN
# 25             1.0   601818             NaN
# 26             1.0   601818             NaN
# 27             1.0   601802             NaN
# 28             0.0   601850             NaN
# 29             0.0   601866             NaN
# 30             1.0   601808             NaN
# 31             0.0   601851             NaN
# 32             1.0   601807             NaN
# ...            ...      ...             ...
# 3950           0.0      NaN             NaN
# 3951           0.0      NaN             NaN
# 3952           1.0      NaN             NaN
# 3953           0.0      NaN             NaN
# 3954           1.0      NaN             NaN
# 3955           0.0      NaN             NaN
# 3956           1.0      NaN             NaN
# 3957           0.0      NaN             NaN
# 3958           0.0      NaN             NaN
# 3959           0.0      NaN             NaN
# 3960           1.0      NaN             NaN
# 3961           0.0      NaN             NaN
# 3962           0.0      NaN             NaN
# 3963           1.0      NaN             NaN
# 3964           1.0      NaN             NaN
# 3965           0.0      NaN             NaN
# 3966           1.0      NaN             NaN
# 3967           0.0      NaN             NaN
# 3968           0.0      NaN             NaN
# 3969           1.0      NaN             NaN
# 3970           1.0      NaN             NaN
# 3971           1.0      NaN             NaN
# 3972           1.0      NaN             NaN
# 3973           0.0      NaN             NaN
# 3974           1.0      NaN             NaN
# 3975           1.0      NaN             NaN
# 3976           0.0      NaN             NaN
# 3977           0.0      NaN             NaN
# 3978           0.0      NaN             NaN
# 3979           0.0      NaN             NaN
#
#                                        agency_raw_name  wheelchair_accessible  \
# 3                                  ACTransit_2015_8_14                    NaN
# 4                                  ACTransit_2015_8_14                    NaN
# 5                                  ACTransit_2015_8_14                    NaN
# 6                                  ACTransit_2015_8_14                    NaN
# 7                                  ACTransit_2015_8_14                    NaN
# 8                                  ACTransit_2015_8_14                    NaN
# 9                                  ACTransit_2015_8_14                    NaN
# 10                                 ACTransit_2015_8_14                    NaN
# 11                                 ACTransit_2015_8_14                    NaN
# 12                                 ACTransit_2015_8_14                    NaN
# 13                                 ACTransit_2015_8_14                    NaN
# 14                                 ACTransit_2015_8_14                    NaN
# 15                                 ACTransit_2015_8_14                    NaN
# 16                                 ACTransit_2015_8_14                    NaN
# 17                                 ACTransit_2015_8_14                    NaN
# 18                                 ACTransit_2015_8_14                    NaN
# 19                                 ACTransit_2015_8_14                    NaN
# 20                                 ACTransit_2015_8_14                    NaN
# 21                                 ACTransit_2015_8_14                    NaN
# 22                                 ACTransit_2015_8_14                    NaN
# 23                                 ACTransit_2015_8_14                    NaN
# 24                                 ACTransit_2015_8_14                    NaN
# 25                                 ACTransit_2015_8_14                    NaN
# 26                                 ACTransit_2015_8_14                    NaN
# 27                                 ACTransit_2015_8_14                    NaN
# 28                                 ACTransit_2015_8_14                    NaN
# 29                                 ACTransit_2015_8_14                    NaN
# 30                                 ACTransit_2015_8_14                    NaN
# 31                                 ACTransit_2015_8_14                    NaN
# 32                                 ACTransit_2015_8_14                    NaN
# ...                                                ...                    ...
# 3950  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3951  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3952  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3953  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3954  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3955  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3956  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3957  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3958  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3959  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3960  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3961  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3962  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3963  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3964  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3965  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3966  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3967  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3968  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3969  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3970  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3971  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3972  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3973  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3974  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3975  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3976  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3977  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3978  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
# 3979  commuteDOTorg_GTFSImportExport_20160127_final_mj                    NaN
#
#       bikes_allowed original_trip_id trip_bikes_allowed  ... *Comment stop_id  \
# 3               NaN              NaN                NaN  ...      NaN     917
# 4               NaN              NaN                NaN  ...      NaN     917
# 5               NaN              NaN                NaN  ...      NaN    4191
# 6               NaN              NaN                NaN  ...      NaN    4042
# 7               NaN              NaN                NaN  ...      NaN    4192
# 8               NaN              NaN                NaN  ...      NaN     235
# 9               NaN              NaN                NaN  ...      NaN    2034
# 10              NaN              NaN                NaN  ...      NaN    2034
# 11              NaN              NaN                NaN  ...      NaN    2034
# 12              NaN              NaN                NaN  ...      NaN    4504
# 13              NaN              NaN                NaN  ...      NaN    4505
# 14              NaN              NaN                NaN  ...      NaN    4505
# 15              NaN              NaN                NaN  ...      NaN     833
# 16              NaN              NaN                NaN  ...      NaN    4126
# 17              NaN              NaN                NaN  ...      NaN     833
# 18              NaN              NaN                NaN  ...      NaN    5167
# 19              NaN              NaN                NaN  ...      NaN     833
# 20              NaN              NaN                NaN  ...      NaN    5167
# 21              NaN              NaN                NaN  ...      NaN    5348
# 22              NaN              NaN                NaN  ...      NaN    5167
# 23              NaN              NaN                NaN  ...      NaN     833
# 24              NaN              NaN                NaN  ...      NaN    5167
# 25              NaN              NaN                NaN  ...      NaN     833
# 26              NaN              NaN                NaN  ...      NaN    5167
# 27              NaN              NaN                NaN  ...      NaN     833
# 28              NaN              NaN                NaN  ...      NaN    4076
# 29              NaN              NaN                NaN  ...      NaN    4504
# 30              NaN              NaN                NaN  ...      NaN    5348
# 31              NaN              NaN                NaN  ...      NaN    4135
# 32              NaN              NaN                NaN  ...      NaN    4153
# ...             ...              ...                ...  ...      ...     ...
# 3950            NaN              NaN                NaN  ...      NaN   22107
# 3951            NaN              NaN                NaN  ...      NaN   22117
# 3952            NaN              NaN                NaN  ...      NaN   22115
# 3953            NaN              NaN                NaN  ...      NaN   22085
# 3954            NaN              NaN                NaN  ...      NaN   22087
# 3955            NaN              NaN                NaN  ...      NaN   22085
# 3956            NaN              NaN                NaN  ...      NaN   22085
# 3957            NaN              NaN                NaN  ...      NaN   22130
# 3958            NaN              NaN                NaN  ...      NaN   22128
# 3959            NaN              NaN                NaN  ...      NaN   22130
# 3960            NaN              NaN                NaN  ...      NaN   22134
# 3961            NaN              NaN                NaN  ...      NaN   22152
# 3962            NaN              NaN                NaN  ...      NaN   22152
# 3963            NaN              NaN                NaN  ...      NaN   22132
# 3964            NaN              NaN                NaN  ...      NaN   22152
# 3965            NaN              NaN                NaN  ...      NaN   22141
# 3966            NaN              NaN                NaN  ...      NaN   22152
# 3967            NaN              NaN                NaN  ...      NaN   22130
# 3968            NaN              NaN                NaN  ...      NaN   22142
# 3969            NaN              NaN                NaN  ...      NaN   22152
# 3970            NaN              NaN                NaN  ...      NaN   22142
# 3971            NaN              NaN                NaN  ...      NaN   22142
# 3972            NaN              NaN                NaN  ...      NaN   22152
# 3973            NaN              NaN                NaN  ...      NaN   22141
# 3974            NaN              NaN                NaN  ...      NaN   22152
# 3975            NaN              NaN                NaN  ...      NaN   22152
# 3976            NaN              NaN                NaN  ...      NaN   22085
# 3977            NaN              NaN                NaN  ...      NaN   22035
# 3978            NaN              NaN                NaN  ...      NaN   22035
# 3979            NaN              NaN                NaN  ...      NaN   22085
#
#      arrival_h arrival_m departure_h departure_m tod trip_num_x  trip_num_y  \
# 3          5.0      33.0         5.0        33.0  EA          1         1.0
# 4          6.0      33.0         6.0        33.0  AM          5         NaN
# 5         16.0       0.0        16.0         0.0  PM         13         NaN
# 6          7.0       9.0         7.0         9.0  AM          9         NaN
# 7          7.0      26.0         7.0        26.0  AM          2         NaN
# 8         16.0      45.0        16.0        45.0  PM          2         NaN
# 9          6.0      10.0         6.0        10.0  AM         10         NaN
# 10        15.0      29.0        15.0        29.0  PM         12         NaN
# 11        19.0      10.0        19.0        10.0  NT          7         6.0
# 12         7.0      34.0         7.0        34.0  AM          1         NaN
# 13         8.0       5.0         8.0         5.0  AM          1         NaN
# 14         8.0       3.0         8.0         3.0  AM          2         NaN
# 15        15.0      52.0        15.0        52.0  PM          1         NaN
# 16         7.0       8.0         7.0         8.0  AM          1         NaN
# 17        14.0       7.0        14.0         7.0  MD          2         NaN
# 18        14.0      52.0        14.0        52.0  MD          1         NaN
# 19        15.0      52.0        15.0        52.0  PM          1         NaN
# 20        14.0      52.0        14.0        52.0  MD          1         NaN
# 21        15.0      45.0        15.0        45.0  PM          2         NaN
# 22        14.0      52.0        14.0        52.0  MD          1         NaN
# 23        14.0       7.0        14.0         7.0  MD          2         NaN
# 24        14.0      52.0        14.0        52.0  MD          1         NaN
# 25        15.0      52.0        15.0        52.0  PM          1         NaN
# 26        14.0      52.0        14.0        52.0  MD          1         NaN
# 27        14.0       7.0        14.0         7.0  MD          2         NaN
# 28         7.0      11.0         7.0        11.0  AM          1         NaN
# 29         7.0      46.0         7.0        46.0  AM          1         NaN
# 30        15.0      45.0        15.0        45.0  PM          1         NaN
# 31         7.0      58.0         7.0        58.0  AM          1         NaN
# 32        14.0      52.0        14.0        52.0  MD          1         NaN
# ...        ...       ...         ...         ...  ..        ...         ...
# 3950      15.0      56.0        15.0        56.0  PM          7         NaN
# 3951       6.0      24.0         6.0        24.0  AM          5         NaN
# 3952      15.0      22.0        15.0        22.0  PM          5         NaN
# 3953       6.0      56.0         6.0        56.0  AM          5         NaN
# 3954      15.0       9.0        15.0         9.0  PM          5         NaN
# 3955       7.0       8.0         7.0         8.0  AM          6         NaN
# 3956      15.0      51.0        15.0        51.0  PM          6         NaN
# 3957       6.0      50.0         6.0        50.0  AM          6         NaN
# 3958      16.0       4.0        16.0         4.0  PM          6         NaN
# 3959       6.0      40.0         6.0        40.0  AM          7         NaN
# 3960      15.0       0.0        15.0         0.0  PM          7         NaN
# 3961       5.0      47.0         5.0        47.0  EA          1         1.0
# 3962       6.0      45.0         6.0        45.0  AM          7         NaN
# 3963      14.0      58.0        14.0        58.0  MD          1         NaN
# 3964      15.0      33.0        15.0        33.0  PM          6         NaN
# 3965       7.0      25.0         7.0        25.0  AM          4         NaN
# 3966      15.0      44.0        15.0        44.0  PM          3         NaN
# 3967       6.0      10.0         6.0        10.0  AM          8         NaN
# 3968      15.0       4.0        15.0         4.0  PM          7         NaN
# 3969       6.0      45.0         6.0        45.0  AM          7         NaN
# 3970      14.0      35.0        14.0        35.0  MD          1         NaN
# 3971      15.0      38.0        15.0        38.0  PM          6         NaN
# 3972       5.0      47.0         5.0        47.0  EA          1         1.0
# 3973       7.0      25.0         7.0        25.0  AM          3         NaN
# 3974       6.0      45.0         6.0        45.0  AM          1         NaN
# 3975      15.0      35.0        15.0        35.0  PM          3         NaN
# 3976       7.0      21.0         7.0        21.0  AM          5         NaN
# 3977      16.0       8.0        16.0         8.0  PM          6         NaN
# 3978      19.0      17.0        19.0        17.0  NT          1         1.0
# 3979      10.0      14.0        10.0        14.0  MD          1         NaN
#
#       trip_num
# 3          1.0
# 4          5.0
# 5         13.0
# 6          9.0
# 7          2.0
# 8          2.0
# 9         10.0
# 10        12.0
# 11         6.0
# 12         1.0
# 13         1.0
# 14         2.0
# 15         1.0
# 16         1.0
# 17         2.0
# 18         1.0
# 19         1.0
# 20         1.0
# 21         2.0
# 22         1.0
# 23         2.0
# 24         1.0
# 25         1.0
# 26         1.0
# 27         2.0
# 28         1.0
# 29         1.0
# 30         1.0
# 31         1.0
# 32         1.0
# ...        ...
# 3950       7.0
# 3951       5.0
# 3952       5.0
# 3953       5.0
# 3954       5.0
# 3955       6.0
# 3956       6.0
# 3957       6.0
# 3958       6.0
# 3959       7.0
# 3960       7.0
# 3961       1.0
# 3962       7.0
# 3963       1.0
# 3964       6.0
# 3965       4.0
# 3966       3.0
# 3967       8.0
# 3968       7.0
# 3969       7.0
# 3970       1.0
# 3971       6.0
# 3972       1.0
# 3973       3.0
# 3974       1.0
# 3975       3.0
# 3976       5.0
# 3977       6.0
# 3978       1.0
# 3979       1.0
#
# [3691 rows x 53 columns]

# %%
link_df[link_df.u == 890045140][["roadway", "drive_access", "walk_access", "bike_access"]]
# Out:
#          roadway  drive_access  walk_access  bike_access
# 235925   service             1            1            1
# 863713   service             1            1            1
# 1530026  service             1            1            1

# %%
bus_osmnx_link_shape_df, bus_osmnx_broken_trip_list = route_bus_link_osmnx(drive_link_df, 
                                                                            drive_node_gdf, 
                                                                            G_drive, 
                                                                            all_stop_times_df,
                                                                            all_routes_df,
                                                                            trip_df, 
                                                                            stop_df)
# Out:
# routing bus on roadway network with osmnx...
# routing9
# routing10
# routing11
# routing20
# routing21
# routing22
# routing23
# routing31
# routing42
# routing44
# routing45
# routing46
# routing48
# routing49
# routing50
# routing51
# routing52
# routing53
# routing54
# routing55
# routing57
# routing58
# routing59
# routing60
# routing61
# routing63
# routing64
# routing65
# routing66
# routing67
# routing69
# routing74
# routing75
# routing78
# routing80
# routing81
# routing83
# routing91
# routing92
# routing94
# routing95
# routing96
# routing97
# routing104
# routing106
# routing108
# routing114
# routing116
# routing120
# routing126
# routing127
# routing128
# routing139
# routing144
# routing149
# routing153
# routing183
# routing184
# routing188
# routing193
# routing197
# routing199
# routing207
# routing217
# routing225
# routing228
# routing235
# routing245
# routing253
# routing257
# routing277
# routing302
# routing322
# routing324
# routing344
# routing369
# routing389
# routing392
# routing393
# routing395
# routing396
# routing399
# routing400
# routing408
# routing409
# routing443
# routing444
# routing447
# routing450
# routing459
# routing460
# routing462
# routing480
# routing481
# routing496
# routing507
# routing516
# routing522
# routing529
# routing533
# routing544
# routing547
# routing560
# routing569
# routing581
# routing582
# routing590
# routing600
# routing608
# routing614
# routing615
# routing623
# routing633
# routing641
# routing648
# routing652
# routing659
# routing661
# routing664
# routing671
# routing677
# routing722
# routing723
# routing731
# routing736
# routing743
# routing745
# routing754
# routing756
# routing759
# routing770
# routing807
# routing811
# routing812
# routing821
# routing822
# routing827
# routing828
# routing866
# routing867
# routing875
# routing885
# routing893
# routing894
# routing896
# routing904
# routing914
# routing922
# routing928
# routing929
# routing937
# routing947
# routing955
# routing963
# routing973
# routing981
# routing982
# routing983
# routing987
# routing989
# routing1011
# routing1012
# routing1013
# routing1016
# routing1019
# routing1021
# routing1022
# routing1023
# routing1036
# routing1047
# routing1071
# routing1077
# routing1087
# routing1095
# routing1104
# routing1106
# routing1115
# routing1120
# routing1121
# routing1150
# routing1151
# routing1158
# routing1159
# routing1160
# routing1161
# routing1163
# routing1164
# routing1167
# routing1168
# routing1218
# routing1220
# routing1222
# routing1230
# routing1240
# routing1250
# routing1256
# routing1264
# routing1274
# routing1283
# routing1284
# routing1286
# routing1287
# routing1297
# routing1298
# routing1299
# routing1300
# routing1302
# routing1303
# routing1306
# routing1308
# routing1309
# routing1310
# routing1433
# routing1434
# routing1435
# routing1436
# routing1437
# routing1438
# routing1439
# routing1440
# routing1443
# routing1445
# routing1446
# routing1447
# routing1448
# routing1449
# routing1450
# routing1453
# routing1461
# routing1472
# routing1475
# routing1494
# routing1579
# routing1580
# routing1581
# routing1582
# routing1590
# routing1591
# routing1600
# routing1601
# routing1620
# routing1621
# routing1780
# routing1782
# routing1786
# routing1787
# routing1798
# routing1799
# routing1816
# routing1817
# routing1828
# routing1940
# routing1943
# routing1944
# routing1947
# routing1948
# routing1949
# routing1951
# routing1953
# routing1954
# routing1956
# routing1958
# routing1959
# routing1962
# routing1968
# routing1970
# routing1971
# routing1973
# routing1974
# routing1976
# routing1980
# routing1981
# routing1983
# routing1985
# routing1986
# routing1987
# routing1988
# routing1989
# routing1990
# routing1991
# routing1992
# routing1993
# routing1994
# routing1995
# routing1996
# routing1997
# routing1998
# routing1999
# routing2002
# routing2003
# routing2004
# routing2005
# routing2008
# routing2009
# routing2011
# routing2014
# routing2015
# routing2016
# routing2017
# routing2018
# routing2019
# routing2023
# routing2024
# routing5495
# routing5497
# routing5498
# routing5504
# routing5512
# routing5518
# routing5519
# routing5520
# routing5526
# routing5533
# routing5539
# routing5545
# routing5546
# routing5547
# routing5548
# routing5551
# routing5552
# routing5557
# routing5565
# routing5602
# routing5604
# routing5614
# routing5615
# routing5618
# routing5619
# routing5622
# routing5624
# routing5625
# routing5627
# routing5629
# routing5656
# routing5680
# routing5682
# routing5686
# routing5687
# routing5688
# routing5692
# routing5693
# routing5699
# routing5701
# routing5709
# routing5712
# routing5728
# routing5742
# routing5744
# routing5754
# routing5762
# routing5767
# routing7809
# routing7772
# routing7682
# routing7481
# routing7648
# routing7533
# routing7618
# routing7212
# routing7607
# routing7570
# routing7861
# routing6894
# routing7900
# routing7223
# routing7087
# routing7437
# routing7412
# routing7854
# routing6887
# routing7798
# routing7180
# routing7179
# routing7465
# routing7499
# routing7494
# routing7323
# routing7622
# routing7327
# routing7276
# routing7667
# routing7121
# routing7563
# routing7137
# routing7403
# routing6917
# routing7211
# routing7228
# routing7753
# routing7205
# routing7194
# routing7868
# routing7915
# routing7732
# routing7581
# routing6932
# routing7921
# routing6940
# routing7794
# routing7420
# routing7545
# routing7167
# routing7290
# routing7777
# routing7497
# routing7156
# routing6908
# routing7832
# routing7597
# routing7364
# routing6930
# routing7428
# routing6882
# routing7909
# routing7145
# routing7784
# routing7800
# routing7837
# routing7602
# routing7604
# routing7906
# routing7074
# routing7264
# routing7926
# routing7016
# routing7914
# routing6961
# routing7118
# routing6979
# routing7357
# routing7022
# routing7091
# routing7375
# routing7553
# routing6897
# routing7082
# routing7081
# routing7392
# routing7630
# routing7890
# routing7932
# routing7114
# routing7112
# routing6904
# routing7705
# routing7160
# routing7452
# routing7889
# routing7574
# routing7446
# routing7702
# routing7681
# routing6935
# routing7898
# routing7843
# routing7700
# routing7005
# routing7313
# routing7243
# routing7105
# routing7917
# routing6970
# routing7054
# routing7802
# routing7818
# routing7876
# routing6958
# routing7652
# routing7380
# routing7369
# routing6992
# routing7888
# routing7768
# routing7069
# routing6931
# routing7050
# routing7588
# routing7882
# routing7759
# routing7536
# routing7258
# routing6918
# routing7940
# routing7250
# routing7591
# routing7120
# routing7010
# routing7824
# routing7067
# routing7453
# routing7253
# routing7650
# routing7551
# routing7517
# routing7238
# routing7102
# routing7041
# routing7567
# routing7929
# routing7557
# routing7538
# routing7741
# routing6891
# routing7748
# routing7849
# routing7099
# routing6911
# routing6913
# routing7750
# routing7797
# routing7242
# routing7034
# routing7033
# routing7095
# routing7431
# routing7811
# routing7941
# routing7726
# routing7737
# routing7059
# routing7507
# routing7816
# routing6915
# routing7872
# routing7635
# routing7616
# routing7924
# routing7093
# routing6926
# routing7627
# routing7515
# routing7594
# routing7717
# routing7715
# routing7850
# routing7441
# routing7694
# routing7934
# routing6890
# routing7078
# routing7904
# routing7220
# routing7624
# routing7935
# routing7270
# routing7490
# routing7268
# routing7714
# routing7826
# routing7092
# routing7937
# routing7318
# routing7073
# routing7774
# routing7013
# routing7531
# routing7440
# routing7062
# routing32802
# routing11209
#   warning: cannot route bus: 11209
# routing11213
#   warning: cannot route bus: 11213
# routing11216
#   warning: cannot route bus: 11216
# routing11208
#   warning: cannot route bus: 11208
# routing11211
#   warning: cannot route bus: 11211
# routing11210
# routing11217
#   warning: cannot route bus: 11217
# routing11214
#   warning: cannot route bus: 11214
# routing22924
# routing22926
# routing22931
# routing22933
# routing22935
# routing22936
# routing22937
# routing22940
# routing22946
# routing22950
# routing22955
# routing22960
# routing22967
# routing22977
# routing22980
# routing23005
# routing23006
# routing23008
# routing23011
# routing23016
# routing23018
# routing23023
# routing23024
# routing23029
# routing23035
# routing23042
# routing23047
# routing23048
# routing23052
# routing23057
# routing23060
# routing23068
# routing23078
# routing23085
# routing23089
# routing23090
# routing23092
# routing23094
# routing23095
# routing23099
# routing23101
# routing23104
# routing23106
# routing23112
# routing23113
# routing23114
# routing23115
# routing23127
# routing23128
# routing23137
# routing23138
# routing23142
# routing23149
# routing23150
# routing23154
# routing23155
# routing23163
# routing23165
# routing23166
# routing23180
# routing23181
# routing23191
# routing23194
# routing23199
# routing23200
# routing23205
# routing23206
# routing23207
# routing23211
# routing23213
# routing23251
# routing23252
# routing23255
# routing23257
# routing23261
# routing23288
# routing23293
# routing23294
# routing23299
# routing23302
# routing23306
# routing23311
# routing23328
# routing23336
# routing23346
# routing23353
# routing23354
# routing23355
# routing23358
# routing23360
# routing23362
# routing23363
# routing23366
# routing23367
# routing23374
# routing23375
# routing23384
# routing23385
# routing23392
# routing23393
# routing23400
# routing23401
# routing23410
# routing23411
# routing23418
# routing23419
# routing23420
# routing23421
# routing23422
# routing23432
# routing23437
# routing23453
# routing23454
# routing23458
# routing23460
# routing23461
# routing23464
# routing23465
# routing23466
# routing23467
#   warning: cannot route bus: 23467
# routing23468
# routing23469
# routing23477
# routing23479
# routing23480
# routing23481
# routing23482
# routing23485
# routing23486
# routing23487
# routing23491
# routing23492
# routing23495
# routing23496
# routing23497
# routing23498
# routing23499
# routing23501
# routing23502
# routing23504
# routing23505
# routing23507
# routing23509
# routing23510
# routing23511
# routing23512
# routing23513
# routing23514
# routing23519
# routing23520
# routing23526
# routing23527
# routing23528
# routing23530
# routing23531
# routing23533
# routing23534
# routing23535
# routing23536
# routing23537
# routing23538
# routing23539
# routing23541
# routing23542
# routing23546
# routing23547
# routing23556
# routing23557
# routing23568
# routing23576
# routing23604
# routing23605
# routing23613
# routing23616
# routing23624
# routing23625
# routing23631
# routing23638
# routing23640
# routing23644
# routing23645
# routing23652
# routing23655
# routing23656
# routing23662
# routing23663
# routing23667
# routing23668
# routing23680
# routing23697
# routing23740
# routing23756
# routing23757
# routing23759
# routing23760
# routing23763
# routing23779
# routing23780
# routing23784
# routing23797
# routing23798
# routing23803
# routing23804
# routing23818
# routing23823
# routing23910
# routing23934
# routing23988
# routing23989
# routing24086
# routing24162
# routing24163
# routing24190
# routing24270
# routing24271
# routing24273
# routing24283
# routing24286
# routing24297
# routing24298
# routing24313
# routing24314
# routing24318
# routing24326
# routing24327
# routing32561
# routing32557
# routing32555
# routing32562
# routing32571
# routing32572
# routing32577
# routing32582
# routing32585
# routing32588
# routing32590
# routing32591
# routing32593
# routing32594
# routing32596
# routing32597
# routing32598
# routing32599
# routing32601
# routing32602
# routing32603
# routing32604
# routing32605
# routing32606
# routing32607
# routing32608
# routing32610
# routing32611
# routing32612
# routing32613
# routing32614
# routing32615
# routing32636
# routing32630
# routing32622
# routing32616
# routing32618
# routing32639
# routing32643
# routing32648
# routing32652
# routing32656
# routing32661
# routing32665
# routing32676
# routing32666
# routing31969
# routing31985
# routing32005
# routing32021
# routing32077
# routing33707
# routing33708
# routing33711
# routing33714
# routing33715
# routing33725
# routing33726
# routing33523
# routing33528
# routing33578
# routing33586
# routing33546
# routing33550
# routing33594
# routing33602
# routing33609
# routing33736
# routing33742
# routing33625
# routing33632
# routing33697
# routing33702
# routing33556
# routing33561
# routing33567
# routing33572
# routing33534
# routing33540
# routing33610
# routing33617
# routing33639
# routing33640
# routing33647
# routing33648
# routing33654
# routing33657
# routing33667
# routing33675
# routing33682
# routing33689
# routing33690
# routing33696
# routing33664
# routing33660
# routing33661
# routing33510
# routing33515
# routing33521
# routing33522

# %%
bus_osmnx_link_shape_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 934579 entries, 0 to 934578
# Data columns (total 9 columns):
# u                  934579 non-null int64
# v                  934579 non-null int64
# trip_id            934579 non-null int64
# shape_id           934579 non-null int32
# wayId              934579 non-null object
# shstReferenceId    934579 non-null object
# shstGeometryId     934579 non-null object
# A                  934579 non-null int64
# B                  934579 non-null int64
# dtypes: int32(1), int64(5), object(3)
# memory usage: 67.7+ MB

# %%
# osmnx failed to route these trips: can be rail modes
print(bus_osmnx_broken_trip_list)
# Out:
# [8363, 8361, 8357, 8358, 8364, 11209, 11213, 11216, 11208, 11211, 11217, 11214, 23467]

# %%
bus_osmnx_link_shape_df[bus_osmnx_link_shape_df.shape_id == 362]
all_routes_df[(all_routes_df.agency_raw_name == "ACTransit_2015_8_14") & (all_routes_df.route_short_name == "P")]
trip_df[trip_df.route_id == 147][["trip_id", "direction_id"]]
# Out:
#      trip_id  direction_id
# 266     1962           0.0
# 267     1968           0.0
# 323     2080           1.0

# %%
# shapes that were not successfully routed by OSMNX

trip_df[trip_df.trip_id.isin(bus_osmnx_broken_trip_list)].shape_id.unique()
# Out:
# array([ 541,  502,  510,  513,  514,  786,  787,  788,  789, 1224],
#       dtype=int64)

# %%
trip_df.shape_id.nunique()
# Out:
# 1598

# %%
bus_osmnx_link_shape_df.shape_id.nunique()
# Out:
# 1499

# %%
# read shst match result

all_shst_df = pd.DataFrame()

for name in gtfs_agencies_list:
    try: 
        shst_df = gpd.read_file(data_interim_dir + "step6_gtfs/shst_match/" + name + ".out.matched.geojson")
        shst_df["agency_raw_name"] = name
    
        all_shst_df = all_shst_df.append(shst_df, sort = False, ignore_index = True)
    except:
        print(name + ".out.matched.geojson not found.")
# Out:
# ACE_2017_3_20.out.matched.geojson not found.
# BART_2015_8_3.out.matched.geojson not found.
# Blue&Gold_gtfs_10_4_2017.out.matched.geojson not found.
# Caltrain_2015_5_13.out.matched.geojson not found.
# Capitol_2017_3_20.out.matched.geojson not found.
# CCTA_2015_8_11.out.matched.geojson not found.
# MVGo_2016_10_26.out.matched.geojson not found.
# SF_Bay_Ferry2016_07_01.out.matched.geojson not found.
# Vine_GTFS_PLUS_2015.out.matched.geojson not found.
# commuteDOTorg_GTFSImportExport_20160127_final_mj.out.matched.geojson not found.

# %%
all_shst_df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 118279 entries, 0 to 118278
# Data columns (total 18 columns):
# shstReferenceId           118279 non-null object
# shstGeometryId            118279 non-null object
# shstFromIntersectionId    118279 non-null object
# shstToIntersectionId      118279 non-null object
# gisReferenceId            118279 non-null object
# gisGeometryId             118279 non-null object
# gisTotalSegments          118279 non-null int64
# gisSegmentIndex           118279 non-null int64
# gisFromIntersectionId     118279 non-null object
# gisToIntersectionId       118279 non-null object
# startSideOfStreet         118279 non-null object
# endSideOfStreet           118279 non-null object
# sideOfStreet              118279 non-null object
# score                     118279 non-null float64
# matchType                 118279 non-null object
# pp_shape_id               118279 non-null object
# geometry                  118279 non-null geometry
# agency_raw_name           118279 non-null object
# dtypes: float64(1), geometry(1), int64(2), object(14)
# memory usage: 16.2+ MB

# %%
all_shst_df.rename(columns = {"pp_shape_id" : "shape_id_original"}, inplace = True)

all_shst_df = pd.merge(
    all_shst_df,
    unique_shape_id_df,
    how = "left",
    on = ["agency_raw_name", "shape_id_original"]
)

all_shst_df = all_shst_df[all_shst_df.shape_id.notnull()].copy()

# %%
all_shst_df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 69373 entries, 0 to 118278
# Data columns (total 19 columns):
# shstReferenceId           69373 non-null object
# shstGeometryId            69373 non-null object
# shstFromIntersectionId    69373 non-null object
# shstToIntersectionId      69373 non-null object
# gisReferenceId            69373 non-null object
# gisGeometryId             69373 non-null object
# gisTotalSegments          69373 non-null int64
# gisSegmentIndex           69373 non-null int64
# gisFromIntersectionId     69373 non-null object
# gisToIntersectionId       69373 non-null object
# startSideOfStreet         69373 non-null object
# endSideOfStreet           69373 non-null object
# sideOfStreet              69373 non-null object
# score                     69373 non-null float64
# matchType                 69373 non-null object
# shape_id_original         69373 non-null object
# geometry                  69373 non-null geometry
# agency_raw_name           69373 non-null object
# shape_id                  69373 non-null float64
# dtypes: float64(2), geometry(1), int64(2), object(14)
# memory usage: 10.6+ MB

# %%
all_shst_df.shape_id.nunique()
# Out:
# 467

# %%
all_shst_df
# Out:
#                          shstReferenceId                    shstGeometryId  \
# 0       bf94c0db40279cc5ef46d54d8be6139d  90d83676f262ccee0386f52a5167e6fd
# 1       1315a47eae44cb25d4ba5b9bdaa2c04a  b9429a4f0520adc5db786e220ec76c43
# 2       d8bcbf7a1eacd73c6dc94cdf86588477  eb5d72233b87c45388e9be68d7a577d5
# 3       6b89e068ae6857cf10412fd4660d44a9  4bf2adcde4bb039093c4c9e74d93579d
# 4       ba4472bc48862de5802ec9125ef6478c  52a9dbacb520f66f19472d9cef936545
# 5       9b696f36d1ffc826d8b0266e4b076bc0  868a48f8216136f779006b694521cd13
# 118260     Wheels_2016_7_13    2019.0
# 118261     Wheels_2016_7_13    2019.0
# 118262     Wheels_2016_7_13    2019.0
# 118263     Wheels_2016_7_13    2019.0
# 118264     Wheels_2016_7_13    2019.0
# 118265     Wheels_2016_7_13    2019.0
# 118266     Wheels_2016_7_13    2019.0
# 118267     Wheels_2016_7_13    2019.0
# 118268     Wheels_2016_7_13    2019.0
# 118269     Wheels_2016_7_13    2019.0
# 118270     Wheels_2016_7_13    2019.0
# 118271     Wheels_2016_7_13    2019.0
# 118272     Wheels_2016_7_13    2019.0
# 118273     Wheels_2016_7_13    2019.0
# 118274     Wheels_2016_7_13    2019.0
# 118275     Wheels_2016_7_13    2019.0
# 118276     Wheels_2016_7_13    2019.0
# 118277     Wheels_2016_7_13    2019.0
# 118278     Wheels_2016_7_13    2019.0
#
# [69373 rows x 19 columns]

# %%
def route_bus_link_shst(drive_link, gtfs_shst_id):
    
    """
    route bus with shst match result
    
    parameter
    ---------
    drive link
    gtfs shst match return
    
    return
    ---------
    dataframe of drive links bus traverses
    list of imcomplete bus shapes
    
    """
    
    drive_link_df = drive_link.copy()
    shape_shst_df = gtfs_shst_id.copy()

    shape_shst_df = pd.merge(shape_shst_df, 
                             drive_link_df[
                                 ['shstReferenceId','wayId','u','v', "fromIntersectionId", "toIntersectionId", "A", "B"]
                             ],
                             how = 'left',
                             left_on = 'shstReferenceId',
                             right_on = 'shstReferenceId')
    
    shape_shst_df["u"] = shape_shst_df["u"].fillna(0).astype(np.int64)
    shape_shst_df["v"] = shape_shst_df["v"].fillna(0).astype(np.int64)
    shape_shst_df["A"] = shape_shst_df["A"].fillna(0).astype(np.int64)
    shape_shst_df["B"] = shape_shst_df["B"].fillna(0).astype(np.int64)
    
    """shape_shst_df.dropna(subset = ['u','v'], 
                         axis = 0, 
                         inplace = True)"""
    
    shape_shst_df = shape_shst_df.reset_index(drop=True)
    
    shape_shst_df['next_shape_id'] = shape_shst_df['shape_id'].\
                                            iloc[1:].\
                                            append(pd.Series(shape_shst_df['shape_id'].iloc[-1])).\
                                            reset_index(drop=True)
    
    shape_shst_df['next_u'] = shape_shst_df['u'].\
                                iloc[1:].\
                                append(pd.Series(shape_shst_df['v'].iloc[-1])).\
                                reset_index(drop=True)
    
    incomplete_shape_list = shape_shst_df[\
                                   (shape_shst_df.shape_id==shape_shst_df.next_shape_id)\
                                   &(shape_shst_df.v!=shape_shst_df.next_u)\
                                  ].shape_id.unique().\
                                    tolist()
    
    shape_shst_df = shape_shst_df[~shape_shst_df.shape_id.isin(incomplete_shape_list)].copy()
    
    return shape_shst_df, incomplete_shape_list

# %%
bus_shst_link_shape_df, incomplete_shape_list = route_bus_link_shst(drive_link_df, all_shst_df)

print(bus_shst_link_shape_df.shape)
print(bus_shst_link_shape_df.shape_id.nunique())
# Out:
# (49818, 28)
# 351

# %%
print(incomplete_shape_list)
# Out:
# [116.0, 147.0, 148.0, 149.0, 158.0, 160.0, 161.0, 165.0, 167.0, 168.0, 172.0, 174.0, 175.0, 176.0, 188.0, 189.0, 192.0, 193.0, 194.0, 195.0, 205.0, 206.0, 207.0, 208.0, 213.0, 214.0, 217.0, 219.0, 220.0, 222.0, 230.0, 233.0, 237.0, 239.0, 240.0, 244.0, 269.0, 270.0, 274.0, 324.0, 326.0, 695.0, 714.0, 732.0, 733.0, 751.0, 760.0, 761.0, 765.0, 1185.0, 1186.0, 1196.0, 1197.0, 1198.0, 1217.0, 1233.0, 1237.0, 1238.0, 1255.0, 1256.0, 1257.0, 1258.0, 1275.0, 1281.0, 1295.0, 1306.0, 1307.0, 1314.0, 1338.0, 1340.0, 1344.0, 1345.0, 1346.0, 1604.0, 1616.0, 1618.0, 1619.0, 1625.0, 1633.0, 1635.0, 1641.0, 1663.0, 1666.0, 1667.0, 1677.0, 1678.0, 1679.0, 1680.0, 1702.0, 1703.0, 1704.0, 1712.0, 1730.0, 1737.0, 1738.0, 1744.0, 1751.0, 1752.0, 1753.0, 1759.0, 1827.0, 1832.0, 1833.0, 1846.0, 1850.0, 1858.0, 1866.0, 1873.0, 1953.0, 1967.0, 1987.0, 1988.0, 2007.0, 2008.0, 2013.0, 2014.0]

# %%
# some of these buses has parts that are out side of SF county boundary, that's why they are labeled as incomplete shape
# some are due to the discrepency btw shst extraction and osmnx extraction

# %%
bus_shst_link_shape_df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 49818 entries, 0 to 69372
# Data columns (total 28 columns):
# shstReferenceId           49818 non-null object
# shstGeometryId            49818 non-null object
# shstFromIntersectionId    49818 non-null object
# shstToIntersectionId      49818 non-null object
# gisReferenceId            49818 non-null object
# gisGeometryId             49818 non-null object
# gisTotalSegments          49818 non-null int64
# gisSegmentIndex           49818 non-null int64
# gisFromIntersectionId     49818 non-null object
# gisToIntersectionId       49818 non-null object
# startSideOfStreet         49818 non-null object
# endSideOfStreet           49818 non-null object
# sideOfStreet              49818 non-null object
# score                     49818 non-null float64
# matchType                 49818 non-null object
# shape_id_original         49818 non-null object
# geometry                  49818 non-null geometry
# agency_raw_name           49818 non-null object
# shape_id                  49818 non-null float64
# wayId                     49818 non-null object
# u                         49818 non-null int64
# v                         49818 non-null int64
# fromIntersectionId        49818 non-null object
# toIntersectionId          49818 non-null object
# A                         49818 non-null int64
# B                         49818 non-null int64
# next_shape_id             49818 non-null float64
# next_u                    49818 non-null int64
# dtypes: float64(3), geometry(1), int64(7), object(17)
# memory usage: 11.0+ MB

# %%
def bus_link(bus_link_osmnx, bus_link_shst, routes, trip, incomplete_list):
    
    """
    combine bus links from OSMNX and SHST
    """
    
    bus_link_osmnx_df = bus_link_osmnx.copy()
    bus_link_shst_df = bus_link_shst.copy()
    
    trip_df = trip.copy()
    trip_df = pd.merge(trip_df, routes[['route_id', 'route_type']], how = 'left', on = 'route_id')
    bus_trip_df = trip_df[trip_df.route_type == 3].copy()
    
    #bus_link_shst_df.shape_id = bus_link_shst_df.shape_id.astype(str)
    
    shape_id_list = bus_trip_df.shape_id.unique().tolist()
    
    #incomplete_list = [str(x) for x in incomplete_list]
    incomplete_list = [x for x in incomplete_list]
    
    print("Targeting number of bus shape IDs: " + str(bus_trip_df.shape_id.nunique()))
    
    #trip_id, shape_id, u, v, link_id, omsid, shstrefere
    
    shst_shape_list = list(set([x for x in bus_link_shst_df.shape_id]))
    
    shapes_replace_with_shst_list = [x for x in shst_shape_list if x in shape_id_list]
    
    print("\n There are " + str(len(shapes_replace_with_shst_list)) + 
          " shapes that are from shst gtfs matching: \n \t" + 
          str(shapes_replace_with_shst_list))

    bus_link_osmnx_df = bus_link_osmnx_df[~bus_link_osmnx_df.shape_id.isin(shapes_replace_with_shst_list)].copy()
    
    osmnx_shape_list = bus_link_osmnx_df.shape_id.unique().tolist()
    
    print("\n There are " + str(len(osmnx_shape_list)) + 
          " shapes that are from OSMNX routing: \n \t" + 
          str(osmnx_shape_list))
    
    not_routed_list = [x for x in shape_id_list if x not in (shst_shape_list + osmnx_shape_list)]
    
    print("\n There are " + str(len(not_routed_list)) + 
         " shapes that are not routed by either of the two methods: \n \t" + 
         str(not_routed_list))
    
    bus_link_shst_df = pd.merge(bus_link_shst_df,
                                bus_trip_df[['trip_id', 'shape_id']],
                                how = 'inner',
                                left_on = 'shape_id',
                                right_on = 'shape_id')
    #bus_link_shst_df.drop(['pp_shape_id'], axis = 1, inplace = True)
    
    bus_link_df = pd.concat([bus_link_osmnx_df, bus_link_shst_df],
                            sort = False,
                           ignore_index = True)
    
    column_list = bus_link_osmnx.columns.values.tolist()
    
    return bus_link_df[column_list]

# %%
bus_link_df = bus_link(bus_osmnx_link_shape_df, bus_shst_link_shape_df, all_routes_df, trip_df, incomplete_shape_list)
# Out:
# Targeting number of bus shape IDs: 1503
#
#  There are 253 shapes that are from shst gtfs matching:
#  	[7.0, 10.0, 11.0, 13.0, 15.0, 16.0, 2069.0, 2070.0, 48.0, 52.0, 53.0, 61.0, 62.0, 65.0, 66.0, 73.0, 74.0, 77.0, 78.0, 84.0, 85.0, 86.0, 87.0, 94.0, 95.0, 97.0, 101.0, 102.0, 104.0, 105.0, 106.0, 107.0, 109.0, 110.0, 111.0, 114.0, 121.0, 123.0, 124.0, 125.0, 126.0, 127.0, 128.0, 130.0, 131.0, 132.0, 133.0, 134.0, 135.0, 136.0, 137.0, 138.0, 139.0, 140.0, 141.0, 144.0, 145.0, 150.0, 151.0, 171.0, 181.0, 185.0, 186.0, 190.0, 191.0, 196.0, 197.0, 199.0, 201.0, 202.0, 209.0, 210.0, 215.0, 216.0, 226.0, 229.0, 238.0, 241.0, 242.0, 245.0, 246.0, 249.0, 250.0, 251.0, 252.0, 253.0, 254.0, 255.0, 257.0, 258.0, 275.0, 298.0, 301.0, 304.0, 305.0, 306.0, 307.0, 312.0, 313.0, 318.0, 319.0, 323.0, 325.0, 327.0, 335.0, 336.0, 337.0, 350.0, 351.0, 374.0, 574.0, 589.0, 590.0, 591.0, 596.0, 597.0, 598.0, 599.0, 664.0, 737.0, 741.0, 743.0, 747.0, 750.0, 755.0, 759.0, 1156.0, 1158.0, 1166.0, 1167.0, 1222.0, 1224.0, 1225.0, 1226.0, 1227.0, 1230.0, 1234.0, 1253.0, 1254.0, 1259.0, 1260.0, 1261.0, 1262.0, 1264.0, 1277.0, 1278.0, 1279.0, 1296.0, 1299.0, 1300.0, 1302.0, 1303.0, 1305.0, 1308.0, 
head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920493 entries, 0 to 920492
# Data columns (total 9 columns):
# u                  920493 non-null int64
# v                  920493 non-null int64
# trip_id            920493 non-null int64
# shape_id           920493 non-null float64
# wayId              920493 non-null object
# shstReferenceId    920493 non-null object
# shstGeometryId     920493 non-null object
# A                  920493 non-null int64
# B                  920493 non-null int64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 63.2+ MB
#           u         v  trip_id  shape_id      wayId  \
# 0  57808643  57808641        9     359.0  303291893
# 1  57808641  57808639        9     359.0  303291893
# 2  57808639  57808637        9     359.0  303291893
#
#                     shstReferenceId                    shstGeometryId  \
# 0  020aa1becdbef42ef4245a3c278e9d29  c0f97948d99c64e52ae3c463383dabbf
# 1  1f81b33f6a786a97a0ed79bd2074ba02  94987b6adba60bad1ce73f6ec491fdf0
# 2  1e505f22f056942e593ee134ec97e624  f1dc7acbc076866422e7f373d4b2b643
#
#          A        B
# 0  3047632  3052718
# 1  3052718  3006601
# 2  3006601  3070234

# %%
# manual correction for Capitol Corridor
# the shape_id from GTFS are wrong
# use the trips that go to San Jose

trip_df.loc[(trip_df.shape_id==487)&(trip_df.tod=="AM"), 
                 "trip_id"] = 8042
trip_df.loc[(trip_df.shape_id==487)&(trip_df.tod=="MD"), 
                 "trip_id"] = 8049
trip_df.loc[(trip_df.shape_id==487)&(trip_df.tod=="PM"), 
                 "trip_id"] = 8054
trip_df.loc[(trip_df.shape_id==487)&(trip_df.tod=="NT"), 
                 "trip_id"] = 8063

# %%
# create rail links
def non_bus_link(stop_times, shapes, routes, trip, stop):
    
    """
    create rail links and nodes
    
    nodes are based on rail stops, links are true shape between nodes
    
    return
    ---------
    complete rail link path for each rail service
    complete rail node path for each rail service
    
    """
    
    print('generating rail links...')
    
    #get rail trips
    trip_df = trip.copy()
    trip_df = pd.merge(trip_df, routes[['route_id', 'route_type']], how = 'left', on = 'route_id')
    rail_trip_df = trip_df[trip_df.route_type != 3].copy()
    
    stop_df = stop.copy()
    stop_time_df = stop_times.copy()
    
    #get rail trips with stops
    chained_stop_to_node_df = pd.merge(stop_time_df, 
                                       stop_df, 
                                       how = 'left', 
                                       on = 'stop_id')
    
    rail_stop_time_df = chained_stop_to_node_df[
                                                chained_stop_to_node_df['trip_id']\
                                                .isin(rail_trip_df.trip_id.tolist())
                                               ]\
                                                .copy()
    
    #get gtfs rail shapes
    rail_shape_df = shapes[shapes['shape_id'].isin(rail_trip_df.shape_id.tolist())
                                ].copy()
    
    #gtfs shape-trip correspondence
    shape_trip_dict = dict(zip(rail_trip_df.shape_id, rail_trip_df.trip_id))
    
    # manual correction
    shape_trip_dict[486] = 8039
    shape_trip_dict[487] = 8042
    
    print(rail_shape_df.shape_id.unique())
    #for each rail shape
    for i in rail_shape_df.shape_id.unique():
    
        trip_id = shape_trip_dict[i]
        
        #get chained stop
        trip_stop_df = rail_stop_time_df[rail_stop_time_df.trip_id == trip_id].copy()
        
        trip_stop_df.sort_values(by = ["stop_sequence"], inplace = True)
        
        # get gtfs shape nodes for the shape
        trip_shape_df = rail_shape_df[rail_shape_df.shape_id == i].copy()
        # initialize columns
        trip_shape_df['is_stop'] = np.int(0)
        trip_shape_df['stop_id'] = np.nan
        
        # for each rail stop, find the closest node in the shape, and those are the stops and breakpoints of new rail links
        # return is a gtfs node shape dataframe with two columns indicating if the node is a stop and the stop id
        shape_inventory = trip_shape_df[['shape_pt_lon', 'shape_pt_lat']].values
        tree = cKDTree(shape_inventory)
        for s in range(len(trip_stop_df)):
            point = trip_stop_df.iloc[s][['stop_lon', 'stop_lat']].values
            dd, ii = tree.query(point, k = 1)
            trip_shape_df.shape_pt_lon.iloc[ii] = trip_stop_df.iloc[s]['stop_lon']
            trip_shape_df.shape_pt_lat.iloc[ii] = trip_stop_df.iloc[s]['stop_lat']
            trip_shape_df.is_stop.iloc[ii] = 1
            trip_shape_df.stop_id.iloc[ii] = trip_stop_df.iloc[s]['stop_id']
        
        # appending the gtfs shape for each route shape id
        if i == rail_shape_df.shape_id.unique()[0]:
            shape_flag_df = trip_shape_df.copy()
        else:
            shape_flag_df = shape_flag_df.append(trip_shape_df, 
                                                 ignore_index = True, 
                                                 sort = False)
    
    # starting to build new rail links true shape
    linestring_df = pd.DataFrame(columns = ['shape_id', 'u', 'v', 'geometry', 'u_stop_id', 'v_stop_id'])

    # rail links are based on the gtfs shape, with nodes being the shapes that are identified as rail stops.
    for i in shape_flag_df.shape_id.unique():
        # get gtfs shape for shape id
        shape_route_df = shape_flag_df[shape_flag_df.shape_id == i].copy()
        
        # get rail nodes based on the stop flags
        break_list = shape_route_df.index[shape_route_df.is_stop == 1].tolist()
        stop_id_list = shape_route_df[shape_route_df.is_stop == 1]['stop_id'].tolist()
        
        # use the gtfs shape between "stop" shapes to build the rail true shape
        for j in range(len(break_list)-1):
            lon_list = shape_flag_df.shape_pt_lon.iloc[break_list[j]:break_list[j+1]+1].tolist()
            lat_list = shape_flag_df.shape_pt_lat.iloc[break_list[j]:break_list[j+1]+1].tolist()
            linestring = LineString([Point(xy) for xy in zip(lon_list,lat_list)])
            linestring_df = linestring_df.append({'shape_id':i, 
                                                  'u':break_list[j], 
                                                  'v':break_list[j+1],
                                                  'u_stop_id':stop_id_list[j], 
                                                  'v_stop_id':stop_id_list[j+1],
                                                  'geometry' : linestring}, 
                                                 ignore_index = True, 
                                                 sort = False)
    
    # add rail travel time between stops
    stop_time_df = pd.merge(
                            stop_time_df, 
                            rail_trip_df[['trip_id', 'shape_id']], 
                            how = 'left', 
                            on = 'trip_id')
    
    unique_stop_time_df = stop_time_df[
                                        stop_time_df.shape_id.notnull()
                                    ].groupby(['trip_id', 'shape_id'])\
                                    .count().reset_index()\
                                    .drop_duplicates(subset = ['shape_id']).copy()
    
    stop_time_df = stop_time_df[stop_time_df.trip_id.isin(unique_stop_time_df.trip_id.tolist())].copy()

    
    linestring_df = pd.merge(linestring_df, 
                             stop_time_df[['shape_id', 'stop_id' , 'departure_time']].rename(
                                 columns = {"stop_id" : "u_stop_id"}),
                            how = 'left',
                            on = ['shape_id', 'u_stop_id'])
    
    linestring_df = pd.merge(linestring_df, 
                             stop_time_df[['shape_id', 'stop_id', 'arrival_time']].rename(
                                 columns = {"stop_id" : "v_stop_id"}),
                            how = 'left',
                            on = ['shape_id', 'v_stop_id'])
    
    # travel time in minutes
    linestring_df['rail_traveltime'] = (linestring_df['arrival_time'] - linestring_df['departure_time'])/60
    
    rail_node_df = shape_flag_df[shape_flag_df.is_stop == 1].rename_axis('node_id').reset_index()

    
    return linestring_df, rail_node_df

# %%
# %%time
rail_path_link_gdf, rail_path_node_df = non_bus_link(all_stop_times_df, all_shapes_df, all_routes_df, trip_df, stop_df)
# Out:
# generating rail links...
# [ 404  405  406  407  408  409  410  411  412  413  414  415  416  417
#   418  419  420  421  481  483  485  482  484  486  487  668  669  670
#   671 1018 1019 1020 1021 1022 1024 1026 1027 1028 1030 1056 1059 1061
#  1092 1097 1098 1101 1102 1103 1104 1105 1108 1111 1112 1117 1118 1119
#  1120 1122 1123 1124 1126 1127 1129 1131 1132 1134 1137 1138 1139 1140
#  1141 1143 1144 1145 1146 1905 1907 1908 1917 1919 1920 1924 1926 1929
#  1930]
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Wall time: 3h 46min 55s

# %%
print(rail_path_node_df.columns)
print(rail_path_link_gdf.columns)

print(rail_path_node_df.shape)
print(rail_path_link_gdf.shape)
# Out:
# Index(['node_id', 'shape_pt_lat', 'shape_pt_lon', 'shape_pt_sequence',
#        'shape_dist_traveled', 'shape_id', 'is_stop', 'stop_id'],
#       dtype='object')
# Index(['shape_id', 'u', 'v', 'geometry', 'u_stop_id', 'v_stop_id',
#        'departure_time', 'arrival_time', 'rail_traveltime'],
#       dtype='object')
# (1424, 8)
# (1339, 9)

# %%
trip_df[trip_df.agency_raw_name == "Caltrain_2015_5_13"].shape_id
# Out:
# 938    482
# 939    484
# 940    484
# 941    484
# 942    482
# 943    483
# 944    483
# 945    482
# 946    484
# 947    485
# 948    485
# 949    485
# 950    484
# 951    482
# 952    484
# 953    484
# 954    484
# 955    484
# 956    482
# 957    482
# 958    482
# 959    481
# Name: shape_id, dtype: int32

# %%
rail_path_link_gdf[rail_path_link_gdf.shape_id == 484]
# Out:
#     shape_id      u      v                                           geometry  \
# 286      484  26551  26565  LINESTRING (-121.903011 37.329239, -121.903406...
# 287      484  26565  26584  LINESTRING (-121.93608 37.353238, -121.9382321...
# 288      484  26584  26594  LINESTRING (-121.997114 37.370598, -122.000094...
# 289      484  26594  26606  LINESTRING (-122.031372 37.378916, -122.033514...
# 290      484  26606  26616  LINESTRING (-122.075956 37.394459, -122.078039...
# 291      484  26616  26632  LINESTRING (-122.107069 37.407323, -122.108348...
# 292      484  26632  26645  LINESTRING (-122.141927 37.429365, -122.143056...
# 293      484  26645  26654  LINESTRING (-122.164614 37.443475, -122.165468...
# 294      484  26654  26678  LINESTRING (-122.182297 37.454856, -122.183450...
# 295      484  26678  26692  LINESTRING (-122.231936 37.486159, -122.234916...
# 332      487  29303  29341  LINESTRING (-121.737758 38.543494, -121.73713 ...
#
#      u_stop_id  v_stop_id  departure_time  arrival_time  rail_traveltime
# 320     6680.0     6678.0             NaN           NaN              NaN
# 321     6678.0     6669.0             NaN           NaN              NaN
# 322     6669.0     6668.0             NaN           NaN              NaN
# 323     6668.0     6670.0             NaN           NaN              NaN
# 324     6670.0     6672.0             NaN           NaN              NaN
# 325     6672.0     6673.0             NaN       19500.0              NaN
# 326     6673.0     6667.0         19500.0       19980.0              8.0
# 327     6667.0     6665.0         19980.0       20340.0              6.0
# 328     6665.0     6674.0         20340.0       20820.0              8.0
# 329     6674.0     6671.0         20820.0       22440.0             27.0
# 330     6671.0     6681.0         22440.0       23580.0             19.0
# 331     6681.0     6666.0         23580.0       25020.0             24.0
# 332     6666.0     6677.0         25020.0       26580.0             26.0

# %%
all_stop_times_df
# Out:
#          arrival_time  departure_time  stop_sequence  pickup_type  \
# 0             15600.0         15600.0              1          NaN
# 1             16740.0         16740.0              2          NaN
# 2             17460.0         17460.0              3          NaN
# 3             19200.0         19200.0              4          NaN
# 4             19500.0         19500.0              5          NaN
# 5             19980.0         19980.0              6          NaN
# 6             21300.0         21300.0              7          NaN
# 7             22380.0         22380.0              8          NaN
# 8             22800.0         22800.0              9          NaN
# 9             23520.0         23520.0             10          NaN
# 10            20100.0         20100.0              1          NaN
# 11            21240.0         21240.0              2          NaN
# 12            21960.0         21960.0              3          NaN
# 13            23700.0         23700.0              4          NaN
# 14            24000.0         24000.0              5          NaN
# 15            24480.0         24480.0              6          NaN
# 16            25800.0         25800.0              7          NaN
# 17            26880.0         26880.0              8          NaN
# 18            27300.0         27300.0              9          NaN
# 19            28020.0         28020.0             10          NaN
# 20            24000.0         24000.0              1          NaN
# 21            25140.0         25140.0              2          NaN
# 22            25860.0         25860.0              3          NaN
# 23            27600.0         27600.0              4          NaN
# 24            27900.0         27900.0              5          NaN
# 25            28380.0         28380.0              6          NaN
# 26            29700.0         29700.0              7          NaN
# 27            30780.0         30780.0              8          NaN
# 28            31200.0         31200.0              9          NaN
# 29            31920.0         31920.0             10          NaN
# ...               ...             ...            ...          ...
# 1156908       63000.0         63000.0              6          NaN
# 1156909       63840.0         63840.0              1          NaN
# 1156910       63900.0         63900.0              2          NaN
# 1156911       63960.0         63960.0              3          NaN
# 1156912       64020.0         64020.0              4          NaN
# 1156913       64080.0         64080.0              5          NaN
# 1156914       64920.0         64920.0              6          NaN
# 1156915       65760.0         65760.0              1          NaN
# 1156916       65820.0         65820.0              2          NaN
# 1156917       65880.0         65880.0              3          NaN
# 1156918       65940.0         65940.0              4          NaN
# 1156919       66000.0         66000.0              5          NaN
# 1156920       66840.0         66840.0              6          NaN
# 1156921       67620.0         67620.0              1          NaN
# 1156922       67680.0         67680.0              2          NaN
# 1156923       67740.0         67740.0              3          NaN
# 1156924       67800.0         67800.0              4          NaN
# 1156925       67860.0         67860.0              5          NaN
# 1156926       68640.0         68640.0              6          NaN
# 1156927       69420.0         69420.0              1          NaN
# 1156928       69480.0         69480.0              2          NaN
# 1156929       69540.0         69540.0              3          NaN
# 1156930       69600.0         69600.0              4          NaN
# 1156931       69660.0         69660.0              5          NaN
# 1156932       70440.0         70440.0              6          NaN
# 1156933       36840.0         36840.0              1          NaN
# 1156934       37680.0         37680.0              2          1.0
# 1156935       37740.0         37740.0              3          1.0
# 1156936       37800.0         37800.0              4          1.0
# 1156937       37860.0         37860.0              5          1.0
#
#         drop_off_type                           stop_headsign  \
# 0                 NaN                                     NaN
# 1                 NaN                                     NaN
# 2                 NaN                                     NaN
# 3                 NaN                                     NaN
# 4                 NaN                                     NaN
# 5                 NaN                                     NaN
# 6                 NaN                                     NaN
# 7                 NaN                                     NaN
# 8                 NaN                                     NaN
# 9                 NaN                                     NaN
# 10                NaN                                     NaN
# 11                NaN                                     NaN
# 12                NaN                                     NaN
# 13                NaN                                     NaN
# 14                NaN                                     NaN
# 15                NaN                                     NaN
# 16                NaN                                     NaN
# 17                NaN                                     NaN
# 18                NaN                                     NaN
# 19                NaN                                     NaN
# 20                NaN                                     NaN
# 21                NaN                                     NaN
# 22                NaN                                     NaN
# 23                NaN                                     NaN
# 24                NaN                                     NaN
# 25                NaN                                     NaN
# 26                NaN                                     NaN
# 27                NaN                                     NaN
# 28                NaN                                     NaN
# 29                NaN                                     NaN
# ...               ...                                     ...
# 1156908           NaN  2800 Bridge Parkway/Hillsdale Caltrain
# 1156909           NaN  2800 Bridge Parkway/Hillsdale Caltrain
# 1156910           NaN  2800 Bridge Parkway/Hillsdale Caltrain
# 1156911           NaN  2800 Bridge Parkway/Hillsdale Caltrain
# 1156912           NaN  2800 Bridge Parkway/Hillsdale Caltrain
# 1156913           NaN  2800 Bridge Parkway/Hillsdale Caltrain
# 1156914           NaN  2800 Bridge Parkway/Hillsdale Caltrain
# 1156915           NaN  2800 Bridge Parkway/Hillsdale Caltrain
# 1156916           NaN  2800 Bridge Parkway/Hillsdale Caltrain
# 1156917           NaN  2800 Bridge Parkway/Hillsdale Caltrain
# 1156918           NaN  2800 Bridge Parkway/Hillsdale Caltrain
# 1156919           NaN  2800 Bridge Parkway/Hillsdale Caltrain
# 1156920           NaN  2800 Bridge Parkway/Hillsdale Caltrain
# 1156921           NaN  2800 Bridge Parkway/Hillsdale Caltrain
# 1156922           NaN  2800 Bridge Parkway/Hillsdale Caltrain
# 1156923           NaN  2800 Bridge Parkway/Hillsdale Caltrain
# 1156924           NaN  2800 Bridge Parkway/Hillsdale Caltrain
# 1156925           NaN  2800 Bridge Parkway/Hillsdale Caltrain
# 1156926           NaN  2800 Bridge Parkway/Hillsdale Caltrain
# 1156927           NaN  2800 Bridge Parkway/Hillsdale Caltrain
# 1156928           NaN  2800 Bridge Parkway/Hillsdale Caltrain
# 1156929           NaN  2800 Bridge Parkway/Hillsdale Caltrain
# 1156930           NaN  2800 Bridge Parkway/Hillsdale Caltrain
# 1156931           NaN  2800 Bridge Parkway/Hillsdale Caltrain
# 1156932           NaN  2800 Bridge Parkway/Hillsdale Caltrain
# 1156933           NaN                     2800 Bridge Parkway
# 1156934           NaN                     2800 Bridge Parkway
# 1156935           NaN                     2800 Bridge Parkway
# 1156936           NaN                     2800 Bridge Parkway
# 1156937           NaN                     2800 Bridge Parkway
#
#          shape_dist_traveled  timepoint last_stop_on_trip  \
# 0                        NaN        NaN               NaN
# 1                        NaN        NaN               NaN
# 2                        NaN        NaN               NaN
# 3                        NaN        NaN               NaN
# 4                        NaN        NaN               NaN
# 5                        NaN        NaN               NaN
# 6                        NaN        NaN               NaN
# 7                        NaN        NaN               NaN
# 8                        NaN        NaN               NaN
# 9                        NaN        NaN               NaN
# 10                       NaN        NaN               NaN
# 11                       NaN        NaN               NaN
# 12                       NaN        NaN               NaN
# 13                       NaN        NaN               NaN
# 14                       NaN        NaN               NaN
# 15                       NaN        NaN               NaN
# 16                       NaN        NaN               NaN
# 17                       NaN        NaN               NaN
# 18                       NaN        NaN               NaN
# 19                       NaN        NaN               NaN
# 20                       NaN        NaN               NaN
# 21                       NaN        NaN               NaN
# 22                       NaN        NaN               NaN
# 23                       NaN        NaN               NaN
# 24                       NaN        NaN               NaN
# 25                       NaN        NaN               NaN
# 26                       NaN        NaN               NaN
# 27                       NaN        NaN               NaN
# 28                       NaN        NaN               NaN
# 29                       NaN        NaN               NaN
# ...                      ...        ...               ...
# 1156908               13.641        NaN               NaN
# 1156909                5.428        NaN               NaN
# 1156910                5.735        NaN               NaN
# 1156911                5.941        NaN               NaN
# 1156912                6.481        NaN               NaN
# 1156913                6.862        NaN               NaN
# 1156914               13.641        NaN               NaN
# 1156915                5.428        NaN               NaN
# 1156916                5.735        NaN               NaN
# 1156917                5.941        NaN               NaN
# 1156918                6.481        NaN               NaN
# 1156919                6.862        NaN               NaN
# 1156920               13.641        NaN               NaN
# 1156921                5.428        NaN               NaN
# 1156922                5.735        NaN               NaN
# 1156923                5.941        NaN               NaN
# 1156924                6.481        NaN               NaN
# 1156925                6.862        NaN               NaN
# 1156926               13.641        NaN               NaN
# 1156927                5.428        NaN               NaN
# 1156928                5.735        NaN               NaN
# 1156929                5.941        NaN               NaN
# 1156930                6.481        NaN               NaN
# 1156931                6.862        NaN               NaN
# 1156932               13.641        NaN               NaN
# 1156933                0.000        NaN               NaN
# 1156934                5.428        NaN               NaN
# 1156935                5.735        NaN               NaN
# 1156936                5.941        NaN               NaN
# 1156937                6.481        NaN               NaN
#
#         start_service_area_id  ... pickup_area_id drop_off_area_id  \
# 0                         NaN  ...            NaN              NaN
# 1                         NaN  ...            NaN              NaN
# 2                         NaN  ...            NaN              NaN
# 3                         NaN  ...            NaN              NaN
# 4                         NaN  ...            NaN              NaN
# 5                         NaN  ...            NaN              NaN
# 6                         NaN  ...            NaN              NaN
# 7                         NaN  ...            NaN              NaN
# 8                         NaN  ...            NaN              NaN
# 9                         NaN  ...            NaN              NaN
# 10                        NaN  ...            NaN              NaN
# 11                        NaN  ...            NaN              NaN
# 12                        NaN  ...            NaN              NaN
# 13                        NaN  ...            NaN              NaN
# 14                        NaN  ...            NaN              NaN
# 15                        NaN  ...            NaN              NaN
# 16                        NaN  ...            NaN              NaN
# 17                        NaN  ...            NaN              NaN
# 18                        NaN  ...            NaN              NaN
# 19                        NaN  ...            NaN              NaN
# 20                        NaN  ...            NaN              NaN
# 21                        NaN  ...            NaN              NaN
# 22                        NaN  ...            NaN              NaN
# 23                        NaN  ...            NaN              NaN
# 24                        NaN  ...            NaN              NaN
# 25                        NaN  ...            NaN              NaN
# 26                        NaN  ...            NaN              NaN
# 27                        NaN  ...            NaN              NaN
# 28                        NaN  ...            NaN              NaN
# 29                        NaN  ...            NaN              NaN
# ...                       ...  ...            ...              ...
# 1156908                   NaN  ...            NaN              NaN
# 1156909                   NaN  ...            NaN              NaN
# 1156910                   NaN  ...            NaN              NaN
# 1156911                   NaN  ...            NaN              NaN
# 1156912                   NaN  ...            NaN              NaN
# 1156913                   NaN  ...            NaN              NaN
# 1156914                   NaN  ...            NaN              NaN
# 1156915                   NaN  ...            NaN              NaN
# 1156916                   NaN  ...            NaN              NaN
# 1156917                   NaN  ...            NaN              NaN
# 1156918                   NaN  ...            NaN              NaN
# 1156919                   NaN  ...            NaN              NaN
# 1156920                   NaN  ...            NaN              NaN
# 1156921                   NaN  ...            NaN              NaN
# 1156922                   NaN  ...            NaN              NaN
# 1156923                   NaN  ...            NaN              NaN
# 1156924                   NaN  ...            NaN              NaN
# 1156925                   NaN  ...            NaN              NaN
#
#         *seq# *Dist(m) *Comment trip_id stop_id
# 0         NaN      NaN      NaN       1       1
# 1         NaN      NaN      NaN       1       2
# 2         NaN      NaN      NaN       1       3
# 3         NaN      NaN      NaN       1       4
# 4         NaN      NaN      NaN       1       5
# 5         NaN      NaN      NaN       1       6
# 6         NaN      NaN      NaN       1       7
# 7         NaN      NaN      NaN       1       8
# 8         NaN      NaN      NaN       1       9
# 9         NaN      NaN      NaN       1      10
# 10        NaN      NaN      NaN       3       1
# 11        NaN      NaN      NaN       3       2
# 12        NaN      NaN      NaN       3       3
# 13        NaN      NaN      NaN       3       4
# 14        NaN      NaN      NaN       3       5
# 15        NaN      NaN      NaN       3       6
# 16        NaN      NaN      NaN       3       7
# 17        NaN      NaN      NaN       3       8
# 18        NaN      NaN      NaN       3       9
# 19        NaN      NaN      NaN       3      10
# 20        NaN      NaN      NaN       5       1
# 21        NaN      NaN      NaN       5       2
# 22        NaN      NaN      NaN       5       3
# 23        NaN      NaN      NaN       5       4
# 24        NaN      NaN      NaN       5       5
# 25        NaN      NaN      NaN       5       6
# 26        NaN      NaN      NaN       5       7
# 27        NaN      NaN      NaN       5       8
# 28        NaN      NaN      NaN       5       9
# 29        NaN      NaN      NaN       5      10
# ...       ...      ...      ...     ...     ...
# 1156908   126   12.131      NaN   33517   22085
# 1156909    40    1.801      NaN   33518   22035
# 1156910    46    0.455      NaN   33518   22153
# 1156911    55    3.704      NaN   33518   22029
# 1156912    68    4.956      NaN   33518   22030
# 1156913    75      0.8      NaN   33518   22033
# 1156914   126   12.131      NaN   33518   22085
# 1156915    40    1.801      NaN   33519   22035
# 1156916    46    0.455      NaN   33519   22153
# 1156917    55    3.704      NaN   33519   22029
# 1156918    68    4.956      NaN   33519   22030
# 1156919    75      0.8      NaN   33519   22033
# 1156920   126   12.131      NaN   33519   22085
# 1156921    40    1.801      NaN   33520   22035
# 1156922    46    0.455      NaN   33520   22153
# 1156923    55    3.704      NaN   33520   22029
# 1156924    68    4.956      NaN   33520   22030
# 1156925    75      0.8      NaN   33520   22033
# 1156926   126   12.131      NaN   33520   22085
# 1156927    40    1.801      NaN   33521   22035
# 1156928    46    0.455      NaN   33521   22153
# 1156929    55    3.704      NaN   33521   22029
# 1156930    68    4.956      NaN   33521   22030
# 1156931    75      0.8      NaN   33521   22033
# 1156932   126   12.131      NaN   33521   22085
# 1156933     1    1.066      NaN   33522   22085
# 1156934    40    1.801      NaN   33522   22035
# 1156935    46    0.455      NaN   33522   22153
# 1156936    55    3.704      NaN   33522   22029
# 1156937    68    4.956      NaN   33522   22030
#
# [1156938 rows x 25 columns]

# %%
ACE_trips_df = trip_df[trip_df.agency_raw_name == "ACE_2017_3_20"]
shape_trip_dict = dict(zip(ACE_trips_df.shape_id, ACE_trips_df.trip_id))

ACE_linestring_df = pd.DataFrame(columns = ['shape_id', 'u', 'v', 'geometry', 'u_stop_id', 'v_stop_id'])

#get chained stop
chained_trip_stop_df = pd.merge(all_stop_times_df, all_stops_df, how = "left", on = "stop_id")
    
for i in ACE_trips_df.shape_id.unique():
    trip_id = shape_trip_dict[i]
    #get chained stop
    trip_stop_df = chained_trip_stop_df[chained_trip_stop_df.trip_id == trip_id].copy()
    
    trip_shape_df = trip_stop_df.copy()
    trip_shape_df["is_stop"] = 1
    trip_shape_df["shape_id"] = i
    
    break_list = trip_shape_df.index[trip_shape_df.is_stop == 1].tolist()
    stop_id_list = trip_shape_df[trip_shape_df.is_stop == 1]['stop_id'].tolist()
    
    for j in range(len(trip_stop_df)-1):
        lon_list = trip_shape_df.stop_lon.iloc[j:j+2].tolist()
        lat_list = trip_shape_df.stop_lat.iloc[j:j+2].tolist()
        linestring = LineString([Point(xy) for xy in zip(lon_list,lat_list)])
        ACE_linestring_df = ACE_linestring_df.append({'shape_id':i, 
                                                  'u':break_list[j], 
                                                  'v':break_list[j+1],
                                                  'u_stop_id':stop_id_list[j], 
                                                  'v_stop_id':stop_id_list[j+1],
                                                  'geometry' : linestring}, 
                                                 ignore_index = True, 
                                                 sort = False)
    if i == ACE_trips_df.shape_id.unique()[0]:
        ACE_rail_node_df = trip_shape_df
    else:
        ACE_rail_node_df = ACE_rail_node_df.append(trip_shape_df, ignore_index = False, sort = False)

stop_time_df = pd.merge(all_stop_times_df, 
                            ACE_trips_df[['trip_id', 'shape_id']], 
                            how = 'left', 
                            on = 'trip_id')

unique_stop_time_df = stop_time_df[stop_time_df.shape_id.notnull()
                                    ].groupby(['trip_id', 'shape_id'])\
                                    .count().reset_index()\
                                    .drop_duplicates(subset = ['shape_id']).copy()

stop_time_df = stop_time_df[stop_time_df.trip_id.isin(unique_stop_time_df.trip_id.tolist())].copy()
        
ACE_linestring_df = pd.merge(ACE_linestring_df, 
                        stop_time_df[['shape_id', 'stop_id' , 'departure_time']].rename(
                                 columns = {"stop_id" : "u_stop_id"}),
                            how = 'left',
                            on = ['shape_id', 'u_stop_id'])
    
ACE_linestring_df = pd.merge(ACE_linestring_df, 
                        stop_time_df[['shape_id', 'stop_id', 'arrival_time']].rename(
                                 columns = {"stop_id" : "v_stop_id"}),
                            how = 'left',
                            on = ['shape_id', 'v_stop_id'])
    
# travel time in minutes
ACE_linestring_df['rail_traveltime'] = (ACE_linestring_df['arrival_time'] - ACE_linestring_df['departure_time'])/60

ACE_rail_node_df = ACE_rail_node_df.rename_axis('node_id').reset_index()
ACE_rail_node_df.rename(columns = {"stop_lat" : "shape_pt_lat", 
                                   "stop_lon" : "shape_pt_lon", 
                                   "stop_sequence": "shape_pt_sequence"},
                       inplace = True)

# %%
# combine ACE with rest of rail

rail_path_link_with_ACE_gdf = pd.concat([rail_path_link_gdf, ACE_linestring_df], sort = False, ignore_index = True)
rail_path_node_with_ACE_df = pd.concat([rail_path_node_df, ACE_rail_node_df[rail_path_node_df.columns]], 
                                       sort = False, ignore_index = True)

# %%
rail_path_link_with_ACE_gdf
# Out:
#      shape_id      u      v  \
# 0         404     10    278
# 1         404    278    455
# 2         404    455    741
# 3         404    741    840
# 4         404    840    990
# 5         404    990   1169
# 432     10279     10287         54011.0       54039.0         0.466667
# 433     10287     10272         54039.0       54071.0         0.533333
# 434     10272     10283         54071.0       54115.0         0.733333
# 435     10283     10281         54115.0       54134.0         0.316667
# 436     10281     10288         54134.0       54190.0         0.933333
# 437     10288     11577         54190.0       54227.0         0.616667
# 438     11577     10858         54227.0       54281.0         0.900000
# 439     10858     10878         54281.0       54322.0         0.683333
# 440     10878     10856         54322.0       54360.0         0.633333
# 441     10856     10874         54360.0       54424.0         1.066667
# 442     10874     10854         54424.0       54477.0         0.883333
# 443     10854     10880         54477.0       54540.0         1.050000
# 444     10880     10875         54540.0       54582.0         0.700000
# 445     10875     10862         54582.0       54642.0         1.000000
# 446     10862     10871         54642.0       54702.0         1.000000
# 447     10871     10868         54702.0       54840.0         2.300000

# %%
unique_stop_id_df[unique_stop_id_df.stop_id_original == "6644"]
# Out:
#        agency_raw_name  stop_id stop_id_original
# 11357  SFMTA_2015_8_11    11358             6644

# %%
rail_path_node_with_ACE_df[rail_path_node_with_ACE_df.stop_id == 11358]
# Out:
#      node_id  shape_pt_lat  shape_pt_lon shape_pt_sequence  \
# 460    29923     37.805257   -122.415307                 1
#
#      shape_dist_traveled  shape_id  is_stop  stop_id
# 460                  0.0      1024        1  11358.0

# %%
def combine_bus_and_rail_shape(rail_path_link, rail_path_node, link, node, shape):
    
    """
    add only unique rail links and nodes to roadway standard
    
    parameter
    -----------
    complete rail link path
    complete rail node path
    all roadway links
    all roadway nodes
    all roadway shapes
    
    return
    -----------
    all roadway and rail links
    all roadway and rail nodes
    all roadway and rail shapes
    unique rail links
    unique rail nodes
    complete rail link path with updated link ID
    
    """
    
    print('indexing rail links and nodes...')
    
    node_gdf = node.copy()
    link_df = link.copy()
    shape_gdf = shape.copy()
    
    # add unique rail nodes to roadway node dataframe
    rail_path_node_gdf = rail_path_node.copy()
    
    unique_rail_node_df = rail_path_node_gdf.drop_duplicates(['shape_pt_lat', 'shape_pt_lon']).copy()
    
    # http://bayareametro.github.io/travel-model-two/input/#roadway-network
    TAP_start_number = 90001 
    
    unique_rail_node_df['model_node_id'] = range(TAP_start_number, TAP_start_number + len(unique_rail_node_df))
    
    rail_path_node_gdf = pd.merge(rail_path_node_gdf, 
                            unique_rail_node_df[['shape_pt_lat', 'shape_pt_lon', 'model_node_id']], 
                            how = 'left', 
                            on = ['shape_pt_lat', 'shape_pt_lon'])
    
    # get unique rail nodes
    unique_rail_node_df['geometry'] = [Point(xy) for xy in zip(unique_rail_node_df.shape_pt_lon, 
                                                               unique_rail_node_df.shape_pt_lat)]
    
    unique_rail_node_df = gpd.GeoDataFrame(unique_rail_node_df)
    unique_rail_node_df.crs = {'init' : 'epsg:4326'}
    unique_rail_node_df = unique_rail_node_df.to_crs(node_gdf.crs)
    
    unique_rail_node_df['rail_only'] = int(1)
    unique_rail_node_df["walk_access"] = int(1)
    
    # combine rail nodes and roadway nodes
    node_gdf["rail_only"] = int(0)
    
    rail_node_columns = ["model_node_id", "geometry", "rail_only", "walk_access"]
    
    roadway_and_rail_node_gdf = node_gdf.append(unique_rail_node_df[rail_node_columns],
                                                ignore_index = True, 
                                                sort = False)
    
    
    rail_node_osmid_dict = dict(zip(rail_path_node_gdf.node_id, rail_path_node_gdf.model_node_id))
    
    rail_path_link_df = rail_path_link.copy()
    
    rail_path_link_df['A'] = rail_path_link_df.u.map(rail_node_osmid_dict)
    rail_path_link_df['B'] = rail_path_link_df.v.map(rail_node_osmid_dict)
    
    rail_path_link_df.drop(["u", "v"], axis = 1, inplace = True)
    
    rail_path_link_df = gpd.GeoDataFrame(rail_path_link_df)
    rail_path_link_df.crs = {'init' : 'epsg:4326'}
    
    # get unique rail links
    unique_rail_link_gdf = rail_path_link_df.drop_duplicates(['A', 'B']).copy()
    
    # fake rail link shst geom id
    unique_rail_link_gdf['shstGeometryId'] = range(1, 1 + len(unique_rail_link_gdf))
    unique_rail_link_gdf['shstGeometryId'] = unique_rail_link_gdf.shstGeometryId.apply(lambda x:'rail'+str(x))
    unique_rail_link_gdf['id'] = unique_rail_link_gdf['shstGeometryId']

    unique_rail_link_gdf['rail_only'] = int(1)
    
    rail_path_link_df = pd.merge(rail_path_link_df,
                                unique_rail_link_gdf[["A", "B", "shstGeometryId"]],
                                how = "left",
                                on = ["A", "B"])
    
    rail_link_columns = ['A', 'B', "shstGeometryId", "rail_traveltime", "rail_only", "id"]
    rail_shape_columns = ["id", "geometry"]
    
    # combine rail and roadway links
    roadway_and_rail_link_df = link_df.append(unique_rail_link_gdf[rail_link_columns], 
                                              ignore_index = True, 
                                              sort = False)
    
    # combine rail and roadway shapes
    roadway_and_rail_shape_gdf = shape_gdf.append(unique_rail_link_gdf[rail_shape_columns],
                                                 ignore_index = True,
                                                 sort = False)
    
    """rail_path_link_df = pd.merge(rail_path_link_df[['shape_id', 'geometry', 'u_stop_id', 'v_stop_id']],
                            unique_rail_shape_gdf.drop(['geometry', 'shape_id'], axis = 1),
                            how = 'left',
                            on = ['u_stop_id', 'v_stop_id'])"""
    
    rail_path_link_df = rail_path_link_df.to_crs({'init' : 'epsg:4326'})
        
    return roadway_and_rail_link_df, roadway_and_rail_node_gdf, roadway_and_rail_shape_gdf, \
                unique_rail_link_gdf, unique_rail_node_df, \
                rail_path_link_df

# %%
roadway_and_rail_link_df, roadway_and_rail_node_gdf, roadway_and_rail_shape_gdf, unique_rail_link_gdf, unique_rail_node_gdf, \
                                            rail_link_gdf = combine_bus_and_rail_shape(
                                                                                      rail_path_link_with_ACE_gdf, 
                                                                                      rail_path_node_with_ACE_df,
                                                                                      link_df, 
                                                                                      node_gdf,
                                                                                      shape_gdf)
# Out:
# indexing rail links and nodes...
# C:\Users\wangs1\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:68: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
shape_gdf.shape
# Out:
# (868567, 6)

# %%
unique_rail_link_gdf.shape
# Out:
# (750, 12)

# %%
link_df.id.nunique()
# Out:
# 868567

# %%
roadway_and_rail_shape_gdf.id.nunique()
# Out:
# 869317

# %%
roadway_and_rail_link_df.id.nunique()
# Out:
# 869317

# %%
roadway_and_rail_link_df.columns
# Out:
# Index(['access', 'area', 'bike_access', 'bridge', 'drive_access', 'est_width',
#        'fromIntersectionId', 'highway', 'id', 'junction', 'key', 'landuse',
#        'lanes', 'link', 'maxspeed', 'name', 'oneWay', 'ref', 'roadway',
#        'roundabout', 'service', 'shstGeometryId', 'shstReferenceId',
#        'toIntersectionId', 'tunnel', 'u', 'v', 'walk_access', 'wayId', 'width',
#        'county', 'length', 'model_link_id', 'county_numbering_start', 'A', 'B',
#        'rail_traveltime', 'rail_only'],
#       dtype='object')

# %%
unique_rail_node_gdf.shape
# Out:
# (669, 12)

# %%
unique_rail_link_gdf.shape
# Out:
# (750, 12)

# %%
print(link_df.shape)
print(node_gdf.shape)
print(shape_gdf.shape)
# Out:
# (1632702, 36)
# (643811, 9)
# (868567, 6)

# %%
print(roadway_and_rail_node_gdf.shape)
print(roadway_and_rail_link_df.shape)
print(roadway_and_rail_shape_gdf.shape)
# Out:
# (644480, 10)
# (1633452, 38)
# (869317, 6)

# %%
unique_rail_node_gdf
# Out:
#       node_id  shape_pt_lat  shape_pt_lon shape_pt_sequence  \
# 0          10     38.018914   -121.945154                10
# 1         278     38.003275   -122.024597               278
# 2         455     37.973737   -122.029095               455
# 3         741     37.928403   -122.056013               741
# 4         840     37.905628   -122.067423               840
# 5         990     37.893394   -122.123801               990
# 6        1169     37.878361   -122.183791              1169
# 7        1242     37.844601   -122.251793              1242
# 8        1318     37.828415   -122.267227              1319
# 9        1373     37.807870   -122.269029              1376
# 10       1379     37.803664   -122.271604              1382
# 11       1499     37.804675   -122.294582              1504
# 12       1751     37.792976   -122.396742              1756
# 13       1755     37.789256   -122.401407              1760
# 14       1761     37.784991   -122.406857              1766
# 15       1766     37.779528   -122.413756              1771
# 16       1798     37.765062   -122.419694              1803
# 17       1808     37.752254   -122.418466              1813
# 18       1850     37.732921   -122.434092              1855
# 19       1901     37.721981   -122.447414              1906
# 20       2028     37.706121   -122.469081              2033
# 21       2126     37.684638   -122.466233              2133
# 22       2182     37.664174   -122.444116              2189
# 23       2239     37.637753   -122.416038              2246
# 24       2331     37.599787   -122.386660              2338
# 25       2332     37.616035   -122.392612              2339
# 51       4754     37.557355   -121.976400                 0
# 52       4839     37.591208   -122.017867                85
# 53       4962     37.634800   -122.057551               208
# 54       5040     37.670399   -122.087967               286
# ...       ...           ...           ...               ...
# 1378    37033     37.404327   -122.049167               154
# 1379    37068     37.402367   -122.033460               189
# 1380    37114     37.410048   -122.026891               235
# 1381    37158     37.411326   -122.016702               279
# 1382    37176     37.408841   -122.011180               297
# 1383    37208     37.402578   -122.008638               329
# 1384    37231     37.403354   -121.998254               352
# 1385    37254     37.403510   -121.987407               375
# 1386    37266     37.403299   -121.978871               387
# 1387    37274     37.403555   -121.974058               395
# 1388    37291     37.407795   -121.962925               412
# 1389    37342     37.408898   -121.951936               463
# 1403    37485     37.330248   -121.899045               606
# 1404    37529     37.328393   -121.903407               650
# 1405    37571     37.317155   -121.910753               692
# 1406    37589     37.310122   -121.918483               710
# 29      2.088695e+09  7a241d6d9f2f9d31c48cd1b67e0d44a1    Santa Clara
# ...              ...                               ...            ...
# 644450           NaN                               NaN            NaN
# 644451           NaN                               NaN            NaN
# 644452           NaN                               NaN            NaN
# 644453           NaN                               NaN            NaN
# 644454           NaN                               NaN            NaN
# 644455           NaN                               NaN            NaN
# 644456           NaN                               NaN            NaN
# 644457           NaN                               NaN            NaN
# 644458           NaN                               NaN            NaN
# 644459           NaN                               NaN            NaN
# 644460           NaN                               NaN            NaN
# 644461           NaN                               NaN            NaN
# 644462           NaN                               NaN            NaN
# 644463           NaN                               NaN            NaN
# 644464           NaN                               NaN            NaN
# 644465           NaN                               NaN            NaN
# 644466           NaN                               NaN            NaN
# 644467           NaN                               NaN            NaN
# 644468           NaN                               NaN            NaN
# 644469           NaN                               NaN            NaN
# 644470           NaN                               NaN            NaN
# 644471           NaN                               NaN            NaN
# 644472           NaN                               NaN            NaN
# 644473           NaN                               NaN            NaN
# 644474           NaN                               NaN            NaN
# 644475           NaN                               NaN            NaN
# 644476           NaN                               NaN            NaN
# 644477           NaN                               NaN            NaN
# 644478           NaN                               NaN            NaN
# 644479           NaN                               NaN            NaN
#
#         drive_access  walk_access  bike_access  model_node_id  \
# 0                1.0            1          1.0        3000000
# 1                1.0            1          1.0        3000001
# 2                1.0            1          1.0        5000000
# 3                1.0            1          1.0        2000000
# 4                1.0            1          1.0        2000001
# 5                1.0            1          1.0        2000002
# 6                1.0            1          1.0        2500000
# 7                0.0            1          1.0        2000003
# 8                1.0            1          1.0        3000002
# 9                1.0            1          1.0        1000000
# 10               1.0            1          1.0        3000003
# 11               1.0            1          1.0        3000004
# 12               1.0            1          1.0        2000004
# 13               1.0            1          1.0        1000001
# 14               1.0            1          1.0        4500000
# 15               1.0            1          1.0        3000005
# 16               1.0            1          1.0        4500001
# 17               1.0            1          1.0        2500001
# 18               1.0            1          1.0        2500002
# 19               1.0            1          1.0        2000005
# 20               1.0            1          1.0        3500000
# 21               1.0            1          1.0        1500000
# 22               1.0            1          1.0        1500001
# 23               1.0            1          1.0        3000006
# 24               1.0            1          1.0        2500003
# 25               1.0            1          1.0        2500004
# 26               0.0            1          1.0        3000007
# 27               1.0            1          1.0        4500002
# 28               1.0            1          1.0        4500003
# 29               1.0            1          1.0        2000006
# ...              ...          ...          ...            ...
# 644450           NaN            1          NaN          90640
# 644451           NaN            1          NaN          90641
# 644452           NaN            1          NaN          90642
# 644453           NaN            1          NaN          90643
# 644454           NaN            1          NaN          90644
# 644455           NaN            1          NaN          90645
# 644456           NaN            1          NaN          90646
# 644457           NaN            1          NaN          90647
# 644458           NaN            1          NaN          90648
# 644459           NaN            1          NaN          90649
# 644460           NaN            1          NaN          90650
# 644461           NaN            1          NaN          90651
# 644462           NaN            1          NaN          90652
# 644463           NaN            1          NaN          90653
# 644464           NaN            1          NaN          90654
# 644465           NaN            1          NaN          90655
# 644466           NaN            1          NaN          90656
# 644467           NaN            1          NaN          90657
# 644468           NaN            1          NaN          90658
# 644465                     NaN  POINT (-121.91848 37.31012)          1
# 644466                     NaN  POINT (-121.93030 37.29947)          1
# 644467                     NaN  POINT (-121.93658 37.29369)          1
# 644468                     NaN  POINT (-121.94340 37.28548)          1
# 644469                     NaN  POINT (-121.94831 37.27918)          1
# 644470                     NaN  POINT (-121.27895 37.95706)          1
# 644471                     NaN  POINT (-121.26366 37.79791)          1
# 644472                     NaN  POINT (-121.43387 37.69647)          1
# 644473                     NaN  POINT (-121.71938 37.70139)          1
# 644474                     NaN  POINT (-121.76750 37.68511)          1
# 644475                     NaN  POINT (-121.88296 37.65755)          1
# 644476                     NaN  POINT (-122.00760 37.55856)          1
# 644477                     NaN  POINT (-121.96667 37.40640)          1
# 644478                     NaN  POINT (-121.93635 37.35289)          1
# 644479                     NaN  POINT (-121.90319 37.32957)          1
#
# [644480 rows x 10 columns]

# %%
county_file = "../../data/external/county_boundaries/cb_2018_us_county_500k/cb_2018_us_county_500k.shp"

county_gdf = gpd.read_file(county_file)

county_gdf = county_gdf.to_crs(shape_gdf.crs)

# %%
unique_rail_link_gdf.crs
# Out:
# <Geographic 2D CRS: +init=epsg:4326 +type=crs>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - lon[east]: Longitude (degree)
# - lat[north]: Latitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# re-number rail nodes and links

# use nearest match for nodes that did not get county match (e.g. in the Bay)
node_county_matched_gdf = node_gdf.copy()
node_county_unmatched_gdf = unique_rail_node_gdf.copy()

node_county_matched_gdf = node_county_matched_gdf.to_crs(epsg = 26915)
node_county_matched_gdf['X'] = node_county_matched_gdf.geometry.map(lambda g:g.x)
node_county_matched_gdf['Y'] = node_county_matched_gdf.geometry.map(lambda g:g.y)

node_matched_inventory_ref = node_county_matched_gdf[['X', 'Y']].values
node_matched_tree = cKDTree(node_matched_inventory_ref)

node_county_unmatched_gdf = node_county_unmatched_gdf.to_crs({'init' : 'epsg:26915'})
node_county_unmatched_gdf['X'] = node_county_unmatched_gdf['geometry'].apply(lambda p: p.x)
node_county_unmatched_gdf['Y'] = node_county_unmatched_gdf['geometry'].apply(lambda p: p.y)

node_county_rematch_gdf = pd.DataFrame()

for i in range(len(node_county_unmatched_gdf)):
    point = node_county_unmatched_gdf.iloc[i][['X', 'Y']].values
    dd, ii = node_matched_tree.query(point, k = 1)
    add_snap_gdf = gpd.GeoDataFrame(node_county_matched_gdf.iloc[ii][["county"]]).transpose().reset_index(drop = True)
    
    add_snap_gdf['model_node_id'] = node_county_unmatched_gdf.iloc[i]['model_node_id']
    
    if i == 0:
        node_county_rematch_gdf = add_snap_gdf.copy()
    else:
        node_county_rematch_gdf = node_county_rematch_gdf.append(add_snap_gdf, ignore_index=True, sort=False)
        
        
# use nearest for links that did not get county match
node_county_matched_gdf = node_gdf.copy()

node_county_matched_gdf = node_county_matched_gdf.to_crs(epsg = 26915)
node_county_matched_gdf['X'] = node_county_matched_gdf.geometry.map(lambda g:g.x)
node_county_matched_gdf['Y'] = node_county_matched_gdf.geometry.map(lambda g:g.y)

node_matched_inventory_ref = node_county_matched_gdf[['X', 'Y']].values
node_matched_tree = cKDTree(node_matched_inventory_ref)

shape_county_unmatched_gdf = unique_rail_link_gdf.copy()
shape_county_unmatched_gdf["geometry"] = unique_rail_link_gdf.centroid

shape_county_unmatched_gdf = shape_county_unmatched_gdf.to_crs({'init' : 'epsg:26915'})
shape_county_unmatched_gdf["geometry"] = shape_county_unmatched_gdf["geometry"].centroid
shape_county_unmatched_gdf['X'] = shape_county_unmatched_gdf['geometry'].apply(lambda p: p.x)
shape_county_unmatched_gdf['Y'] = shape_county_unmatched_gdf['geometry'].apply(lambda p: p.y)

shape_county_rematch_gdf = pd.DataFrame()

for i in range(len(shape_county_unmatched_gdf)):
    point = shape_county_unmatched_gdf.iloc[i][['X', 'Y']].values
    dd, ii = node_matched_tree.query(point, k = 1)
    add_snap_gdf = gpd.GeoDataFrame(node_county_matched_gdf.iloc[ii][["county"]]).transpose().reset_index(drop = True)
    
    add_snap_gdf['id'] = shape_county_unmatched_gdf.iloc[i]['id']
    
    if i == 0:
        shape_county_rematch_gdf = add_snap_gdf.copy()
    else:
        shape_county_rematch_gdf = shape_county_rematch_gdf.append(add_snap_gdf, ignore_index=True, sort=False)
# Out:
# C:\Users\wangs1\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:68: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\wangs1\.conda\envs\MetC_new\lib\site-packages\ipykernel_launcher.py:44: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
# C:\Users\wangs1\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:68: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
node_gdf.county.value_counts()
# Out:
# Santa Clara      192799
# Alameda          125942
# Contra Costa      97273
# San Mateo         56363
# Sonoma            56146
# Solano            47318
# San Francisco     27608
# Marin             26529
# Napa              13833
# Name: county, dtype: int64

# %%
node_county_rematch_gdf
shape_county_rematch_gdf
# Out:
#             county       id
# 0     Contra Costa    rail1
# 1     Contra Costa    rail2
# 2     Contra Costa    rail3
# 3     Contra Costa    rail4
# 4     Contra Costa    rail5
# 5     Contra Costa    rail6
# 6          Alameda    rail7
# 7          Alameda    rail8
# 8          Alameda    rail9
# 9          Alameda   rail10
# 10         Alameda   rail11
# 11         Alameda   rail12
# 12   San Francisco   rail13
# 13   San Francisco   rail14
# 14   San Francisco   rail15
# 15   San Francisco   rail16
# 16   San Francisco   rail17
# 17   San Francisco   rail18
# 18   San Francisco   rail19
# 19   San Francisco   rail20
# 20       San Mateo   rail21
# 21       San Mateo   rail22
# 22       San Mateo   rail23
# 23       San Mateo   rail24
# 24       San Mateo   rail25
# 25       San Mateo   rail26
# 26       San Mateo   rail27
# 27       San Mateo   rail28
# 28       San Mateo   rail29
# 29   San Francisco   rail30
# ..             ...      ...
# 720    Santa Clara  rail721
# 721    Santa Clara  rail722
# 722    Santa Clara  rail723
# 723    Santa Clara  rail724
# 724    Santa Clara  rail725
# 725    Santa Clara  rail726
# 726    Santa Clara  rail727
# 727    Santa Clara  rail728
# 728    Santa Clara  rail729
# 729    Santa Clara  rail730
# 730    Santa Clara  rail731
# 731    Santa Clara  rail732
# 732   Contra Costa  rail733
# 733        Alameda  rail734
# 734        Alameda  rail735
# 735        Alameda  rail736
# 736        Alameda  rail737
# 737        Alameda  rail738
# 738        Alameda  rail739
# 739    Santa Clara  rail740
# 740    Santa Clara  rail741
# 741    Santa Clara  rail742
# 742    Santa Clara  rail743
# 743        Alameda  rail744
# 744        Alameda  rail745
# 745        Alameda  rail746
# 746        Alameda  rail747
# 747        Alameda  rail748
# 748        Alameda  rail749
# 749   Contra Costa  rail750
#
# [750 rows x 2 columns]

# %%
# get the last node and link number of counties

county_last_node_id_df = node_gdf.groupby("county")["model_node_id"].max().reset_index().rename(
    columns = {"model_node_id" : "county_last_id"})

county_last_link_id_df = link_df.groupby("county")["model_link_id"].max().reset_index().rename(
    columns = {"model_link_id" : "county_last_id"})

node_county_rematch_gdf = pd.merge(
    node_county_rematch_gdf.rename(columns = {"model_node_id" : "rail_node_id"}),
    county_last_node_id_df,
    how = "left",
    on = "county"
)

node_county_rematch_gdf["model_node_id"] = node_county_rematch_gdf.groupby(["county"]).cumcount() + 1

node_county_rematch_gdf["model_node_id"] = node_county_rematch_gdf["model_node_id"] + node_county_rematch_gdf["county_last_id"]

shape_county_rematch_gdf = pd.merge(
    shape_county_rematch_gdf,
    county_last_link_id_df,
    how = "left",
    on = "county"
)

shape_county_rematch_gdf["model_link_id"] = shape_county_rematch_gdf.groupby(["county"]).cumcount() + 1

shape_county_rematch_gdf["model_link_id"] = shape_county_rematch_gdf["model_link_id"] + shape_county_rematch_gdf["county_last_id"]

# %%
rail_node_id_dict = dict(zip(node_county_rematch_gdf.rail_node_id, node_county_rematch_gdf.model_node_id))
rail_node_county_dict = dict(zip(node_county_rematch_gdf.model_node_id, node_county_rematch_gdf.county))
rail_link_id_dict = dict(zip(shape_county_rematch_gdf.id, shape_county_rematch_gdf.model_link_id))
rail_link_county_dict = dict(zip(shape_county_rematch_gdf.id, shape_county_rematch_gdf.county))

# %%
unique_rail_node_gdf["model_node_id"] = unique_rail_node_gdf["model_node_id"].map(rail_node_id_dict)
unique_rail_node_gdf["county"] = unique_rail_node_gdf["model_node_id"].map(rail_node_county_dict)
unique_rail_link_gdf["model_link_id"] = unique_rail_link_gdf["id"].map(rail_link_id_dict)
unique_rail_link_gdf["county"] = unique_rail_link_gdf["id"].map(rail_link_county_dict)

# %%
unique_rail_link_gdf["A"] = unique_rail_link_gdf["A"].map(rail_node_id_dict)
unique_rail_link_gdf["B"] = unique_rail_link_gdf["B"].map(rail_node_id_dict)

# %%
rail_link_gdf["A"] = rail_link_gdf["A"].map(rail_node_id_dict)
rail_link_gdf["B"] = rail_link_gdf["B"].map(rail_node_id_dict)

# %%
rail_node_columns = ["model_node_id", "geometry", "rail_only", "walk_access", "county"]
    
roadway_and_rail_node_gdf = node_gdf.append(unique_rail_node_gdf[rail_node_columns],
                                            ignore_index = True, 
                                            sort = False)

roadway_and_rail_node_gdf["rail_only"].fillna(0, inplace = True)
roadway_and_rail_node_gdf["rail_only"] = roadway_and_rail_node_gdf["rail_only"].astype(int)

rail_link_columns = ['A', 'B', "shstGeometryId", "rail_traveltime","rail_only", "id", "model_link_id", "county"]
rail_shape_columns = ["id", "geometry"]
    
# combine rail and roadway links

# 1426  POINT (-121.43387 37.69647)          1            1        Alameda
# 1427  POINT (-121.71938 37.70139)          1            1        Alameda
# 1428  POINT (-121.76750 37.68511)          1            1        Alameda
# 1429  POINT (-121.88296 37.65755)          1            1        Alameda
# 1430  POINT (-122.00760 37.55856)          1            1        Alameda
# 1431  POINT (-121.96667 37.40640)          1            1    Santa Clara
# 1432  POINT (-121.93635 37.35289)          1            1    Santa Clara
# 1433  POINT (-121.90319 37.32957)          1            1    Santa Clara
#
# [669 rows x 13 columns]

# %%
roadway_and_rail_node_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 644480 entries, 0 to 644479
# Data columns (total 10 columns):
# osm_node_id               643811 non-null float64
# shst_node_id              643811 non-null object
# county                    644480 non-null object
# drive_access              643811 non-null float64
# walk_access               644480 non-null int64
# bike_access               643811 non-null float64
# model_node_id             644480 non-null int64
# county_numbering_start    643811 non-null float64
# geometry                  644480 non-null geometry
# rail_only                 644480 non-null int32
# dtypes: float64(4), geometry(1), int32(1), int64(2), object(2)
# memory usage: 46.7+ MB

# %%
roadway_and_rail_node_gdf.model_node_id.nunique()
# Out:
# 644480

# %%
roadway_and_rail_link_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1633452 entries, 0 to 1633451
# Data columns (total 38 columns):
# access                    1632702 non-null object
# area                      1632702 non-null object
# bike_access               1632702 non-null float64
# bridge                    1632702 non-null object
# drive_access              1632702 non-null float64
# est_width                 1632702 non-null object
# fromIntersectionId        1632702 non-null object
# highway                   1632702 non-null object
# id                        1633452 non-null object
# junction                  1632702 non-null object
# key                       1632702 non-null object
# landuse                   1632702 non-null object
# lanes                     1632702 non-null object
# link                      1632702 non-null object
# maxspeed                  1632702 non-null object
# name                      1632702 non-null object
# oneWay                    1632702 non-null object
# ref                       1632702 non-null object
# roadway                   1632702 non-null object
# roundabout                1632702 non-null object
# service                   1632702 non-null object
# shstGeometryId            1633452 non-null object
# shstReferenceId           1632702 non-null object
# toIntersectionId          1632702 non-null object
# tunnel                    1632702 non-null object
# u                         1632702 non-null float64
# v                         1632702 non-null float64
# walk_access               1632702 non-null float64
# wayId                     1632702 non-null object
# width                     1632702 non-null object
# county                    1633452 non-null object
# length                    1632702 non-null float64
# model_link_id             1633452 non-null int64
# county_numbering_start    1632702 non-null float64
# A                         1633452 non-null int64
# B                         1633452 non-null int64
# rail_traveltime           613 non-null float64
# rail_only                 1633452 non-null int32
# dtypes: float64(8), int32(1), int64(3), object(26)
# memory usage: 467.3+ MB

# %%
roadway_and_rail_link_df.rail_only.value_counts()
# Out:
# 0    1632702
# 1        750
# Name: rail_only, dtype: int64

# %%
roadway_and_rail_link_df.model_link_id.nunique()
# Out:
# 1633452

# %%
roadway_and_rail_shape_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 869317 entries, 0 to 869316
# Data columns (total 6 columns):
# id                    869317 non-null object
# fromIntersectionId    868567 non-null object
# toIntersectionId      868567 non-null object
# forwardReferenceId    868567 non-null object
# backReferenceId       868567 non-null object
# geometry              869317 non-null geometry
# dtypes: geometry(1), object(5)
# memory usage: 39.8+ MB

# %%
roadway_and_rail_node_gdf.county.value_counts()
# Out:
# Santa Clara      192949
# Alameda          125977
# Contra Costa      97287
# San Mateo         56392
# Sonoma            56146
# Solano            47321
# San Francisco     28041
# Marin             26534
# Napa              13833
# Name: county, dtype: int64

# %%
def create_freq_table(trip_df):
    
    """
    create frequency table for network standard
    """
    
    print('creating frequency reference...')
    
    # calculate EA and NT frequency using 5-6am, and 7-10pm
    tod_numhours_dict = {"AM" : 4, "MD" : 5, "PM" :4, "NT" : 3, "EA" : 1}
    
    freq_df = trip_df[['trip_id', 'tod', 'direction_id', 'trip_num']].copy()
    freq_df['headway_secs'] = freq_df.tod.map(tod_numhours_dict)
    freq_df['headway_secs'] = freq_df.apply(lambda x: int(x.headway_secs * 60 * 60 / x.trip_num),
                                           axis = 1)
    
    freq_enum_list = {'start_time' : {'AM' : '06:00:00', 
                                      'MD' : '10:00:00',
                                      "PM" : "15:00:00",
                                      "NT" : "19:00:00",
                                      "EA" : "03:00:00"},
                      'end_time' : {'AM' : '10:00:00', 
                                    'MD' : '15:00:00',
                                    "PM" : "19:00:00",
                                    "NT" : "03:00:00",
                                    "EA" : "06:00:00"}}
    
    freq_df['start_time'] = freq_df.tod.map(freq_enum_list.get("start_time"))
    freq_df['end_time'] = freq_df.tod.map(freq_enum_list.get("end_time"))
    
    return freq_df

# %%
freq_df = create_freq_table(trip_df)
# Out:
# creating frequency reference...

# %%
freq_df
# Out:
#       trip_id tod  direction_id  trip_num  headway_secs start_time  end_time
# 0           1  EA           0.0       1.0          3600   03:00:00  06:00:00
# 1           5  AM           0.0       2.0          7200   06:00:00  10:00:00
# 2           4  PM           1.0       4.0          3600   15:00:00  19:00:00
# 3           9  EA           1.0       1.0          3600   03:00:00  06:00:00
# 4          10  AM           1.0       5.0          2880   06:00:00  10:00:00
# 5          11  PM           0.0      13.0          1107   15:00:00  19:00:00
# 6          20  AM           1.0       9.0          1600   06:00:00  10:00:00
# 7          21  AM           0.0       2.0          7200   06:00:00  10:00:00
# 8          22  PM           1.0       2.0          7200   15:00:00  19:00:00
# 9          23  AM           0.0      10.0          1440   06:00:00  10:00:00
# 10         31  PM           0.0      12.0          1200   15:00:00  19:00:00
# 11         42  NT           0.0       6.0          1800   19:00:00  03:00:00
# 12         44  AM           0.0       1.0         14400   06:00:00  10:00:00
# 13         45  AM           0.0       1.0         14400   06:00:00  10:00:00
# 14         46  AM           0.0       2.0          7200   06:00:00  10:00:00
# 15         48  PM           1.0       1.0         14400   15:00:00  19:00:00
# 16         49  AM           0.0       1.0         14400   06:00:00  10:00:00
# 17         50  MD           1.0       2.0          9000   10:00:00  15:00:00
# 18         51  MD           1.0       1.0         18000   10:00:00  15:00:00
# 19         52  PM           1.0       1.0         14400   15:00:00  19:00:00
# 20         53  MD           1.0       1.0         18000   10:00:00  15:00:00
# 21         54  PM           1.0       2.0          7200   15:00:00  19:00:00
# 22         55  MD           1.0       1.0         18000   10:00:00  15:00:00
# 23         57  MD           1.0       2.0          9000   10:00:00  15:00:00
# 24         58  MD           1.0       1.0         18000   10:00:00  15:00:00
# 25         59  PM           1.0       1.0         14400   15:00:00  19:00:00
# 26         60  MD           1.0       1.0         18000   10:00:00  15:00:00
# 27         61  MD           1.0       2.0          9000   10:00:00  15:00:00
# 28         63  AM           0.0       1.0         14400   06:00:00  10:00:00
# 29         64  AM           0.0       1.0         14400   06:00:00  10:00:00
# ...       ...  ..           ...       ...           ...        ...       ...
# 3950    33632  PM           0.0       7.0          2057   15:00:00  19:00:00
# 3951    33697  AM           0.0       5.0          2880   06:00:00  10:00:00
# 3952    33702  PM           1.0       5.0          2880   15:00:00  19:00:00
# 3953    33556  AM           0.0       5.0          2880   06:00:00  10:00:00
# 3954    33561  PM           1.0       5.0          2880   15:00:00  19:00:00
# 3955    33567  AM           0.0       6.0          2400   06:00:00  10:00:00
# 3956    33572  PM           1.0       6.0          2400   15:00:00  19:00:00
# 3957    33534  AM           0.0       6.0          2400   06:00:00  10:00:00
# 3958    33540  PM           0.0       6.0          2400   15:00:00  19:00:00
# 3959    33610  AM           0.0       7.0          2057   06:00:00  10:00:00
# 3960    33617  PM           1.0       7.0          2057   15:00:00  19:00:00
# 3961    33639  EA           0.0       1.0          3600   03:00:00  06:00:00
# 3962    33640  AM           0.0       7.0          2057   06:00:00  10:00:00
# 3963    33647  MD           1.0       1.0         18000   10:00:00  15:00:00
# 3964    33648  PM           1.0       6.0          2400   15:00:00  19:00:00
# 3965    33654  AM           0.0       4.0          3600   06:00:00  10:00:00
# 3966    33657  PM           1.0       3.0          4800   15:00:00  19:00:00
# 3967    33667  AM           0.0       8.0          1800   06:00:00  10:00:00
# 3968    33675  PM           0.0       7.0          2057   15:00:00  19:00:00
# 3969    33682  AM           1.0       7.0          2057   06:00:00  10:00:00
# 3970    33689  MD           1.0       1.0         18000   10:00:00  15:00:00
# 3971    33690  PM           1.0       6.0          2400   15:00:00  19:00:00
# 3972    33696  EA           1.0       1.0          3600   03:00:00  06:00:00
# 3973    33664  AM           0.0       3.0          4800   06:00:00  10:00:00
# 3974    33660  AM           1.0       1.0         14400   06:00:00  10:00:00
# 3975    33661  PM           1.0       3.0          4800   15:00:00  19:00:00
# 3976    33510  AM           0.0       5.0          2880   06:00:00  10:00:00
# 3977    33515  PM           0.0       6.0          2400   15:00:00  19:00:00
# 3978    33521  NT           0.0       1.0         10800   19:00:00  03:00:00
# 3979    33522  MD           0.0       1.0         18000   10:00:00  15:00:00
#
# [3980 rows x 7 columns]

# %%
# create new shape with complete node list the route passes
def create_new_node_shape(node, bus_link, rail_link = pd.DataFrame(columns = ["u", "v", "shape_id", "A", "B"])):
    
    """
    create complete node lists each transit traverses to replace the gtfs shape.txt
    """
    bus_link_df = bus_link.copy()
    bus_trip_list_with_unique_shape_id = bus_link_df.drop_duplicates(subset = ["shape_id"]).trip_id.tolist()
    
    bus_link_df = bus_link_df[bus_link_df.trip_id.isin(bus_trip_list_with_unique_shape_id)].copy()
    
    shape_link_df = pd.concat([bus_link_df[["u", "v", 'shape_id', "A", "B"]]
                                , rail_link[['shape_id', "A", "B"]]],
                               sort = False,
                               ignore_index = True)
    
    shape_link_df.u = shape_link_df.u.fillna(0).astype(np.int64)
    shape_link_df.v = shape_link_df.v.fillna(0).astype(np.int64)

    shape_point_df = gpd.GeoDataFrame()
    
    for shape_id in shape_link_df.shape_id.unique():
        shape_df = shape_link_df[shape_link_df.shape_id == shape_id]
        point_df = pd.DataFrame(data = {"shape_id" : shape_id,
                                         "shape_osm_node_id" : shape_df.u.tolist() + [shape_df.v.iloc[-1]],
                                        "shape_model_node_id" : shape_df.A.tolist() + [shape_df.B.iloc[-1]],
                                       "shape_pt_sequence" : range(1, 1+len(shape_df)+1)})
   
        shape_point_df = pd.concat([shape_point_df,
                                   point_df],
                                  sort = False,
                                  ignore_index = True)

    shape_point_df = pd.merge(shape_point_df,
                             node[["osm_node_id", "shst_node_id", "model_node_id", "geometry"]],
                             how = "left",
                             left_on = "shape_model_node_id",
                             right_on = "model_node_id")
    
    shape_point_df.crs = {'init' : 'epsg:4326'}
    #shape_point_df = shape_point_df.to_crs(epsg = 4326)
    
    print(shape_point_df[shape_point_df.geometry.isnull()])
    
    shape_point_df["shape_pt_lat"] = shape_point_df.geometry.map(lambda g:g.y)
    shape_point_df["shape_pt_lon"] = shape_point_df.geometry.map(lambda g:g.x)
    
    shape_point_df["shape_id"] = shape_point_df["shape_id"].astype(int)
    
    shape_point_df.rename(columns = {"shst_node_id":"shape_shst_node_id"}, inplace = True)
        
    return shape_point_df[["shape_id", "shape_pt_sequence", "shape_osm_node_id", "shape_shst_node_id", "shape_model_node_id"]]

# %%
bus_link_df
# Out:
#                  u           v  trip_id  shape_id  \
# 0         57808643    57808641        9     359.0
# 1         57808641    57808639        9     359.0
# 2         57808639    57808637        9     359.0
# 3         57808637    57808634        9     359.0
# 4         57808634  4924860621        9     359.0
# 5       4924860621  4924860622        9     359.0
# 6       4924860622    57808632        9     359.0
# 7         57808632    57808630        9     359.0
# 8         57808630    57807822        9     359.0
# 9         57807822   262120801        9     359.0
# 10       262120801    57808628        9     359.0
# 11        57808628    57808625        9     359.0
# 12        57808625    57808621        9     359.0
# 13        57808621    57808619        9     359.0
# 14        57808619    57808618        9     359.0
# 15        57808618  2053862007        9     359.0
# 16      2053862007    57808615        9     359.0
# 17        57808615  2053862022        9     359.0
# 18      2053862022  2006039012        9     359.0
# 19      2006039012  5482922720        9     359.0
# 20      5482922720    57808614        9     359.0
# 21        57808614  5482922722        9     359.0
# 22      5482922722    57865385        9     359.0
# 23        57865385    57835314        9     359.0
# 24        57835314   237136348        9     359.0
# 25       237136348    57865388        9     359.0
# 26        57865388    57865390        9     359.0
# 27        57865390    57833215        9     359.0
# 28        57833215  5482922760        9     359.0
# 29      5482922760    57865392        9     359.0
# ...            ...         ...      ...       ...
# 920463    53036468    53036464    32613    2019.0
# 920464    53036464    53036462    32613    2019.0
# 920465    53036462    53036458    32613    2019.0
# 920466    53036458  1424235720    32613    2019.0
# 920467  1424235720    53036452    32613    2019.0
# 920468    53036452  1424235722    32613    2019.0
# 920469  1424235722   430099341    32613    2019.0
UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
# Empty DataFrame
# Columns: [shape_id, shape_osm_node_id, shape_model_node_id, shape_pt_sequence, osm_node_id, shst_node_id, model_node_id, geometry]
# Index: []

# %%
shape_point_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 350940 entries, 0 to 350939
# Data columns (total 5 columns):
# shape_id               350940 non-null int32
# shape_pt_sequence      350940 non-null int64
# shape_osm_node_id      350940 non-null int64
# shape_shst_node_id     349496 non-null object
# shape_model_node_id    350940 non-null int64
# dtypes: int32(1), int64(3), object(1)
# memory usage: 14.7+ MB

# %%
shape_point_df.shape_id.nunique()
# Out:
# 1586

# %%
all_routes_df.agency_raw_name.value_counts()
# Out:
# ACTransit_2015_8_14                                 152
# SFMTA_2015_8_11                                      81
# VTA_2015_8_27                                        80
# SamTrans_2015_8_20                                   75
# GGTransit_2015_9_3                                   38
# Wheels_2016_7_13                                     36
# CCTA_2015_8_11                                       30
# SonomaCounty_2015_8_18                               29
# Marguerite_2016_10_10                                29
# commuteDOTorg_GTFSImportExport_20160127_final_mj     19
# SantaRosa_google_transit_08_28_15                    17
# Fairfield_2015_10_14                                 16
# TriDelta-GTFS-2018-05-24_21-43-17                    14
# westcat-ca-us_9_17_2015                              14
# Soltrans_2016_5_20                                   14
# Vine_GTFS_PLUS_2015                                  13
# petalumatransit-petaluma-ca-us__11_12_15             11
# Union_City_Transit_Aug-01-2015 to Jun-30-2017         9
# MarinTransit_2015_8_31                                8
# Emeryville_2016_10_26                                 7
# SF_Bay_Ferry2016_07_01                                6
# BART_2015_8_3                                         6
# MVGo_2016_10_26                                       4
# vacavillecitycoach-2020-ca-us                         4
# Caltrain_2015_5_13                                    3
# Blue&Gold_gtfs_10_4_2017                              3
# RioVista_2015_8_20                                    2
# Capitol_2017_3_20                                     2
# ACE_2017_3_20                                         1
# Name: agency_raw_name, dtype: int64

# %%
def write_out_transit_standard(trip, stop, shape_point, freq, stop_times, routes, trips, rail_node = None):
    
    shape_point_df = shape_point.copy()
    trip_df = trip.copy()
    
    #trip_df = pd.merge(trip_df, routes[["route_id", "agency_raw_name"]], how = "left", on = ["route_id"])
    
    trip_df = trip_df[~ trip_df.agency_raw_name.isin(["Petaluma_2016_5_22", "WestCAT_2016_5_26", "GGFerries_2017_3_18"])].copy()
    
    trip_df["shape_id"] = trip_df["shape_id"].astype(int)
    
    trip_df = trip_df[trip_df.shape_id.isin(shape_point_df.shape_id.unique().tolist())]
    
    final_trip_list = trip_df.trip_id.unique().tolist()
    
    freq_df = freq.copy()
    freq_df = freq_df[freq_df.trip_id.isin(final_trip_list)]
    
    stop_df = stop.copy()
    
    if len(rail_node) > 0:
        rail_node_df = rail_node.copy()
        rail_node_dict = dict(zip(rail_node_df.stop_id, rail_node_df.model_node_id))
        
        stop_df['model_node_id'] = stop_df.apply(lambda x: rail_node_dict[x.stop_id] 
                                               if x.stop_id in rail_node_df.stop_id.tolist() 
                                               else x.model_node_id,
                                                axis = 1)
        stop_df['osm_node_id'] = stop_df.apply(lambda x: ""
                                                if x.stop_id in rail_node_df.stop_id.tolist() 
                                                else x.osm_node_id,
                                                axis = 1)
        stop_df['shst_node_id'] = stop_df.apply(lambda x: '' 
                                                if x.stop_id in rail_node_df.stop_id.tolist() 
                                                else x.shst_node_id,
                                                axis = 1)
    

    stop_times_df = stop_times.copy()
    stop_times_df = stop_times_df[stop_times_df.trip_id.isin(final_trip_list)]
    
    # update time to relative time for frequency based transit system
    stop_times_df['first_arrival'] = stop_times_df.groupby(['trip_id'])['arrival_time'].transform(min)
    stop_times_df['arrival_time'] = stop_times_df['arrival_time'] - stop_times_df['first_arrival']
    stop_times_df['departure_time'] = stop_times_df['departure_time'] - stop_times_df['first_arrival']
    
    stop_times_df['arrival_time'] = stop_times_df['arrival_time'].apply(
        lambda x : time.strftime('%H:%M:%S', time.gmtime(x)) if ~np.isnan(x) else x)
    stop_times_df['departure_time'] = stop_times_df['departure_time'].apply(
        lambda x : time.strftime('%H:%M:%S', time.gmtime(x)) if ~np.isnan(x) else x)

    
    stop_times_df.drop(['first_arrival'], axis = 1, inplace = True)
    
    route_df = routes.copy()
    route_df = route_df[route_df.route_id.isin(trip_df.route_id.tolist())]
    
    route_df.to_csv(output_folder + "routes.txt", 
                    index = False, 
                    sep = ',')
   
    shape_point_df.to_csv(output_folder + "shapes.txt", 
                          index = False, 
                          sep = ',')
  
    trip_df[trips.columns.values].to_csv(output_folder + "trips.txt", 
                                              index = False, 
                                              sep = ',')
  
    freq_df[['trip_id', 'headway_secs', 'start_time', 'end_time']].to_csv(output_folder + "frequencies.txt", 
                                                index = False, 
                                                sep = ',')
    
    stop_df.to_csv(output_folder + "stops.txt", 
                   index = False, 
                   sep = ',')
   
    stop_times_df.to_csv(output_folder + "stop_times.txt", 
                         index = False, 
                         sep = ',')

# %%
stop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22153 entries, 0 to 22152
# Data columns (total 20 columns):
# stop_name              22153 non-null object
# stop_lat               22153 non-null float64
# stop_lon               22153 non-null float64
# zone_id                12267 non-null object
# agency_raw_name        22153 non-null object
# stop_code              15488 non-null object
# location_type          5558 non-null float64
# parent_station         620 non-null object
# stop_desc              4319 non-null object
# stop_url               4168 non-null object
# stop_timezone          137 non-null object
# wheelchair_boarding    388 non-null float64
# platform_code          58 non-null object
# position               0 non-null object
# direction              0 non-null object
# * used by routes       125 non-null object
# stop_id                22153 non-null int32
# osm_node_id            22153 non-null object
# shst_node_id           22153 non-null object
# model_node_id          22153 non-null object
# dtypes: float64(4), int32(1), object(15)
# memory usage: 3.5+ MB

# %%
all_stop_times_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1156938 entries, 0 to 1156937
# Data columns (total 25 columns):
# arrival_time                    723025 non-null float64
# departure_time                  723025 non-null float64
# stop_sequence                   1156938 non-null int64
# pickup_type                     168191 non-null float64
# drop_off_type                   597183 non-null object
# stop_headsign                   485565 non-null object
# shape_dist_traveled             89748 non-null float64
# timepoint                       50400 non-null float64
# last_stop_on_trip               382 non-null object
# start_service_area_id           0 non-null object
# end_service_area_id             0 non-null object
# start_service_area_radius       0 non-null object
# end_service_area_radius         0 non-null object
# continuous_pickup               1092 non-null object
# continuous_drop_off             1092 non-null object
# pickup_area_id                  0 non-null object
# drop_off_area_id                0 non-null object
# pickup_service_area_radius      0 non-null object
# drop_off_service_area_radius    0 non-null object
# *shape_id                       2583 non-null object
# *seq#                           2583 non-null object
# *Dist(m)                        2583 non-null object
# *Comment                        12 non-null object
# trip_id                         1156938 non-null int32
# stop_id                         1156938 non-null int32
# dtypes: float64(5), int32(2), int64(1), object(17)
# memory usage: 220.7+ MB

# %%
unique_stop_id_df[unique_stop_id_df.stop_id_original == "1814"]
# Out:
#       agency_raw_name  stop_id stop_id_original
# 5976   CCTA_2015_8_11     5977             1814
# 17164   VTA_2015_8_27    17165             1814

# %%
unique_trip_id_df[unique_trip_id_df.trip_id == 2040]
# Out:
#           agency_raw_name  trip_id              trip_id_original
# 2039  ACTransit_2015_8_14     2040  4174746-1508FA-D4-Weekday-04

# %%
np.isnan(all_stop_times_df[all_stop_times_df.arrival_time.isnull()].arrival_time.iloc[0])
# Out:
# True

# %%
write_out_transit_standard(trip_df, 
                           stop_df, 
                           shape_point_df, 
                           freq_df, 
                           all_stop_times_df,
                           all_routes_df,
                           all_trips_df,
                           unique_rail_node_gdf)

# %%
trip_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3980 entries, 0 to 3979
# Data columns (total 53 columns):
# service_id                      3980 non-null object
# trip_headsign                   3605 non-null object
# direction_id                    3980 non-null float64
# block_id                        2780 non-null object
# trip_short_name                 363 non-null object
# agency_raw_name                 3980 non-null object
# wheelchair_accessible           125 non-null float64
# bikes_allowed                   634 non-null float64
# original_trip_id                147 non-null object
# trip_bikes_allowed              8 non-null object
# trip_type                       0 non-null object
# drt_max_travel_time             18 non-null object
# drt_avg_travel_time             18 non-null object
# drt_advance_book_min            18 non-null object
# drt_pickup_message              0 non-null object
# drt_drop_off_message            0 non-null object
# continuous_pickup_message       0 non-null object
# continuous_drop_off_message     0 non-null object
# route_id                        3980 non-null int32
# trip_id                         3980 non-null int32
# shape_id                        3980 non-null int32
# arrival_time                    3979 non-null float64
# departure_time                  3979 non-null float64
# stop_sequence                   3980 non-null int64
# pickup_type                     1208 non-null float64
# drop_off_type                   1794 non-null object
# stop_headsign                   944 non-null object
# shape_dist_traveled             845 non-null float64
# timepoint                       352 non-null float64
# last_stop_on_trip               0 non-null object
# start_service_area_id           0 non-null object
# end_service_area_id             0 non-null object
# start_service_area_radius       0 non-null object
# end_service_area_radius         0 non-null object
# continuous_pickup               18 non-null object
# continuous_drop_off             18 non-null object
# pickup_area_id                  0 non-null object
# drop_off_area_id                0 non-null object
# pickup_service_area_radius      0 non-null object
# drop_off_service_area_radius    0 non-null object
# *shape_id                       49 non-null object
# *seq#                           49 non-null object
# *Dist(m)                        49 non-null object
# *Comment                        0 non-null object
# stop_id                         3980 non-null int32
# arrival_h                       3979 non-null float64
# arrival_m                       3979 non-null float64
# departure_h                     3979 non-null float64
# departure_m                     3979 non-null float64
# tod                             3980 non-null object
# trip_num_x                      3980 non-null int64
# trip_num_y                      1026 non-null float64
# trip_num                        3980 non-null float64
# dtypes: float64(14), int32(4), int64(2), object(33)
# memory usage: 1.6+ MB

# %%
def create_transit_access_link(all_link, all_node, all_shape):
    
    """
    create rail walk access/egress links
    """
    
    tran_node_df = all_node[all_node.rail_only == 1].copy()
    walk_node_df = all_node[(all_node.walk_access == 1) & (all_node.rail_only == 0)].copy().reset_index(drop = True)
    
    walk_node_df = walk_node_df.to_crs({'init' : 'epsg:26915'})
    walk_node_df['X'] = walk_node_df.geometry.map(lambda g:g.x)
    walk_node_df['Y'] = walk_node_df.geometry.map(lambda g:g.y)
    inventory_node_ref = walk_node_df[['X', 'Y']].values
    tree = cKDTree(inventory_node_ref)
    
    tran_node_df = tran_node_df.to_crs({'init' : 'epsg:26915'})
    tran_node_df['X'] = tran_node_df.geometry.map(lambda g:g.x)
    tran_node_df['Y'] = tran_node_df.geometry.map(lambda g:g.y)
    
    for i in range(len(tran_node_df)):
        point = tran_node_df.iloc[i][['X', 'Y']].values
        dd, ii = tree.query(point, k = 1)
        add_node_gdf = gpd.GeoDataFrame(walk_node_df.iloc[ii]).transpose().reset_index(drop = True)
        add_node_gdf['tran_node'] = tran_node_df.iloc[i].model_node_id
        add_node_gdf['geometry_tran'] = tran_node_df.iloc[i].geometry
        
        if i == 0:
            rail_access_gdf = add_node_gdf.copy()
        else:
            rail_access_gdf = rail_access_gdf.append(add_node_gdf, ignore_index=True, sort=False)
    
    rail_access_gdf.rename(columns = {'geometry' : "geometry_walk"}, inplace = True)

    
    rail_access_gdf['geometry'] = [LineString(xy) for xy in zip(rail_access_gdf['geometry_walk'], 
                                                                rail_access_gdf['geometry_tran'])]
    
    # fake rail link shst geom id
    rail_access_gdf['shstGeometryId'] = range(1, 
                                     1 + len(rail_access_gdf))
    
    rail_access_gdf['shstGeometryId'] = rail_access_gdf.shstGeometryId.apply(lambda x:'walktorail'+str(x))
    rail_access_gdf['id'] = rail_access_gdf['shstGeometryId']
    
    rail_access_gdf["fromIntersectionId"] = rail_access_gdf.shst_node_id

    rail_access_gdf_copy = rail_access_gdf.copy()
    rail_access_gdf.rename(columns = {'model_node_id' : 'A', 'tran_node' : 'B'}, inplace = True)
    
    rail_access_gdf_copy.rename(columns = {'tran_node' : 'A', 'model_node_id' : 'B'}, inplace = True)
    
    rail_access_gdf = pd.concat(
                            [rail_access_gdf[['A', 'B', 'geometry', 'shstGeometryId', "id", "fromIntersectionId"]],
                            rail_access_gdf_copy[['A', 'B', 'geometry','shstGeometryId', "id", "fromIntersectionId"]]],
                               ignore_index = True,
                               sort = False)
    
    rail_access_gdf = gpd.GeoDataFrame(rail_access_gdf)
    rail_access_gdf.crs = {'init' : 'epsg:26915'}
    rail_access_gdf = rail_access_gdf.to_crs(all_node.crs)
    
    rail_access_gdf['walk_access'] = 1
    
    rail_access_link_columns = ["A", "B", "shstGeometryId", "walk_access", "id"]
    rail_access_shape_columns = ["id", "fromIntersectionId", "geometry"]
    
    all_link_df = all_link.copy()
    all_shape_gdf = all_shape.copy()
    
        
    all_shape_gdf = pd.concat([
                                all_shape_gdf,
                                rail_access_gdf[rail_access_shape_columns].drop_duplicates(
                                                                        subset = ["id"])
                              ],
                             sort = False,
                             ignore_index= True)

    
    all_link_df = pd.concat([all_link_df, 
                             rail_access_gdf[rail_access_link_columns]], 
                            ignore_index = True, 
                            sort = False)
    
    all_link_gdf = pd.merge(all_link_df,
                           all_shape_gdf,
                           how = "left",
                           left_on = "shstGeometryId",
                           right_on = "id")
    
    geom_length = gpd.GeoDataFrame(all_link_gdf[['geometry']])
    geom_length.crs = all_node.crs
    geom_length = geom_length.to_crs(epsg = 26915)
    geom_length["length"] = geom_length.length

    all_link_df["length"] = geom_length["length"]

    return all_link_df, all_shape_gdf

all_link_df, all_shape_gdf = create_transit_access_link(roadway_and_rail_link_df, 
                                                        roadway_and_rail_node_gdf,
                                                        roadway_and_rail_shape_gdf)
# Out:
# C:\Users\wangs1\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:68: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\wangs1\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:68: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\wangs1\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:68: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
# use nearest for links that did not get county match
node_county_matched_gdf = node_gdf.copy()

node_county_matched_gdf = node_county_matched_gdf.to_crs(epsg = 26915)
node_county_matched_gdf['X'] = node_county_matched_gdf.geometry.map(lambda g:g.x)
node_county_matched_gdf['Y'] = node_county_matched_gdf.geometry.map(lambda g:g.y)

node_matched_inventory_ref = node_county_matched_gdf[['X', 'Y']].values
node_matched_tree = cKDTree(node_matched_inventory_ref)

link_county_unmatched_gdf = all_link_df[all_link_df.model_link_id.isnull()].copy()
link_county_unmatched_gdf = pd.merge(link_county_unmatched_gdf, all_shape_gdf[["id", "geometry"]], how = "left", on = "id")
link_county_unmatched_gdf = gpd.GeoDataFrame(link_county_unmatched_gdf, 
                                             geometry = link_county_unmatched_gdf.geometry, 
                                             crs = all_shape_gdf.crs)
#link_county_unmatched_gdf["geometry"] = link_county_unmatched_gdf.centroid

link_county_unmatched_gdf = link_county_unmatched_gdf.to_crs({'init' : 'epsg:26915'})
#link_county_unmatched_gdf["geometry"] = link_county_unmatched_gdf["geometry"].centroid
link_county_unmatched_gdf['X'] = link_county_unmatched_gdf['geometry'].apply(lambda p: p.centroid.x)
link_county_unmatched_gdf['Y'] = link_county_unmatched_gdf['geometry'].apply(lambda p: p.centroid.y)

link_county_rematch_gdf = pd.DataFrame()

for i in range(len(link_county_unmatched_gdf)):
    point = link_county_unmatched_gdf.iloc[i][['X', 'Y']].values
    dd, ii = node_matched_tree.query(point, k = 1)
    add_snap_gdf = gpd.GeoDataFrame(node_county_matched_gdf.iloc[ii][["county"]]).transpose().reset_index(drop = True)
    
    add_snap_gdf = pd.concat([add_snap_gdf,
                              link_county_unmatched_gdf.drop("county", axis = 1).iloc[[i]].reset_index(drop = True)], 
                               axis = 1) 
    
    if i == 0:
        link_county_rematch_gdf = add_snap_gdf.copy()
    else:
        link_county_rematch_gdf = link_county_rematch_gdf.append(add_snap_gdf, ignore_index=True, sort=False)

link_county_rematch_gdf.crs = link_county_unmatched_gdf.crs
link_county_rematch_gdf = link_county_rematch_gdf.to_crs(node_gdf.crs)
# Out:
# C:\Users\wangs1\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:68: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
# 13                  NaN     NaN   walktorail14  ...      3.439780
# 14                  NaN     NaN   walktorail15  ...     11.974298
# 15                  NaN     NaN   walktorail16  ...      1.796831
# 16                  NaN     NaN   walktorail17  ...      1.285403
# 17                  NaN     NaN   walktorail18  ...      1.288758
# 18                  NaN     NaN   walktorail19  ...     29.257480
# 19                  NaN     NaN   walktorail20  ...     47.007505
# 20                  NaN     NaN   walktorail21  ...     16.602744
# 21                  NaN     NaN   walktorail22  ...     21.499390
# 22                  NaN     NaN   walktorail23  ...     12.497248
# 23                  NaN     NaN   walktorail24  ...     10.166765
# 24                  NaN     NaN   walktorail25  ...      9.833497
# 25                  NaN     NaN   walktorail26  ...     24.811353
# 26                  NaN     NaN   walktorail27  ...     10.593786
# 27                  NaN     NaN   walktorail28  ...     65.675410
# 28                  NaN     NaN   walktorail29  ...     24.683120
# 29                  NaN     NaN   walktorail30  ...     38.356366
# ...                 ...     ...            ...  ...           ...
# 1308                NaN     NaN  walktorail640  ...     10.035116
# 1309                NaN     NaN  walktorail641  ...     13.285265
# 1310                NaN     NaN  walktorail642  ...     26.921404
# 1311                NaN     NaN  walktorail643  ...     18.174682
# 1312                NaN     NaN  walktorail644  ...     13.635526
# 1313                NaN     NaN  walktorail645  ...     41.008217
# 1314                NaN     NaN  walktorail646  ...     47.493121
# 1315                NaN     NaN  walktorail647  ...     36.675961
# 1316                NaN     NaN  walktorail648  ...     23.506945
# 1317                NaN     NaN  walktorail649  ...     21.671290
# 1318                NaN     NaN  walktorail650  ...     12.889893
# 1319                NaN     NaN  walktorail651  ...     12.406193
# 1320                NaN     NaN  walktorail652  ...     10.057415
# 1321                NaN     NaN  walktorail653  ...     21.661634
# 1322                NaN     NaN  walktorail654  ...      0.468873
# 1323                NaN     NaN  walktorail655  ...     39.606554
# 1324                NaN     NaN  walktorail656  ...     10.892729
# 1325                NaN     NaN  walktorail657  ...     60.934733
# 1326                NaN     NaN  walktorail658  ...      0.387987
# 1327                NaN     NaN  walktorail659  ...     11.261104
# 1328                NaN     NaN  walktorail660  ...  26760.660330
# 1329                NaN     NaN  walktorail661  ...  26548.874664
# 1330                NaN     NaN  walktorail662  ...  11899.710480
# 1331                NaN     NaN  walktorail663  ...     36.300699
# 1332                NaN     NaN  walktorail664  ...     26.515372
# 1333                NaN     NaN  walktorail665  ...     45.641045
# 1334                NaN     NaN  walktorail666  ...     13.863604
# 1335                NaN     NaN  walktorail667  ...     17.942730
# 1336                NaN     NaN  walktorail668  ...      4.728233
# 1337                NaN     NaN  walktorail669  ...      7.391509
#
#      model_link_id county_numbering_start        A        B rail_traveltime  \
# 0              NaN                    NaN  3047769  3097273             NaN
# 1              NaN                    NaN  3079878  3097274             NaN
# 2              NaN                    NaN  3052965  3097275             NaN
# 3              NaN                    NaN  3060241  3097276             NaN
# 4              NaN                    NaN  3021886  3097277             NaN
# 5              NaN                    NaN  3070076  3097278             NaN
# 6              NaN                    NaN  3060432  3097279             NaN
# 7              NaN                    NaN  2588445  2625942             NaN
# 1328 -2.019193e+06  4.602461e+06
# 1329 -2.022162e+06  4.587932e+06
# 1330 -2.035222e+06  4.577387e+06
# 1331 -2.055481e+06  4.584000e+06
# 1332 -2.060454e+06  4.583590e+06
# 1333 -2.071930e+06  4.583992e+06
# 1334 -2.087040e+06  4.576520e+06
# 1335 -2.089174e+06  4.557924e+06
# 1336 -2.088458e+06  4.550903e+06
# 1337 -2.086334e+06  4.547238e+06
#
# [1338 rows x 41 columns]

# %%
link_county_rematch_gdf.info()
link_county_rematch_gdf.county.value_counts()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 41 columns):
# county                    1338 non-null object
# access                    0 non-null object
# area                      0 non-null object
# bike_access               0 non-null float64
# bridge                    0 non-null object
# drive_access              0 non-null float64
# est_width                 0 non-null object
# fromIntersectionId        0 non-null object
# highway                   0 non-null object
# id                        1338 non-null object
# junction                  0 non-null object
# key                       0 non-null object
# landuse                   0 non-null object
# lanes                     0 non-null object
# link                      0 non-null object
# maxspeed                  0 non-null object
# name                      0 non-null object
# oneWay                    0 non-null object
# ref                       0 non-null object
# roadway                   0 non-null object
# roundabout                0 non-null object
# service                   0 non-null object
# shstGeometryId            1338 non-null object
# shstReferenceId           0 non-null object
# toIntersectionId          0 non-null object
# tunnel                    0 non-null object
# u                         0 non-null float64
# v                         0 non-null float64
# walk_access               1338 non-null float64
# wayId                     0 non-null object
# width                     0 non-null object
# length                    1338 non-null float64
# model_link_id             0 non-null float64
# county_numbering_start    0 non-null float64
# A                         1338 non-null object
# B                         1338 non-null object
# rail_traveltime           0 non-null float64
# rail_only                 0 non-null float64
# geometry                  1338 non-null geometry
# X                         1338 non-null float64
# Y                         1338 non-null float64
# dtypes: float64(12), geometry(1), object(28)
# memory usage: 428.7+ KB
# San Francisco    866
# Santa Clara      300
# Alameda           70
# San Mateo         58
# Contra Costa      28
# Marin             10
# Solano             6
# Name: county, dtype: int64

# %%
# get the last node and link number of counties

county_last_link_id_df = roadway_and_rail_link_df.groupby("county")["model_link_id"].max().reset_index().rename(
    columns = {"model_link_id" : "county_last_id"})

link_county_rematch_gdf = pd.merge(
    link_county_rematch_gdf,
    county_last_link_id_df,
    how = "left",
    on = "county"
)

link_county_rematch_gdf["model_link_id"] = link_county_rematch_gdf.groupby(["county"]).cumcount() + 1

link_county_rematch_gdf["model_link_id"] = link_county_rematch_gdf["model_link_id"] + link_county_rematch_gdf["county_last_id"]

# %%
link_county_rematch_gdf[link_county_rematch_gdf.id == "walktorail1"]
# Out:
#            county access area  bike_access bridge  drive_access est_width  \
# 0    Contra Costa    NaN  NaN          NaN    NaN           NaN       NaN
# 669  Contra Costa    NaN  NaN          NaN    NaN           NaN       NaN
#
#     fromIntersectionId highway           id  ... model_link_id  \
# 0                  NaN     NaN  walktorail1  ...       4237470
# 669                NaN     NaN  walktorail1  ...       4237484
#
#     county_numbering_start        A        B rail_traveltime rail_only  \
# 0                      NaN  3047769  3097273             NaN       NaN
# 669                    NaN  3097273  3047769             NaN       NaN
#
#                                               geometry             X  \
# 0    LINESTRING (-121.94539 38.01829, -121.94515 38... -2.063638e+06
# 669  LINESTRING (-121.94539 38.01829, -121.94515 38... -2.063638e+06
#
#                 Y county_last_id
# 0    4.626937e+06        4237469
# 669  4.626937e+06        4237469
#
# [2 rows x 42 columns]

# %%
# combine rail and roadway links

all_link_df = roadway_and_rail_link_df.append(link_county_rematch_gdf, 
                                              ignore_index = True, 
                                              sort = False)

# %%
print(roadway_and_rail_link_df.model_link_id.nunique())
print(roadway_and_rail_link_df.shape)
print(roadway_and_rail_link_df.county.value_counts())
# Out:
# 1633452
# (1633452, 38)
# Santa Clara      516714
# Alameda          315392
# Contra Costa     237470
# San Mateo        140966
# Sonoma           135042
# Solano           117108
# San Francisco     73892
# Marin             63188
# Napa              33680
# Name: county, dtype: int64

# %%
all_link_df.model_link_id.nunique()
# Out:
# 1634790

# %%
all_shape_gdf.id.nunique()
# Out:
# 869986

# %%
all_link_df.id.nunique()
# Out:
# 869986

# %%
# number geometry increse should be the number of transit nodes: 664+5
print(roadway_and_rail_link_df.shstGeometryId.nunique())
print(roadway_and_rail_shape_gdf.id.nunique())
print(roadway_and_rail_shape_gdf.shape)
print(all_shape_gdf.id.nunique())
print(all_shape_gdf.shape)
print(all_link_df.shstGeometryId.nunique())
# Out:
# 869317
# 869317
# (869317, 6)
# 869986
# (869986, 6)
# 869986

# %%
# number of link increase should be 2 times of transit nodes : 1328+10

print(roadway_and_rail_link_df.shape)
print(all_link_df.shape)
# Out:
# (1633452, 38)
# (1634790, 42)

# %%
print(all_link_df.county.value_counts(dropna=False))
print(all_link_df.groupby("county")["model_link_id"].max())
# Out:
# Santa Clara      517014
# Alameda          315462
# Contra Costa     237498
# San Mateo        141024
# Sonoma           135042
# Solano           117114
# San Francisco     74758
# Marin             63198
# Napa              33680
# Name: county, dtype: int64
# county
# Alameda          3315461
# Contra Costa     4237497
# Marin            8063197
# Napa             6033679
# San Francisco      74758
# San Mateo        1141023
# Santa Clara      2517013
# Solano           5117113
# Sonoma           7135041
# Name: model_link_id, dtype: int64

# %% [markdown]
# # true shapes for line record
#
# from shapely import ops, geometry
#
# def get_true_line_shape(trip_df, bus_link, roadway_and_rail_shape,
#                         rail_link = pd.DataFrame(columns = ['LINK_ID','shape_id', 'u', 'v'])):
#
#     """
#     write out true shape for each trip
#     """
#
#     rail_link_df = rail_link.copy()
#     rail_link_df = pd.merge(trip_df[['trip_id', 'shape_id']],
#                             rail_link_df,
#                            how = 'right',
#                            on = 'shape_id')
#
#     transit_link_gdf = pd.concat([bus_link[['shape_id', 'trip_id', "shstGeometryId"]],
#                                   rail_link_df[['shape_id', 'trip_id', "shstGeometryId"]]],
#                                  sort = False, ignore_index = True)
#
#     transit_link_gdf = pd.merge(transit_link_gdf,
#                                 roadway_and_rail_shape[['id', 'geometry']],
#                                 how = 'left',
#                                 left_on = 'shstGeometryId',
#                                right_on = "id")
#
#     true_line_shape_df = transit_link_gdf.groupby(['trip_id', 'shape_id'])['geometry'].agg(
#                                                                 lambda x:
#                                                                 ops.linemerge(geometry.MultiLineString(x.tolist())))\
#                                         .reset_index()
#
#     """true_line_shape_df = pd.merge(true_line_shape_df,
#                                   cube,
#                                  how = 'left',
#                                  on = ['shape_id', 'trip_id'])"""
#
#     true_line_shape_gdf = gpd.GeoDataFrame(true_line_shape_df,
#                                            crs = roadway_and_rail_shape.crs,
#                                            geometry = 'geometry')
#
#     return true_line_shape_gdf

# %% [markdown]
# true_line_shape_gdf = get_true_line_shape(trip_df,
#                                                 bus_link_df,
#                                                 roadway_and_rail_shape_gdf,
#                                                 rail_link_gdf)

# %% [markdown]
# true_line_shape_gdf.to_file(data_interim_folder + "transit_route.geojson",
#                            driver = "GeoJSON")

# %% [markdown]
# true_line_shape_gdf.columns

# %% [markdown]
# def link_df_to_geojson(df, properties):
#     """
#     Author: Geoff Boeing:
#     https://geoffboeing.com/2015/10/exporting-python-data-geojson/
#     """
#     geojson = {"type":"FeatureCollection", "features":[]}
#     for _, row in df.iterrows():
#         feature = {"type":"Feature",
#                    "properties":{},
#                    "geometry":{"type":"LineString",
#                                "coordinates":[]}}
#         feature["geometry"]["coordinates"] = [[x, y] for (x,y) in list(row["geometry"].coords)]
#         for prop in properties:
#             feature["properties"][prop] = row[prop]
#         geojson["features"].append(feature)
#     return geojson
#
#
# def point_df_to_geojson(df: pd.DataFrame, properties: list):
#     """
#     Author: Geoff Boeing:
#     https://geoffboeing.com/2015/10/exporting-python-data-geojson/
#     """
#
#     geojson = {"type": "FeatureCollection", "features": []}
#     for _, row in df.iterrows():
#         feature = {
#             "type": "Feature",
#             "properties": {},
#             "geometry": {"type": "Point", "coordinates": []},
#         }
#         feature["geometry"]["coordinates"] = [row["geometry"].x, row["geometry"].y]
#         for prop in properties:
#             feature["properties"][prop] = row[prop]
#         geojson["features"].append(feature)
#     return geojson
#
# def fill_na(df_na):
#     """
#     fill str NaN with ""
#     fill numeric NaN with 0
#     """
#     df = df_na.copy()
#     num_col = list(df.select_dtypes([np.number]).columns)
#     print("numeric columns: ", num_col)
#     object_col = list(df.select_dtypes(['object']).columns)
#     print("str columns: ", object_col)
#
#     for x in list(df.columns):
#         if x in num_col:
#             df[x].fillna(0, inplace = True)
#         elif x in object_col:
#             df[x].fillna("", inplace = True)
#
#     return df

# %% [markdown]
# all_shape_gdf = fill_na(all_shape_gdf)

# %%
int_col = ["bike_access", "walk_access", "drive_access", "rail_only"]
for c in int_col:
    all_link_df[c] = all_link_df[c].fillna(0).astype(np.int64)
    
#all_link_df = fill_na(all_link_df)

# %%
int_col = ["bike_access", "walk_access", "drive_access", "rail_only"]
for c in int_col:
    roadway_and_rail_node_gdf[c] = roadway_and_rail_node_gdf[c].fillna(0).astype(np.int64)
    
#roadway_and_rail_node_gdf = fill_na(roadway_and_rail_node_gdf)

# %%
pd.crosstab(all_link_df.rail_only, all_link_df.walk_access, dropna = False)
pd.crosstab(roadway_and_rail_node_gdf.rail_only, roadway_and_rail_node_gdf.walk_access, dropna = False)
# Out:
# walk_access    0       1
# rail_only
# 0            130  643681
# 1              0     669

# %%
print(link_df.drive_access.value_counts())
print(all_link_df.drive_access.value_counts())

print(link_df.bike_access.value_counts())
print(all_link_df.bike_access.value_counts())

print(link_df.walk_access.value_counts())
print(all_link_df.walk_access.value_counts())
# Out:
# 1    1002162
# 0     630540
# Name: drive_access, dtype: int64
# 1    1002162
# 0     632628
# Name: drive_access, dtype: int64
# 1    1382439
# 0     250263
# Name: bike_access, dtype: int64
# 1    1382439
# 0     252351
# Name: bike_access, dtype: int64
# 1    1629928
# 0       2774
# Name: walk_access, dtype: int64
# 1    1631266
# 0       3524
# Name: walk_access, dtype: int64

# %%
all_link_df.info()
all_shape_gdf.info()
roadway_and_rail_node_gdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1634790 entries, 0 to 1634789
# Data columns (total 42 columns):
# access                    1632702 non-null object
# area                      1632702 non-null object
# bike_access               1634790 non-null int64
# bridge                    1632702 non-null object
# drive_access              1634790 non-null int64
# est_width                 1632702 non-null object
# fromIntersectionId        1632702 non-null object
# highway                   1632702 non-null object
# id                        1634790 non-null object
# junction                  1632702 non-null object
# key                       1632702 non-null object
# landuse                   1632702 non-null object
# lanes                     1632702 non-null object
# link                      1632702 non-null object
# maxspeed                  1632702 non-null object
# name                      1632702 non-null object
# oneWay                    1632702 non-null object
# ref                       1632702 non-null object
# roadway                   1632702 non-null object
# roundabout                1632702 non-null object
# service                   1632702 non-null object
# shstGeometryId            1634790 non-null object
# shstReferenceId           1632702 non-null object
# toIntersectionId          1632702 non-null object
# tunnel                    1632702 non-null object
# u                         1632702 non-null float64
# v                         1632702 non-null float64
# walk_access               1634790 non-null int64
# wayId                     1632702 non-null object
# width                     1632702 non-null object
# county                    1634790 non-null object
# length                    1634040 non-null float64
# model_link_id             1634790 non-null int64
# county_numbering_start    1632702 non-null float64
# A                         1634790 non-null object
# B                         1634790 non-null object
# rail_traveltime           613 non-null float64
# rail_only                 1634790 non-null int64
# geometry                  1338 non-null object
# X                         1338 non-null float64
# Y                         1338 non-null float64
# county_last_id            1338 non-null float64
# dtypes: float64(8), int64(5), object(29)
# memory usage: 523.8+ MB
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 869986 entries, 0 to 869985
# Data columns (total 6 columns):
# id                    869986 non-null object
# fromIntersectionId    869236 non-null object
# toIntersectionId      868567 non-null object
# forwardReferenceId    868567 non-null object
# backReferenceId       868567 non-null object
# geometry              869986 non-null geometry
# dtypes: geometry(1), object(5)
# memory usage: 39.8+ MB
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 644480 entries, 0 to 644479
# Data columns (total 10 columns):
# osm_node_id               643811 non-null float64
# shst_node_id              643811 non-null object
# county                    644480 non-null object
# drive_access              644480 non-null int64
# walk_access               644480 non-null int64
# bike_access               644480 non-null int64
# model_node_id             644480 non-null int64
# county_numbering_start    643811 non-null float64
# geometry                  644480 non-null geometry
# rail_only                 644480 non-null int64
# dtypes: float64(2), geometry(1), int64(5), object(2)
# memory usage: 49.2+ MB

# %%
all_link_df[all_link_df.shstReferenceId.isin(["feab62cc90650bfc45dc453816782f9c", "9ab364b22d6b33ec158d8bc4008c1be7"])][
    ["roadway", "drive_access", "walk_access", "bike_access"]]
# Out:
#         roadway  drive_access  walk_access  bike_access
# 524671  service             1            1            1
# 863713  service             1            1            1

# %%
roadway_and_rail_node_gdf[roadway_and_rail_node_gdf.osm_node_id.isin([890045140, 5372055804, 890045129])]
# Out:
#          osm_node_id                      shst_node_id         county  \
# 130712  5.372056e+09  3291f7c2f15101c22abf554ce230343e  San Francisco
# 215684  8.900451e+08  4c0619714744bed10b7de965adc7048d  San Francisco
# 244341  8.900451e+08  490be8656a6428c6fc871a1f0e6432eb  San Francisco
#
#         drive_access  walk_access  bike_access  model_node_id  \
# 130712             1            1            1        1006138
# 215684             1            1            1        1010031
# 244341             1            1            1        1011380
#
#         county_numbering_start                     geometry  rail_only
# 130712               1000000.0  POINT (-122.39210 37.78934)          0
# 215684               1000000.0  POINT (-122.39263 37.78966)          0
# 244341               1000000.0  POINT (-122.39203 37.78925)          0

# %%
# %%time

print("-------write out link shape geojson---------")

shape_prop = ['id', 'fromIntersectionId', 'toIntersectionId', 'forwardReferenceId', 'backReferenceId']
shape_geojson = link_df_to_geojson(all_shape_gdf, shape_prop)

with open(data_interim_dir + "step6_gtfs/version_12/shape.geojson", "w") as f:
    json.dump(shape_geojson, f)
# Out:
# -------write out link shape geojson---------
# Wall time: 2min 53s

# %%
# %%time

# write out link variable json
# link unique handle "shstReferenceId" + "shstGeometryId"

print("-------write out link json---------")

link_prop = all_link_df.drop(["county_numbering_start", "X", "Y", "county_last_id", "geometry"], axis = 1).columns.tolist()

out = all_link_df[link_prop].to_json(orient = "records")

with open(data_interim_dir + "step6_gtfs/version_12/link.json", 'w') as f:
    f.write(out)
# Out:
# -------write out link json---------
# Wall time: 29.2 s

# %%
# %%time

print("-------write out node geojson---------")

node_prop = roadway_and_rail_node_gdf.drop(["geometry", "county_numbering_start"], axis = 1).columns.tolist()
node_geojson = point_df_to_geojson(roadway_and_rail_node_gdf, node_prop)

with open(data_interim_dir + "step6_gtfs/version_12/node.geojson", "w") as f:
    json.dump(node_geojson, f)
# Out:
# -------write out node geojson---------
# Wall time: 2min 5s

# %%
print("-------write out link feather---------")

link_feather = all_link_df.drop(["county_numbering_start", "X", "Y", "county_last_id", "geometry"], axis = 1).copy()

link_feather.to_feather(data_interim_dir + 'step6_gtfs/version_12/link.feather')
# Out:
# -------write out link feather---------

# %%
link_df.columns
# Out:
# Index(['access', 'area', 'bike_access', 'bridge', 'drive_access', 'est_width',
#        'fromIntersectionId', 'highway', 'id', 'junction', 'key', 'landuse',
#        'lanes', 'link', 'maxspeed', 'name', 'oneWay', 'ref', 'roadway',
#        'roundabout', 'service', 'shstGeometryId', 'shstReferenceId',
#        'toIntersectionId', 'tunnel', 'u', 'v', 'walk_access', 'wayId', 'width',
#        'county', 'length', 'model_link_id', 'county_numbering_start', 'A',
#        'B'],
#       dtype='object')

# %% [markdown]
# # write out to CUBE .lin

# %%
all_routes_df.route_type.value_counts()
# Out:
# 3    668
# 0     10
# 4      9
# 2      8
# 1      6
# 5      3
# Name: route_type, dtype: int64

# %%
trip_df.columns
# Out:
# Index(['service_id', 'trip_headsign', 'direction_id', 'block_id',
#        'wheelchair_accessible', 'bikes_allowed', 'agency_raw_name',
#        'trip_short_name', 'original_trip_id', 'trip_bikes_allowed',
#        'trip_type', 'drt_max_travel_time', 'drt_avg_travel_time',
#        'drt_advance_book_min', 'drt_pickup_message', 'drt_drop_off_message',
#        'continuous_pickup_message', 'continuous_drop_off_message', 'route_id',
#        'trip_id', 'shape_id', 'arrival_time', 'departure_time',
#        'stop_sequence', 'stop_headsign', 'pickup_type', 'drop_off_type',
#        'shape_dist_traveled', 'timepoint', 'start_service_area_id',
#        'end_service_area_id', 'start_service_area_radius',
#        'end_service_area_radius', 'continuous_pickup', 'continuous_drop_off',
#        'pickup_area_id', 'drop_off_area_id', 'pickup_service_area_radius',
#        'drop_off_service_area_radius', 'last_stop_on_trip', 'stop_id',
#        'arrival_h', 'arrival_m', 'departure_h', 'departure_m', 'tod',
#        'trip_num_x', 'trip_num_y', 'trip_num'],
#       dtype='object')

# %%
all_routes_df
# Out:
#        route_id_original   agency_id route_short_name  \
# 0                     01        BART              NaN
# 1                     03        BART              NaN
# 2                     05        BART              NaN
# 3                     07        BART              NaN
# 4                     11        BART              NaN
# 5                     19        BART              NaN
# 6                    ACE          CE              ACE
# 7    34_merged_381003112         NaN              93X
# 8    28_merged_381003096         NaN                5
# 9    26_merged_381003090         NaN               36
# 10   13_merged_381003100         NaN               21
# 11   15_merged_381003102         NaN               28
# 12   11_merged_381003098         NaN                2
# 13                     1         NaN                1
# 14                     3         NaN               11
# 15                     2         NaN               10
# 16                     5         NaN               15
# 17                     4         NaN               14
# 18                     7         NaN               17
# 19                     6         NaN               16
# 20                     9         NaN               19
# 21                     8         NaN               18
# 22   36_merged_381003110         NaN              96X
# 23   12_merged_381003101         NaN               20
# 24   14_merged_381003103         NaN               25
# 25   16_merged_381003105         NaN                3
# 26   31_merged_381003108         NaN                9
# 27                    38         NaN              98X
# 28   27_merged_381003091         NaN                4
# 29   10_merged_381003099         NaN               1M
# ..                   ...         ...              ...
# 638               OX-118  AC Transit               OX
# 639                P-118  AC Transit                P
# 640                S-118  AC Transit                S
# 641               SB-118  AC Transit               SB
# 642                U-118  AC Transit                U
# 643                V-118  AC Transit                V
# 644                W-118  AC Transit                W
# 645                Z-118  AC Transit                Z
# 646         Angel Island          BG     Angel Island
# 647            Sausalito          BG        Sausalito
# 648              Tiburon          BG          Tiburon
# 649                   CC          AM               CC
# 650                   SF          AM               SF
# 651                    2   SRCityBus                1
# 652                    3   SRCityBus                2
# 653                    4   SRCityBus                3
# 654                    5   SRCityBus                4
# 655                    6   SRCityBus                5
# 656                    7   SRCityBus                6
# 657                    8   SRCityBus                7
# 658                    9   SRCityBus                8
# 659                   10   SRCityBus                9
# 660                   11   SRCityBus               10
# 661                   12   SRCityBus               11
# 662                   13   SRCityBus               12
# 663                   14   SRCityBus               14
# 664                   15   SRCityBus               15
# 665                   16   SRCityBus               17
# 666                   17   SRCityBus               18
# 667                   18   SRCityBus               19
#
#                             route_long_name route_desc  route_type  \
# 0       Pittsburg/Bay Point - SFIA/Millbrae        NaN           1
# 1                        Fremont - Richmond        NaN           1
# 2                       Fremont - Daly City        NaN           1
# 3             Richmond - Daly City/Millbrae        NaN           1
# 4             Dublin/Pleasanton - Daly City        NaN           1
# 5          Coliseum - Oakland Int'l Airport        NaN           1
# 6                                       NaN        NaN           2
# 7                       Kirker Pass Express        NaN           3
# 8               Creekside/BART Walnut Creek        NaN           3
# 9                     San Ramon/BART Dublin        NaN           3
# 10              BART Walnut Creek/San Ramon        NaN           3
# 11              BART North Concord/Martinez        NaN           3
# 12                Rudgear/BART Walnut Creek        NaN           3
# 13                      Rossmoor/Shadelands        NaN           3
# 14            BART Concord/BART Pleasant Hi        NaN           3
# 15                     BART Concord/Clayton        NaN           3
# 16                               Treat Blvd        NaN           3
# 17                            Monument Blvd        NaN           3
# 18               BART Concord/North Concord        NaN           3
# 19                      AMTRAK/BART Concord        NaN           3
# 20                      AMTRAK/BART Concord        NaN           3
# 21                AMTRAK/BART Pleasant Hill        NaN           3
# 22           BART Walnut Creek/Bishop Ranch        NaN           3
# 23                         DVC/BART Concord        NaN           3
# 24         BART Lafayette/BART Walnut Creek        NaN           3
# 25                       Martinez Community        NaN           3
# 26                    DVC/BART Walnut Creek        NaN           3
# 27               Martinez/BART Walnut Creek        NaN           3
# 28         Broadway Plaza/BART Walnut Creek        NaN           3
# 29      BART WALNUT CREEK/JOHN MUIR MED CTR        NaN           3
# ..                                      ...        ...         ...
# 638  San Francisco - Alameda - Bay Farm Is.        NaN           3
# 639                San Francisco - Piedmont        NaN           3
# 640    San Francisco - San Lorenzo- Hayward        NaN           3
# 641        San Francisco - Hayward - Newark        NaN           3
# 642         Frmt. BART- Stanford University        NaN           3
# 643               San Francisco - Montclair        NaN           3
# 644                 San Francisco - Alameda        NaN           3
# 645                  San Francisco - Albany        NaN           3
# 646      San Francisco - Angel Island Ferry        NaN           4
# 647         San Francisco - Sausalito Ferry        NaN           4
# 648           San Francisco - Tiburon Ferry        NaN           4
# 649                                     NaN        NaN           2
# 650                                     NaN        NaN           2
# 651                         1 Mendocino Ave        NaN           3
# 652                        2 Bennett Valley        NaN           3
# 653                         3 West Ninth St        NaN           3
# 654                         4 Rincon Valley        NaN           3
# 655                        5 Santa Rosa Ave        NaN           3
# 656                         6 West Third St        NaN           3
# 657    7 Montgomery Village / Rincon Valley        NaN           3
# 658                            8 Sonoma Ave        NaN           3
# 659                         9 Sebastopol Rd        NaN           3
# 660                          10 Coddingtown        NaN           3
# 661                            11 Fulton Rd        NaN           3
# 662                             12 Roseland        NaN           3
# 663                        14 County Center        NaN           3
# 664                       15 Stony Point Rd        NaN           3
# 665                             17 Piner Rd        NaN           3
# 666                 18 Southeast Circulator        NaN           3
# 667                 19 South City Connector        NaN           3
#
#                                              route_url route_color  \
# 0    http://www.bart.gov/schedules/bylineresults?ro...      ffff33
# 1    http://www.bart.gov/schedules/bylineresults?ro...      ff9933
# 2    http://www.bart.gov/schedules/bylineresults?ro...      339933
# 3    http://www.bart.gov/schedules/bylineresults?ro...      ff0000
# 4    http://www.bart.gov/schedules/bylineresults?ro...      0099cc
# 5    http://www.bart.gov/schedules/bylineresults?ro...      d5cfa3
# 6                                                  NaN         NaN
# 7                                                  NaN         NaN
# 8                                                  NaN         NaN
# 9                                                  NaN         NaN
# 10                                                 NaN         NaN
# 11                                                 NaN         NaN
# 12                                                 NaN         NaN
# 13                                                 NaN         NaN
# 14                                                 NaN         NaN
# 15                                                 NaN         NaN
# 16                                                 NaN         NaN
# 17                                                 NaN         NaN
# 18                                                 NaN         NaN
# 19                                                 NaN         NaN
# 20                                                 NaN         NaN
# 21                                                 NaN         NaN
# 22                                                 NaN         NaN
# 23                                                 NaN         NaN
# 24                                                 NaN         NaN
# 25                                                 NaN         NaN
# 26                                                 NaN         NaN
# 27                                                 NaN         NaN
# 28                                                 NaN         NaN
# 29                                                 NaN         NaN
# ..                                                 ...         ...
# 638                                                NaN         NaN
# 639                                                NaN         NaN
# 640                                                NaN         NaN
# 641                                                NaN         NaN
# 642                                                NaN         NaN
# 643                                                NaN         NaN
# 644                                                NaN         NaN
# 645                                                NaN         NaN
# 646                                                NaN         NaN
# 647                                                NaN         NaN
# 648                                                NaN         NaN
# 649                                                NaN         NaN
# 650                                                NaN         NaN
# 651                                                NaN      0DF7FF
# 652                                                NaN      017811
# 653                                                NaN      FF370F
# 654                                                NaN      E7FF0D
# 655                                                NaN      FF5274
# 656                                                NaN      B5572F
# 657                                                NaN      FFDC2E
# 658                                                NaN      FF52EE
# 659                                                NaN      FF6600
# 660                                                NaN      1921FF
# 661                                                NaN      FF6363
# 662                                                NaN      9823A1
# 663                                                NaN      AD6C17
# 664                                                NaN      1B196B
# 665                                                NaN      87FF69
# 666                                                NaN      000000
# 667                                                NaN      A30041
#
#     route_text_color                    agency_raw_name route_sort_order  \
# 0                NaN                      BART_2015_8_3              NaN
# 1                NaN                      BART_2015_8_3              NaN
# 2                NaN                      BART_2015_8_3              NaN
# 3                NaN                      BART_2015_8_3              NaN
# 4                NaN                      BART_2015_8_3              NaN
# 5                NaN                      BART_2015_8_3              NaN
# 6                NaN                      ACE_2017_3_20              NaN
# 7                NaN                     CCTA_2015_8_11              NaN
# 8                NaN                     CCTA_2015_8_11              NaN
# 9                NaN                     CCTA_2015_8_11              NaN
# 10               NaN                     CCTA_2015_8_11              NaN
# 11               NaN                     CCTA_2015_8_11              NaN
# 12               NaN                     CCTA_2015_8_11              NaN
# 13               NaN                     CCTA_2015_8_11              NaN
# 14               NaN                     CCTA_2015_8_11              NaN
# 15               NaN                     CCTA_2015_8_11              NaN
# 16               NaN                     CCTA_2015_8_11              NaN
# 17               NaN                     CCTA_2015_8_11              NaN
# 18               NaN                     CCTA_2015_8_11              NaN
# 19               NaN                     CCTA_2015_8_11              NaN
# 20               NaN                     CCTA_2015_8_11              NaN
# 21               NaN                     CCTA_2015_8_11              NaN
# 22               NaN                     CCTA_2015_8_11              NaN
# 23               NaN                     CCTA_2015_8_11              NaN
# 24               NaN                     CCTA_2015_8_11              NaN
# 25               NaN                     CCTA_2015_8_11              NaN
# 26               NaN                     CCTA_2015_8_11              NaN
# 27               NaN                     CCTA_2015_8_11              NaN
# 28               NaN                     CCTA_2015_8_11              NaN
# 29               NaN                     CCTA_2015_8_11              NaN
# ..               ...                                ...              ...
# 638              NaN                ACTransit_2015_8_14              NaN
# 639              NaN                ACTransit_2015_8_14              NaN
# 640              NaN                ACTransit_2015_8_14              NaN
# 641              NaN                ACTransit_2015_8_14              NaN
# 642              NaN                ACTransit_2015_8_14              NaN
# 643              NaN                ACTransit_2015_8_14              NaN
# 644              NaN                ACTransit_2015_8_14              NaN
# 645              NaN                ACTransit_2015_8_14              NaN
# 646              NaN           Blue&Gold_gtfs_10_4_2017              NaN
# 647              NaN           Blue&Gold_gtfs_10_4_2017              NaN
# 648              NaN           Blue&Gold_gtfs_10_4_2017              NaN
# 649              NaN                  Capitol_2017_3_20              NaN
# 650              NaN                  Capitol_2017_3_20              NaN
# 651           FFFFFF  SantaRosa_google_transit_08_28_15              NaN
# 652           FFFFFF  SantaRosa_google_transit_08_28_15              NaN
# 653           FFFFFF  SantaRosa_google_transit_08_28_15              NaN
# 654           000000  SantaRosa_google_transit_08_28_15              NaN
# 655           FFFFFF  SantaRosa_google_transit_08_28_15              NaN
# 656           FFFFFF  SantaRosa_google_transit_08_28_15              NaN
# 657           000000  SantaRosa_google_transit_08_28_15              NaN
# 658           FFFFFF  SantaRosa_google_transit_08_28_15              NaN
# 659           FFFFFF  SantaRosa_google_transit_08_28_15              NaN
# 660           FFFFFF  SantaRosa_google_transit_08_28_15              NaN
# 661           FFFFFF  SantaRosa_google_transit_08_28_15              NaN
# 662           FFFFFF  SantaRosa_google_transit_08_28_15              NaN
# 663           FFFFFF  SantaRosa_google_transit_08_28_15              NaN
# 664           FFFFFF  SantaRosa_google_transit_08_28_15              NaN
# 665           FFFFFF  SantaRosa_google_transit_08_28_15              NaN
# 666           FFFFFF  SantaRosa_google_transit_08_28_15              NaN
# 667           FFFFFF  SantaRosa_google_transit_08_28_15              NaN
#
#     min_headway_minutes eligibility_restricted continuous_pickup  \
# 0                   NaN                    NaN               NaN
# 1                   NaN                    NaN               NaN
# 2                   NaN                    NaN               NaN
# 3                   NaN                    NaN               NaN
# 4                   NaN                    NaN               NaN
# 5                   NaN                    NaN               NaN
# 6                   NaN                    NaN               NaN
# 7                   NaN                    NaN               NaN
# 8                   NaN                    NaN               NaN
# 9                   NaN                    NaN               NaN
# 10                  NaN                    NaN               NaN
# 11                  NaN                    NaN               NaN
# 12                  NaN                    NaN               NaN
# 13                  NaN                    NaN               NaN
# 14                  NaN                    NaN               NaN
# 15                  NaN                    NaN               NaN
# 16                  NaN                    NaN               NaN
# 17                  NaN                    NaN               NaN
# 18                  NaN                    NaN               NaN
# 19                  NaN                    NaN               NaN
# 20                  NaN                    NaN               NaN
# 21                  NaN                    NaN               NaN
# 22                  NaN                    NaN               NaN
# 23                  NaN                    NaN               NaN
# 24                  NaN                    NaN               NaN
# 25                  NaN                    NaN               NaN
# 26                  NaN                    NaN               NaN
# 27                  NaN                    NaN               NaN
# 28                  NaN                    NaN               NaN
# 29                  NaN                    NaN               NaN
# ..                  ...                    ...               ...
# 638                 NaN                    NaN               NaN
# 639                 NaN                    NaN               NaN
# 640                 NaN                    NaN               NaN
# 641                 NaN                    NaN               NaN
# 642                 NaN                    NaN               NaN
# 643                 NaN                    NaN               NaN
# 644                 NaN                    NaN               NaN
# 645                 NaN                    NaN               NaN
# 646                 NaN                    NaN               NaN
# 647                 NaN                    NaN               NaN
# 648                 NaN                    NaN               NaN
# 649                 NaN                    NaN               NaN
# 650                 NaN                    NaN               NaN
# 651                 NaN                    NaN               NaN
# 652                 NaN                    NaN               NaN
# 653                 NaN                    NaN               NaN
# 654                 NaN                    NaN               NaN
# 655                 NaN                    NaN               NaN
# 656                 NaN                    NaN               NaN
# 657                 NaN                    NaN               NaN
# 658                 NaN                    NaN               NaN
# 659                 NaN                    NaN               NaN
# 660                 NaN                    NaN               NaN
# 661                 NaN                    NaN               NaN
# 662                 NaN                    NaN               NaN
# 663                 NaN                    NaN               NaN
# 664                 NaN                    NaN               NaN
# 665                 NaN                    NaN               NaN
# 666                 NaN                    NaN               NaN
# 667                 NaN                    NaN               NaN
#
#     continuous_drop_off  route_id
# 0                   NaN       154
# 1                   NaN       155
# 2                   NaN       156
# 3                   NaN       157
# 4                   NaN       158
# 5                   NaN       159
# 6                   NaN         1
# 7                   NaN       182
# 8                   NaN       175
# 9                   NaN       173
# 10                  NaN       167
# 11                  NaN       169
# 12                  NaN       165
# 13                  NaN       163
# 14                  NaN       177
# 15                  NaN       171
# 16                  NaN       188
# 17                  NaN       187
# 18                  NaN       190
# 19                  NaN       189
# 20                  NaN       192
# 21                  NaN       191
# 22                  NaN       184
# 23                  NaN       166
# 24                  NaN       168
# 25                  NaN       170
# 26                  NaN       179
# 27                  NaN       186
# 28                  NaN       174
# 29                  NaN       164
# ..                  ...       ...
# 638                 NaN       146
# 639                 NaN       147
# 640                 NaN       148
# 641                 NaN       149
# 642                 NaN       150
# 643                 NaN       151
# 644                 NaN       152
# 645                 NaN       153
# 646                 NaN       160
# 647                 NaN       161
# 648                 NaN       162
# 649                 NaN       196
# 650                 NaN       197
# 651                 NaN       473
# 652                 NaN       474
# 653                 NaN       475
# 654                 NaN       476
# 655                 NaN       477
# 656                 NaN       478
# 657                 NaN       479
# 658                 NaN       480
# 659                 NaN       464
# 660                 NaN       465
# 661                 NaN       466
# 662                 NaN       467
# 663                 NaN       468
# 664                 NaN       469
# 665                 NaN       470
# 666                 NaN       471
# 667                 NaN       472
#
# [668 rows x 16 columns]

# %%
def prepare_df_for_cube(routes, mode_crosswalk, trip, bus_link, freq,
                        rail_link = pd.DataFrame(columns = ['shape_id'])):
    
    
    transit_link_gdf = pd.concat([bus_link[['shape_id']], rail_link[['shape_id']]], 
                                 sort = False, ignore_index = True)
    trip_df = trip.copy()
    
    trip_df = trip_df[trip_df.shape_id.isin(transit_link_gdf.shape_id.unique().tolist())]
    
    trip_df = pd.merge(trip_df.drop("agency_raw_name", axis = 1), routes, how = 'left', on = 'route_id')
    
    trip_df = trip_df[~ trip_df.agency_raw_name.isin(["Petaluma_2016_5_22", "WestCAT_2016_5_26", "GGFerries_2017_3_18"])].copy()
    
    trip_df = pd.merge(trip_df, freq[['trip_id','headway_secs']], how = 'left', on = 'trip_id')
    
    #trip_df['tod'] = np.where(trip_df.tod == 'peak', 'pk', 'op')
    
    trip_df['NAME'] = trip_df.apply(lambda x: str(x.agency_id) + '_' + str(x.route_id) + '_' 
                                    + str(x.route_short_name) 
                                    #+ '_'
                                    #+ x.tod 
                                    #+ str(x.direction_id)
                                    , 
                                    axis = 1)
    trip_df['LONGNAME'] = trip_df['route_long_name']
    trip_df['HEADWAY'] = (trip_df['headway_secs']/60).astype(int)
    
    """
    def mode_gtfs_to_muni(x):
        if x.route_type == 0:
            return 15
        elif x.route_type == 5:
            return 14
        elif x.route_short_name[-1] in ["X", "R"]:
            return 12
        else:
            return 11
    
    trip_df['MODE'] = trip_df.apply(lambda x : mode_gtfs_to_muni(x),
                                   axis = 1)
    """
    
    trip_df = pd.merge(
        trip_df,
        mode_crosswalk.drop("agency_id", axis = 1),
        how = "left",
        on = ["agency_raw_name", "route_type"]
    )
    
    trip_df['TM2_mode'].fillna(11, inplace = True)
    trip_df['TM2_mode'] = trip_df['TM2_mode'].astype(int)
    
    trip_df['ONEWAY'] = 'T'
    
    return trip_df

# %%
gtfs_to_tm2_mode_crosswalk_df = pd.read_csv(data_interim_dir + "gtfs_to_tm2_mode_crosswalk.csv")

gtfs_to_tm2_mode_crosswalk_df.drop_duplicates(subset = ["agency_raw_name", "route_type"], inplace = True)

# %%
gtfs_to_tm2_mode_crosswalk_df
# Out:
#                                   agency_raw_name  \
# 0                                   ACE_2017_3_20
# 1                             ACTransit_2015_8_14
# 2                                   BART_2015_8_3
# 3                        Blue&Gold_gtfs_10_4_2017
# 4                                  CCTA_2015_8_11
# 5                              Caltrain_2015_5_13
# 6                              Caltrain_2015_5_13
# 7                               Capitol_2017_3_20
# 8                           Emeryville_2016_10_26
# 9                            Fairfield_2015_10_14
# 10                            GGFerries_2017_3_18
# 11                             GGTransit_2015_9_3
# 12                             GGTransit_2015_9_3
# 13                                MVGo_2016_10_26
# 14                          Marguerite_2016_10_10
# 15                         MarinTransit_2015_8_31
# 16                             Petaluma_2016_5_22
# 17                             RioVista_2015_8_20
# 18                                SFMTA_2015_8_11
# 19                                SFMTA_2015_8_11
# 20                                SFMTA_2015_8_11
# 21                         SF_Bay_Ferry2016_07_01
# 22                             SamTrans_2015_8_20
# 23              SantaRosa_google_transit_08_28_15
# 24                             Soltrans_2016_5_20
# 25                         SonomaCounty_2015_8_18
# 27              TriDelta-GTFS-2018-05-24_21-43-17
# 28  Union_City_Transit_Aug-01-2015 to Jun-30-2017
# 29                                  VTA_2015_8_27
# 30                                  VTA_2015_8_27
# 31                            Vine_GTFS_PLUS_2015
# 32                              WestCAT_2016_5_26
# 33       petalumatransit-petaluma-ca-us__11_12_15
# 34                  vacavillecitycoach-2020-ca-us
# 35                        westcat-ca-us_9_17_2015
#
#                                       agency_name          agency_id  \
# 0                   ACE Altamont Corridor Express                 CE
# 1                                      AC Transit         AC Transit
# 2                          Bay Area Rapid Transit               BART
# 3                               Blue & Gold Fleet                 BG
# 4                               County Connection                NaN
# 5                                        Caltrain                NaN
# 6                                        Caltrain                NaN
# 7                                Capitol Corridor                 AM
# 8                                  Emery Go-Round                573
# 9                    Fairfield and Suisun Transit                 36
# 10                        San Francisco Bay Ferry                 SB
# 11                            Golden Gate Transit                NaN
# 12                            Golden Gate Transit                NaN
# 13                             MVgo Mountain View                533
# 14                    Stanford Marguerite Shuttle                NaN
# 15                                  Marin Transit               MCTD
# 16                               Petaluma Transit                267
# 17                         Rio Vista Delta Breeze                  5
# 18  San Francisco Municipal Transportation Agency              SFMTA
# 19  San Francisco Municipal Transportation Agency              SFMTA
# 20  San Francisco Municipal Transportation Agency              SFMTA
# 21                        San Francisco Bay Ferry                 SB
# 22                                       SamTrans                NaN
# 23                             Santa Rosa CityBus          SRCityBus
# 24                                       SolTrans                247
# 25                          Sonoma County Transit                175
# 27                              Tri Delta Transit  tri-delta-transit
# 28                             Union City Transit                UCT
# 29                                            VTA                VTA
# 30                                            VTA                VTA
# 31                             Vine (Napa County)                362
# 32                 WestCat (Western Contra Costa)                392
# 33                               Petaluma Transit                267
# 34                           Vacaville City Coach                869
# 35                 WestCat (Western Contra Costa)                392
#
#     route_type  TM2_mode TM2_line_haul_name
# 0            2       133      Commuter rail
# 1            3        30          Local bus
# 2            1       120         Heavy rail
# 3            4       103      Ferry service
# 4            3        42          Local bus
# 5            2       130      Commuter rail
# 6            3        14          Local bus
# 7            2       131      Commuter rail
# 8            3        12          Local bus
# 9            3        52          Local bus
# 10           4       101      Ferry service
# 11           2       101      Ferry service
# 12           3        70          Local bus
# 13           3        16          Local bus
# 14           3        13          Local bus
# 15           3        71          Local bus
# 16           3        68          Local bus
# 17           3        52          Local bus
# 18           0       110         Light rail
# 19           3        20          Local bus
# 20           5        21          Local bus
# 21           4       101      Ferry service
# 22           3        24          Local bus
# 23           3        66          Local bus
# 24           3        49          Local bus
# 25           3        63          Local bus
# 27           3        44          Local bus
# 28           3        38          Local bus
# 29           0       111         Light rail
# 30           3        28          Local bus
# 31           3        60          Local bus
# 32           3        46          Local bus
# 33           3        68          Local bus
# 34           3        56          Local bus
# 35           3        46          Local bus

# %%
cube_trip_df = prepare_df_for_cube(all_routes_df, 
                                   gtfs_to_tm2_mode_crosswalk_df,
                                trip_df, 
                                bus_link_df, 
                                freq_df, 
                                rail_link_gdf)

# %%
trip_df.shape
# Out:
# (3818, 49)

# %%
cube_trip_df.shape
# Out:
# (3785, 71)

# %%
cube_trip_df[cube_trip_df.agency_raw_name == "GGFerries_2017_3_18"]
# Out:
# Empty DataFrame
# Columns: [service_id, trip_headsign, direction_id, block_id, wheelchair_accessible, bikes_allowed, trip_short_name, original_trip_id, trip_bikes_allowed, trip_type, drt_max_travel_time, drt_avg_travel_time, drt_advance_book_min, drt_pickup_message, drt_drop_off_message, continuous_pickup_message, continuous_drop_off_message, route_id, trip_id, shape_id, arrival_time, departure_time, stop_sequence, stop_headsign, pickup_type, drop_off_type, shape_dist_traveled, timepoint, start_service_area_id, end_service_area_id, start_service_area_radius, end_service_area_radius, continuous_pickup_x, continuous_drop_off_x, pickup_area_id, drop_off_area_id, pickup_service_area_radius, drop_off_service_area_radius, last_stop_on_trip, stop_id, arrival_h, arrival_m, departure_h, departure_m, tod, trip_num_x, trip_num_y, trip_num, route_id_original, agency_id, route_short_name, route_long_name, route_desc, route_type, route_url, route_color, route_text_color, agency_raw_name, route_sort_order, min_headway_minutes, eligibility_restricted, continuous_pickup_y, continuous_drop_off_y, headway_secs, NAME, LONGNAME, HEADWAY, agency_name, TM2_mode, TM2_line_haul_name, ONEWAY]
# Index: []
#
# [0 rows x 71 columns]

# %%
cube_trip_df.TM2_mode.value_counts().sum()
# Out:
# 3785

# %%
cube_trip_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3785 entries, 0 to 3784
# Data columns (total 71 columns):
# service_id                      3785 non-null object
# trip_headsign                   3411 non-null object
# direction_id                    3785 non-null float64
# block_id                        2751 non-null object
# wheelchair_accessible           105 non-null float64
# bikes_allowed                   610 non-null float64
# trip_short_name                 363 non-null object
# original_trip_id                147 non-null object
# trip_bikes_allowed              8 non-null object
# trip_type                       0 non-null object
# drt_max_travel_time             18 non-null object
# drt_avg_travel_time             18 non-null object
# drt_advance_book_min            18 non-null object
# drt_pickup_message              0 non-null object
# drt_drop_off_message            0 non-null object
# continuous_pickup_message       0 non-null object
# continuous_drop_off_message     0 non-null object
# route_id                        3785 non-null int32
# trip_id                         3785 non-null int32
# shape_id                        3785 non-null int32
# arrival_time                    3784 non-null float64
# departure_time                  3784 non-null float64
# stop_sequence                   3785 non-null int64
# stop_headsign                   895 non-null object
# pickup_type                     1184 non-null float64
# drop_off_type                   1770 non-null object
# shape_dist_traveled             659 non-null float64
# timepoint                       219 non-null float64
# start_service_area_id           0 non-null object
# end_service_area_id             0 non-null object
# start_service_area_radius       0 non-null object
# end_service_area_radius         0 non-null object
# continuous_pickup_x             18 non-null object
# continuous_drop_off_x           18 non-null object
# pickup_area_id                  0 non-null object
# drop_off_area_id                0 non-null object
# pickup_service_area_radius      0 non-null object
# drop_off_service_area_radius    0 non-null object
# last_stop_on_trip               0 non-null object
# stop_id                         3785 non-null int32
# arrival_h                       3784 non-null float64
# arrival_m                       3784 non-null float64
# departure_h                     3784 non-null float64
# departure_m                     3784 non-null float64
# tod                             3785 non-null object
# trip_num_x                      3785 non-null int64
# trip_num_y                      995 non-null float64
# trip_num                        3785 non-null float64
# route_id_original               3785 non-null object
# agency_id                       2925 non-null object
# route_short_name                3577 non-null object
# route_long_name                 3685 non-null object
# route_desc                      685 non-null object
# route_type                      3785 non-null int64
# route_url                       1492 non-null object
# route_color                     1707 non-null object
# route_text_color                1601 non-null object
# agency_raw_name                 3785 non-null object
# route_sort_order                497 non-null object
# min_headway_minutes             208 non-null object
# eligibility_restricted          18 non-null object
# continuous_pickup_y             18 non-null object
# continuous_drop_off_y           18 non-null object
# headway_secs                    3785 non-null int64
# NAME                            3785 non-null object
# LONGNAME                        3685 non-null object
# HEADWAY                         3785 non-null int32
# agency_name                     3785 non-null object
# TM2_mode                        3785 non-null int32
# TM2_line_haul_name              3785 non-null object
# ONEWAY                          3785 non-null object
# dtypes: float64(14), int32(6), int64(4), object(47)
# memory usage: 2.0+ MB

# %%
cube_trip_df.iloc[1]
# Out:
# service_id                                                                  WKDY
# trip_headsign                                                     Montgomery St.
# direction_id                                                                   0
# block_id                                                                     NaN
# wheelchair_accessible                                                          1
# bikes_allowed                                                                  1
# trip_short_name                                                              NaN
# original_trip_id                                                             NaN
# trip_bikes_allowed                                                           NaN
# trip_type                                                                    NaN
# drt_max_travel_time                                                          NaN
# drt_avg_travel_time                                                          NaN
# drt_advance_book_min                                                         NaN
# drt_pickup_message                                                           NaN
# drt_drop_off_message                                                         NaN
# continuous_pickup_message                                                    NaN
# continuous_drop_off_message                                                  NaN
# route_id                                                                     154
# trip_id                                                                     5877
# shape_id                                                                     404
# arrival_time                                                               22320
# departure_time                                                             22320
# stop_sequence                                                                  1
# stop_headsign                                                     Montgomery St.
# pickup_type                                                                  NaN
# drop_off_type                                                                NaN
# shape_dist_traveled                                                          NaN
# timepoint                                                                      1
# start_service_area_id                                                        NaN
# end_service_area_id                                                          NaN
#                                                      ...
# arrival_m                                                                     12
# departure_h                                                                    6
# departure_m                                                                   12
# tod                                                                           AM
# trip_num_x                                                                    29
# trip_num_y                                                                   NaN
# trip_num                                                                      29
# route_id_original                                                             01
# agency_id                                                                   BART
# route_short_name                                                             NaN
# route_long_name                              Pittsburg/Bay Point - SFIA/Millbrae
# route_desc                                                                   NaN
# route_type                                                                     1
# route_url                      http://www.bart.gov/schedules/bylineresults?ro...
# route_color                                                               ffff33
# route_text_color                                                             NaN
# agency_raw_name                                                    BART_2015_8_3
# route_sort_order                                                             NaN
# min_headway_minutes                                                          NaN
# eligibility_restricted                                                       NaN
# continuous_pickup_y                                                          NaN
# continuous_drop_off_y                                                        NaN
# headway_secs                                                                 496
# NAME                                                                BART_154_nan
# LONGNAME                                     Pittsburg/Bay Point - SFIA/Millbrae
# HEADWAY                                                                        8
# agency_name                                               Bay Area Rapid Transit
# TM2_mode                                                                     120
# TM2_line_haul_name                                                    Heavy rail
# ONEWAY                                                                         T
# Name: 1, Length: 71, dtype: object

# %%
def node_list(x, trip_df, stop_df, bus_link, stop_times, node_gdf, link_gdf, 
              rail_link = pd.DataFrame(columns = ['shape_id', 'u', 'v']), rail_node_df = None):
    print(x.trip_id)
    
    if len(rail_node_df) > 0:
        rail_node_dict = dict(zip(rail_node_df.stop_id, rail_node_df.model_node_id))
        stop_df['model_node_id'] = stop_df.apply(lambda x: rail_node_dict[x.stop_id] 
                                               if x.stop_id in rail_node_df.stop_id.tolist()
                                               else x.model_node_id,
                                    axis = 1)
        
    rail_link_df = rail_link.copy()
    rail_link_df = pd.merge(trip_df[['trip_id', 'shape_id']],
                            rail_link_df,
                           how = 'right',
                           on = 'shape_id')
    
    transit_link_gdf = pd.concat([bus_link[['u', 'v', 'shape_id', 'trip_id' , "A", "B"]], 
                                  rail_link_df[['shape_id', 'trip_id', "A", "B"]]], 
                                 sort = False, 
                                 ignore_index = True)
    
    """transit_link_gdf = pd.merge(transit_link_gdf,
                               link_gdf[['LINK_ID',"u","v"]],
                               how = "left",
                               on = ["u","v"])"""
   
    stop_times_df = stop_times.copy()
    stop_id_list = stop_times_df[stop_times_df.trip_id == x.trip_id]['stop_id'].tolist()
    stop_node_list = stop_df[stop_df['stop_id'].isin(stop_id_list)]['model_node_id'].tolist()
    
    #print(stop_node_list)
    
    node_list = transit_link_gdf[transit_link_gdf['trip_id'] == x.trip_id]['A'].tolist() + \
                    [transit_link_gdf[transit_link_gdf['trip_id'] == x.trip_id]['B'].iloc[-1]]
    
    #osmid_N_dict = dict(zip(node_gdf.OSMID, node_gdf.N))
    
    #node_list = list(map(osmid_N_dict.get, node_list))
    
    s = '\nLINE NAME=\"%s\",' % (x.NAME,)
    
    #line attribtes
    s += '\n LONGNAME=\"%s",' % (x.LONGNAME,)
    s += '\n USERA1=\"%s",' % (x.agency_id,)
    s += '\n USERA2=\"%s",' % (x.TM2_line_haul_name,)
    if x.tod == 'AM':
        s += '\n HEADWAY[2]=%s,' % (x.HEADWAY,)
    elif x.tod == "MD":
        s += '\n HEADWAY[3]=%s,' % (x.HEADWAY,)
    elif x.tod == "PM":
        s += '\n HEADWAY[4]=%s,' % (x.HEADWAY,)
    elif x.tod == "NT":
        s += '\n HEADWAY[5]=%s,' % (x.HEADWAY,)
    elif x.tod == "EA":
        s += '\n HEADWAY[1]=%s,' % (x.HEADWAY,)
    s += '\n MODE=%s,' % (x.TM2_mode,)
    s += '\n ONEWAY=%s,' % (x.ONEWAY,)
    s += '\n OPERATOR=%s,' % (x.agency_id,)
    s += '\n SHORTNAME=%s,' % (x.route_short_name,)
    s += '\nN='
    
    circular = 0
    #node list
    trip_stop_list = []
    for nodeIdx in range(len(node_list)):
        # added condition to make sure stops only get stopped once
        if (node_list[nodeIdx] in stop_node_list) & (node_list[nodeIdx] not in trip_stop_list):
            s += '\n %s' % (node_list[nodeIdx])
            trip_stop_list += [node_list[nodeIdx]]
            if nodeIdx < (len(node_list)-1):
                s += ','
        else:
            s += '\n -%s' % (node_list[nodeIdx])
            if nodeIdx < (len(node_list)-1):
                s += ','
            if (node_list[nodeIdx] in trip_stop_list):
                circular = 1
    
    #if circular == 1:
    #    s += ','
    #    s += '\n CIRCULAR=T'                
            
    lines.append(s)

# %%
# %%time

lines = [';;<<PT>><<LINE>>;;']

cube_trip_df.apply(lambda x: node_list(x, 
                                    trip_df,
                                    stop_df, 
                                    bus_link_df,
                                    all_stop_times_df,
                                    roadway_and_rail_node_gdf,
                                    roadway_and_rail_link_df,
                                    rail_link_gdf,
                                    unique_rail_node_gdf), 
                axis=1)

with open(output_folder + "transit.LIN", 'w') as f:
    f.write("\n".join(map(str, lines)))
# Out:
# 5781
# 5877
# 6391
# 6619
# 6765
# 5775
# 5871
# 6229
# 6469
# 6639
# 5776
# 5872
# 6230
# 6470
# 6640
# 5777
# 5825
# 6423
# 5881
# 6025
# 5782
# 5910
# 6296
# 6536
# 6770
# 5778
# 5826
# 6424
# 5882
# 6026
# 5780
# 5876
# 6234
# 6474
# 6644
# 5779
# 5863
# 6221
# 6461
# 6635
# 5772
# 5820
# 6178
# 6418
# 5771
# 6123
# 6369
# 5773
# 5869
# 6227
# 6467
# 5774
# 5810
# 6168
# 6408
# 6592
# 1
# 5
# 4
# 7809
# 7772
# 7682
# 7481
# 7648
# 7533
# 7618
# 7212
# 7607
# 7570
# 7861
# 6894
# 7900
# 7223
# 7087
# 7437
# 7412
# 7854
# 6887
# 7798
# 7180
# 7179
# 7465
# 7499
# 7494
