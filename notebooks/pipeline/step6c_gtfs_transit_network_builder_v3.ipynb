# %% [markdown]
# # This notebook goes through building transit network from gtfs to network standard
#
# 1. extract representative trips
# 2. snap stops to roadway nodes
# 3. route bus on roadway via osmnx routing
# 4. route bus on roadway via shst routing
# 5. build non-bus/rail links and nodes
# 6. complete network node list that each transit path traverses
# 7. frequence based stop time
# 8. write out to transit network standard
# 9. write out quick QA/QC transit route true shape
# 10. write out network standard with rail nodes and links
# 11. write out travel model transit network

# %%
import partridge as ptg
import peartree as pt
#%matplotlib inline
import requests
from urllib.request import urlopen
from zipfile import ZipFile
from io import BytesIO
import pandas as pd
import numpy as np
import geopandas as gpd
from shapely.geometry import Point, LineString
import networkx as nx
from shapely import wkt
from scipy.spatial import cKDTree
import osmnx as ox
from dbfread import DBF
from osgeo import ogr
import glob
import time
import json
import os

# %%
from methods import link_df_to_geojson
from methods import point_df_to_geojson
from methods import fill_na

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# input directories - use Box
TM2_REBUILD_BOX_DIR     = r"C:\Users\{}\Box\Modeling and Surveys\Development\Travel Model Two Development\Travel Model Two Network Rebuild".format(os.getenv('USERNAME'))
TM2_NETWORKS_DATA_DIR   = os.path.join(TM2_REBUILD_BOX_DIR,    "travel-model-two-networks", "data")
input_data_interim_dir  = os.path.join(TM2_NETWORKS_DATA_DIR,  "interim")
input_data_external_dir = os.path.join(TM2_NETWORKS_DATA_DIR,  "external")

# %%
# output folders - use local, most likely
output_data_interim_dir = r"C:\Users\{}\Documents\scratch\tm2_network_building\interim\step6_gtfs\\".format(os.getenv('USERNAME'))
output_folder           = r"C:\Users\{}\Documents\scratch\tm2_network_building\processed\version_12\\".format(os.getenv('USERNAME'))
os.makedirs(output_data_interim_dir, exist_ok=True))
os.makedirs(output_folder,           exist_ok=True))

# todo: describe what goes in here
output_data_gtfs_dir = os.path.join(output_data_interim_dir,'consolidated_gtfs_input')
os.makedirs(output_data_gtfs_dir, exist_ok=True)

# todo: describe what goes in here
output_data_version_dir = os.path.join(output_data_interim_dir,'version_12')
os.makedirs(output_data_version_dir, exist_ok=True)

# %% [markdown]
# #  Read Network

# %%
# %%time
link_file = os.path.join(input_data_interim_dir,"step5_tidy_roadway","link.feather")
link_df = pd.read_feather(link_file)

node_file = os.path.join(input_data_interim_dir,"step5_tidy_roadway","node.geojson")
node_gdf = gpd.read_file(node_file)

shape_file = os.path.join(input_data_interim_dir,"step5_tidy_roadway","shape.geojson")
shape_gdf = gpd.read_file(shape_file)
# Out:
# Wall time: 2min 41s

# %%
print('link_df has {} rows'.format(len(link_df)))
print('node_gdf has {} rows'.format(len(node_gdf)))
print('shape_gdf has {} rows'.format(len(shape_gdf)))
print('link_df columns: {}'.format(link_df.columns))
print('shape_gdf columns: {}'.format(shape_gdf.columns))
# Out:
# link_df has 1632702 rows
# node_gdf has 643811 rows
# shape_gdf has 868567 rows
# link_df columns: Index(['access', 'area', 'bike_access', 'bridge', 'drive_access', 'est_width',
#        'fromIntersectionId', 'highway', 'id', 'junction', 'key', 'landuse',
#        'lanes', 'link', 'maxspeed', 'name', 'oneWay', 'ref', 'roadway',
#        'roundabout', 'service', 'shstGeometryId', 'shstReferenceId',
#        'toIntersectionId', 'tunnel', 'u', 'v', 'walk_access', 'wayId', 'width',
#        'county', 'length', 'model_link_id', 'county_numbering_start', 'A',
#        'B'],
#       dtype='object')
# shape_gdf columns: Index(['id', 'fromIntersectionId', 'toIntersectionId', 'forwardReferenceId',
#        'backReferenceId', 'geometry'],
#       dtype='object')

# %%
# network type correction at Transbay temporary terminal:

display(link_df[link_df.shstReferenceId.isin(["feab62cc90650bfc45dc453816782f9c", "9ab364b22d6b33ec158d8bc4008c1be7"])][
        ["roadway", "drive_access", "walk_access", "bike_access"]])
# Out:
#          roadway  drive_access  walk_access  bike_access
# 524671  cycleway             0            1            1
# 863713   service             0            1            1

# %%
# set roadway type as 'service' and drive_access = 1
link_df.loc[link_df.shstReferenceId.isin(["feab62cc90650bfc45dc453816782f9c", "9ab364b22d6b33ec158d8bc4008c1be7"]), 
            "roadway"] = "service"
link_df.loc[link_df.shstReferenceId.isin(["feab62cc90650bfc45dc453816782f9c", "9ab364b22d6b33ec158d8bc4008c1be7"]), 
            "drive_access"] = 1

# check
link_df[link_df.shstReferenceId.isin(["feab62cc90650bfc45dc453816782f9c", "9ab364b22d6b33ec158d8bc4008c1be7"])][
    ["roadway", "drive_access", "walk_access", "bike_access"]]
# Out:
#         roadway  drive_access  walk_access  bike_access
# 524671  service             1            1            1
# 863713  service             1            1            1

# %%
# related nodes
display(node_gdf[node_gdf.osm_node_id.isin([890045140, 5372055804, 890045129])])

# set drive_access = 1
node_gdf.loc[node_gdf.osm_node_id.isin([890045140, 5372055804, 890045129]), "drive_access"] = 1

# check
node_gdf[node_gdf.osm_node_id.isin([890045140, 5372055804, 890045129])]
# Out:
#         osm_node_id                      shst_node_id         county  \
# 130712   5372055804  3291f7c2f15101c22abf554ce230343e  San Francisco
# 215684    890045140  4c0619714744bed10b7de965adc7048d  San Francisco
# 244341    890045129  490be8656a6428c6fc871a1f0e6432eb  San Francisco
#
#         drive_access  walk_access  bike_access  model_node_id  \
# 130712             0            1            1        1006138
# 215684             1            1            1        1010031
# 244341             1            1            1        1011380
#
#         county_numbering_start                     geometry
# 130712                 1000000  POINT (-122.39210 37.78934)
# 215684                 1000000  POINT (-122.39263 37.78966)
# 244341                 1000000  POINT (-122.39203 37.78925)
#         osm_node_id                      shst_node_id         county  \
# 130712   5372055804  3291f7c2f15101c22abf554ce230343e  San Francisco
# 215684    890045140  4c0619714744bed10b7de965adc7048d  San Francisco
# 244341    890045129  490be8656a6428c6fc871a1f0e6432eb  San Francisco
#
#         drive_access  walk_access  bike_access  model_node_id  \
# 130712             1            1            1        1006138
# 215684             1            1            1        1010031
# 244341             1            1            1        1011380
#
#         county_numbering_start                     geometry
# 130712                 1000000  POINT (-122.39210 37.78934)
# 215684                 1000000  POINT (-122.39263 37.78966)
# 244341                 1000000  POINT (-122.39203 37.78925)

# %%
# build network routing file for osmnx routing

def ox_graph(nodes_df, links_df):
    """
        create an osmnx-flavored network graph
        osmnx doesn't like values that are arrays, so remove the variables
        that have arrays.  osmnx also requires that certain variables
        be filled in, so do that too.
        Parameters
        ----------
        nodes_df : GeoDataFrame
        link_df : GeoDataFrame
        Returns
        -------
        networkx multidigraph
    """
    try:
        graph_nodes = nodes_df.drop(
                ["inboundReferenceId", "outboundReferenceId"], axis=1
            )
    except:
        graph_nodes = nodes_df.copy()

    graph_nodes.gdf_name = "network_nodes"
    graph_nodes['id'] = graph_nodes['shst_node_id']

    graph_links = links_df.copy()
    graph_links['id'] = graph_links['shstReferenceId']
    graph_links['key'] = graph_links['shstReferenceId']

    # G = ox.gdfs_to_graph(graph_nodes, graph_links)
    # "ox.gdfs_to_graph()" was replaced by "ox.graph_from_gdfs()" in osmnx module v0.13.0
    G = ox.graph_from_gdfs(graph_nodes, graph_links)

    return G


drive_node_gdf = node_gdf[node_gdf.drive_access == 1].copy()
drive_link_df = link_df[link_df.drive_access == 1].copy()
print("drive_link_df has {} rows and {} unique ids".format(len(drive_link_df), len(drive_link_df.id.unique())))

# lmz added: convert drive_link_df to a gdf using the geometry/crs in shape_gdf
drive_link_gdf = pd.merge(left=drive_link_df, right=shape_gdf[['id','geometry']],
                          how='left', on='id', indicator=True)
print("drive_link_gdf has {} rows".format(len(drive_link_gdf)))
print(drive_link_gdf['_merge'].value_counts())
drive_link_gdf = gpd.GeoDataFrame(drive_link_gdf, crs=shape_gdf.crs)

G_drive = ox_graph(drive_node_gdf,
                   drive_link_gdf)
# Out:
# drive_link_df has 1002162 rows and 551937 unique ids
# drive_link_gdf has 1002162 rows
# both          1002162
# right_only          0
# left_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# # Consolidate all gtfs into one

# %%
gtfs_2015_dir = os.path.join(input_data_external_dir,"gtfs","2015")
gtfs_agencies_list = os.listdir(gtfs_2015_dir)
# print(gtfs_agencies_list)
gtfs_agencies_list.remove("Petaluma_2016_5_22")
gtfs_agencies_list.remove("WestCAT_2016_5_26")
gtfs_agencies_list.remove("GGFerries_2017_3_18")
gtfs_agencies_list.remove("commuteDOTorg_GTFSImportExport_20160127_final_mj")

gtfs_agencies_list = gtfs_agencies_list + ["commuteDOTorg_GTFSImportExport_20160127_final_mj"]

# %%
gtfs_agencies_list
# Out:
# ['ACE_2017_3_20',
#  'ACTransit_2015_8_14',
#  'BART_2015_8_3',
#  'Blue&Gold_gtfs_10_4_2017',
#  'Caltrain_2015_5_13',
#  'Capitol_2017_3_20',
#  'CCTA_2015_8_11',
#  'Emeryville_2016_10_26',
#  'Fairfield_2015_10_14',
#  'Fairfield_2015_10_14_updates',
#  'GGTransit_2015_9_3',
#  'Marguerite_2016_10_10',
#  'MarinTransit_2015_8_31',
#  'MVGo_2016_10_26',
#  'petalumatransit-petaluma-ca-us__11_12_15',
#  'RioVista_2015_8_20',
#  'SamTrans_2015_8_20',
#  'SantaRosa_google_transit_08_28_15',
#  'SFMTA_2015_8_11',
#  'SF_Bay_Ferry2016_07_01',
#  'Soltrans_2016_5_20',
#  'SonomaCounty_2015_8_18',
#  'TriDelta-GTFS-2018-05-24_21-43-17',
#  'Union_City_Transit_Aug-01-2015 to Jun-30-2017',
#  'vacavillecitycoach-2020-ca-us',
#  'Vine_GTFS_PLUS_2015',
#  'VTA_2015_8_27',
#  'westcat-ca-us_9_17_2015',
#  'Wheels_2016_7_13',
#  'commuteDOTorg_GTFSImportExport_20160127_final_mj']

# %%
all_routes_df = pd.DataFrame()
all_trips_df = pd.DataFrame()
all_stops_df = pd.DataFrame()
all_shapes_df = pd.DataFrame()
all_stop_times_df = pd.DataFrame()
all_agency_df = pd.DataFrame()
all_fare_attributes_df = pd.DataFrame()
all_fare_rules_df = pd.DataFrame()

def get_representative_feed_from_gtfs(work_dir, in_url = "", fetch = False):
    
    print('getting representative feed...')
    
    if fetch == True:
        #read and save zip from url
        resp = urlopen(in_url)
        zipfile = ZipFile(BytesIO(resp.read()))
    
    if fetch == True:
        zipfile.extractall(work_dir + "muni")
    
    file_loc = work_dir
    
    # get feed for the busiest day
    feed = pt.get_representative_feed(file_loc)
    
    return feed

for name in gtfs_agencies_list:
    
    # exclude weekend only services
    if "calendar_orig.txt" in os.listdir(os.path.join(gtfs_2015_dir,name)):
        calendar_df = pd.read_csv(os.path.join(gtfs_2015_dir,name,"calendar.txt"))
        
    elif "calendar.txt" in os.listdir(os.path.join(gtfs_2015_dir,name)):
        calendar_df = pd.read_csv(os.path.join(gtfs_2015_dir,name,"calendar.txt"))
        calendar_df.to_csv(os.path.join(gtfs_2015_dir,name,"calendar_orig.txt"),
                                                 index = False,
                                                 sep = ",")
    
        calendar_df["weekdays"] = calendar_df.apply(lambda x: x.monday + x.tuesday + x.wednesday + x.thursday + x.friday,
                                               axis = 1)
        calendar_df = calendar_df[calendar_df.weekdays > 0]
        
        # writing data to external :p
        calendar_df.drop("weekdays", axis = 1).to_csv(os.path.join(gtfs_2015_dir,name,"calendar.txt"),
                                                 index = False,
                                                 sep = ",")
    
    feed = get_representative_feed_from_gtfs(os.path.join(gtfs_2015_dir,name))
    
    routes_df = feed.routes.copy()
    routes_df["agency_raw_name"] = name
    
    stops_df = feed.stops.copy()
    stops_df["agency_raw_name"] = name
    
    trips_df = feed.trips.copy()
    trips_df["agency_raw_name"] = name
    
    if "direction_id" not in trips_df.columns: # Marguerita
        trips_df["direction_id"] = 0
    
    trips_df["direction_id"].fillna(0, inplace = True)
   
    shapes_df = feed.shapes.copy()
    shapes_df["agency_raw_name"] = name
    
    stop_times_df = feed.stop_times.copy()
    stop_times_df["agency_raw_name"] = name
    
    agency_df = feed.agency.copy()
    agency_df["agency_raw_name"] = name
    
    # gtfs cannot read fare tables for all agencies
        
    if "fare_attributes.txt" in os.listdir(os.path.join(gtfs_2015_dir,name)):
        
        fare_attributes_df = pd.read_csv(os.path.join(gtfs_2015_dir,name,"fare_attributes.txt"),
                                         dtype = {"fare_id" : str})
        fare_attributes_df["agency_raw_name"] = name
    
    else:
        
        fare_attributes_df = pd.DataFrame()
    
    if "fare_rules.txt" in os.listdir(os.path.join(gtfs_2015_dir,name)):
        
        fare_rules_df = pd.read_csv(os.path.join(gtfs_2015_dir,name,"fare_rules.txt"),
                                    dtype = {"fare_id" : str, "route_id" : str, "origin_id" : str, "destination_id" : str,
                                             " route_id" : str, " origin_id" : str, " destination_id" : str,})
        fare_rules_df["agency_raw_name"] = name
        
    else:
        
        fare_rules_df = pd.DataFrame()
        
    # add agency_id in routes.txt if missing
    if "agency_id" not in routes_df.columns:
        if "agency_id" in agency_df.columns:
            routes_df["agency_id"] = agency_df.agency_id.iloc[0]
    
    if len(shapes_df) == 0: # ACE, CCTA, VINE
        print("missing shapes.txt for {}".format(name))
        group_df = trips_df.groupby(["route_id", "direction_id"])["trip_id"].first().reset_index().drop("trip_id", axis = 1)
        group_df["shape_id"] = range(1, len(group_df) + 1)
        if "shape_id" in trips_df.columns:
            trips_df.drop("shape_id", axis = 1, inplace = True)
        trips_df = pd.merge(trips_df, group_df, how = "left", on = ["route_id", "direction_id"])
        
    if len(trips_df[trips_df.shape_id.isnull()]) > 0:
        print("partial complete shape_id for {}".format(name))
        trips_missing_shape_df = trips_df[trips_df.shape_id.isnull()].copy()
        group_df = trips_missing_shape_df.groupby(["route_id", "direction_id"])["trip_id"].first().reset_index().drop("trip_id", axis = 1)
        group_df["shape_id"] = range(1, len(group_df) + 1)
        group_df["shape_id"] = group_df["shape_id"].apply(lambda x: "psudo" + str(x))
        trips_missing_shape_df = pd.merge(trips_missing_shape_df.drop("shape_id", axis = 1), 
                                          group_df, how = "left", on = ["route_id", "direction_id"])
        trips_df = pd.concat([trips_df[trips_df.shape_id.notnull()], trips_missing_shape_df],
                             ignore_index = True,
                             sort = False)
        
    all_routes_df = all_routes_df.append(routes_df, sort = False, ignore_index = True)
    all_trips_df = all_trips_df.append(trips_df, sort = False, ignore_index = True)
    all_stops_df = all_stops_df.append(stops_df, sort = False, ignore_index = True)
    all_shapes_df = all_shapes_df.append(shapes_df, sort = False, ignore_index = True)
    all_stop_times_df = all_stop_times_df.append(stop_times_df, sort = False, ignore_index = True)
    all_agency_df = all_agency_df.append(agency_df, sort = False, ignore_index = True)
    all_fare_attributes_df = all_fare_attributes_df.append(fare_attributes_df, sort = False, ignore_index = True)
    all_fare_rules_df = all_fare_rules_df.append(fare_rules_df, sort = False, ignore_index = True)
# Out:
# getting representative feed...
# missing shapes.txt for ACE_2017_3_20
# getting representative feed...
# getting representative feed...
# getting representative feed...
# getting representative feed...
# getting representative feed...
# partial complete shape_id for Capitol_2017_3_20
# getting representative feed...
# missing shapes.txt for CCTA_2015_8_11
# getting representative feed...
# getting representative feed...
# getting representative feed...
# getting representative feed...
# getting representative feed...
# getting representative feed...
# getting representative feed...
# getting representative feed...
# getting representative feed...
# getting representative feed...
# partial complete shape_id for SamTrans_2015_8_20
# getting representative feed...
# getting representative feed...
# getting representative feed...
# partial complete shape_id for SF_Bay_Ferry2016_07_01
# getting representative feed...
# getting representative feed...
# getting representative feed...
# getting representative feed...
# getting representative feed...
# getting representative feed...
# missing shapes.txt for Vine_GTFS_PLUS_2015
# getting representative feed...
# getting representative feed...
# getting representative feed...
# getting representative feed...

# %%
# clean up field names
all_fare_rules_df["origin_id"] = np.where(all_fare_rules_df["origin_id"].isnull(),
                                          all_fare_rules_df[" origin_id"],
                                          all_fare_rules_df["origin_id"])

all_fare_rules_df["destination_id"] = np.where(all_fare_rules_df["destination_id"].isnull(),
                                          all_fare_rules_df[" destination_id"],
                                          all_fare_rules_df["destination_id"])

all_fare_rules_df["contains_id"] = np.where(all_fare_rules_df["contains_id"].isnull(),
                                          all_fare_rules_df[" contains_id"],
                                          all_fare_rules_df["contains_id"])

all_fare_rules_df.drop(columns = [" origin_id", " destination_id", " contains_id"], inplace = True)

# %%
# examine transit agencies included
all_agency_df.astype(str).groupby(["agency_raw_name", "agency_name", "agency_id"]).count()
# Out:
#                                                                                                                   agency_url  \
# agency_raw_name                                  agency_name                                   agency_id
# ACE_2017_3_20                                    ACE Altamont Corridor Express                 CE                          1
# ACTransit_2015_8_14                              AC Transit                                    AC Transit                  1
# BART_2015_8_3                                    Bay Area Rapid Transit                        BART                        1
# Blue&Gold_gtfs_10_4_2017                         Blue & Gold Fleet                             BG                          1
# CCTA_2015_8_11                                   County Connection                             nan                         1
# Caltrain_2015_5_13                               Caltrain                                      caltrain-ca-us              1
# Capitol_2017_3_20                                Capitol Corridor                              AM                          1
# Emeryville_2016_10_26                            Emery Go-Round                                573                         1
# Fairfield_2015_10_14                             Fairfield and Suisun Transit                  36                          1
# Fairfield_2015_10_14_updates                     Fairfield and Suisun Transit                  36                          1
# GGTransit_2015_9_3                               Golden Gate Transit                           nan                         1
# MVGo_2016_10_26                                  MVgo Mountain View                            533                         1
# Marguerite_2016_10_10                            Stanford Marguerite Shuttle                   nan                         1
# MarinTransit_2015_8_31                           Marin Transit                                 MCTD                        1
# RioVista_2015_8_20                               Rio Vista Delta Breeze                        5                           1
# SFMTA_2015_8_11                                  San Francisco Municipal Transportation Agency SFMTA                       1
# SF_Bay_Ferry2016_07_01                           San Francisco Bay Ferry                       SB                          1
# SamTrans_2015_8_20                               SamTrans                                      samtrans-ca-us              1
# SantaRosa_google_transit_08_28_15                Santa Rosa CityBus                            SRCityBus                   1
# Soltrans_2016_5_20                               SolTrans                                      247                         1
# SonomaCounty_2015_8_18                           Cloverdale Transit                            183                         1
#                                                  Sonoma County Transit                         175                         1
# TriDelta-GTFS-2018-05-24_21-43-17                Tri Delta Transit                             tri-delta-transit           1
# Union_City_Transit_Aug-01-2015 to Jun-30-2017    Union City Transit                            UCT                         1
# VTA_2015_8_27                                    VTA                                           VTA                         1
# Vine_GTFS_PLUS_2015                              Vine (Napa County)                            362                         1
# Wheels_2016_7_13                                 Wheels Bus                                    LAVTA                       1
# commuteDOTorg_GTFSImportExport_20160127_final_mj Commute.org Shuttle                           alliance                    1
# petalumatransit-petaluma-ca-us__11_12_15         Petaluma Transit                              267                         1
# vacavillecitycoach-2020-ca-us                    Vacaville City Coach                          869                         1
# westcat-ca-us_9_17_2015                          WestCat (Western Contra Costa)                392                         1
#
#                                                                                                                   agency_timezone  \
# agency_raw_name                                  agency_name                                   agency_id
# ACE_2017_3_20                                    ACE Altamont Corridor Express                 CE                               1
# ACTransit_2015_8_14                              AC Transit                                    AC Transit                       1
# BART_2015_8_3                                    Bay Area Rapid Transit                        BART                             1
# Blue&Gold_gtfs_10_4_2017                         Blue & Gold Fleet                             BG                               1
# CCTA_2015_8_11                                   County Connection                             nan                              1
# Caltrain_2015_5_13                               Caltrain                                      caltrain-ca-us                   1
# Capitol_2017_3_20                                Capitol Corridor                              AM                               1
# Emeryville_2016_10_26                            Emery Go-Round                                573                              1
# Fairfield_2015_10_14                             Fairfield and Suisun Transit                  36                               1
# Fairfield_2015_10_14_updates                     Fairfield and Suisun Transit                  36                               1
# GGTransit_2015_9_3                               Golden Gate Transit                           nan                              1
# MVGo_2016_10_26                                  MVgo Mountain View                            533                              1
# Marguerite_2016_10_10                            Stanford Marguerite Shuttle                   nan                              1
# MarinTransit_2015_8_31                           Marin Transit                                 MCTD                             1
# RioVista_2015_8_20                               Rio Vista Delta Breeze                        5                                1
# SFMTA_2015_8_11                                  San Francisco Municipal Transportation Agency SFMTA                            1
# SF_Bay_Ferry2016_07_01                           San Francisco Bay Ferry                       SB                               1
# SamTrans_2015_8_20                               SamTrans                                      samtrans-ca-us                   1
# SantaRosa_google_transit_08_28_15                Santa Rosa CityBus                            SRCityBus                        1
# Soltrans_2016_5_20                               SolTrans                                      247                              1
# SonomaCounty_2015_8_18                           Cloverdale Transit                            183                              1
#                                                  Sonoma County Transit                         175                              1
# TriDelta-GTFS-2018-05-24_21-43-17                Tri Delta Transit                             tri-delta-transit                1
# Union_City_Transit_Aug-01-2015 to Jun-30-2017    Union City Transit                            UCT                              1
# VTA_2015_8_27                                    VTA                                           VTA                              1
# Vine_GTFS_PLUS_2015                              Vine (Napa County)                            362                              1
# Wheels_2016_7_13                                 Wheels Bus                                    LAVTA                            1
# commuteDOTorg_GTFSImportExport_20160127_final_mj Commute.org Shuttle                           alliance                         1
# petalumatransit-petaluma-ca-us__11_12_15         Petaluma Transit                              267                              1
# vacavillecitycoach-2020-ca-us                    Vacaville City Coach                          869                              1
# westcat-ca-us_9_17_2015                          WestCat (Western Contra Costa)                392                              1
#
#                                                                                                                   agency_lang  \
# agency_raw_name                                  agency_name                                   agency_id
# ACE_2017_3_20                                    ACE Altamont Corridor Express                 CE                           1
# ACTransit_2015_8_14                              AC Transit                                    AC Transit                   1
# BART_2015_8_3                                    Bay Area Rapid Transit                        BART                         1
# Blue&Gold_gtfs_10_4_2017                         Blue & Gold Fleet                             BG                           1
# CCTA_2015_8_11                                   County Connection                             nan                          1
# Caltrain_2015_5_13                               Caltrain                                      caltrain-ca-us               1
# Capitol_2017_3_20                                Capitol Corridor                              AM                           1
# Emeryville_2016_10_26                            Emery Go-Round                                573                          1
# Fairfield_2015_10_14                             Fairfield and Suisun Transit                  36                           1
# Fairfield_2015_10_14_updates                     Fairfield and Suisun Transit                  36                           1
# GGTransit_2015_9_3                               Golden Gate Transit                           nan                          1
# MVGo_2016_10_26                                  MVgo Mountain View                            533                          1
# Marguerite_2016_10_10                            Stanford Marguerite Shuttle                   nan                          1
# MarinTransit_2015_8_31                           Marin Transit                                 MCTD                         1
# RioVista_2015_8_20                               Rio Vista Delta Breeze                        5                            1
# SFMTA_2015_8_11                                  San Francisco Municipal Transportation Agency SFMTA                        1
# SF_Bay_Ferry2016_07_01                           San Francisco Bay Ferry                       SB                           1
# SamTrans_2015_8_20                               SamTrans                                      samtrans-ca-us               1
# SantaRosa_google_transit_08_28_15                Santa Rosa CityBus                            SRCityBus                    1
# Soltrans_2016_5_20                               SolTrans                                      247                          1
# SonomaCounty_2015_8_18                           Cloverdale Transit                            183                          1
#                                                  Sonoma County Transit                         175                          1
# TriDelta-GTFS-2018-05-24_21-43-17                Tri Delta Transit                             tri-delta-transit            1
# Union_City_Transit_Aug-01-2015 to Jun-30-2017    Union City Transit                            UCT                          1
# VTA_2015_8_27                                    VTA                                           VTA                          1
# Vine_GTFS_PLUS_2015                              Vine (Napa County)                            362                          1
# Wheels_2016_7_13                                 Wheels Bus                                    LAVTA                        1
# commuteDOTorg_GTFSImportExport_20160127_final_mj Commute.org Shuttle                           alliance                     1
# petalumatransit-petaluma-ca-us__11_12_15         Petaluma Transit                              267                          1
# vacavillecitycoach-2020-ca-us                    Vacaville City Coach                          869                          1
# westcat-ca-us_9_17_2015                          WestCat (Western Contra Costa)                392                          1
#
#                                                                                                                   agency_phone  \
# agency_raw_name                                  agency_name                                   agency_id
# ACE_2017_3_20                                    ACE Altamont Corridor Express                 CE                            1
# ACTransit_2015_8_14                              AC Transit                                    AC Transit                    1
# BART_2015_8_3                                    Bay Area Rapid Transit                        BART                          1
# Blue&Gold_gtfs_10_4_2017                         Blue & Gold Fleet                             BG                            1
# CCTA_2015_8_11                                   County Connection                             nan                           1
# Caltrain_2015_5_13                               Caltrain                                      caltrain-ca-us                1
# Capitol_2017_3_20                                Capitol Corridor                              AM                            1
# Emeryville_2016_10_26                            Emery Go-Round                                573                           1
# Fairfield_2015_10_14                             Fairfield and Suisun Transit                  36                            1
# Fairfield_2015_10_14_updates                     Fairfield and Suisun Transit                  36                            1
# GGTransit_2015_9_3                               Golden Gate Transit                           nan                           1
# MVGo_2016_10_26                                  MVgo Mountain View                            533                           1
# Marguerite_2016_10_10                            Stanford Marguerite Shuttle                   nan                           1
# MarinTransit_2015_8_31                           Marin Transit                                 MCTD                          1
# RioVista_2015_8_20                               Rio Vista Delta Breeze                        5                             1
# SFMTA_2015_8_11                                  San Francisco Municipal Transportation Agency SFMTA                         1
# SF_Bay_Ferry2016_07_01                           San Francisco Bay Ferry                       SB                            1
# SamTrans_2015_8_20                               SamTrans                                      samtrans-ca-us                1
# SantaRosa_google_transit_08_28_15                Santa Rosa CityBus                            SRCityBus                     1
# Soltrans_2016_5_20                               SolTrans                                      247                           1
# SonomaCounty_2015_8_18                           Cloverdale Transit                            183                           1
#                                                  Sonoma County Transit                         175                           1
# TriDelta-GTFS-2018-05-24_21-43-17                Tri Delta Transit                             tri-delta-transit             1
# Union_City_Transit_Aug-01-2015 to Jun-30-2017    Union City Transit                            UCT                           1
# VTA_2015_8_27                                    VTA                                           VTA                           1
# Vine_GTFS_PLUS_2015                              Vine (Napa County)                            362                           1
# Wheels_2016_7_13                                 Wheels Bus                                    LAVTA                         1
# commuteDOTorg_GTFSImportExport_20160127_final_mj Commute.org Shuttle                           alliance                      1
# petalumatransit-petaluma-ca-us__11_12_15         Petaluma Transit                              267                           1
# vacavillecitycoach-2020-ca-us                    Vacaville City Coach                          869                           1
# westcat-ca-us_9_17_2015                          WestCat (Western Contra Costa)                392                           1
#
#                                                                                                                   agency_fare_url  \
# agency_raw_name                                  agency_name                                   agency_id
# ACE_2017_3_20                                    ACE Altamont Corridor Express                 CE                               1
# ACTransit_2015_8_14                              AC Transit                                    AC Transit                       1
# BART_2015_8_3                                    Bay Area Rapid Transit                        BART                             1
# Blue&Gold_gtfs_10_4_2017                         Blue & Gold Fleet                             BG                               1
# CCTA_2015_8_11                                   County Connection                             nan                              1
# Caltrain_2015_5_13                               Caltrain                                      caltrain-ca-us                   1
# Capitol_2017_3_20                                Capitol Corridor                              AM                               1
# Emeryville_2016_10_26                            Emery Go-Round                                573                              1
# Fairfield_2015_10_14                             Fairfield and Suisun Transit                  36                               1
# Fairfield_2015_10_14_updates                     Fairfield and Suisun Transit                  36                               1
# GGTransit_2015_9_3                               Golden Gate Transit                           nan                              1
# MVGo_2016_10_26                                  MVgo Mountain View                            533                              1
# Marguerite_2016_10_10                            Stanford Marguerite Shuttle                   nan                              1
# MarinTransit_2015_8_31                           Marin Transit                                 MCTD                             1
# RioVista_2015_8_20                               Rio Vista Delta Breeze                        5                                1
# SFMTA_2015_8_11                                  San Francisco Municipal Transportation Agency SFMTA                            1
# SF_Bay_Ferry2016_07_01                           San Francisco Bay Ferry                       SB                               1
# SamTrans_2015_8_20                               SamTrans                                      samtrans-ca-us                   1
# SantaRosa_google_transit_08_28_15                Santa Rosa CityBus                            SRCityBus                        1
# Soltrans_2016_5_20                               SolTrans                                      247                              1
# SonomaCounty_2015_8_18                           Cloverdale Transit                            183                              1
#                                                  Sonoma County Transit                         175                              1
# TriDelta-GTFS-2018-05-24_21-43-17                Tri Delta Transit                             tri-delta-transit                1
# Union_City_Transit_Aug-01-2015 to Jun-30-2017    Union City Transit                            UCT                              1
# VTA_2015_8_27                                    VTA                                           VTA                              1
# Vine_GTFS_PLUS_2015                              Vine (Napa County)                            362                              1
# Wheels_2016_7_13                                 Wheels Bus                                    LAVTA                            1
# commuteDOTorg_GTFSImportExport_20160127_final_mj Commute.org Shuttle                           alliance                         1
# petalumatransit-petaluma-ca-us__11_12_15         Petaluma Transit                              267                              1
# vacavillecitycoach-2020-ca-us                    Vacaville City Coach                          869                              1
# westcat-ca-us_9_17_2015                          WestCat (Western Contra Costa)                392                              1
#
#                                                                                                                   agency_email
# agency_raw_name                                  agency_name                                   agency_id
# ACE_2017_3_20                                    ACE Altamont Corridor Express                 CE                            1
# ACTransit_2015_8_14                              AC Transit                                    AC Transit                    1
# BART_2015_8_3                                    Bay Area Rapid Transit                        BART                          1
# Blue&Gold_gtfs_10_4_2017                         Blue & Gold Fleet                             BG                            1
# CCTA_2015_8_11                                   County Connection                             nan                           1
# Caltrain_2015_5_13                               Caltrain                                      caltrain-ca-us                1
# Capitol_2017_3_20                                Capitol Corridor                              AM                            1
# Emeryville_2016_10_26                            Emery Go-Round                                573                           1
# Fairfield_2015_10_14                             Fairfield and Suisun Transit                  36                            1
# Fairfield_2015_10_14_updates                     Fairfield and Suisun Transit                  36                            1
# GGTransit_2015_9_3                               Golden Gate Transit                           nan                           1
# MVGo_2016_10_26                                  MVgo Mountain View                            533                           1
# Marguerite_2016_10_10                            Stanford Marguerite Shuttle                   nan                           1
# MarinTransit_2015_8_31                           Marin Transit                                 MCTD                          1
# RioVista_2015_8_20                               Rio Vista Delta Breeze                        5                             1
# SFMTA_2015_8_11                                  San Francisco Municipal Transportation Agency SFMTA                         1
# SF_Bay_Ferry2016_07_01                           San Francisco Bay Ferry                       SB                            1
# SamTrans_2015_8_20                               SamTrans                                      samtrans-ca-us                1
# SantaRosa_google_transit_08_28_15                Santa Rosa CityBus                            SRCityBus                     1
# Soltrans_2016_5_20                               SolTrans                                      247                           1
# SonomaCounty_2015_8_18                           Cloverdale Transit                            183                           1
#                                                  Sonoma County Transit                         175                           1
# TriDelta-GTFS-2018-05-24_21-43-17                Tri Delta Transit                             tri-delta-transit             1
# Union_City_Transit_Aug-01-2015 to Jun-30-2017    Union City Transit                            UCT                           1
# VTA_2015_8_27                                    VTA                                           VTA                           1
# Vine_GTFS_PLUS_2015                              Vine (Napa County)                            362                           1
# Wheels_2016_7_13                                 Wheels Bus                                    LAVTA                         1
# commuteDOTorg_GTFSImportExport_20160127_final_mj Commute.org Shuttle                           alliance                      1
# petalumatransit-petaluma-ca-us__11_12_15         Petaluma Transit                              267                           1
# vacavillecitycoach-2020-ca-us                    Vacaville City Coach                          869                           1
# westcat-ca-us_9_17_2015                          WestCat (Western Contra Costa)                392                           1

# %% [markdown]
# # Re-ID the consolidated gtfs

# %%
# route_id, shape_id, trip_id, stop_id, 

unique_route_id_df = all_routes_df[
    all_routes_df.agency_raw_name != "commuteDOTorg_GTFSImportExport_20160127_final_mj"].copy()
unique_route_id_df = unique_route_id_df.groupby(
    ["agency_raw_name", "route_id"])["agency_id"].count().reset_index().drop(["agency_id"], axis = 1)
unique_route_id_df["route_id_original"] = unique_route_id_df["route_id"]
unique_route_id_df["route_id"] = range(1,  len(unique_route_id_df) + 1)

unique_trip_id_df = all_trips_df[
    all_trips_df.agency_raw_name != "commuteDOTorg_GTFSImportExport_20160127_final_mj"].copy()
unique_trip_id_df = unique_trip_id_df.groupby(
    ["agency_raw_name", "trip_id"])["route_id"].count().reset_index().drop(["route_id"], axis = 1)
unique_trip_id_df["trip_id_original"] = unique_trip_id_df["trip_id"]
unique_trip_id_df["trip_id"] = range(1,  len(unique_trip_id_df) + 1)

unique_shape_id_df = all_trips_df[
    all_trips_df.agency_raw_name != "commuteDOTorg_GTFSImportExport_20160127_final_mj"].copy()
unique_shape_id_df = unique_shape_id_df.groupby(
    ["agency_raw_name", "shape_id"])["trip_id"].count().reset_index().drop(["trip_id"], axis = 1)
unique_shape_id_df["shape_id_original"] = unique_shape_id_df["shape_id"]
unique_shape_id_df["shape_id"] = range(1,  len(unique_shape_id_df) + 1)

unique_stop_id_df = all_stops_df[
    all_stops_df.agency_raw_name != "commuteDOTorg_GTFSImportExport_20160127_final_mj"].copy()
unique_stop_id_df = unique_stop_id_df.groupby(
    ["agency_raw_name", "stop_id"])["stop_lat"].count().reset_index().drop(["stop_lat"], axis = 1)
unique_stop_id_df["stop_id_original"] = unique_stop_id_df["stop_id"]
unique_stop_id_df["stop_id"] = range(1,  len(unique_stop_id_df) + 1)

## caltrain shuttle June 11th, 2021
# appending caltrain data without renumbering the existing transit

cs_unique_route_id_df = all_routes_df[
    all_routes_df.agency_raw_name == "commuteDOTorg_GTFSImportExport_20160127_final_mj"].copy()
cs_unique_route_id_df = cs_unique_route_id_df.groupby(
    ["agency_raw_name", "route_id"])["agency_id"].count().reset_index().drop(["agency_id"], axis = 1)
cs_unique_route_id_df["route_id_original"] = cs_unique_route_id_df["route_id"]
cs_unique_route_id_df["route_id"] = range(1 + max(unique_route_id_df.route_id),  
                                          len(cs_unique_route_id_df) + 1 + max(unique_route_id_df.route_id))

unique_route_id_df = pd.concat([unique_route_id_df, cs_unique_route_id_df], sort = False, ignore_index = True)

cs_unique_trip_id_df = all_trips_df[
    all_trips_df.agency_raw_name == "commuteDOTorg_GTFSImportExport_20160127_final_mj"].copy()
cs_unique_trip_id_df = cs_unique_trip_id_df.groupby(
    ["agency_raw_name", "trip_id"])["route_id"].count().reset_index().drop(["route_id"], axis = 1)
cs_unique_trip_id_df["trip_id_original"] = cs_unique_trip_id_df["trip_id"]
cs_unique_trip_id_df["trip_id"] = range(1 + max(unique_trip_id_df.trip_id),  
                                        len(cs_unique_trip_id_df) + 1 + max(unique_trip_id_df.trip_id))

unique_trip_id_df = pd.concat([unique_trip_id_df, cs_unique_trip_id_df], sort = False, ignore_index = True)

cs_unique_shape_id_df = all_trips_df[
    all_trips_df.agency_raw_name == "commuteDOTorg_GTFSImportExport_20160127_final_mj"].copy()
cs_unique_shape_id_df = cs_unique_shape_id_df.groupby(
    ["agency_raw_name", "shape_id"])["trip_id"].count().reset_index().drop(["trip_id"], axis = 1)
cs_unique_shape_id_df["shape_id_original"] = cs_unique_shape_id_df["shape_id"]
cs_unique_shape_id_df["shape_id"] = range(1 + max(unique_shape_id_df.shape_id),  
                                          len(cs_unique_shape_id_df) + 1 + max(unique_shape_id_df.shape_id))

unique_shape_id_df = pd.concat([unique_shape_id_df, cs_unique_shape_id_df], sort = False, ignore_index = True)

cs_unique_stop_id_df = all_stops_df[
    all_stops_df.agency_raw_name == "commuteDOTorg_GTFSImportExport_20160127_final_mj"].copy()
cs_unique_stop_id_df = cs_unique_stop_id_df.groupby(
    ["agency_raw_name", "stop_id"])["stop_lat"].count().reset_index().drop(["stop_lat"], axis = 1)
cs_unique_stop_id_df["stop_id_original"] = cs_unique_stop_id_df["stop_id"]
cs_unique_stop_id_df["stop_id"] = range(1 + max(unique_stop_id_df.stop_id),  
                                        len(cs_unique_stop_id_df) + 1 + max(unique_stop_id_df.stop_id))

unique_stop_id_df = pd.concat([unique_stop_id_df, cs_unique_stop_id_df], sort = False, ignore_index = True)

# %%
# merge unique shape id and stio id back to aggregated gtfs data

all_routes_df = pd.merge(
    all_routes_df.rename(columns = {"route_id" : "route_id_original"}),
    unique_route_id_df,
    how = "left",
    on = ["agency_raw_name", "route_id_original"]
)

all_trips_df = pd.merge(
    all_trips_df.rename(columns = {"route_id" : "route_id_original", "trip_id" : "trip_id_original",
                                 "shape_id" : "shape_id_original"}),
    unique_route_id_df,
    how = "left",
    on = ["agency_raw_name", "route_id_original"]
)
all_trips_df = pd.merge(
    all_trips_df,
    unique_trip_id_df,
    how = "left",
    on = ["agency_raw_name", "trip_id_original"]
)
all_trips_df = pd.merge(
    all_trips_df,
    unique_shape_id_df,
    how = "left",
    on = ["agency_raw_name", "shape_id_original"]
)

all_stops_df = pd.merge(
    all_stops_df.rename(columns = {"stop_id" : "stop_id_original"}),
    unique_stop_id_df,
    how = "left",
    on = ["agency_raw_name", "stop_id_original"]
)

all_shapes_df = pd.merge(
    all_shapes_df.rename(columns = {"shape_id" : "shape_id_original"}),
    unique_shape_id_df,
    how = "left",
    on = ["agency_raw_name", "shape_id_original"]
)


all_stop_times_df = pd.merge(
    all_stop_times_df.rename(columns = {"trip_id" : "trip_id_original", "stop_id" : "stop_id_original"}),
    unique_trip_id_df,
    how = "left",
    on = ["agency_raw_name", "trip_id_original"]
)
all_stop_times_df = pd.merge(
    all_stop_times_df,
    unique_stop_id_df,
    how = "left",
    on = ["agency_raw_name", "stop_id_original"]
)

all_fare_rules_df["route_id"] = all_fare_rules_df["route_id"].astype(str)
all_fare_rules_df = pd.merge(
    all_fare_rules_df.rename(columns = {"route_id" : "route_id_original"}),
    unique_route_id_df,
    how = "left",
    on = ["agency_raw_name", "route_id_original"]
)

# %%
# examine and export
print('all_routes_df field: \n{}'.format(all_routes_df.columns))
all_routes_df.to_csv(os.path.join(output_data_gtfs_dir,'routes.txt'), index = False, sep = ',')

print('all_trips_df field: \n{}'.format(all_trips_df.columns))
all_trips_df.to_csv(os.path.join(output_data_gtfs_dir,'trips.txt'), index = False, sep = ',')

print('all_stops_df fields: \n{}'.format(all_stops_df.columns))
all_stops_df.to_csv(os.path.join(output_data_gtfs_dir,'stops.txt'), index = False, sep = ',')

print('all_shapes_df fields: \n{}'.format(all_shapes_df.columns))
all_shapes_df.to_csv(os.path.join(output_data_gtfs_dir,'shapes.txt'), index = False, sep = ',')

print('all_stop_times_df fields: \n{}'.format(all_stop_times_df.columns))
all_stop_times_df.to_csv(os.path.join(output_data_gtfs_dir,'stop_times.txt'), index = False, sep = ',')

print('all_agency_df fields: \n{}'.format(all_agency_df.columns))
all_agency_df.to_csv(os.path.join(output_data_gtfs_dir,'agency.txt'), index = False, sep = ',')

print('all_fare_attributes_df fields: \n{}'.format(all_fare_attributes_df.columns))
all_fare_attributes_df.to_csv(os.path.join(output_data_gtfs_dir,'fare_attributes.txt'), index = False, sep = ',')

print('all_fare_rules_df fields: \n{}'.format(all_fare_rules_df.columns))
all_fare_rules_df.to_csv(os.path.join(output_data_gtfs_dir,'fare_rules.txt'), index = False, sep = ',')
# Out:
# all_routes_df field:
# Index(['route_id_original', 'agency_id', 'route_short_name', 'route_long_name',
#        'route_type', 'route_color', 'route_text_color', 'agency_raw_name',
#        'route_desc', 'route_url', 'route_sort_order', 'min_headway_minutes',
#        'eligibility_restricted', 'continuous_pickup', 'continuous_drop_off',
#        'route_id'],
#       dtype='object')
# all_trips_df field:
# Index(['route_id_original', 'service_id', 'trip_id_original', 'trip_headsign',
#        'direction_id', 'block_id', 'trip_short_name', 'agency_raw_name',
#        'shape_id_original', 'wheelchair_accessible', 'bikes_allowed',
#        'original_trip_id', 'trip_bikes_allowed', 'trip_type',
#        'drt_max_travel_time', 'drt_avg_travel_time', 'drt_advance_book_min',
#        'drt_pickup_message', 'drt_drop_off_message',
#        'continuous_pickup_message', 'continuous_drop_off_message', 'route_id',
#        'trip_id', 'shape_id'],
#       dtype='object')
# all_stops_df fields:
# Index(['stop_id_original', 'stop_name', 'stop_lat', 'stop_lon', 'zone_id',
#        'agency_raw_name', 'stop_code', 'location_type', 'parent_station',
#        'stop_desc', 'stop_url', 'stop_timezone', 'wheelchair_boarding',
#        'platform_code', 'position', 'direction', '* used by routes',
#        'stop_id'],
#       dtype='object')
# all_shapes_df fields:
# Index(['shape_id_original', 'shape_pt_lat', 'shape_pt_lon',
#        'shape_pt_sequence', 'agency_raw_name', 'shape_dist_traveled',
#        'shape_id'],
#       dtype='object')
# all_stop_times_df fields:
# Index(['trip_id_original', 'arrival_time', 'departure_time',
#        'stop_id_original', 'stop_sequence', 'agency_raw_name', 'pickup_type',
#        'drop_off_type', 'stop_headsign', 'shape_dist_traveled', 'timepoint',
#        'last_stop_on_trip', 'start_service_area_id', 'end_service_area_id',
#        'start_service_area_radius', 'end_service_area_radius',
#        'continuous_pickup', 'continuous_drop_off', 'pickup_area_id',
#        'drop_off_area_id', 'pickup_service_area_radius',
#        'drop_off_service_area_radius', '*shape_id', '*seq#', '*Dist(m)',
#        '*Comment', 'trip_id', 'stop_id'],
#       dtype='object')
# all_agency_df fields:
# Index(['agency_id', 'agency_name', 'agency_url', 'agency_timezone',
#        'agency_lang', 'agency_phone', 'agency_raw_name', 'agency_fare_url',
#        'agency_email'],
#       dtype='object')
# all_fare_attributes_df fields:
# Index(['fare_id', 'price', 'currency_type', 'payment_method', 'transfers',
#        'transfer_duration', 'agency_raw_name', 'agency_id'],
#       dtype='object')
# all_fare_rules_df fields:
# Index(['fare_id', 'route_id_original', 'agency_raw_name', 'origin_id',
#        'destination_id', 'contains_id', 'route_id'],
#       dtype='object')

# %%
# drop fields not needed
all_trips_df.drop(["route_id_original", "trip_id_original", "shape_id_original"], axis = 1, inplace = True)
all_stops_df.drop(["stop_id_original"], axis = 1, inplace = True)
all_shapes_df.drop(["agency_raw_name", "shape_id_original"], axis = 1, inplace = True)
all_stop_times_df.drop(["agency_raw_name", "trip_id_original", "stop_id_original"], axis = 1, inplace = True)

# %% [markdown]
# # Processing

# %% [markdown]
# ### get representative trip for each route by direction

# %%
# pick representatives for each route by direction, with most number of trip 
def get_representative_trip_for_route(trips, stop_times):
    
    """
    get the representative trips for each route, by direction, tod
    
    """
    
    print('getting representative trip...')
    
    # get the first stop of each trip to determine the time period for each trip
    # process time
    stop_times_df = stop_times.copy()
    stop_times_df['arrival_h'] = pd.to_datetime(stop_times_df['arrival_time'], unit = 's').dt.hour
    stop_times_df['arrival_m'] = pd.to_datetime(stop_times_df['arrival_time'], unit = 's').dt.minute
    stop_times_df['departure_h'] = pd.to_datetime(stop_times_df['departure_time'], unit = 's').dt.hour
    stop_times_df['departure_m'] = pd.to_datetime(stop_times_df['departure_time'], unit = 's').dt.minute
    
    # according to the gtfs reference, the stop sequence does not have to be consecutive, but has to always increase
    # so we can get the fisrt stop by the smallest stop sequence on the trip
    stop_times_df.sort_values(by = ["trip_id", "stop_sequence"], 
                              ascending = True, 
                              inplace = True)
    first_stop_df = stop_times_df.drop_duplicates(subset = ["trip_id"])
    
    ## identify peak, offpeak trips, based on the arrival time of first stop
    trip_df = trips.copy()
    trip_df = pd.merge(trip_df, 
                       first_stop_df,
                       how = 'left',
                       on = 'trip_id')
    
    ## AM: 6-10am, MD: 10am-3pm, PM: 3-7pm, NT 7pm-3am, EA 3-6am
    trip_df['tod'] = np.where((trip_df['arrival_h'] >= 6) & (trip_df['arrival_h'] < 10),
                                 'AM',
                                 np.where((trip_df['arrival_h'] >= 10) & (trip_df['arrival_h'] < 15),
                                     'MD',
                                    np.where((trip_df['arrival_h'] >= 15) & (trip_df['arrival_h'] < 19),
                                         'PM',
                                        np.where((trip_df['arrival_h'] >= 3) & (trip_df['arrival_h'] < 6),
                                             'EA',
                                                 'NT'))))
  
    # calculate frequency for EA and NT period using 5-6am, and 7-10pm
    trip_EA_NT_df = trip_df.copy()
    trip_EA_NT_df["tod"] = np.where((trip_df['arrival_h'] >= 5) & (trip_df['arrival_h'] < 6),
                                  "EA",
                                  np.where((trip_df['arrival_h'] >= 19) & (trip_df['arrival_h'] < 22),
                                          "NT",
                                          "NA")
                                  )
    
    # get the most frequent trip for each route, by direction, by time of day
    ## trips share the same shape_id is considered being the same
    ## first get the trip count for each shape_id
#     trip_freq_df = trip_df.groupby(['route_id', 'tod', 'direction_id', 'shape_id'])['trip_id'].count().\
#                             to_frame().\
#                             drop(index = 'other', level = 1).\
#                             reset_index()
    trip_freq_df = trip_df.groupby(['route_id', 'tod', 'direction_id', 'shape_id'])['trip_id'].count()

    ## then choose the most frequent shape_id for each route, frequency use the total number of trips
    def agg(x):
        m = x.shape_id.iloc[np.argmax(x.trip_id.values)]
        return pd.Series({'trip_num' : x.trip_id.sum(), 'shape_id' : m})
   
    trip_freq_df = trip_freq_df.reset_index().groupby(['route_id', 'tod', 'direction_id']).apply(agg)
    
    # retain the complete trip info of represent trip only
    trip_df = pd.merge(trip_df, trip_freq_df.reset_index(),
                      how = 'inner',
                      on = ['route_id', 'tod', 'direction_id', 'shape_id']).\
                drop_duplicates(['route_id', 'direction_id', 'tod'])
        
    trip_EA_NT_df = pd.merge(trip_EA_NT_df, trip_freq_df.reset_index(),
                      how = 'inner',
                      on = ['route_id', 'tod', 'direction_id', 'shape_id'])
    
    trip_EA_NT_df = trip_EA_NT_df[trip_EA_NT_df.tod.isin(["EA", "NT"])].groupby(
        ["route_id", "tod", "direction_id", "shape_id"])["trip_id"].count().reset_index()
    
    trip_EA_NT_df.rename(columns = {"trip_id" : "trip_num"}, inplace = True)
    
    trip_df = pd.merge(
        trip_df,
        trip_EA_NT_df,
        how = "left",
        on = ["route_id", "tod", "direction_id", "shape_id"]
    )
    
    trip_df["trip_num"] = np.where(trip_df.trip_num_y.isnull(),
                                  trip_df.trip_num_x,
                                  trip_df.trip_num_y)
    
    return trip_df

# %%
# code departure/arrival hour and minute
stop_times_df = all_stop_times_df.copy()
stop_times_df['arrival_h'] = pd.to_datetime(stop_times_df['arrival_time'], unit = 's').dt.hour
stop_times_df['arrival_m'] = pd.to_datetime(stop_times_df['arrival_time'], unit = 's').dt.minute
stop_times_df['departure_h'] = pd.to_datetime(stop_times_df['departure_time'], unit = 's').dt.hour
stop_times_df['departure_m'] = pd.to_datetime(stop_times_df['departure_time'], unit = 's').dt.minute

# sort in order to get first stop of each trip
stop_times_df.sort_values(by = ["trip_id", "stop_sequence"], 
                          ascending = True, 
                          inplace = True)
first_stop_df = stop_times_df.drop_duplicates(subset = ["trip_id"])

# %%
# code type of day
trip_df = all_trips_df.copy()
trip_df = pd.merge(trip_df, 
                   first_stop_df,
                   how = 'left',
                   on = 'trip_id')

trip_df['tod'] = np.where((trip_df['arrival_h'] >= 6) & (trip_df['arrival_h'] < 10),
                                 'AM',
                                 np.where((trip_df['arrival_h'] >= 10) & (trip_df['arrival_h'] < 15),
                                     'MD',
                                    np.where((trip_df['arrival_h'] >= 15) & (trip_df['arrival_h'] < 19),
                                         'PM',
                                        np.where((trip_df['arrival_h'] >= 3) & (trip_df['arrival_h'] < 6),
                                             'EA',
                                                 'NT'))))

# %%
# %%time
# obtain the representative trip of each route

trip_df = get_representative_trip_for_route(all_trips_df, all_stop_times_df)
# Out:
# getting representative trip...
# Wall time: 26.2 s

# %% [markdown]
# ### map gtfs stops to roadway nodes

# %%
def snap_stop_to_node(stops, node_gdf):
    
    """
    map gtfs stops to roadway nodes
    
    Parameters:
    ------------
    feed
    drive nodes
    
    return
    ------------
    stops with drive nodes id
    """
    
    print('snapping gtfs stops to roadway node osmid...')
    
    node_non_c_gdf = node_gdf.copy()
    node_non_c_gdf = node_non_c_gdf.to_crs({'init' : 'epsg:26915'})
    node_non_c_gdf['X'] = node_non_c_gdf.geometry.map(lambda g:g.x)
    node_non_c_gdf['Y'] = node_non_c_gdf.geometry.map(lambda g:g.y)
    inventory_node_ref = node_non_c_gdf[['X', 'Y']].values
    tree = cKDTree(inventory_node_ref)
    
    stop_df = stops.copy()
    stop_df['geometry'] = [Point(xy) for xy in zip(stop_df['stop_lon'], stop_df['stop_lat'])]
    stop_df = gpd.GeoDataFrame(stop_df)
    stop_df.crs = {'init' : 'epsg:4326'}
    stop_df = stop_df.to_crs({'init' : 'epsg:26915'})
    stop_df['X'] = stop_df['geometry'].apply(lambda p: p.x)
    stop_df['Y'] = stop_df['geometry'].apply(lambda p: p.y)
   
    for i in range(len(stop_df)):
        point = stop_df.iloc[i][['X', 'Y']].values
        dd, ii = tree.query(point, k = 1)
        add_snap_gdf = gpd.GeoDataFrame(node_non_c_gdf.iloc[ii]).transpose().reset_index(drop = True)
        add_snap_gdf['stop_id'] = stop_df.iloc[i]['stop_id']
        if i == 0:
            stop_to_node_gdf = add_snap_gdf.copy()
        else:
            stop_to_node_gdf = stop_to_node_gdf.append(add_snap_gdf, ignore_index=True, sort=False)
    
    stop_df.drop(['X','Y'], axis = 1, inplace = True)
    stop_to_node_gdf = pd.merge(stop_df, stop_to_node_gdf, how = 'left', on = 'stop_id')
    
    column_list = stops.columns.values.tolist() + ['osm_node_id', 'shst_node_id', "model_node_id"]
    
    return stop_to_node_gdf[column_list]

# %%
# get rid of motorway nodes. 
# Motorway and motorway are restricted-access freeway and freeway ramps, shouldn't have transit stops
non_motorway_links_df = drive_link_df[~drive_link_df.roadway.isin(["motorway", "motorway_link"])].copy()

nodes_for_stops_df = drive_node_gdf[drive_node_gdf.model_node_id.isin(non_motorway_links_df.A.tolist() + 
                                                                     non_motorway_links_df.B.tolist())].copy()

# %%
# %%time
stop_df = snap_stop_to_node(all_stops_df, nodes_for_stops_df)
# Out:
# snapping gtfs stops to roadway node osmid...
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# Wall time: 7min 7s

# %%
# examine the data
stop_df.info()
stop_df.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22402 entries, 0 to 22401
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   stop_name            22402 non-null  object
#  1   stop_lat             22402 non-null  float64
#  2   stop_lon             22402 non-null  float64
#  3   zone_id              12516 non-null  object
#  4   agency_raw_name      22402 non-null  object
#  5   stop_code            15737 non-null  object
#  6   location_type        5807 non-null   float64
#  7   parent_station       620 non-null    object
#  8   stop_desc            4492 non-null   object
#  9   stop_url             4168 non-null   object
#  10  stop_timezone        137 non-null    object
#  11  wheelchair_boarding  388 non-null    float64
#  12  platform_code        58 non-null     object
#  13  position             0 non-null      object
#  14  direction            0 non-null      object
#  15  * used by routes     125 non-null    object
#  16  stop_id              22402 non-null  int32
#  17  osm_node_id          22402 non-null  object
#  18  shst_node_id         22402 non-null  object
#  19  model_node_id        22402 non-null  object
# dtypes: float64(4), int32(1), object(15)
# memory usage: 3.5+ MB
#                      stop_name   stop_lat    stop_lon zone_id agency_raw_name  \
# 0          FMT FREMONT STATION  37.558559 -122.007598   55644   ACE_2017_3_20
# 1    GAC GREAT AMERICA STATION  37.406398 -121.966671   55645   ACE_2017_3_20
# 2  LAT LATHROP/MANTECA STATION  37.797908 -121.263664   55449   ACE_2017_3_20
#
#   stop_code  location_type parent_station stop_desc stop_url stop_timezone  \
# 0       NaN            NaN            NaN       NaN      NaN           NaN
# 1       NaN            NaN            NaN       NaN      NaN           NaN
# 2       NaN            NaN            NaN       NaN      NaN           NaN
#
#    wheelchair_boarding platform_code position direction * used by routes  \
# 0                  NaN           NaN      NaN       NaN              NaN
# 1                  NaN           NaN      NaN       NaN              NaN
# 2                  NaN           NaN      NaN       NaN              NaN
#
#    stop_id osm_node_id                      shst_node_id model_node_id
# 0        7    53026824  0d6e8c51d77d4cbf23cf1150a4c73d22       2582218
# 1        8   312418202  4cfcb17d2cf046c6f55ce459194ebc0e       2019349
# 2        2  1832575219  584a0ca93779f09a42595e3d094b8151       2551601

# %% [markdown]
# ### route bus on roadway via osmnx routing

# %%
def route_bus_link_osmnx(roadway_gdf, node_gdf, G, stop_times, routes, trip, stop):
    
    """
    route bus with OSMNX routing
    
    Parameters
    ----------
    drive link
    drive node
    drive graph
    feed
    trip 
    stop
    
    return
    ----------
    dataframe of drive links bus trips traverses
    list of trips that could not be routed by OSMNX
    """
    
    trip_df = trip.copy()
    stop_df = stop.copy()
    stop_time_df = stop_times.copy()
    
    chained_stop_df = stop_time_df[stop_time_df['trip_id'].isin(trip_df.trip_id.tolist())]
    chained_stop_to_node_df = pd.merge(chained_stop_df, 
                                       stop_df,
                                        how = 'left',
                                        on = 'stop_id')
    
    print('routing bus on roadway network with osmnx...')
    
    #osm_node_dict = dict(zip(node_gdf.osmid, node_gdf.N))
    
    trip_df = pd.merge(trip_df, routes, how = 'left', on = 'route_id')
    bus_trip_df = trip_df[trip_df['route_type'] == 3]
    
    # to track trips that osmnx failed to route
    broken_shape_trip_list = []
    
    # output dataframe for osmnx success
    trip_link_shape_df = pd.DataFrame()
    
    # loop through for bus trips
    for trip_id in bus_trip_df.trip_id.unique():
        
        # get the stops on the trip
        trip_stop_df = chained_stop_to_node_df[chained_stop_to_node_df['trip_id'] == trip_id].copy()
        
        trip_stop_df.sort_values(by = ["stop_sequence"], inplace = True)

        try:
            print("routing" + str(trip_id))
            for s in range(len(trip_stop_df)-1):
                # from stop node OSM id
                closest_node_to_stop1 = int(trip_stop_df.osm_node_id.iloc[s])
                
                # to stop node OSM id
                closest_node_to_stop2 = int(trip_stop_df.osm_node_id.iloc[s+1])
                
                # osmnx routing btw from and to stops, return the list of nodes
                node_osmid_list = nx.shortest_path(G, closest_node_to_stop1, closest_node_to_stop2, weight = "length")
                
                # get the links
                if len(node_osmid_list) > 1:
                    osm_link_gdf = pd.DataFrame({'u' : node_osmid_list[:len(node_osmid_list)-1], 
                                            'v' : node_osmid_list[1:len(node_osmid_list)],
                                            'trip_id' : trip_id},
                                               )
                else:
                    continue
                
                trip_link_shape_df = trip_link_shape_df.append(osm_link_gdf, ignore_index = True, sort = False)                

        except:
            broken_shape_trip_list = broken_shape_trip_list + [trip_id]
            print('  warning: cannot route bus: ' + str(trip_id))
            continue      
        
    trip_link_shape_df = pd.merge(trip_link_shape_df, trip_df[['trip_id', 'shape_id']], how = 'left', on = 'trip_id')

    trip_link_shape_df = pd.merge(trip_link_shape_df,
                                  drive_link_df[["u", "v", "wayId", "shstReferenceId", "shstGeometryId", "A", "B"]].\
                                      drop_duplicates(subset = ["u", "v"]),
                                  how = "left",
                                  on = ["u", "v"])
    
    return trip_link_shape_df, broken_shape_trip_list

# %%
# %%time
# lmz 25min
bus_osmnx_link_shape_df, bus_osmnx_broken_trip_list = route_bus_link_osmnx(drive_link_df, 
                                                                           drive_node_gdf, 
                                                                           G_drive, 
                                                                           all_stop_times_df,
                                                                           all_routes_df,
                                                                           trip_df, 
                                                                           stop_df)
# Out:
# routing bus on roadway network with osmnx...
# routing9
# routing10
# routing11
# routing20
# routing21
# routing22
# routing23
# routing31
# routing42
# routing44
# routing45
# routing46
# routing48
# routing49
# routing50
# routing51
# routing52
# routing53
# routing54
# routing55
# routing57
# routing58
# routing59
# routing60
# routing61
# routing63
# routing64
# routing65
# routing66
# routing67
# routing69
# routing74
# routing75
# routing78
# routing80
# routing81
# routing83
# routing91
# routing92
# routing94
# routing95
# routing96
# routing97
# routing104
# routing106
# routing108
# routing114
# routing116
# routing120
# routing126
# routing127
# routing128
# routing139
# routing144
# routing149
# routing153
# routing183
# routing184
# routing188
# routing193
# routing197
# routing199
# routing207
# routing217
# routing225
# routing228
# routing235
# routing245
# routing253
# routing257
# routing277
# routing302
# routing322
# routing324
# routing344
# routing369
# routing389
# routing392
# routing393
# routing395
# routing396
# routing399
# routing400
# routing408
# routing409
# routing443
# routing444
# routing447
# routing450
# routing459
# routing460
# routing462
# routing480
# routing481
# routing496
# routing507
# routing516
# routing522
# routing529
# routing533
# routing544
# routing547
# routing560
# routing569
# routing581
# routing582
# routing590
# routing600
# routing608
# routing614
# routing615
# routing623
# routing633
# routing641
# routing648
# routing652
# routing659
# routing661
# routing664
# routing671
# routing677
# routing722
# routing723
# routing731
# routing736
# routing743
# routing745
# routing754
# routing756
# routing759
# routing770
# routing807
# routing811
# routing812
# routing821
# routing822
# routing827
# routing828
# routing866
# routing867
# routing875
# routing885
# routing893
# routing894
# routing896
# routing904
# routing914
# routing922
# routing928
# routing929
# routing937
# routing947
# routing955
# routing963
# routing973
# routing981
# routing982
# routing983
# routing987
# routing989
# routing1011
# routing1012
# routing1013
# routing1016
# routing1019
# routing1021
# routing1022
# routing1023
# routing1036
# routing1047
# routing1071
# routing1077
# routing1087
# routing1095
# routing1104
# routing1106
# routing1115
# routing1120
# routing1121
# routing1150
# routing1151
# routing1158
# routing1159
# routing1160
# routing1161
# routing1163
# routing1164
# routing1167
# routing1168
# routing1218
# routing1220
# routing1222
# routing1230
# routing1240
# routing1250
# routing1256
# routing1264
# routing1274
# routing1283
# routing1284
# routing1286
# routing1287
# routing1297
# routing1298
# routing1299
# routing1300
# routing1302
# routing1303
# routing1306
# routing1308
# routing1309
# routing1310
# routing1433
# routing1434
# routing1435
# routing1436
# routing1437
# routing1438
# routing1439
# routing1440
# routing1443
# routing1445
# routing1446
# routing1447
# routing1448
# routing1449
# routing1450
# routing1453
# routing1461
# routing1472
# routing1475
# routing1494
# routing1579
# routing1580
# routing1581
# routing1582
# routing1590
# routing1591
# routing1600
# routing1601
# routing1620
# routing1621
# routing1780
# routing1782
# routing1786
# routing1787
# routing1798
# routing1799
# routing1816
# routing1817
# routing1828
# routing1940
# routing1943
# routing1944
# routing1947
# routing1948
# routing1949
# routing1951
# routing1953
# routing1954
# routing1956
# routing1958
# routing1959
# routing1962
# routing1968
# routing1970
# routing1971
# routing1973
# routing1974
# routing1976
# routing1980
# routing1981
# routing1983
# routing1985
# routing1986
# routing1987
# routing1988
# routing1989
# routing1990
# routing1991
# routing1992
# routing1993
# routing1994
# routing1995
# routing1996
# routing1997
# routing1998
# routing1999
# routing2002
# routing2003
# routing2004
# routing2005
# routing2008
# routing2009
# routing2011
# routing2014
# routing2015
# routing2016
# routing2017
# routing2018
# routing2019
# routing2023
# routing2024
# routing2025
# routing2030
# routing2035
# routing2036
# routing2044
# routing2048
# routing2049
# routing2050
# routing2051
# routing2053
# routing2059
# routing2060
# routing2063
# routing2064
# routing2065
# routing2077
# routing2079
# routing2080
# routing2082
# routing2084
# routing2085
# routing2090
# routing2093
# routing2097
# routing2104
# routing2105
# routing2108
# routing2120
# routing2121
# routing2122
# routing2123
# routing2140
# routing2160
# routing2176
# routing2180
# routing2198
# routing2218
# routing2233
# routing2237
# routing2238
# routing2244
# routing2249
# routing2250
# routing2251
# routing2253
# routing2254
# routing2255
# routing2259
# routing2260
# routing2261
# routing2265
# routing2270
# routing2274
# routing2275
# routing2279
# routing2284
# routing2288
# routing2289
# routing2290
# routing2294
# routing2298
# routing2299
# routing2300
# routing2301
# routing2302
# routing2303
# routing2304
# routing2306
# routing2307
# routing2312
# routing2316
# routing2331
# routing2332
# routing2333
# routing2335
# routing2336
# routing2346
# routing2354
# routing2366
# routing2377
# routing2379
# routing2382
# routing2384
# routing2389
# routing2393
# routing2397
# routing2402
# routing2406
# routing2411
# routing2421
# routing2429
# routing2436
# routing2446
# routing2457
# routing2458
# routing2474
# routing2494
# routing2510
# routing2525
# routing2540
# routing2559
# routing2576
# routing2591
# routing2595
# routing2598
# routing2605
# routing2607
# routing2617
# routing2627
# routing2643
# routing2645
# routing2646
# routing2648
# routing2652
# routing2655
# routing2664
# routing2665
# routing2667
# routing2671
# routing2674
# routing2677
# routing2680
# routing2683
# routing2703
# routing2712
# routing2731
# routing2741
# routing2747
# routing2757
# routing2765
# routing2772
# routing2778
# routing2788
# routing2796
# routing2804
# routing2805
# routing2811
# routing2816
# routing2836
# routing2840
# routing2863
# routing2905
# routing2929
# routing2958
# routing2967
# routing3001
# routing3002
# routing3003
# routing3004
# routing3014
# routing3024
# routing3034
# routing3040
# routing3050
# routing3060
# routing3075
# routing3083
# routing3086
# routing3088
# routing3123
# routing3139
# routing3158
# routing3159
# routing3174
# routing3194
# routing3210
# routing3229
# routing3231
# routing3243
# routing3258
# routing3313
# routing3326
# routing3327
# routing3339
# routing3354
# routing3406
# routing3427
# routing3429
# routing3433
# routing3435
# routing3451
# routing3463
# routing3477
# routing3478
# routing3480
# routing3481
# routing3482
# routing3485
# routing3486
# routing3490
# routing3491
# routing3494
# routing3495
# routing3548
# routing3556
# routing3557
# routing3558
# routing3561
# routing3562
# routing3566
# routing3567
# routing3570
# routing3571
# routing3591
# routing3614
# routing3615
# routing3647
# routing3655
# routing3656
# routing3663
# routing3664
# routing3673
# routing3674
# routing3681
# routing3694
# routing3700
# routing3701
# routing3702
# routing3703
# routing3709
# routing3710
# routing3711
# routing3712
# routing3719
# routing3720
# routing3721
# routing3722
# routing3727
# routing3728
# routing3729
# routing3755
# routing3756
# routing3787
# routing3788
# routing3789
# routing3792
# routing3793
# routing3797
# routing3798
# routing3799
# routing3800
# routing3801
# routing3802
# routing3803
# routing3815
# routing3829
# routing3845
# routing3846
# routing3847
# routing3896
# routing3899
# routing3910
# routing4024
# routing4025
# routing4026
# routing4030
# routing4035
# routing4039
# routing4040
# routing4041
# routing4045
# routing4050
# routing4054
# routing4055
# routing4057
# routing4064
# routing4070
# routing4075
# routing4077
# routing4078
# routing4080
# routing4090
# routing4097
# routing4101
# routing4102
# routing4105
# routing4106
# routing4107
# routing4109
# routing4111
# routing4112
# routing4113
# routing4114
# routing4115
# routing4116
# routing4120
# routing4123
# routing4125
# routing4133
# routing4143
# routing4151
# routing4159
# routing4160
# routing4168
# routing4178
# routing4189
# routing4197
# routing4207
# routing4215
# routing4224
# routing4231
# routing4241
# routing4249
# routing4258
# routing4259
# routing4264
# routing4265
# routing4269
# routing4272
# routing4284
# routing4299
# routing4311
# routing4321
# routing4323
# routing4335
# routing4350
# routing4362
# routing4373
# routing4374
# routing4378
# routing4383
# routing4386
# routing4387
# routing4391
# routing4396
# routing4400
# routing4402
# routing4405
# routing4411
# routing4414
# routing4415
# routing4419
# routing4424
# routing4428
# routing4430
# routing4433
# routing4434
# routing4438
# routing4439
# routing4443
# routing4447
# routing4448
# routing4449
# routing4453
# routing4457
# routing4461
# routing4465
# routing4470
# routing4474
# routing4476
# routing4477
# routing4479
# routing4490
# routing4492
# routing4493
# routing4494
# routing4498
# routing4503
# routing4507
# routing4509
# routing4510
# routing4514
# routing4519
# routing4523
# routing4524
# routing4525
# routing4526
# routing4530
# routing4535
# routing4539
# routing4541
# routing4545
# routing4550
# routing4554
# routing4555
# routing4559
# routing4564
# routing4568
# routing4573
# routing4575
# routing4578
# routing4579
# routing4580
# routing4584
# routing4589
# routing4596
# routing4599
# routing4602
# routing4603
# routing4608
# routing4636
# routing4637
# routing4638
# routing4639
# routing4640
# routing4644
# routing4645
# routing4651
# routing4652
# routing4654
# routing4655
# routing4662
# routing4672
# routing4680
# routing4685
# routing4693
# routing4703
# routing4711
# routing4716
# routing4724
# routing4734
# routing4742
# routing4748
# routing4754
# routing4764
# routing4772
# routing4779
# routing4783
# routing4788
# routing4792
# routing4793
# routing4797
# routing4802
# routing4806
# routing4807
# routing4811
# routing4816
# routing4820
# routing4822
# routing4825
# routing4830
# routing4834
# routing4836
# routing4837
# routing4841
# routing4845
# routing4849
# routing4855
# routing4859
# routing4864
# routing4868
# routing4870
# routing4874
# routing4879
# routing4883
# routing4887
# routing4888
# routing4889
# routing4890
# routing4892
# routing4893
# routing4895
# routing4896
# routing4898
# routing4899
# routing4901
# routing5003
# routing5004
# routing5005
# routing5019
# routing5020
# routing5026
# routing5032
# routing5048
# routing5052
# routing5057
# routing5061
# routing5062
# routing5065
# routing5070
# routing5074
# routing5075
# routing5077
# routing5097
# routing5122
# routing5142
# routing5160
# routing5185
# routing5205
# routing5206
# routing5210
# routing5224
# routing5236
# routing5237
# routing5257
# routing5271
# routing5287
# routing5304
# routing5316
# routing5333
# routing5334
# routing5335
# routing5341
# routing5342
# routing5345
# routing5346
# routing5348
# routing5349
# routing5351
# routing5352
# routing5445
# routing5446
# routing5464
# routing5465
# routing5469
# routing5473
# routing5478
# routing5479
# routing5480
# routing5485
# routing5490
# routing5495
# routing5497
# routing5498
# routing5504
# routing5512
# routing5518
# routing5519
# routing5520
# routing5526
# routing5533
# routing5539
# routing5545
# routing5546
# routing5547
# routing5548
# routing5551
# routing5552
# routing5557
# routing5565
# routing5602
# routing5604
# routing5614
# routing5615
# routing5618
# routing5619
# routing5622
# routing5624
# routing5625
# routing5627
# routing5629
# routing5656
# routing5680
# routing5682
# routing5686
# routing5687
# routing5688
# routing5692
# routing5693
# routing5699
# routing5701
# routing5709
# routing5712
# routing5728
# routing5742
# routing5744
# routing5754
# routing5762
# routing5767
# routing7809
# routing7772
# routing7682
# routing7481
# routing7648
# routing7533
# routing7618
# routing7212
# routing7607
# routing7570
# routing7861
# routing6894
# routing7900
# routing7223
# routing7087
# routing7437
# routing7412
# routing7854
# routing6887
# routing7798
# routing7180
# routing7179
# routing7465
# routing7499
# routing7494
# routing7323
# routing7622
# routing7327
# routing7276
# routing7667
# routing7121
# routing7563
# routing7137
# routing7403
# routing6917
# routing7211
# routing7228
# routing7753
# routing7205
# routing7194
# routing7868
# routing7915
# routing7732
# routing7581
# routing6932
# routing7921
# routing6940
# routing7794
# routing7420
# routing7545
# routing7167
# routing7290
# routing7777
# routing7497
# routing7156
# routing6908
# routing7832
# routing7597
# routing7364
# routing6930
# routing7428
# routing6882
# routing7909
# routing7145
# routing7784
# routing7800
# routing7837
# routing7602
# routing7604
# routing7906
# routing7074
# routing7264
# routing7926
# routing7016
# routing7914
# routing6961
# routing7118
# routing6979
# routing7357
# routing7022
# routing7091
# routing7375
# routing7553
# routing6897
# routing7082
# routing7081
# routing7392
# routing7630
# routing7890
# routing7932
# routing7114
# routing7112
# routing6904
# routing7705
# routing7160
# routing7452
# routing7889
# routing7574
# routing7446
# routing7702
# routing7681
# routing6935
# routing7898
# routing7843
# routing7700
# routing7005
# routing7313
# routing7243
# routing7105
# routing7917
# routing6970
# routing7054
# routing7802
# routing7818
# routing7876
# routing6958
# routing7652
# routing7380
# routing7369
# routing6992
# routing7888
# routing7768
# routing7069
# routing6931
# routing7050
# routing7588
# routing7882
# routing7759
# routing7536
# routing7258
# routing6918
# routing7940
# routing7250
# routing7591
# routing7120
# routing7010
# routing7824
# routing7067
# routing7453
# routing7253
# routing7650
# routing7551
# routing7517
# routing7238
# routing7102
# routing7041
# routing7567
# routing7929
# routing7557
# routing7538
# routing7741
# routing6891
# routing7748
# routing7849
# routing7099
# routing6911
# routing6913
# routing7750
# routing7797
# routing7242
# routing7034
# routing7033
# routing7095
# routing7431
# routing7811
# routing7941
# routing7726
# routing7737
# routing7059
# routing7507
# routing7816
# routing6915
# routing7872
# routing7635
# routing7616
# routing7924
# routing7093
# routing6926
# routing7627
# routing7515
# routing7594
# routing7717
# routing7715
# routing7850
# routing7441
# routing7694
# routing7934
# routing6890
# routing7078
# routing7904
# routing7220
# routing7624
# routing7935
# routing7270
# routing7490
# routing7268
# routing7714
# routing7826
# routing7092
# routing7937
# routing7318
# routing7073
# routing7774
# routing7013
# routing7531
# routing7440
# routing7062
# routing7256
# routing7460
# routing7104
# routing7564
# routing7596
# routing8173
# routing8155
# routing8271
# routing8334
# routing8232
# routing8314
# routing8187
# routing8248
# routing8107
# routing8261
# routing8214
# routing8299
# routing8106
# routing8100
# routing8139
# routing8219
# routing8135
# routing8242
# routing8095
# routing8393
# routing8375
# routing8388
# routing8383
# routing8367
# routing8396
# routing8363
#   warning: cannot route bus: 8363
# routing8404
# routing8361
#   warning: cannot route bus: 8361
# routing8354
# routing8408
# routing8373
# routing8411
# routing8351
# routing8381
# routing8357
#   warning: cannot route bus: 8357
# routing8352
# routing8358
#   warning: cannot route bus: 8358
# routing8348
# routing8364
#   warning: cannot route bus: 8364
# routing8418
# routing8349
# routing8350
# routing8424
# routing8738
# routing8840
# routing8423
# routing8737
# routing8839
# routing8522
# routing8422
# routing8736
# routing8838
# routing8521
# routing8421
# routing8818
# routing8584
# routing8702
# routing8420
# routing8817
# routing8583
# routing8701
# routing8438
# routing8625
# routing8815
# routing8501
# routing8437
# routing8730
# routing8834
# routing8436
# routing8833
# routing8594
# routing8435
# routing8832
# routing8593
# routing8434
# routing8811
# routing8580
# routing8698
# routing8433
# routing8830
# routing8591
# routing8709
# routing8432
# routing8746
# routing8848
# routing8530
# routing8431
# routing8745
# routing8847
# routing8529
# routing8430
# routing8807
# routing8578
# routing8696
# routing8429
# routing8826
# routing8589
# routing8707
# routing8428
# routing8805
# routing8576
# routing8694
# routing8626
# routing8627
# routing8425
# routing8822
# routing8585
# routing8703
# routing8426
# routing8823
# routing8586
# routing8704
# routing8427
# routing8824
# routing8587
# routing8705
# routing8900
# routing8882
# routing8895
# routing8890
# routing8874
# routing8903
# routing8870
#   warning: cannot route bus: 8870
# routing8911
# routing8868
#   warning: cannot route bus: 8868
# routing8861
# routing8915
# routing8880
# routing8918
# routing8858
# routing8888
# routing8864
#   warning: cannot route bus: 8864
# routing8859
# routing8865
#   warning: cannot route bus: 8865
# routing8855
# routing8871
#   warning: cannot route bus: 8871
# routing8925
# routing8856
# routing8857
# routing8931
# routing9245
# routing9347
# routing8930
# routing9244
# routing9346
# routing9029
# routing8929
# routing9243
# routing9345
# routing9028
# routing8928
# routing9325
# routing9091
# routing9209
# routing8927
# routing9324
# routing9090
# routing9208
# routing8945
# routing9132
# routing9322
# routing9008
# routing8944
# routing9237
# routing9341
# routing8943
# routing9340
# routing9101
# routing8942
# routing9339
# routing9100
# routing8941
# routing9318
# routing9087
# routing9205
# routing8940
# routing9337
# routing9098
# routing9216
# routing8939
# routing9253
# routing9355
# routing9037
# routing8938
# routing9252
# routing9354
# routing9036
# routing8937
# routing9314
# routing9085
# routing9203
# routing8936
# routing9333
# routing9096
# routing9214
# routing8935
# routing9312
# routing9083
# routing9201
# routing9133
# routing9134
# routing8932
# routing9329
# routing9092
# routing9210
# routing8933
# routing9330
# routing9093
# routing9211
# routing8934
# routing9331
# routing9094
# routing9212
# routing9362
# routing9367
# routing9370
# routing9373
# routing9376
# routing9377
# routing9388
# routing9390
# routing9395
# routing9408
# routing9409
# routing9410
# routing9424
# routing9430
# routing9448
# routing9454
# routing9456
# routing9467
# routing9468
# routing9469
# routing9470
# routing9476
# routing9490
# routing9493
# routing9497
# routing9499
# routing9502
# routing9505
# routing9509
# routing9512
# routing9517
# routing9518
# routing9527
# routing9531
# routing9536
# routing9537
# routing9547
# routing9551
# routing9553
# routing9554
# routing9564
# routing9565
# routing9571
# routing9574
# routing9592
# routing9595
# routing9599
# routing9603
# routing9608
# routing9616
# routing9617
# routing9618
# routing9626
# routing9629
# routing9636
# routing9637
# routing9641
# routing9645
# routing9649
# routing9651
# routing9652
# routing9656
# routing9661
# routing9668
# routing9670
# routing9672
# routing9676
# routing9682
# routing9683
# routing9684
# routing9690
# routing9704
# routing9708
# routing9710
# routing9714
# routing9719
# routing9724
# routing9732
# routing9740
# routing9744
# routing9750
# routing9753
# routing9754
# routing9761
# routing9767
# routing9771
# routing9778
# routing9784
# routing9785
# routing9787
# routing9788
# routing9796
# routing9797
# routing9814
# routing9831
# routing9836
# routing9840
# routing9845
# routing9850
# routing9856
# routing9870
# routing9872
# routing9875
# routing9879
# routing9881
# routing9890
# routing9899
# routing9900
# routing9902
# routing9908
# routing9913
# routing9917
# routing9918
# routing9922
# routing9927
# routing9930
# routing9938
# routing9942
# routing9947
# routing9951
# routing9952
# routing9956
# routing9961
# routing9965
# routing9966
# routing9969
# routing9974
# routing9979
# routing9984
# routing9989
# routing9990
# routing9992
# routing10001
# routing10002
# routing10006
# routing10012
# routing10017
# routing10018
# routing10024
# routing10026
# routing10029
# routing10036
# routing10044
# routing10045
# routing10047
# routing10048
# routing10049
# routing10051
# routing10053
# routing10070
# routing10071
# routing10072
# routing10074
# routing10077
# routing10078
# routing10082
# routing10085
# routing10093
# routing10094
# routing10095
# routing10102
# routing10103
# routing10111
# routing10119
# routing10129
# routing10137
# routing10148
# routing10149
# routing10153
# routing10160
# routing10167
# routing10171
# routing10209
# routing10210
# routing10217
# routing10222
# routing10223
# routing10227
# routing10232
# routing10233
# routing10236
# routing10247
# routing10252
# routing10255
# routing10258
# routing10263
# routing10329
# routing10335
# routing10336
# routing10343
# routing10347
# routing10423
# routing10432
# routing10447
# routing10458
# routing10461
# routing10465
# routing10470
# routing10474
# routing10484
# routing10498
# routing10504
# routing10514
# routing10522
# routing10526
# routing10530
# routing10535
# routing10541
# routing10542
# routing10543
# routing10561
# routing10589
# routing10619
# routing10648
# routing10686
# routing10690
# routing10708
# routing10710
# routing10729
# routing10745
# routing10766
# routing10772
# routing10783
# routing10801
# routing10804
# routing10814
# routing10824
# routing10840
# routing10863
# routing10885
# routing10896
# routing10941
# routing11001
# routing11049
# routing11056
# routing11067
# routing11079
# routing11090
# routing11091
# routing11095
# routing11102
# routing11107
# routing11111
# routing11125
# routing11131
# routing11141
# routing11149
# routing11153
# routing11156
# routing11169
# routing11171
# routing11183
# routing11192
# routing11206
# routing11213
# routing11223
# routing11235
# routing11247
# routing11262
# routing11274
# routing11279
# routing11280
# routing11291
# routing11301
# routing11311
# routing11323
# routing11338
# routing11350
# routing11355
# routing11374
# routing11384
# routing11404
# routing11405
# routing11413
# routing11414
# routing11430
# routing11431
# routing11443
# routing11446
# routing11448
# routing11449
# routing11454
# routing11455
# routing11464
# routing11465
# routing11473
# routing11474
# routing11475
# routing11480
# routing11483
# routing11490
# routing11493
# routing11498
# routing11502
# routing11503
# routing11510
# routing11511
# routing11520
# routing11521
# routing11527
# routing11528
# routing11533
# routing11534
# routing11543
# routing11544
# routing11551
# routing11552
# routing11580
# routing11581
# routing11584
# routing11585
# routing11590
# routing11593
# routing11600
# routing11601
# routing11556
# routing11557
# routing11560
# routing11564
# routing11565
# routing11570
# routing11571
# routing11573
# routing11622
# routing11623
# routing11628
# routing11671
# routing11686
# routing11713
# routing10387
# routing10359
# routing10364
# routing10410
# routing10352
# routing10399
# routing10357
# routing10417
# routing10422
# routing10353
# routing10421
# routing10354
# routing33199
# routing33200
# routing33211
# routing33205
# routing33194
# routing33203
# routing33214
# routing33208
# routing33215
# routing33213
# routing33212
# routing33218
# routing33202
# routing33221
# routing33311
# routing33363
# routing33269
# routing33220
# routing33310
# routing33362
# routing33226
# routing33240
# routing33225
# routing33314
# routing33223
# routing33237
# routing33284
# routing33232
# routing33319
# routing33371
# routing33272
# routing33229
# routing33317
# routing33369
# routing33271
# routing33219
# routing33309
# routing11716
#   warning: cannot route bus: 11716
# routing11720
#   warning: cannot route bus: 11720
# routing11723
#   warning: cannot route bus: 11723
# routing11715
#   warning: cannot route bus: 11715
# routing11718
#   warning: cannot route bus: 11718
# routing11717
# routing11724
#   warning: cannot route bus: 11724
# routing11721
#   warning: cannot route bus: 11721
# routing23431
# routing23433
# routing23438
# routing23440
# routing23442
# routing23443
# routing23444
# routing23447
# routing23453
# routing23457
# routing23462
# routing23467
# routing23474
# routing23484
# routing23487
# routing23512
# routing23513
# routing23515
# routing23518
# routing23523
# routing23525
# routing23530
# routing23531
# routing23536
# routing23542
# routing23549
# routing23554
# routing23555
# routing23559
# routing23564
# routing23567
# routing23575
# routing23585
# routing23592
# routing23596
# routing23597
# routing23599
# routing23601
# routing23602
# routing23606
# routing23608
# routing23611
# routing23613
# routing23619
# routing23620
# routing23621
# routing23622
# routing23634
# routing23635
# routing23644
# routing23645
# routing23649
# routing23656
# routing23657
# routing23661
# routing23662
# routing23670
# routing23672
# routing23673
# routing23687
# routing23688
# routing23698
# routing23701
# routing23706
# routing23707
# routing23712
# routing23713
# routing23714
# routing23718
# routing23720
# routing23758
# routing23759
# routing23762
# routing23764
# routing23768
# routing23795
# routing23800
# routing23801
# routing23806
# routing23809
# routing23813
# routing23818
# routing23835
# routing23843
# routing23853
# routing23860
# routing23861
# routing23862
# routing23865
# routing23867
# routing23869
# routing23870
# routing23873
# routing23874
# routing23881
# routing23882
# routing23891
# routing23892
# routing23899
# routing23900
# routing23907
# routing23908
# routing23917
# routing23918
# routing23925
# routing23926
# routing23927
# routing23928
# routing23929
# routing23939
# routing23944
# routing23960
# routing23961
# routing23965
# routing23967
# routing23968
# routing23971
# routing23972
# routing23973
# routing23974
#   warning: cannot route bus: 23974
# routing23975
# routing23976
# routing23984
# routing23986
# routing23987
# routing23988
# routing23989
# routing23992
# routing23993
# routing23994
# routing23998
# routing23999
# routing24002
# routing24003
# routing24004
# routing24005
# routing24006
# routing24008
# routing24009
# routing24011
# routing24012
# routing24014
# routing24016
# routing24017
# routing24018
# routing24019
# routing24020
# routing24021
# routing24026
# routing24027
# routing24033
# routing24034
# routing24035
# routing24037
# routing24038
# routing24040
# routing24041
# routing24042
# routing24043
# routing24044
# routing24045
# routing24046
# routing24048
# routing24049
# routing24053
# routing24054
# routing24063
# routing24064
# routing24075
# routing24083
# routing24111
# routing24112
# routing24120
# routing24123
# routing24131
# routing24132
# routing24138
# routing24145
# routing24147
# routing24151
# routing24152
# routing24159
# routing24162
# routing24163
# routing24169
# routing24170
# routing24174
# routing24175
# routing24187
# routing24204
# routing24247
# routing24263
# routing24264
# routing24266
# routing24267
# routing24270
# routing24286
# routing24287
# routing24291
# routing24304
# routing24305
# routing24310
# routing24311
# routing24325
# routing24330
# routing24417
# routing24441
# routing24495
# routing24496
# routing24593
# routing24669
# routing24670
# routing24697
# routing24777
# routing24778
# routing24780
# routing24790
# routing24793
# routing24804
# routing24805
# routing24820
# routing24821
# routing24825
# routing24833
# routing24834
# routing24849
# routing24850
# routing24861
# routing24862
# routing24873
# routing24889
# routing24910
# routing24926
# routing24927
# routing24937
# routing24947
# routing24955
# routing24961
# routing24964
# routing24980
# routing25000
# routing25015
# routing25024
# routing25028
# routing25029
# routing25033
# routing25034
# routing25037
# routing25038
# routing25042
# routing25043
# routing25046
# routing25047
# routing25051
# routing25052
# routing25056
# routing25072
# routing25093
# routing25106
# routing25109
# routing25124
# routing25144
# routing25176
# routing25183
# routing25188
# routing25195
# routing25201
# routing25202
# routing25207
# routing25213
# routing25220
# routing25226
# routing25227
# routing25229
# routing25236
# routing25237
# routing25239
# routing25241
# routing25242
# routing25243
# routing25245
# routing25250
# routing25251
# routing25253
# routing25255
# routing25257
# routing25258
# routing25261
# routing25265
# routing25271
# routing25272
# routing25273
# routing25275
# routing25276
# routing25277
# routing25278
# routing25279
# routing25280
# routing25281
# routing25285
# routing25287
# routing25290
# routing25292
# routing25295
# routing25299
# routing25301
# routing25302
# routing25305
# routing25306
# routing25307
# routing25309
# routing25313
# routing25314
# routing25321
# routing25323
# routing25328
# routing25329
# routing25330
# routing25332
# routing25333
# routing25334
# routing25335
# routing25337
# routing25340
# routing25341
# routing25342
# routing25343
# routing25345
# routing25346
# routing25347
# routing25349
# routing25350
# routing25359
# routing25365
# routing25366
# routing23497
# routing23501
# routing23507
# routing25367
# routing25368
# routing25438
# routing25500
# routing25514
# routing25566
# routing25620
# routing25659
# routing25706
# routing25722
# routing25731
# routing25734
# routing25738
# routing25744
# routing25748
# routing25369
# routing25377
# routing25388
# routing25397
# routing25400
# routing25406
# routing25415
# routing25420
# routing25423
# routing25428
# routing25434
# routing25439
# routing25448
# routing25460
# routing25468
# routing25472
# routing25482
# routing25491
# routing25501
# routing25504
# routing25512
# routing25523
# routing25530
# routing25532
# routing25542
# routing25553
# routing25562
# routing25564
# routing25574
# routing25585
# routing25594
# routing25595
# routing25605
# routing25616
# routing25625
# routing25629
# routing25633
# routing25639
# routing25643
# routing25644
# routing25649
# routing25654
# routing25658
# routing25660
# routing25663
# routing25669
# routing25671
# routing25681
# routing25692
# routing25701
# routing11780
# routing11870
# routing11869
# routing11802
# routing11765
# routing12133
# routing12132
# routing12121
# routing12048
# routing12158
# routing19927
# routing21623
# routing21620
# routing19985
# routing19885
# routing19907
# routing21617
# routing19954
# routing20831
# routing19914
# routing21680
# routing19915
# routing19911
# routing12284
# routing12273
# routing12217
# routing12268
# routing12249
# routing12207
# routing12200
# routing12289
# routing12368
# routing12360
# routing12181
# routing12339
# routing12324
# routing12307
# routing12378
# routing12376
# routing12301
# routing12411
# routing12666
# routing12650
# routing12607
# routing21056
# routing21049
# routing21019
# routing12603
# routing12620
# routing12497
# routing12491
# routing12553
# routing12552
# routing21205
# routing21183
# routing12562
# routing12427
# routing12464
# routing12805
# routing12741
# routing12795
# routing12794
# routing12835
# routing12881
# routing12874
# routing12827
# routing12870
# routing12962
# routing13048
# routing13020
# routing13016
# routing12972
# routing12974
# routing13028
# routing13043
# routing13024
# routing13018
# routing12907
# routing21256
# routing21272
# routing20841
# routing20772
# routing21240
# routing20825
# routing20823
# routing20696
# routing13097
# routing20865
# routing13073
# routing20721
# routing20643
# routing20767
# routing20747
# routing13113
# routing13134
# routing13276
# routing13261
# routing13205
# routing13242
# routing13283
# routing13277
# routing13238
# routing13206
# routing13409
# routing13382
# routing13332
# routing13290
# routing13432
# routing13408
# routing13379
# routing13329
# routing21415
# routing21414
# routing21411
# routing21410
# routing21424
# routing21408
# routing21407
# routing21384
# routing21373
# routing21534
# routing21526
# routing21515
# routing21501
# routing21481
# routing21509
# routing21503
# routing21482
# routing21452
# routing21427
# routing13667
# routing13664
# routing13652
# routing13645
# routing13638
# routing13440
# routing13520
# routing13490
# routing13457
# routing13592
# routing20555
# routing20518
# routing20616
# routing20615
# routing20496
# routing20444
# routing20513
# routing20672
# routing21673
# routing20680
# routing13891
# routing13876
# routing13864
# routing13838
# routing13946
# routing13849
# routing13932
# routing13920
# routing13905
# routing13893
# routing14016
# routing14000
# routing13984
# routing13964
# routing13948
# routing14086
# routing14084
# routing14083
# routing14069
# routing14035
# routing14172
# routing14137
# routing14134
# routing14109
# routing14100
# routing14212
# routing14262
# routing14250
# routing14244
# routing14222
# routing14388
# routing14403
# routing14392
# routing14371
# routing14318
# routing14542
# routing14532
# routing14504
# routing14499
# routing14456
# routing14614
# routing14613
# routing14600
# routing14591
# routing14575
# routing14659
# routing14668
# routing14653
# routing14641
# routing14626
# routing14835
# routing14819
# routing14811
# routing14809
# routing14869
# routing14746
# routing14722
# routing14720
# routing14717
# routing14785
# routing20065
# routing20064
# routing20062
# routing20060
# routing20042
# routing20140
# routing20138
# routing20121
# routing20105
# routing20089
# routing14981
# routing14977
# routing14965
# routing14945
# routing14934
# routing14986
# routing15054
# routing15052
# routing15038
# routing15017
# routing15172
# routing15170
# routing15144
# routing15140
# routing15062
# routing15171
# routing15169
# routing15160
# routing15286
# routing15264
# routing15248
# routing15230
# routing15228
# routing15285
# routing15284
# routing15277
# routing21580
# routing15320
# routing15303
# routing21583
# routing15365
# routing15360
# routing21604
# routing15402
# routing15437
# routing15439
# routing15751
# routing15759
# routing15726
# routing15563
# routing15636
# routing15718
# routing15758
# routing15755
# routing15695
# routing15592
# routing15930
# routing15882
# routing15810
# routing15987
# routing15973
# routing16060
# routing16050
# routing16025
# routing15809
# routing15854
# routing20167
# routing20162
# routing16207
# routing16194
# routing16188
# routing16239
# routing16233
# routing16092
# routing16086
# routing16166
# routing16149
# routing16114
# routing16325
# routing16318
# routing16306
# routing16286
# routing16324
# routing16394
# routing16384
# routing16364
# routing16348
# routing16403
# routing16445
# routing16444
# routing16428
# routing16418
# routing16480
# routing16471
# routing16463
# routing16454
# routing16507
# routing16506
# routing16498
# routing16488
# routing16546
# routing16542
# routing16534
# routing16524
# routing16516
# routing16587
# routing16586
# routing16603
# routing16630
# routing16624
# routing16560
# routing16613
# routing16654
# routing16803
# routing21277
# routing21276
# routing16664
# routing16759
# routing16864
# routing16955
# routing16953
# routing16809
# routing16928
# routing21280
# routing21001
# routing20269
# routing20208
# routing21285
# routing21284
# routing21142
# routing20998
# routing17006
# routing16992
# routing16991
# routing16979
# routing16964
# routing16994
# routing17023
# routing17021
# routing17122
# routing17118
# routing17075
# routing17031
# routing17027
# routing17025
# routing17064
# routing17120
# routing17305
# routing17232
# routing17219
# routing17258
# routing17288
# routing17216
# routing17133
# routing17194
# routing17168
# routing17155
# routing21851
# routing21892
# routing21833
# routing21923
# routing21879
# routing21761
# routing21754
# routing21801
# routing21725
# routing21712
# routing17408
# routing17385
# routing17366
# routing17346
# routing17339
# routing17509
# routing17489
# routing17488
# routing17464
# routing17614
# routing17612
# routing17654
# routing17638
# routing17534
# routing17524
# routing17584
# routing17574
# routing17559
# routing17812
# routing17929
# routing17925
# routing17923
# routing17892
# routing17666
# routing17659
# routing17747
# routing17678
# routing17713
# routing18003
# routing18002
# routing17998
# routing17979
# routing17937
# routing17933
# routing17961
# routing17954
# routing18116
# routing18104
# routing18089
# routing18120
# routing18077
# routing18048
# routing18036
# routing18024
# routing18064
# routing18063
# routing18189
# routing18133
# routing18172
# routing18156
# routing18253
# routing18242
# routing18226
# routing18206
# routing18190
# routing18310
# routing18304
# routing18279
# routing18273
# routing18264
# routing18314
# routing18285
# routing18294
# routing13824
# routing13818
# routing13801
# routing13792
# routing13784
# routing13808
# routing13837
# routing13774
# routing19197
# routing19187
# routing19185
# routing19214
# routing19165
# routing19153
# routing19140
# routing19137
# routing19179
# routing19300
# routing19291
# routing19336
# routing19264
# routing19263
# routing19326
# routing19284
# routing19248
# routing19348
# routing19349
# routing19364
# routing20404
# routing20405
# routing20401
# routing20391
# routing20429
# routing20428
# routing20417
# routing20403
# routing19377
# routing19373
# routing19389
# routing19388
# routing19398
# routing19397
# routing19409
# routing19406
# routing19419
# routing19417
# routing19453
# routing19450
# routing19423
# routing19422
# routing21709
# routing21708
# routing19454
# routing19451
# routing19449
# routing19431
# routing19435
# routing19429
# routing21969
# routing21962
# routing20362
# routing20363
# routing20360
# routing25850
# routing25894
# routing25901
# routing25786
# routing25814
# routing25798
# routing25760
# routing25845
# routing25776
# routing25890
# routing25904
# routing25885
# routing25784
# routing25837
# routing25753
# routing25764
# routing25756
# routing25881
# routing25880
# routing25916
# routing25766
# routing25763
# routing25899
# routing25892
# routing25917
# routing25907
# routing25913
# routing25878
# routing25830
# routing25875
# routing25759
# routing25769
# routing25876
# routing25897
# routing25755
# routing25910
# routing25912
# routing25886
# routing25972
# routing26783
# routing26360
# routing26467
# routing25989
# routing26058
# routing26689
# routing26105
# routing25945
# routing26552
# routing26819
# routing26215
# routing25921
# routing25990
# routing26584
# routing26059
# routing26231
# routing25959
# routing26564
# routing26830
# routing26420
# routing26421
# routing26734
# routing26423
# routing26735
# routing26576
# routing26577
# routing26267
# routing26448
# routing25985
# routing26523
# routing26790
# routing26188
# routing25988
# routing26430
# routing26741
# routing26043
# routing26678
# routing26631
# routing26308
# routing26455
# routing25960
# routing25970
# routing26728
# routing26352
# routing26463
# routing25971
# routing26729
# routing26353
# routing26464
# routing25964
# routing26024
# routing26827
# routing25956
# routing26403
# routing26724
# routing26404
# routing26725
# routing26138
# routing27087
# routing27066
# routing27011
# routing26874
# routing26889
# routing27077
# routing26946
# routing26863
# routing26912
# routing26888
# routing26846
# routing26966
# routing26938
# routing27057
# routing26853
# routing26981
# routing26861
# routing26868
# routing27107
# routing26898
# routing26929
# routing26908
# routing27109
# routing27007
# routing26896
# routing26944
# routing26856
# routing26956
# routing26924
# routing27072
# routing27050
# routing26934
# routing26871
# routing26845
# routing27048
# routing26952
# routing27033
# routing26844
# routing26960
# routing26873
# routing26897
# routing26852
# routing27119
# routing27056
# routing27130
# routing27096
# routing26970
# routing27022
# routing26933
# routing27112
# routing27006
# routing26987
# routing27068
# routing26963
# routing26854
# routing27020
# routing26842
# routing27091
# routing27003
# routing27051
# routing27024
# routing26930
# routing26998
# routing26880
# routing27017
# routing26865
# routing26969
# routing27012
# routing26939
# routing26881
# routing26857
# routing26937
# routing26879
# routing27123
# routing26959
# routing26851
# routing26984
# routing27030
# routing26909
# routing27101
# routing26858
# routing26979
# routing26862
# routing26922
# routing27142
# routing26950
# routing27099
# routing27015
# routing27117
# routing27013
# routing27044
# routing27019
# routing26954
# routing27127
# routing27143
# routing26935
# routing27081
# routing27067
# routing26850
# routing27041
# routing26894
# routing27032
# routing27054
# routing26860
# routing26957
# routing27002
# routing27043
# routing26875
# routing26977
# routing26918
# routing26878
# routing26962
# routing26953
# routing27128
# routing27141
# routing26882
# routing26895
# routing26997
# routing26900
# routing27079
# routing26877
# routing27025
# routing27145
# routing27256
# routing27478
# routing27543
# routing27587
# routing27146
# routing27168
# routing27179
# routing27201
# routing27212
# routing27257
# routing27268
# routing27534
# routing27539
# routing27547
# routing27548
# routing27558
# routing27559
# routing27161
# routing27162
# routing27163
# routing27164
# routing27165
# routing27166
# routing27167
# routing27169
# routing27171
# routing27172
# routing27173
# routing27174
# routing27175
# routing27176
# routing27177
# routing27178
# routing27180
# routing27183
# routing27184
# routing27185
# routing27186
# routing27187
# routing27189
# routing27191
# routing27193
# routing27194
# routing27195
# routing27196
# routing27198
# routing27199
# routing27200
# routing27206
# routing27207
# routing27208
# routing27209
# routing27214
# routing27215
# routing27217
# routing27219
# routing27220
# routing27221
# routing27222
# routing27224
# routing27225
# routing27226
# routing27229
# routing27231
# routing27232
# routing27238
# routing27241
# routing27248
# routing27252
# routing27253
# routing27261
# routing27263
# routing27264
# routing27275
# routing27276
# routing27277
# routing27278
# routing27283
# routing27285
# routing27287
# routing27294
# routing27296
# routing27297
# routing27299
# routing27315
# routing27320
# routing27338
# routing27339
# routing27342
# routing27359
# routing27377
# routing27416
# routing27440
# routing27448
# routing27504
# routing27598
# routing27606
# routing27642
# routing27677
# routing27718
# routing27600
# routing27604
# routing27607
# routing27614
# routing27647
# routing27678
# routing27686
# routing27719
# routing27611
# routing27644
# routing27682
# routing27722
# routing27613
# routing27646
# routing27684
# routing27724
# routing27601
# routing27608
# routing27643
# routing27680
# routing27720
# routing27641
# routing27648
# routing27685
# routing27603
# routing27612
# routing27645
# routing27683
# routing27723
# routing27609
# routing27681
# routing33372
# routing33374
# routing33414
# routing33392
# routing33412
# routing33401
# routing33410
# routing33405
# routing33407
# routing33393
# routing33398
# routing33395
# routing33381
# routing33384
# routing33383
# routing33403
# routing33380
# routing33404
# routing32137
# routing32141
# routing32148
# routing32152
# routing32154
# routing32162
# routing32169
# routing32174
# routing32176
# routing32183
# routing32188
# routing32195
# routing32199
# routing32202
# routing32209
# routing32216
# routing32218
# routing32219
# routing32223
# routing32231
# routing32237
# routing32244
# routing32254
# routing32261
# routing32262
# routing32263
# routing32266
# routing32268
# routing32270
# routing32272
# routing32275
# routing32277
# routing32279
# routing32282
# routing32285
# routing32287
# routing32289
# routing32290
# routing32293
# routing32296
# routing32299
# routing32300
# routing32303
# routing32307
# routing32310
# routing32313
# routing32315
# routing32322
# routing32332
# routing32339
# routing32346
# routing32356
# routing32363
# routing32370
# routing32380
# routing32387
# routing32391
# routing32398
# routing32403
# routing32409
# routing32419
# routing32426
# routing32433
# routing32443
# routing32450
# routing32456
# routing32466
# routing27793
# routing27731
# routing27790
# routing27779
# routing32128
# routing27856
# routing27827
# routing27823
# routing27832
# routing27820
# routing27867
# routing27864
# routing27868
# routing27877
# routing27873
# routing27878
# routing31787
# routing27893
# routing27890
# routing27883
# routing27907
# routing27904
# routing27897
# routing27916
# routing27911
# routing27915
# routing27925
# routing27924
# routing27923
# routing27940
# routing27937
# routing27930
# routing27955
# routing27952
# routing27944
# routing27973
# routing27968
# routing27961
# routing27991
# routing27985
# routing27978
# routing27992
# routing28005
# routing27998
# routing27993
# routing28012
# routing28014
# routing28030
# routing28025
# routing28018
# routing28050
# routing28089
# routing28044
# routing28058
# routing28099
# routing28148
# routing28143
# routing28127
# routing28201
# routing28146
# routing28238
# routing28272
# routing28233
# routing28277
# routing28262
# routing28365
# routing28327
# routing28337
# routing28294
# routing28320
# routing32013
# routing31938
# routing31973
# routing31959
# routing31962
# routing32090
# routing32042
# routing32017
# routing32059
# routing32049
# routing28384
# routing28398
# routing28395
# routing28375
# routing28401
# routing28426
# routing28437
# routing28410
# routing28412
# routing28435
# routing28444
# routing28449
# routing28451
# routing28460
# routing28468
# routing28469
# routing28475
# routing28464
# routing28483
# routing28497
# routing28495
# routing28486
# routing28499
# routing28546
# routing28539
# routing28530
# routing28523
# routing28564
# routing28556
# routing28551
# routing28591
# routing28590
# routing28579
# routing28569
# routing28583
# routing28597
# routing28596
# routing28603
# routing28602
# routing28621
# routing28609
# routing28630
# routing28604
# routing28640
# routing28634
# routing28651
# routing28635
# routing28643
# routing31876
# routing31879
# routing31884
# routing31900
# routing31904
# routing31913
# routing31919
# routing31930
# routing28681
# routing28677
# routing28666
# routing28669
# routing28689
# routing28698
# routing28693
# routing28682
# routing28724
# routing28716
# routing28732
# routing28709
# routing28756
# routing28748
# routing28765
# routing28758
# routing28770
# routing28787
# routing28782
# routing28775
# routing28804
# routing28800
# routing28793
# routing28818
# routing28814
# routing28809
# routing28831
# routing28827
# routing28822
# routing28853
# routing28835
# routing28848
# routing28880
# routing28879
# routing28856
# routing28875
# routing28883
# routing28909
# routing28902
# routing28892
# routing28940
# routing28934
# routing28924
# routing28916
# routing31792
# routing31796
# routing31803
# routing31804
# routing31813
# routing31819
# routing31820
# routing31823
# routing31827
# routing31832
# routing31836
# routing31843
# routing31848
# routing31838
# routing28955
# routing28968
# routing28941
# routing28995
# routing28986
# routing28972
# routing29023
# routing29017
# routing29005
# routing28999
# routing29050
# routing29043
# routing29034
# routing29026
# routing29067
# routing29058
# routing29052
# routing29072
# routing29086
# routing29083
# routing29089
# routing29098
# routing29110
# routing29092
# routing29118
# routing29127
# routing29141
# routing29117
# routing29196
# routing29195
# routing29168
# routing29149
# routing29160
# routing29216
# routing29236
# routing29241
# routing29250
# routing29224
# routing29274
# routing29269
# routing29257
# routing29259
# routing29254
# routing29292
# routing29308
# routing29301
# routing29295
# routing29317
# routing29320
# routing29327
# routing29324
# routing29338
# routing29344
# routing29343
# routing29350
# routing29396
# routing29359
# routing29372
# routing29385
# routing29360
# routing29400
# routing29405
# routing29430
# routing29399
# routing29458
# routing29457
# routing29451
# routing29443
# routing29437
# routing29482
# routing29475
# routing29467
# routing29461
# routing29505
# routing29508
# routing29492
# routing29485
# routing29516
# routing29515
# routing29534
# routing29526
# routing29519
# routing29559
# routing29544
# routing29540
# routing29570
# routing29582
# routing29576
# routing29562
# routing29610
# routing29612
# routing29619
# routing29609
# routing29617
# routing29695
# routing29683
# routing29679
# routing29686
# routing29675
# routing29711
# routing29705
# routing29699
# routing29716
# routing29724
# routing29717
# routing29783
# routing29764
# routing29748
# routing29732
# routing29768
# routing29829
# routing29826
# routing29800
# routing29840
# routing29809
# routing29900
# routing29863
# routing29853
# routing29887
# routing29893
# routing29962
# routing29933
# routing29924
# routing29952
# routing29940
# routing30002
# routing30005
# routing29983
# routing30014
# routing30016
# routing30080
# routing30053
# routing30026
# routing30075
# routing30073
# routing30091
# routing30107
# routing30122
# routing30113
# routing30120
# routing30168
# routing30167
# routing30155
# routing30141
# routing30130
# routing30188
# routing30219
# routing30207
# routing30183
# routing30194
# routing30268
# routing30266
# routing30235
# routing30248
# routing30295
# routing30316
# routing30283
# routing30300
# routing30314
# routing30347
# routing30342
# routing30331
# routing30344
# routing30409
# routing30410
# routing30393
# routing30378
# routing30400
# routing30437
# routing30420
# routing30415
# routing30454
# routing30467
# routing30484
# routing30469
# routing30464
# routing30489
# routing30510
# routing30507
# routing30511
# routing30517
# routing30518
# routing30539
# routing30526
# routing30541
# routing30560
# routing30566
# routing30552
# routing30559
# routing30594
# routing30590
# routing30577
# routing30598
# routing30605
# routing30600
# routing30614
# routing30621
# routing30623
# routing30625
# routing30628
# routing30626
# routing30635
# routing30643
# routing30642
# routing30647
# routing30646
# routing30648
# routing30651
# routing30650
# routing30656
# routing30661
# routing30672
# routing30665
# routing30682
# routing30683
# routing30684
# routing30689
# routing30693
# routing30702
# routing30698
# routing30703
# routing30728
# routing30726
# routing30721
# routing30737
# routing30733
# routing30742
# routing30767
# routing30760
# routing30750
# routing30745
# routing30787
# routing30821
# routing31777
# routing30812
# routing30784
# routing30851
# routing30831
# routing30861
# routing30875
# routing30848
# routing30886
# routing30887
# routing30889
# routing30890
# routing30903
# routing30928
# routing30943
# routing30959
# routing30979
# routing30999
# routing31022
# routing31033
# routing31028
# routing31040
# routing31041
# routing31042
# routing31088
# routing31078
# routing31057
# routing31089
# routing31139
# routing31132
# routing31113
# routing31145
# routing31154
# routing31155
# routing31160
# routing31169
# routing31222
# routing31197
# routing31186
# routing31191
# routing31212
# routing31291
# routing31265
# routing31289
# routing31245
# routing31238
# routing31297
# routing31301
# routing31305
# routing31309
# routing31313
# routing31317
# routing31321
# routing31325
# routing31329
# routing31333
# routing31337
# routing31341
# routing31345
# routing31349
# routing31353
# routing31357
# routing29483
# routing31852
# routing31853
# routing31862
# routing32099
# routing33827
# routing33934
# routing33708
# routing33507
# routing33428
# routing33781
# routing33503
# routing33703
# routing33532
# routing33861
# routing33930
# routing33455
# routing33625
# routing33879
# routing33945
# routing33607
# routing33807
# routing33594
# routing33866
# routing34004
# routing33754
# routing33958
# routing33423
# routing33593
# routing33920
# routing34013
# routing33744
# routing33794
# routing33965
# routing33830
# routing33640
# routing33558
# routing33473
# routing33608
# routing34010
# routing33527
# routing33899
# routing33932
# routing33499
# routing33656
# routing33586
# routing33911
# routing33519
# routing33823
# routing33767
# routing33651
# routing33636
# routing33565
# routing33964
# routing33698
# routing33721
# routing33770
# routing33772
# routing33469
# routing33476
# routing33759
# routing33791
# routing33676
# routing33533
# routing33742
# routing33680
# routing33888
# routing33502
# routing33679
# routing33914
# routing33479
# routing33996
# routing33790
# routing33648
# routing33897
# routing33990
# routing33619
# routing33645
# routing33624
# routing33597
# routing33536
# routing33618
# routing33443
# routing33659
# routing33872
# routing33426
# routing33999
# routing33923
# routing33668
# routing33537
# routing33810
# routing33869
# routing33937
# routing33860
# routing33492
# routing33515
# routing33591
# routing33834
# routing33518
# routing33420
# routing33538
# routing33840
# routing33665
# routing33832
# routing33838
# routing33613
# routing33452
# routing33784
# routing33605
# routing33631
# routing33592
# routing33633
# routing33664
# routing33725
# routing33614
# routing33723
# routing33793
# routing34009
# routing33975
# routing33630
# routing33447
# routing33435
# routing32968
# routing32976
# routing32985
# routing32992
# routing32965
# routing32966
# routing32967
# routing32823
# routing32824
# routing32694
# routing32702
# routing32712
# routing32751
# routing32754
# routing32762
# routing32772
# routing32808
# routing32843
# routing32846
# routing32864
# routing32870
# routing32876
# routing32883
# routing32889
# routing32895
# routing32900
# routing32906
# routing32853
# routing32851
# routing32857
# routing32861
# routing32913
# routing32918
# routing32927
# routing32933
# routing32935
# routing32937
# routing32944
# routing32951
# routing32959
# routing33011
# routing33014
# routing33015
# routing33010
# routing32997
# routing33005
# routing33028
# routing33029
# routing33018
# routing33030
# routing33036
# routing33046
# routing33048
# routing33050
# routing33051
# routing33052
# routing33054
# routing33055
# routing33056
# routing33058
# routing33060
# routing33061
# routing33068
# routing33064
# routing33062
# routing33069
# routing33078
# routing33079
# routing33084
# routing33089
# routing33092
# routing33095
# routing33097
# routing33098
# routing33100
# routing33101
# routing33103
# routing33104
# routing33105
# routing33106
# routing33108
# routing33109
# routing33110
# routing33111
# routing33112
# routing33113
# routing33114
# routing33115
# routing33117
# routing33118
# routing33119
# routing33120
# routing33121
# routing33122
# routing33143
# routing33137
# routing33129
# routing33123
# routing33125
# routing33146
# routing33150
# routing33155
# routing33159
# routing33163
# routing33168
# routing33172
# routing33183
# routing33173
# routing32476
# routing32492
# routing32512
# routing32528
# routing32584
# routing34214
# routing34215
# routing34218
# routing34221
# routing34222
# routing34232
# routing34233
# routing34030
# routing34035
# routing34085
# routing34093
# routing34053
# routing34057
# routing34101
# routing34109
# routing34116
# routing34243
# routing34249
# routing34132
# routing34139
# routing34204
# routing34209
# routing34063
# routing34068
# routing34074
# routing34079
# routing34041
# routing34047
# routing34117
# routing34124
# routing34146
# routing34147
# routing34154
# routing34155
# routing34161
# routing34164
# routing34174
# routing34182
# routing34189
# routing34196
# routing34197
# routing34203
# routing34171
# routing34167
# routing34168
# routing34017
# routing34022
# routing34028
# routing34029
# Wall time: 27min 51s

# %%
# trips successfully routed by osmnx
bus_osmnx_link_shape_df.info()

print('# unique shape_id of all trips: {}'.format(trip_df.shape_id.nunique()))
print('# unique shape_id of routed trips: {}'.format(bus_osmnx_link_shape_df.shape_id.nunique()))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 953169 entries, 0 to 953168
# Data columns (total 9 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   u                953169 non-null  int64
#  1   v                953169 non-null  int64
#  2   trip_id          953169 non-null  int32
#  3   shape_id         953169 non-null  int32
#  4   wayId            953169 non-null  object
#  5   shstReferenceId  953169 non-null  object
#  6   shstGeometryId   953169 non-null  object
#  7   A                953169 non-null  int64
#  8   B                953169 non-null  int64
# dtypes: int32(2), int64(4), object(3)
# memory usage: 65.4+ MB
# # unique shape_id of all trips: 1634
# # unique shape_id of routed trips: 1531

# %%
# osmnx failed to route these trips: can be rail modes
print(bus_osmnx_broken_trip_list)
# Out:
# [8363, 8361, 8357, 8358, 8364, 8870, 8868, 8864, 8865, 8871, 11716, 11720, 11723, 11715, 11718, 11724, 11721, 23974]

# %%
# shapes that were not successfully routed by OSMNX
trip_df[trip_df.trip_id.isin(bus_osmnx_broken_trip_list)].shape_id.unique()
# Out:
# array([ 541,  502,  510,  513,  514,  584,  545,  553,  556,  557,  829,
#         830,  831,  832, 1267])

# %% [markdown]
# ### route bus on roadway via shst routing

# %%
# read shst match result

all_shst_df = pd.DataFrame()
shsht_input_dir = os.path.join(input_data_interim_dir, "shst_match")

for name in gtfs_agencies_list:
    print(name)
    try: 
        filename = os.path.join(shsht_input_dir, name + ".out.matched.geojson")
        shst_df = gpd.read_file(filename)
        shst_df["agency_raw_name"] = name
    
        all_shst_df = all_shst_df.append(shst_df, sort = False, ignore_index = True)
    except Exception as e:
        print("  Couldn't read: {}".format(name + ".out.matched.geojson"))
        print("  " + str(e))
# Out:
# ACE_2017_3_20
#   Couldn't read: ACE_2017_3_20.out.matched.geojson
#   C:\Users\lzorn\Box\Modeling and Surveys\Development\Travel Model Two Development\Travel Model Two Network Rebuild\travel-model-two-networks\data\interim\step6_gtfs\shst_match\ACE_2017_3_20.out.matched.geojson: No such file or directory
# ACTransit_2015_8_14
# BART_2015_8_3
#   Couldn't read: BART_2015_8_3.out.matched.geojson
#   C:\Users\lzorn\Box\Modeling and Surveys\Development\Travel Model Two Development\Travel Model Two Network Rebuild\travel-model-two-networks\data\interim\step6_gtfs\shst_match\BART_2015_8_3.out.matched.geojson: No such file or directory
# Blue&Gold_gtfs_10_4_2017
#   Couldn't read: Blue&Gold_gtfs_10_4_2017.out.matched.geojson
#   C:\Users\lzorn\Box\Modeling and Surveys\Development\Travel Model Two Development\Travel Model Two Network Rebuild\travel-model-two-networks\data\interim\step6_gtfs\shst_match\Blue&Gold_gtfs_10_4_2017.out.matched.geojson: No such file or directory
# Caltrain_2015_5_13
#   Couldn't read: Caltrain_2015_5_13.out.matched.geojson
#   C:\Users\lzorn\Box\Modeling and Surveys\Development\Travel Model Two Development\Travel Model Two Network Rebuild\travel-model-two-networks\data\interim\step6_gtfs\shst_match\Caltrain_2015_5_13.out.matched.geojson: No such file or directory
# Capitol_2017_3_20
#   Couldn't read: Capitol_2017_3_20.out.matched.geojson
#   C:\Users\lzorn\Box\Modeling and Surveys\Development\Travel Model Two Development\Travel Model Two Network Rebuild\travel-model-two-networks\data\interim\step6_gtfs\shst_match\Capitol_2017_3_20.out.matched.geojson: No such file or directory
# CCTA_2015_8_11
#   Couldn't read: CCTA_2015_8_11.out.matched.geojson
#   C:\Users\lzorn\Box\Modeling and Surveys\Development\Travel Model Two Development\Travel Model Two Network Rebuild\travel-model-two-networks\data\interim\step6_gtfs\shst_match\CCTA_2015_8_11.out.matched.geojson: No such file or directory
# Emeryville_2016_10_26
# Fairfield_2015_10_14
# Fairfield_2015_10_14_updates
#   Couldn't read: Fairfield_2015_10_14_updates.out.matched.geojson
#   C:\Users\lzorn\Box\Modeling and Surveys\Development\Travel Model Two Development\Travel Model Two Network Rebuild\travel-model-two-networks\data\interim\step6_gtfs\shst_match\Fairfield_2015_10_14_updates.out.matched.geojson: No such file or directory
# GGTransit_2015_9_3
# Marguerite_2016_10_10
# MarinTransit_2015_8_31
# MVGo_2016_10_26
#   Couldn't read: MVGo_2016_10_26.out.matched.geojson
#   C:\Users\lzorn\Box\Modeling and Surveys\Development\Travel Model Two Development\Travel Model Two Network Rebuild\travel-model-two-networks\data\interim\step6_gtfs\shst_match\MVGo_2016_10_26.out.matched.geojson: No such file or directory
# petalumatransit-petaluma-ca-us__11_12_15
# RioVista_2015_8_20
# SamTrans_2015_8_20
# SantaRosa_google_transit_08_28_15
# SFMTA_2015_8_11
# SF_Bay_Ferry2016_07_01
#   Couldn't read: SF_Bay_Ferry2016_07_01.out.matched.geojson
#   C:\Users\lzorn\Box\Modeling and Surveys\Development\Travel Model Two Development\Travel Model Two Network Rebuild\travel-model-two-networks\data\interim\step6_gtfs\shst_match\SF_Bay_Ferry2016_07_01.out.matched.geojson: No such file or directory
# Soltrans_2016_5_20
# SonomaCounty_2015_8_18
# TriDelta-GTFS-2018-05-24_21-43-17
# Union_City_Transit_Aug-01-2015 to Jun-30-2017
# vacavillecitycoach-2020-ca-us
# Vine_GTFS_PLUS_2015
#   Couldn't read: Vine_GTFS_PLUS_2015.out.matched.geojson
#   C:\Users\lzorn\Box\Modeling and Surveys\Development\Travel Model Two Development\Travel Model Two Network Rebuild\travel-model-two-networks\data\interim\step6_gtfs\shst_match\Vine_GTFS_PLUS_2015.out.matched.geojson: No such file or directory
# VTA_2015_8_27
# westcat-ca-us_9_17_2015
# Wheels_2016_7_13
# commuteDOTorg_GTFSImportExport_20160127_final_mj
#   Couldn't read: commuteDOTorg_GTFSImportExport_20160127_final_mj.out.matched.geojson
#   C:\Users\lzorn\Box\Modeling and Surveys\Development\Travel Model Two Development\Travel Model Two Network Rebuild\travel-model-two-networks\data\interim\step6_gtfs\shst_match\commuteDOTorg_GTFSImportExport_20160127_final_mj.out.matched.geojson: No such file or directory

# %%
all_shst_df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 118279 entries, 0 to 118278
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   shstReferenceId         118279 non-null  object
#  1   shstGeometryId          118279 non-null  object
#  2   shstFromIntersectionId  118279 non-null  object
#  3   shstToIntersectionId    118279 non-null  object
#  4   gisReferenceId          118279 non-null  object
#  5   gisGeometryId           118279 non-null  object
#  6   gisTotalSegments        118279 non-null  int64
#  7   gisSegmentIndex         118279 non-null  int64
#  8   gisFromIntersectionId   118279 non-null  object
#  9   gisToIntersectionId     118279 non-null  object
#  10  startSideOfStreet       118279 non-null  object
#  11  endSideOfStreet         118279 non-null  object
#  12  sideOfStreet            118279 non-null  object
#  13  score                   118279 non-null  float64
#  14  matchType               118279 non-null  object
#  15  pp_shape_id             118279 non-null  object
#  16  geometry                118279 non-null  geometry
#  17  agency_raw_name         118279 non-null  object
# dtypes: float64(1), geometry(1), int64(2), object(14)
# memory usage: 16.2+ MB

# %%
# add consolidated IDs

all_shst_df.rename(columns = {"pp_shape_id" : "shape_id_original"}, inplace = True)

all_shst_df = pd.merge(
    all_shst_df,
    unique_shape_id_df,
    how = "left",
    on = ["agency_raw_name", "shape_id_original"]
)

all_shst_df = all_shst_df[all_shst_df.shape_id.notnull()].copy()

# %%
def route_bus_link_shst(drive_link, gtfs_shst_id):
    
    """
    route bus with shst match result
    
    parameter
    ---------
    drive link
    gtfs shst match return
    
    return
    ---------
    dataframe of drive links bus traverses
    list of imcomplete bus shapes
    
    """
    
    drive_link_df = drive_link.copy()
    shape_shst_df = gtfs_shst_id.copy()

    shape_shst_df = pd.merge(shape_shst_df, 
                             drive_link_df[
                                 ['shstReferenceId','wayId','u','v', "fromIntersectionId", "toIntersectionId", "A", "B"]
                             ],
                             how = 'left',
                             left_on = 'shstReferenceId',
                             right_on = 'shstReferenceId')
    
    shape_shst_df["u"] = shape_shst_df["u"].fillna(0).astype(np.int64)
    shape_shst_df["v"] = shape_shst_df["v"].fillna(0).astype(np.int64)
    shape_shst_df["A"] = shape_shst_df["A"].fillna(0).astype(np.int64)
    shape_shst_df["B"] = shape_shst_df["B"].fillna(0).astype(np.int64)
    
    """shape_shst_df.dropna(subset = ['u','v'], 
                         axis = 0, 
                         inplace = True)"""
    
    shape_shst_df = shape_shst_df.reset_index(drop=True)
    
    shape_shst_df['next_shape_id'] = shape_shst_df['shape_id'].\
                                            iloc[1:].\
                                            append(pd.Series(shape_shst_df['shape_id'].iloc[-1])).\
                                            reset_index(drop=True)
    
    shape_shst_df['next_u'] = shape_shst_df['u'].\
                                iloc[1:].\
                                append(pd.Series(shape_shst_df['v'].iloc[-1])).\
                                reset_index(drop=True)
    
    incomplete_shape_list = shape_shst_df[\
                                   (shape_shst_df.shape_id==shape_shst_df.next_shape_id)\
                                   &(shape_shst_df.v!=shape_shst_df.next_u)\
                                  ].shape_id.unique().\
                                    tolist()
    
    shape_shst_df = shape_shst_df[~shape_shst_df.shape_id.isin(incomplete_shape_list)].copy()
    
    return shape_shst_df, incomplete_shape_list

# %%
# %%time
bus_shst_link_shape_df, incomplete_shape_list = route_bus_link_shst(drive_link_df, all_shst_df)

print('total {} bus_shst links with {} shapes; {} links with {} shapes were successfully routed'.format(
    all_shst_df.shape[0],
    all_shst_df.shape_id.nunique(),
    bus_shst_link_shape_df.shape[0],
    bus_shst_link_shape_df.shape_id.nunique()))
# Out:
# total 69373 bus_shst links with 467 shapes; 49818 links with 351 shapes were successfully routed
# Wall time: 2.72 s

# %%
bus_shst_link_shape_df.info()
bus_shst_link_shape_df.head(3)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 49818 entries, 0 to 69372
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   shstReferenceId         49818 non-null  object
#  1   shstGeometryId          49818 non-null  object
#  2   shstFromIntersectionId  49818 non-null  object
#  3   shstToIntersectionId    49818 non-null  object
#  4   gisReferenceId          49818 non-null  object
#  5   gisGeometryId           49818 non-null  object
#  6   gisTotalSegments        49818 non-null  int64
#  7   gisSegmentIndex         49818 non-null  int64
#  8   gisFromIntersectionId   49818 non-null  object
#  9   gisToIntersectionId     49818 non-null  object
#  10  startSideOfStreet       49818 non-null  object
#  11  endSideOfStreet         49818 non-null  object
#  12  sideOfStreet            49818 non-null  object
#  13  score                   49818 non-null  float64
#  14  matchType               49818 non-null  object
#  15  shape_id_original       49818 non-null  object
#  16  geometry                49818 non-null  geometry
#  17  agency_raw_name         49818 non-null  object
#  18  shape_id                49818 non-null  float64
#  19  wayId                   49818 non-null  object
#  20  u                       49818 non-null  int64
#  21  v                       49818 non-null  int64
#  22  fromIntersectionId      49818 non-null  object
#  23  toIntersectionId        49818 non-null  object
#  24  A                       49818 non-null  int64
#  25  B                       49818 non-null  int64
#  26  next_shape_id           49818 non-null  float64
#  27  next_u                  49818 non-null  int64
# dtypes: float64(3), geometry(1), int64(7), object(17)
# memory usage: 11.0+ MB
#                     shstReferenceId                    shstGeometryId  \
# 0  bf94c0db40279cc5ef46d54d8be6139d  90d83676f262ccee0386f52a5167e6fd
# 1  1315a47eae44cb25d4ba5b9bdaa2c04a  b9429a4f0520adc5db786e220ec76c43
# 2  d8bcbf7a1eacd73c6dc94cdf86588477  eb5d72233b87c45388e9be68d7a577d5
#
#              shstFromIntersectionId              shstToIntersectionId  \
# 0  47bfb418bcc178ad00fef4071aaf5a57  c31e4495db3607e2dc4dbed346f2e363
# 1  c31e4495db3607e2dc4dbed346f2e363  1a1364a96b0a5bd7bd7a81079f3812ea
# 2  1a1364a96b0a5bd7bd7a81079f3812ea  f813a2083833e119b39a3a4d443a8978
#
#                      gisReferenceId                     gisGeometryId  \
# 0  74b0e1ba27de4555ef113010eb16ed5e  743dd80bd02aca964d6783f584141692
# 1  74b0e1ba27de4555ef113010eb16ed5e  743dd80bd02aca964d6783f584141692
# 2  74b0e1ba27de4555ef113010eb16ed5e  743dd80bd02aca964d6783f584141692
#
#    gisTotalSegments  gisSegmentIndex             gisFromIntersectionId  \
# 0               247                1  4264bd2eb5f2270e1a9c2d34fa505f7d
# 1               247                2  4264bd2eb5f2270e1a9c2d34fa505f7d
# 2               247                3  4264bd2eb5f2270e1a9c2d34fa505f7d
#
#                 gisToIntersectionId  ... shape_id                   wayId  \
# 0  7415e23dc4b24042982eb73250380539  ...      7.0                 6345240
# 1  7415e23dc4b24042982eb73250380539  ...      7.0               562054606
# 2  7415e23dc4b24042982eb73250380539  ...      7.0  [417401349, 562054606]
#
#             u           v                fromIntersectionId  \
# 0    53073691    53073689  47bfb418bcc178ad00fef4071aaf5a57
# 1    53073689  5484284278  c31e4495db3607e2dc4dbed346f2e363
# 2  5484284278    53085389  1a1364a96b0a5bd7bd7a81079f3812ea
#
#                    toIntersectionId        A        B  next_shape_id  \
# 0  c31e4495db3607e2dc4dbed346f2e363  2549243  2551858            7.0
# 1  1a1364a96b0a5bd7bd7a81079f3812ea  2551858  2520680            7.0
# 2  f813a2083833e119b39a3a4d443a8978  2520680  2515655            7.0
#
#        next_u
# 0    53073689
# 1  5484284278
# 2    53085389
#
# [3 rows x 28 columns]

# %%
# shst failed to route these trips

# some of these buses has parts that are out side of SF county boundary, that's why they are labeled as incomplete shape
# some are due to the discrepency btw shst extraction and osmnx extraction

print(incomplete_shape_list)
# Out:
# [116.0, 147.0, 148.0, 149.0, 158.0, 160.0, 161.0, 165.0, 167.0, 168.0, 172.0, 174.0, 175.0, 176.0, 188.0, 189.0, 192.0, 193.0, 194.0, 195.0, 205.0, 206.0, 207.0, 208.0, 213.0, 214.0, 217.0, 219.0, 220.0, 222.0, 230.0, 233.0, 237.0, 239.0, 240.0, 244.0, 269.0, 270.0, 274.0, 324.0, 326.0, 738.0, 757.0, 775.0, 776.0, 794.0, 803.0, 804.0, 808.0, 1228.0, 1229.0, 1239.0, 1240.0, 1241.0, 1260.0, 1276.0, 1280.0, 1281.0, 1298.0, 1299.0, 1300.0, 1301.0, 1318.0, 1324.0, 1338.0, 1349.0, 1350.0, 1357.0, 1381.0, 1383.0, 1387.0, 1388.0, 1389.0, 1647.0, 1659.0, 1661.0, 1662.0, 1668.0, 1676.0, 1678.0, 1684.0, 1706.0, 1709.0, 1710.0, 1720.0, 1721.0, 1722.0, 1723.0, 1745.0, 1746.0, 1747.0, 1755.0, 1773.0, 1780.0, 1781.0, 1787.0, 1794.0, 1795.0, 1796.0, 1802.0, 1870.0, 1875.0, 1876.0, 1889.0, 1893.0, 1901.0, 1909.0, 1916.0, 1996.0, 2010.0, 2030.0, 2031.0, 2050.0, 2051.0, 2056.0, 2057.0]

# %% [markdown]
# ### combine routing results of the two approaches

# %%
def bus_link(bus_link_osmnx, bus_link_shst, routes, trip, incomplete_list):
    
    """
    combine bus links from OSMNX and SHST
    
    Prioritize SHST matching, for those failed to match through SHST, use OSMNX routing
    """
    
    bus_link_osmnx_df = bus_link_osmnx.copy()
    bus_link_shst_df = bus_link_shst.copy()
    
    trip_df = trip.copy()
    trip_df = pd.merge(trip_df, routes[['route_id', 'route_type']], how = 'left', on = 'route_id')
    bus_trip_df = trip_df[trip_df.route_type == 3].copy()
    
    shape_id_list = bus_trip_df.shape_id.unique().tolist()

    incomplete_list = [x for x in incomplete_list]
    
    print("Targeting number of bus shape IDs: " + str(bus_trip_df.shape_id.nunique()))
    
    shst_shape_list = list(set([x for x in bus_link_shst_df.shape_id]))
    
    shapes_replace_with_shst_list = [x for x in shst_shape_list if x in shape_id_list]
    
    print("\n There are " + str(len(shapes_replace_with_shst_list)) + 
          " shapes that are from shst gtfs matching: \n \t" + 
          str(shapes_replace_with_shst_list))

    bus_link_osmnx_df = bus_link_osmnx_df[~bus_link_osmnx_df.shape_id.isin(shapes_replace_with_shst_list)].copy()
    
    osmnx_shape_list = bus_link_osmnx_df.shape_id.unique().tolist()
    
    print("\n There are " + str(len(osmnx_shape_list)) + 
          " shapes that are from OSMNX routing: \n \t" + 
          str(osmnx_shape_list))
    
    not_routed_list = [x for x in shape_id_list if x not in (shst_shape_list + osmnx_shape_list)]
    
    print("\n There are " + str(len(not_routed_list)) + 
         " shapes that are not routed by either of the two methods: \n \t" + 
         str(not_routed_list))
    
    bus_link_shst_df = pd.merge(bus_link_shst_df,
                                bus_trip_df[['trip_id', 'shape_id']],
                                how = 'inner',
                                left_on = 'shape_id',
                                right_on = 'shape_id')
    
    bus_link_df = pd.concat([bus_link_osmnx_df, bus_link_shst_df],
                            sort = False,
                           ignore_index = True)
    
    column_list = bus_link_osmnx.columns.values.tolist()
    
    return bus_link_df[column_list]

# %%
bus_link_df = bus_link(bus_osmnx_link_shape_df, bus_shst_link_shape_df, all_routes_df, trip_df, incomplete_shape_list)
# Out:
# Targeting number of bus shape IDs: 1539
#
#  There are 253 shapes that are from shst gtfs matching:
#  	[2048.0, 2054.0, 7.0, 10.0, 11.0, 13.0, 2061.0, 15.0, 16.0, 2062.0, 48.0, 52.0, 53.0, 61.0, 62.0, 2112.0, 65.0, 66.0, 2113.0, 73.0, 74.0, 77.0, 78.0, 84.0, 85.0, 86.0, 87.0, 94.0, 95.0, 97.0, 101.0, 102.0, 104.0, 105.0, 106.0, 107.0, 109.0, 110.0, 111.0, 114.0, 121.0, 123.0, 124.0, 125.0, 126.0, 127.0, 128.0, 130.0, 131.0, 132.0, 133.0, 134.0, 135.0, 136.0, 137.0, 138.0, 139.0, 140.0, 141.0, 144.0, 145.0, 150.0, 151.0, 171.0, 181.0, 185.0, 186.0, 190.0, 191.0, 196.0, 197.0, 199.0, 201.0, 202.0, 209.0, 210.0, 215.0, 216.0, 226.0, 229.0, 238.0, 241.0, 242.0, 245.0, 246.0, 249.0, 250.0, 251.0, 252.0, 253.0, 254.0, 255.0, 257.0, 258.0, 275.0, 298.0, 301.0, 304.0, 305.0, 306.0, 307.0, 312.0, 313.0, 318.0, 319.0, 323.0, 325.0, 327.0, 335.0, 336.0, 337.0, 350.0, 351.0, 374.0, 617.0, 632.0, 633.0, 634.0, 639.0, 640.0, 641.0, 642.0, 707.0, 780.0, 784.0, 786.0, 790.0, 793.0, 798.0, 802.0, 1199.0, 1201.0, 1209.0, 1210.0, 1265.0, 1267.0, 1268.0, 1269.0, 1270.0, 1273.0, 1277.0, 1296.0, 1297.0, 1302.0, 1303.0, 1304.0, 1305.0, 1307.0, 1320.0, 1321.0, 1322.0, 1339.0, 1342.0, 1343.0, 1345.0, 1346.0, 1348.0, 1351.0, 1352.0, 1355.0, 1358.0, 1365.0, 1367.0, 1371.0, 1372.0, 1375.0, 1376.0, 1377.0, 1378.0, 1379.0, 1384.0, 1386.0, 1390.0, 1391.0, 1392.0, 1393.0, 1394.0, 1395.0, 1397.0, 1398.0, 1399.0, 1400.0, 1401.0, 1403.0, 1404.0, 1405.0, 1413.0, 1414.0, 1415.0, 1441.0, 1633.0, 1669.0, 1670.0, 1674.0, 1682.0, 1687.0, 1696.0, 1700.0, 1712.0, 1713.0, 1714.0, 1715.0, 1716.0, 1750.0, 1751.0, 1752.0, 1753.0, 1758.0, 1760.0, 1761.0, 1762.0, 1765.0, 1774.0, 1775.0, 1778.0, 1782.0, 1790.0, 1798.0, 1803.0, 1805.0, 1814.0, 1816.0, 1823.0, 1825.0, 1834.0, 1841.0, 1855.0, 1856.0, 1865.0, 1866.0, 1867.0, 1869.0, 1900.0, 1902.0, 1904.0, 1906.0, 1907.0, 1908.0, 1918.0, 1920.0, 1921.0, 1924.0, 1927.0, 1937.0, 1941.0, 1944.0, 1945.0, 1946.0, 1947.0, 2025.0, 2027.0, 2046.0, 2047.0]
#
#  There are 1278 shapes that are from OSMNX routing:
#  	[359, 370, 369, 402, 403, 223, 228, 236, 217, 120, 220, 232, 225, 237, 233, 240, 230, 221, 239, 243, 244, 218, 357, 358, 373, 365, 366, 234, 231, 247, 248, 361, 362, 72, 364, 363, 182, 256, 273, 272, 9, 367, 55, 57, 50, 51, 103, 100, 8, 58, 54, 261, 259, 92, 91, 224, 368, 290, 292, 287, 285, 338, 353, 354, 356, 355, 360, 281, 280, 277, 276, 14, 271, 268, 265, 266, 263, 99, 331, 339, 340, 342, 341, 349, 352, 390, 398, 162, 187, 194, 112, 116, 213, 119, 166, 122, 117, 208, 207, 193, 161, 167, 179, 188, 205, 400, 401, 399, 378, 381, 383, 382, 380, 384, 379, 155, 152, 391, 334, 159, 160, 153, 332, 195, 177, 297, 300, 333, 118, 168, 147, 165, 189, 176, 149, 148, 88, 67, 68, 172, 174, 79, 82, 81, 83, 108, 274, 385, 80, 296, 293, 22, 20, 29, 26, 328, 75, 76, 388, 389, 387, 386, 376, 377, 214, 212, 158, 227, 12, 289, 299, 395, 394, 142, 143, 24, 25, 44, 45, 392, 393, 47, 46, 63, 64, 279, 278, 288, 316, 317, 90, 89, 69, 70, 396, 129, 19, 18, 33, 32, 37, 36, 35, 34, 375, 302, 303, 330, 329, 59, 60, 39, 38, 17, 5, 3, 397, 326, 324, 49, 320, 42, 43, 314, 315, 344, 343, 348, 346, 347, 345, 470, 468, 463, 451, 462, 453, 459, 439, 458, 454, 473, 422, 475, 440, 434, 447, 446, 424, 438, 449, 444, 460, 443, 437, 450, 426, 476, 466, 427, 477, 428, 469, 425, 472, 456, 423, 457, 433, 442, 430, 436, 429, 445, 461, 478, 465, 448, 474, 464, 441, 431, 471, 432, 455, 479, 452, 435, 467, 492, 494, 495, 490, 496, 498, 493, 499, 491, 512, 538, 540, 539, 501, 505, 506, 508, 510, 511, 513, 516, 517, 518, 519, 520, 522, 523, 524, 525, 526, 527, 528, 529, 530, 532, 533, 534, 521, 537, 536, 535, 555, 581, 583, 582, 544, 548, 549, 551, 553, 554, 556, 559, 560, 561, 562, 563, 565, 566, 567, 568, 569, 570, 571, 572, 573, 575, 576, 577, 564, 580, 579, 578, 645, 646, 602, 601, 649, 648, 647, 650, 653, 598, 596, 597, 638, 629, 627, 603, 606, 604, 605, 643, 644, 623, 619, 621, 620, 607, 608, 660, 661, 679, 678, 682, 685, 686, 688, 690, 691, 600, 599, 613, 612, 610, 664, 663, 662, 665, 671, 669, 668, 670, 659, 658, 666, 667, 680, 681, 586, 588, 590, 592, 594, 595, 702, 703, 709, 708, 695, 696, 706, 704, 705, 710, 692, 694, 636, 635, 697, 698, 701, 700, 618, 631, 728, 729, 730, 731, 739, 740, 742, 743, 744, 745, 746, 747, 748, 749, 750, 753, 756, 758, 761, 762, 763, 764, 765, 766, 767, 768, 769, 771, 772, 773, 774, 777, 778, 779, 781, 782, 783, 785, 791, 792, 795, 794, 796, 789, 805, 797, 788, 787, 803, 804, 810, 809, 811, 808, 807, 815, 816, 819, 817, 822, 820, 812, 824, 823, 716, 720, 721, 722, 723, 727, 726, 719, 725, 2101, 2094, 2106, 2091, 2086, 2085, 2087, 2090, 2089, 2092, 2105, 2093, 2095, 2096, 2097, 2098, 2099, 829, 830, 831, 832, 833, 1257, 1251, 1263, 1253, 1435, 1436, 1434, 1252, 1256, 1207, 1200, 1356, 1206, 1353, 1328, 1354, 1337, 1208, 1338, 1330, 1327, 1325, 1329, 1331, 1438, 1308, 1298, 1301, 1300, 1299, 1437, 1422, 1237, 1247, 1248, 1266, 1323, 1196, 1211, 1223, 1224, 1212, 1214, 1215, 1213, 1333, 1334, 1226, 1227, 1220, 1221, 1311, 1317, 1318, 1312, 1240, 1241, 1242, 1243, 1229, 1228, 1291, 1287, 1288, 1279, 1275, 1335, 1274, 1336, 1282, 1280, 1276, 1420, 1238, 1233, 1389, 1381, 1362, 1370, 1374, 1368, 1344, 1388, 1382, 1383, 1411, 1410, 1406, 1408, 1357, 1363, 1309, 1316, 1369, 1373, 1412, 1360, 1409, 1310, 1361, 1416, 1417, 1439, 1448, 1449, 1450, 1451, 1452, 1453, 1454, 1455, 1456, 1440, 1442, 1443, 1444, 1445, 1446, 1447, 835, 836, 839, 1113, 1114, 1115, 1116, 1110, 1111, 1112, 1117, 1106, 1107, 1108, 1109, 841, 842, 843, 845, 858, 857, 854, 852, 851, 848, 846, 859, 860, 861, 862, 863, 864, 899, 900, 866, 867, 865, 869, 871, 870, 873, 874, 875, 876, 877, 879, 881, 882, 884, 883, 886, 887, 888, 889, 897, 893, 890, 1120, 1121, 1122, 1123, 1132, 1131, 903, 904, 905, 906, 907, 909, 910, 912, 915, 919, 921, 922, 923, 924, 925, 935, 928, 927, 1118, 1119, 940, 941, 942, 943, 945, 946, 947, 948, 949, 953, 954, 961, 963, 964, 967, 968, 971, 972, 976, 1125, 1124, 981, 979, 977, 982, 983, 986, 987, 988, 989, 990, 992, 995, 998, 999, 1000, 1001, 1003, 100 ...
#
#  There are 8 shapes that are not routed by either of the two methods:
#  	[541, 502, 503, 514, 584, 545, 546, 557]

# %%
bus_link_df.info()
bus_link_df.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 939083 entries, 0 to 939082
# Data columns (total 9 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   u                939083 non-null  int64
#  1   v                939083 non-null  int64
#  2   trip_id          939083 non-null  int32
#  3   shape_id         939083 non-null  float64
#  4   wayId            939083 non-null  object
#  5   shstReferenceId  939083 non-null  object
#  6   shstGeometryId   939083 non-null  object
#  7   A                939083 non-null  int64
#  8   B                939083 non-null  int64
# dtypes: float64(1), int32(1), int64(4), object(3)
# memory usage: 60.9+ MB
#           u         v  trip_id  shape_id      wayId  \
# 0  57808643  57808641        9     359.0  303291893
# 1  57808641  57808639        9     359.0  303291893
# 2  57808639  57808637        9     359.0  303291893
#
#                     shstReferenceId                    shstGeometryId  \
# 0  020aa1becdbef42ef4245a3c278e9d29  c0f97948d99c64e52ae3c463383dabbf
# 1  1f81b33f6a786a97a0ed79bd2074ba02  94987b6adba60bad1ce73f6ec491fdf0
# 2  1e505f22f056942e593ee134ec97e624  f1dc7acbc076866422e7f373d4b2b643
#
#          A        B
# 0  3047632  3052718
# 1  3052718  3006601
# 2  3006601  3070234

# %% [markdown]
# ### build non-bus/rail links and nodes

# %%
# manual correction for Capitol Corridor
# the shape_id from GTFS are wrong
# use the trips that go to San Jose

trip_df.loc[(trip_df.shape_id==487)&(trip_df.tod=="AM"), 
                 "trip_id"] = 8042
trip_df.loc[(trip_df.shape_id==487)&(trip_df.tod=="MD"), 
                 "trip_id"] = 8049
trip_df.loc[(trip_df.shape_id==487)&(trip_df.tod=="PM"), 
                 "trip_id"] = 8054
trip_df.loc[(trip_df.shape_id==487)&(trip_df.tod=="NT"), 
                 "trip_id"] = 8063

# %%
# create rail links
def non_bus_link(stop_times, shapes, routes, trip, stop):
    
    """
    create rail links and nodes
    
    nodes are based on rail stops, links are true shape between nodes
    
    return
    ---------
    complete rail link path for each rail service
    complete rail node path for each rail service
    
    """
    
    print('generating rail links...')
    
    #get rail trips
    trip_df = trip.copy()
    trip_df = pd.merge(trip_df, routes[['route_id', 'route_type']], how = 'left', on = 'route_id')
    rail_trip_df = trip_df[trip_df.route_type != 3].copy()
    
    stop_df = stop.copy()
    stop_time_df = stop_times.copy()
    
    #get rail trips with stops
    chained_stop_to_node_df = pd.merge(stop_time_df, 
                                       stop_df, 
                                       how = 'left', 
                                       on = 'stop_id')
    
    rail_stop_time_df = chained_stop_to_node_df[
                                                chained_stop_to_node_df['trip_id']\
                                                .isin(rail_trip_df.trip_id.tolist())
                                               ]\
                                                .copy()
    
    #get gtfs rail shapes
    rail_shape_df = shapes[shapes['shape_id'].isin(rail_trip_df.shape_id.tolist())
                                ].copy()
    
    #gtfs shape-trip correspondence
    shape_trip_dict = dict(zip(rail_trip_df.shape_id, rail_trip_df.trip_id))
    
    # manual correction
    shape_trip_dict[486] = 8039
    shape_trip_dict[487] = 8042
    
    print(rail_shape_df.shape_id.unique())
    #for each rail shape
    for i in rail_shape_df.shape_id.unique():
    
        trip_id = shape_trip_dict[i]
        
        #get chained stop
        trip_stop_df = rail_stop_time_df[rail_stop_time_df.trip_id == trip_id].copy()
        
        trip_stop_df.sort_values(by = ["stop_sequence"], inplace = True)
        
        # get gtfs shape nodes for the shape
        trip_shape_df = rail_shape_df[rail_shape_df.shape_id == i].copy()
        # initialize columns
        trip_shape_df['is_stop'] = np.int(0)
        trip_shape_df['stop_id'] = np.nan
        
        # for each rail stop, find the closest node in the shape, and those are the stops and breakpoints of new rail links
        # return is a gtfs node shape dataframe with two columns indicating if the node is a stop and the stop id
        shape_inventory = trip_shape_df[['shape_pt_lon', 'shape_pt_lat']].values
        tree = cKDTree(shape_inventory)
        for s in range(len(trip_stop_df)):
            point = trip_stop_df.iloc[s][['stop_lon', 'stop_lat']].values
            dd, ii = tree.query(point, k = 1)
            trip_shape_df.shape_pt_lon.iloc[ii] = trip_stop_df.iloc[s]['stop_lon']
            trip_shape_df.shape_pt_lat.iloc[ii] = trip_stop_df.iloc[s]['stop_lat']
            trip_shape_df.is_stop.iloc[ii] = 1
            trip_shape_df.stop_id.iloc[ii] = trip_stop_df.iloc[s]['stop_id']
        
        # appending the gtfs shape for each route shape id
        if i == rail_shape_df.shape_id.unique()[0]:
            shape_flag_df = trip_shape_df.copy()
        else:
            shape_flag_df = shape_flag_df.append(trip_shape_df, 
                                                 ignore_index = True, 
                                                 sort = False)
    
    # starting to build new rail links true shape
    linestring_df = pd.DataFrame(columns = ['shape_id', 'u', 'v', 'geometry', 'u_stop_id', 'v_stop_id'])

    # rail links are based on the gtfs shape, with nodes being the shapes that are identified as rail stops.
    for i in shape_flag_df.shape_id.unique():
        # get gtfs shape for shape id
        shape_route_df = shape_flag_df[shape_flag_df.shape_id == i].copy()
        
        # get rail nodes based on the stop flags
        break_list = shape_route_df.index[shape_route_df.is_stop == 1].tolist()
        stop_id_list = shape_route_df[shape_route_df.is_stop == 1]['stop_id'].tolist()
        
        # use the gtfs shape between "stop" shapes to build the rail true shape
        for j in range(len(break_list)-1):
            lon_list = shape_flag_df.shape_pt_lon.iloc[break_list[j]:break_list[j+1]+1].tolist()
            lat_list = shape_flag_df.shape_pt_lat.iloc[break_list[j]:break_list[j+1]+1].tolist()
            linestring = LineString([Point(xy) for xy in zip(lon_list,lat_list)])
            linestring_df = linestring_df.append({'shape_id':i, 
                                                  'u':break_list[j], 
                                                  'v':break_list[j+1],
                                                  'u_stop_id':stop_id_list[j], 
                                                  'v_stop_id':stop_id_list[j+1],
                                                  'geometry' : linestring}, 
                                                 ignore_index = True, 
                                                 sort = False)
    
    # add rail travel time between stops
    stop_time_df = pd.merge(
                            stop_time_df, 
                            rail_trip_df[['trip_id', 'shape_id']], 
                            how = 'left', 
                            on = 'trip_id')
    
    unique_stop_time_df = stop_time_df[
                                        stop_time_df.shape_id.notnull()
                                    ].groupby(['trip_id', 'shape_id'])\
                                    .count().reset_index()\
                                    .drop_duplicates(subset = ['shape_id']).copy()
    
    stop_time_df = stop_time_df[stop_time_df.trip_id.isin(unique_stop_time_df.trip_id.tolist())].copy()

    
    linestring_df = pd.merge(linestring_df, 
                             stop_time_df[['shape_id', 'stop_id' , 'departure_time']].rename(
                                 columns = {"stop_id" : "u_stop_id"}),
                            how = 'left',
                            on = ['shape_id', 'u_stop_id'])
    
    linestring_df = pd.merge(linestring_df, 
                             stop_time_df[['shape_id', 'stop_id', 'arrival_time']].rename(
                                 columns = {"stop_id" : "v_stop_id"}),
                            how = 'left',
                            on = ['shape_id', 'v_stop_id'])
    
    # travel time in minutes
    linestring_df['rail_traveltime'] = (linestring_df['arrival_time'] - linestring_df['departure_time'])/60
    
    rail_node_df = shape_flag_df[shape_flag_df.is_stop == 1].rename_axis('node_id').reset_index()

    
    return linestring_df, rail_node_df

# %%
# %%time
rail_path_link_gdf, rail_path_node_df = non_bus_link(all_stop_times_df, all_shapes_df, all_routes_df, trip_df, stop_df)
# Out:
# generating rail links...
# [ 404  405  406  407  408  409  410  411  412  413  414  415  416  417
#   418  419  420  421  481  483  485  482  484  486  487  711  712  713
#   714 1061 1062 1063 1064 1065 1067 1069 1070 1071 1073 1099 1102 1104
#  1135 1140 1141 1144 1145 1146 1147 1148 1151 1154 1155 1160 1161 1162
#  1163 1165 1166 1167 1169 1170 1172 1174 1175 1177 1180 1181 1182 1183
#  1184 1186 1187 1188 1189 1948 1950 1951 1960 1962 1963 1967 1969 1972
#  1973]
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# Wall time: 19.3 s

# %%
print('{} rail nodes'.format(rail_path_node_df.shape[0]))
print(rail_path_node_df.columns)

print('\n{} rail links with {} unique shapes'.format(rail_path_link_gdf.shape[0],
                                                     rail_path_link_gdf.shape_id.nunique()))
print(rail_path_link_gdf.columns)
# Out:
# 1424 rail nodes
# Index(['node_id', 'shape_pt_lat', 'shape_pt_lon', 'shape_pt_sequence',
#        'shape_dist_traveled', 'shape_id', 'is_stop', 'stop_id'],
#       dtype='object')
#
# 1339 rail links with 85 unique shapes
# Index(['shape_id', 'u', 'v', 'geometry', 'u_stop_id', 'v_stop_id',
#        'departure_time', 'arrival_time', 'rail_traveltime'],
#       dtype='object')

# %% [markdown]
# ### add ACE whose gtfs data doesn't have 'shape' info

# %%
ACE_trips_df = trip_df[trip_df.agency_raw_name == "ACE_2017_3_20"]
shape_trip_dict = dict(zip(ACE_trips_df.shape_id, ACE_trips_df.trip_id))

ACE_linestring_df = pd.DataFrame(columns = ['shape_id', 'u', 'v', 'geometry', 'u_stop_id', 'v_stop_id'])

#get chained stop
chained_trip_stop_df = pd.merge(all_stop_times_df, all_stops_df, how = "left", on = "stop_id")
    
for i in ACE_trips_df.shape_id.unique():
    trip_id = shape_trip_dict[i]
    #get chained stop
    trip_stop_df = chained_trip_stop_df[chained_trip_stop_df.trip_id == trip_id].copy()
    
    trip_shape_df = trip_stop_df.copy()
    trip_shape_df["is_stop"] = 1
    trip_shape_df["shape_id"] = i
    
    break_list = trip_shape_df.index[trip_shape_df.is_stop == 1].tolist()
    stop_id_list = trip_shape_df[trip_shape_df.is_stop == 1]['stop_id'].tolist()
    
    for j in range(len(trip_stop_df)-1):
        lon_list = trip_shape_df.stop_lon.iloc[j:j+2].tolist()
        lat_list = trip_shape_df.stop_lat.iloc[j:j+2].tolist()
        linestring = LineString([Point(xy) for xy in zip(lon_list,lat_list)])
        ACE_linestring_df = ACE_linestring_df.append({'shape_id':i, 
                                                  'u':break_list[j], 
                                                  'v':break_list[j+1],
                                                  'u_stop_id':stop_id_list[j], 
                                                  'v_stop_id':stop_id_list[j+1],
                                                  'geometry' : linestring}, 
                                                 ignore_index = True, 
                                                 sort = False)
    if i == ACE_trips_df.shape_id.unique()[0]:
        ACE_rail_node_df = trip_shape_df
    else:
        ACE_rail_node_df = ACE_rail_node_df.append(trip_shape_df, ignore_index = False, sort = False)

stop_time_df = pd.merge(all_stop_times_df, 
                            ACE_trips_df[['trip_id', 'shape_id']], 
                            how = 'left', 
                            on = 'trip_id')

unique_stop_time_df = stop_time_df[stop_time_df.shape_id.notnull()
                                    ].groupby(['trip_id', 'shape_id'])\
                                    .count().reset_index()\
                                    .drop_duplicates(subset = ['shape_id']).copy()

stop_time_df = stop_time_df[stop_time_df.trip_id.isin(unique_stop_time_df.trip_id.tolist())].copy()
        
ACE_linestring_df = pd.merge(ACE_linestring_df, 
                        stop_time_df[['shape_id', 'stop_id' , 'departure_time']].rename(
                                 columns = {"stop_id" : "u_stop_id"}),
                            how = 'left',
                            on = ['shape_id', 'u_stop_id'])
    
ACE_linestring_df = pd.merge(ACE_linestring_df, 
                        stop_time_df[['shape_id', 'stop_id', 'arrival_time']].rename(
                                 columns = {"stop_id" : "v_stop_id"}),
                            how = 'left',
                            on = ['shape_id', 'v_stop_id'])
    
# travel time in minutes
ACE_linestring_df['rail_traveltime'] = (ACE_linestring_df['arrival_time'] - ACE_linestring_df['departure_time'])/60

ACE_rail_node_df = ACE_rail_node_df.rename_axis('node_id').reset_index()
ACE_rail_node_df.rename(columns = {"stop_lat" : "shape_pt_lat", 
                                   "stop_lon" : "shape_pt_lon", 
                                   "stop_sequence": "shape_pt_sequence"},
                       inplace = True)

# %%
# combine ACE with rest of rail

rail_path_link_with_ACE_gdf = pd.concat([rail_path_link_gdf, ACE_linestring_df], sort = False, ignore_index = True)
rail_path_node_with_ACE_df = pd.concat([rail_path_node_df, ACE_rail_node_df[rail_path_node_df.columns]], 
                                       sort = False, ignore_index = True)

# %%
print('including ACE, {} rail links with {} shapes, and {} rail nodes'.format(
    rail_path_link_with_ACE_gdf.shape[0],
    rail_path_link_with_ACE_gdf.shape_id.nunique(),
    rail_path_node_with_ACE_df.shape[0]))
# Out:
# including ACE, 1357 rail links with 87 shapes, and 1444 rail nodes

# %% [markdown]
# ### combine bus and rail

# %%
def combine_bus_and_rail_shape(rail_path_link, rail_path_node, link, node, shape):
    
    """
    add only unique rail links and nodes to roadway standard
    
    parameter
    -----------
    complete rail link path
    complete rail node path
    all roadway links
    all roadway nodes
    all roadway shapes
    
    return
    -----------
    all roadway and rail links
    all roadway and rail nodes
    all roadway and rail shapes
    unique rail links
    unique rail nodes
    complete rail link path with updated link ID
    
    """
    
    print('indexing rail links and nodes...')
    
    node_gdf = node.copy()
    link_df = link.copy()
    shape_gdf = shape.copy()
    
    # add unique rail nodes to roadway node dataframe
    rail_path_node_gdf = rail_path_node.copy()
    
    unique_rail_node_df = rail_path_node_gdf.drop_duplicates(['shape_pt_lat', 'shape_pt_lon']).copy()
    
    # http://bayareametro.github.io/travel-model-two/input/#roadway-network
    TAP_start_number = 90001 
    
    unique_rail_node_df['model_node_id'] = range(TAP_start_number, TAP_start_number + len(unique_rail_node_df))
    
    rail_path_node_gdf = pd.merge(rail_path_node_gdf, 
                            unique_rail_node_df[['shape_pt_lat', 'shape_pt_lon', 'model_node_id']], 
                            how = 'left', 
                            on = ['shape_pt_lat', 'shape_pt_lon'])
    
    # get unique rail nodes
    unique_rail_node_df['geometry'] = [Point(xy) for xy in zip(unique_rail_node_df.shape_pt_lon, 
                                                               unique_rail_node_df.shape_pt_lat)]
    
    unique_rail_node_df = gpd.GeoDataFrame(unique_rail_node_df)
    unique_rail_node_df.crs = {'init' : 'epsg:4326'}
    unique_rail_node_df = unique_rail_node_df.to_crs(node_gdf.crs)
    
    unique_rail_node_df['rail_only'] = int(1)
    unique_rail_node_df["walk_access"] = int(1)
    
    # combine rail nodes and roadway nodes
    node_gdf["rail_only"] = int(0)
    
    rail_node_columns = ["model_node_id", "geometry", "rail_only", "walk_access"]
    
    roadway_and_rail_node_gdf = node_gdf.append(unique_rail_node_df[rail_node_columns],
                                                ignore_index = True, 
                                                sort = False)
    
    
    rail_node_osmid_dict = dict(zip(rail_path_node_gdf.node_id, rail_path_node_gdf.model_node_id))
    
    rail_path_link_df = rail_path_link.copy()
    
    rail_path_link_df['A'] = rail_path_link_df.u.map(rail_node_osmid_dict)
    rail_path_link_df['B'] = rail_path_link_df.v.map(rail_node_osmid_dict)
    
    rail_path_link_df.drop(["u", "v"], axis = 1, inplace = True)
    
    rail_path_link_df = gpd.GeoDataFrame(rail_path_link_df)
    rail_path_link_df.crs = {'init' : 'epsg:4326'}
    
    # get unique rail links
    unique_rail_link_gdf = rail_path_link_df.drop_duplicates(['A', 'B']).copy()
    
    # fake rail link shst geom id
    unique_rail_link_gdf['shstGeometryId'] = range(1, 1 + len(unique_rail_link_gdf))
    unique_rail_link_gdf['shstGeometryId'] = unique_rail_link_gdf.shstGeometryId.apply(lambda x:'rail'+str(x))
    unique_rail_link_gdf['id'] = unique_rail_link_gdf['shstGeometryId']

    unique_rail_link_gdf['rail_only'] = int(1)
    
    rail_path_link_df = pd.merge(rail_path_link_df,
                                unique_rail_link_gdf[["A", "B", "shstGeometryId"]],
                                how = "left",
                                on = ["A", "B"])
    
    rail_link_columns = ['A', 'B', "shstGeometryId", "rail_traveltime", "rail_only", "id"]
    rail_shape_columns = ["id", "geometry"]
    
    # combine rail and roadway links
    roadway_and_rail_link_df = link_df.append(unique_rail_link_gdf[rail_link_columns], 
                                              ignore_index = True, 
                                              sort = False)
    
    # combine rail and roadway shapes
    roadway_and_rail_shape_gdf = shape_gdf.append(unique_rail_link_gdf[rail_shape_columns],
                                                 ignore_index = True,
                                                 sort = False)
    
    """rail_path_link_df = pd.merge(rail_path_link_df[['shape_id', 'geometry', 'u_stop_id', 'v_stop_id']],
                            unique_rail_shape_gdf.drop(['geometry', 'shape_id'], axis = 1),
                            how = 'left',
                            on = ['u_stop_id', 'v_stop_id'])"""
    
    rail_path_link_df = rail_path_link_df.to_crs({'init' : 'epsg:4326'})
        
    return roadway_and_rail_link_df, roadway_and_rail_node_gdf, roadway_and_rail_shape_gdf, \
                unique_rail_link_gdf, unique_rail_node_df, \
                rail_path_link_df

# %%
roadway_and_rail_link_df, \
roadway_and_rail_node_gdf, \
roadway_and_rail_shape_gdf, \
unique_rail_link_gdf, \
unique_rail_node_gdf, \
rail_link_gdf = combine_bus_and_rail_shape(
                                           rail_path_link_with_ACE_gdf, 
                                           rail_path_node_with_ACE_df,
                                           link_df, 
                                           node_gdf,
                                           shape_gdf)
# Out:
# indexing rail links and nodes...
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
print('{} roadway links, {} links after adding transit gtfs'.format(link_df.shape[0],
                                                                    roadway_and_rail_link_df.shape[0]))
print('{} roadway nodes, {} nodes after adding transit gtfs'.format(node_gdf.shape[0],
                                                                    roadway_and_rail_node_gdf.shape[0]))
print('{} roadway shapes, {} shapes after adding transit gtfs'.format(shape_gdf.shape[0],
                                                                      roadway_and_rail_shape_gdf.shape[0]))
# Out:
# 1632702 roadway links, 1633452 links after adding transit gtfs
# 643811 roadway nodes, 644480 nodes after adding transit gtfs
# 868567 roadway shapes, 869317 shapes after adding transit gtfs

# %% [markdown]
# ## re-number rail nodes and links to be consistent with the county numbering ranges

# %%
# county_file = "../../data/external/county_boundaries/cb_2018_us_county_500k/cb_2018_us_county_500k.shp"

# county_gdf = gpd.read_file(county_file)

# # convert to EPSG 4326
# county_gdf = county_gdf.to_crs(shape_gdf.crs)

# # double check
# print(unique_rail_link_gdf.crs)

# %%
# use nearest match for rail nodes

node_county_matched_gdf = node_gdf.copy()
node_county_unmatched_gdf = unique_rail_node_gdf.copy()

node_county_matched_gdf = node_county_matched_gdf.to_crs(epsg = 26915)
node_county_matched_gdf['X'] = node_county_matched_gdf.geometry.map(lambda g:g.x)
node_county_matched_gdf['Y'] = node_county_matched_gdf.geometry.map(lambda g:g.y)

node_matched_inventory_ref = node_county_matched_gdf[['X', 'Y']].values
node_matched_tree = cKDTree(node_matched_inventory_ref)

node_county_unmatched_gdf = node_county_unmatched_gdf.to_crs({'init' : 'epsg:26915'})
node_county_unmatched_gdf['X'] = node_county_unmatched_gdf['geometry'].apply(lambda p: p.x)
node_county_unmatched_gdf['Y'] = node_county_unmatched_gdf['geometry'].apply(lambda p: p.y)

node_county_rematch_gdf = pd.DataFrame()

for i in range(len(node_county_unmatched_gdf)):
    point = node_county_unmatched_gdf.iloc[i][['X', 'Y']].values
    dd, ii = node_matched_tree.query(point, k = 1)
    add_snap_gdf = gpd.GeoDataFrame(node_county_matched_gdf.iloc[ii][["county"]]).transpose().reset_index(drop = True)
    
    add_snap_gdf['model_node_id'] = node_county_unmatched_gdf.iloc[i]['model_node_id']
    
    if i == 0:
        node_county_rematch_gdf = add_snap_gdf.copy()
    else:
        node_county_rematch_gdf = node_county_rematch_gdf.append(add_snap_gdf, ignore_index=True, sort=False)
        
        
# use nearest match for rail links
node_county_matched_gdf = node_gdf.copy()

node_county_matched_gdf = node_county_matched_gdf.to_crs(epsg = 26915)
node_county_matched_gdf['X'] = node_county_matched_gdf.geometry.map(lambda g:g.x)
node_county_matched_gdf['Y'] = node_county_matched_gdf.geometry.map(lambda g:g.y)

node_matched_inventory_ref = node_county_matched_gdf[['X', 'Y']].values
node_matched_tree = cKDTree(node_matched_inventory_ref)

shape_county_unmatched_gdf = unique_rail_link_gdf.copy()
shape_county_unmatched_gdf["geometry"] = unique_rail_link_gdf.centroid

shape_county_unmatched_gdf = shape_county_unmatched_gdf.to_crs({'init' : 'epsg:26915'})
shape_county_unmatched_gdf["geometry"] = shape_county_unmatched_gdf["geometry"].centroid
shape_county_unmatched_gdf['X'] = shape_county_unmatched_gdf['geometry'].apply(lambda p: p.x)
shape_county_unmatched_gdf['Y'] = shape_county_unmatched_gdf['geometry'].apply(lambda p: p.y)

shape_county_rematch_gdf = pd.DataFrame()

for i in range(len(shape_county_unmatched_gdf)):
    point = shape_county_unmatched_gdf.iloc[i][['X', 'Y']].values
    dd, ii = node_matched_tree.query(point, k = 1)
    add_snap_gdf = gpd.GeoDataFrame(node_county_matched_gdf.iloc[ii][["county"]]).transpose().reset_index(drop = True)
    
    add_snap_gdf['id'] = shape_county_unmatched_gdf.iloc[i]['id']
    
    if i == 0:
        shape_county_rematch_gdf = add_snap_gdf.copy()
    else:
        shape_county_rematch_gdf = shape_county_rematch_gdf.append(add_snap_gdf, ignore_index=True, sort=False)
# Out:
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\ipykernel_launcher.py:43: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
display(node_county_rematch_gdf)
display(shape_county_rematch_gdf)
# Out:
#            county  model_node_id
# 0    Contra Costa          90001
# 1    Contra Costa          90002
# 2    Contra Costa          90003
# 3    Contra Costa          90004
# 4    Contra Costa          90005
# ..            ...            ...
# 664       Alameda          90665
# 665       Alameda          90666
# 666   Santa Clara          90667
# 667   Santa Clara          90668
# 668   Santa Clara          90669
#
# [669 rows x 2 columns]
#            county       id
# 0    Contra Costa    rail1
# 1    Contra Costa    rail2
# 2    Contra Costa    rail3
# 3    Contra Costa    rail4
# 4    Contra Costa    rail5
# ..            ...      ...
# 745       Alameda  rail746
# 746       Alameda  rail747
# 747       Alameda  rail748
# 748       Alameda  rail749
# 749  Contra Costa  rail750
#
# [750 rows x 2 columns]

# %%
# get the last node and link number of counties

county_last_node_id_df = node_gdf.groupby("county")["model_node_id"].max().reset_index().rename(
    columns = {"model_node_id" : "county_last_id"})

county_last_link_id_df = link_df.groupby("county")["model_link_id"].max().reset_index().rename(
    columns = {"model_link_id" : "county_last_id"})

node_county_rematch_gdf = pd.merge(
    node_county_rematch_gdf.rename(columns = {"model_node_id" : "rail_node_id"}),
    county_last_node_id_df,
    how = "left",
    on = "county"
)

node_county_rematch_gdf["model_node_id"] = node_county_rematch_gdf.groupby(["county"]).cumcount() + 1

node_county_rematch_gdf["model_node_id"] = node_county_rematch_gdf["model_node_id"] + node_county_rematch_gdf["county_last_id"]

shape_county_rematch_gdf = pd.merge(
    shape_county_rematch_gdf,
    county_last_link_id_df,
    how = "left",
    on = "county"
)

shape_county_rematch_gdf["model_link_id"] = shape_county_rematch_gdf.groupby(["county"]).cumcount() + 1

shape_county_rematch_gdf["model_link_id"] = shape_county_rematch_gdf["model_link_id"] + shape_county_rematch_gdf["county_last_id"]

# %%
# update to model_node_id and model_link_id for rail

# create dictionary
rail_node_id_dict = dict(zip(node_county_rematch_gdf.rail_node_id, node_county_rematch_gdf.model_node_id))
rail_node_county_dict = dict(zip(node_county_rematch_gdf.model_node_id, node_county_rematch_gdf.county))
rail_link_id_dict = dict(zip(shape_county_rematch_gdf.id, shape_county_rematch_gdf.model_link_id))
rail_link_county_dict = dict(zip(shape_county_rematch_gdf.id, shape_county_rematch_gdf.county))

# map to model_node_id and model_link_id
unique_rail_node_gdf["model_node_id"] = unique_rail_node_gdf["model_node_id"].map(rail_node_id_dict)
unique_rail_node_gdf["county"] = unique_rail_node_gdf["model_node_id"].map(rail_node_county_dict)
unique_rail_link_gdf["model_link_id"] = unique_rail_link_gdf["id"].map(rail_link_id_dict)
unique_rail_link_gdf["county"] = unique_rail_link_gdf["id"].map(rail_link_county_dict)

# update A/B
unique_rail_link_gdf["A"] = unique_rail_link_gdf["A"].map(rail_node_id_dict)
unique_rail_link_gdf["B"] = unique_rail_link_gdf["B"].map(rail_node_id_dict)

rail_link_gdf["A"] = rail_link_gdf["A"].map(rail_node_id_dict)
rail_link_gdf["B"] = rail_link_gdf["B"].map(rail_node_id_dict)

# %%
# clean up and combine with roadway links and shapes

# combine rail and roadway nodes
rail_node_columns = ["model_node_id", "geometry", "rail_only", "walk_access", "county"]
    
roadway_and_rail_node_gdf = node_gdf.append(unique_rail_node_gdf[rail_node_columns],
                                            ignore_index = True, 
                                            sort = False)

roadway_and_rail_node_gdf["rail_only"].fillna(0, inplace = True)
roadway_and_rail_node_gdf["rail_only"] = roadway_and_rail_node_gdf["rail_only"].astype(int)
    
# combine rail and roadway links
rail_link_columns = ['A', 'B', "shstGeometryId", "rail_traveltime","rail_only", "id", "model_link_id", "county"]

roadway_and_rail_link_df = link_df.append(unique_rail_link_gdf[rail_link_columns], 
                                              ignore_index = True, 
                                              sort = False)

roadway_and_rail_link_df["rail_only"].fillna(0, inplace = True)
roadway_and_rail_link_df["rail_only"] = roadway_and_rail_link_df["rail_only"].astype(int)
    
# combine rail and roadway shapes
rail_shape_columns = ["id", "geometry"]

roadway_and_rail_shape_gdf = shape_gdf.append(unique_rail_link_gdf[rail_shape_columns],
                                                 ignore_index = True,
                                                 sort = False)

# %%
print('after reassigning model_node_id and model_link_id,\n roadway and rail networks have {} links, {} link shapes, {} nodes'.format(
        roadway_and_rail_link_df.shape[0],
        roadway_and_rail_shape_gdf.shape[0],
        roadway_and_rail_node_gdf.shape[0]))
# Out:
# after reassigning model_node_id and model_link_id,
#  roadway and rail networks have 1633452 links, 869317 link shapes, 644480 nodes

# %% [markdown]
# # modify and write out Transit standard files

# %%
# transit frequence based stop time

def create_freq_table(trip_df):
    
    """
    create frequency table for network standard
    
    trip_df: representative trips from gtfs
    
    """
    
    print('creating frequency reference...')
    
    # calculate EA and NT frequency using 5-6am, and 7-10pm
    tod_numhours_dict = {"AM" : 4, "MD" : 5, "PM" :4, "NT" : 3, "EA" : 1}
    
    freq_df = trip_df[['trip_id', 'tod', 'direction_id', 'trip_num']].copy()
    freq_df['headway_secs'] = freq_df.tod.map(tod_numhours_dict)
    freq_df['headway_secs'] = freq_df.apply(lambda x: int(x.headway_secs * 60 * 60 / x.trip_num),
                                           axis = 1)
    
    freq_enum_list = {'start_time' : {'AM' : '06:00:00', 
                                      'MD' : '10:00:00',
                                      "PM" : "15:00:00",
                                      "NT" : "19:00:00",
                                      "EA" : "03:00:00"},
                      'end_time' : {'AM' : '10:00:00', 
                                    'MD' : '15:00:00',
                                    "PM" : "19:00:00",
                                    "NT" : "03:00:00",
                                    "EA" : "06:00:00"}}
    
    freq_df['start_time'] = freq_df.tod.map(freq_enum_list.get("start_time"))
    freq_df['end_time'] = freq_df.tod.map(freq_enum_list.get("end_time"))
    
    return freq_df

# %%
freq_df = create_freq_table(trip_df)

display(freq_df)
# Out:
# creating frequency reference...
#       trip_id tod  direction_id  trip_num  headway_secs start_time  end_time
# 0           1  EA           0.0       1.0          3600   03:00:00  06:00:00
# 1           5  AM           0.0       2.0          7200   06:00:00  10:00:00
# 2           4  PM           1.0       4.0          3600   15:00:00  19:00:00
# 3           9  EA           1.0       1.0          3600   03:00:00  06:00:00
# 4          10  AM           1.0       5.0          2880   06:00:00  10:00:00
# ...       ...  ..           ...       ...           ...        ...       ...
# 4072    34168  PM           1.0       3.0          4800   15:00:00  19:00:00
# 4073    34017  AM           0.0       5.0          2880   06:00:00  10:00:00
# 4074    34022  PM           0.0       6.0          2400   15:00:00  19:00:00
# 4075    34028  NT           0.0       1.0         10800   19:00:00  03:00:00
# 4076    34029  MD           0.0       1.0         18000   10:00:00  15:00:00
#
# [4077 rows x 7 columns]

# %%
# create new shape with complete node list the route passes
def create_new_node_shape(node, bus_link, rail_link = pd.DataFrame(columns = ["u", "v", "shape_id", "A", "B"])):
    
    """
    create complete node lists each transit traverses to replace the gtfs shape.txt
    """
    bus_link_df = bus_link.copy()
    bus_trip_list_with_unique_shape_id = bus_link_df.drop_duplicates(subset = ["shape_id"]).trip_id.tolist()
    
    bus_link_df = bus_link_df[bus_link_df.trip_id.isin(bus_trip_list_with_unique_shape_id)].copy()
    
    shape_link_df = pd.concat([bus_link_df[["u", "v", 'shape_id', "A", "B"]]
                                , rail_link[['shape_id', "A", "B"]]],
                               sort = False,
                               ignore_index = True)
    
    shape_link_df.u = shape_link_df.u.fillna(0).astype(np.int64)
    shape_link_df.v = shape_link_df.v.fillna(0).astype(np.int64)

    shape_point_df = gpd.GeoDataFrame()
    
    for shape_id in shape_link_df.shape_id.unique():
        shape_df = shape_link_df[shape_link_df.shape_id == shape_id]
        point_df = pd.DataFrame(data = {"shape_id" : shape_id,
                                         "shape_osm_node_id" : shape_df.u.tolist() + [shape_df.v.iloc[-1]],
                                        "shape_model_node_id" : shape_df.A.tolist() + [shape_df.B.iloc[-1]],
                                       "shape_pt_sequence" : range(1, 1+len(shape_df)+1)})
   
        shape_point_df = pd.concat([shape_point_df,
                                   point_df],
                                  sort = False,
                                  ignore_index = True)

    shape_point_df = pd.merge(shape_point_df,
                             node[["osm_node_id", "shst_node_id", "model_node_id", "geometry"]],
                             how = "left",
                             left_on = "shape_model_node_id",
                             right_on = "model_node_id")
    
    shape_point_df.crs = {'init' : 'epsg:4326'}
    
    print('double check: points on route shapes missing geometry: \n{}'.format(shape_point_df[shape_point_df.geometry.isnull()]))
    
    shape_point_df["shape_pt_lat"] = shape_point_df.geometry.map(lambda g:g.y)
    shape_point_df["shape_pt_lon"] = shape_point_df.geometry.map(lambda g:g.x)
    
    shape_point_df["shape_id"] = shape_point_df["shape_id"].astype(int)
    
    shape_point_df.rename(columns = {"shst_node_id":"shape_shst_node_id"}, inplace = True)
        
    return shape_point_df[["shape_id", "shape_pt_sequence", "shape_osm_node_id", "shape_shst_node_id", "shape_model_node_id"]]

# %%
shape_point_df = create_new_node_shape(roadway_and_rail_node_gdf, bus_link_df, rail_link_gdf)
# Out:
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
# double check: points on route shapes missing geometry:
# Empty DataFrame
# Columns: [shape_id, shape_osm_node_id, shape_model_node_id, shape_pt_sequence, osm_node_id, shst_node_id, model_node_id, geometry]
# Index: []

# %%
display(shape_point_df.head(10))

shape_point_df.info()
# Out:
#    shape_id  shape_pt_sequence  shape_osm_node_id  \
# 0       359                  1           57808643
# 1       359                  2           57808641
# 2       359                  3           57808639
# 3       359                  4           57808637
# 4       359                  5           57808634
# 5       359                  6         4924860621
# 6       359                  7         4924860622
# 7       359                  8           57808632
# 8       359                  9           57808630
# 9       359                 10           57807822
#
#                  shape_shst_node_id  shape_model_node_id
# 0  e7d44e84d34760e4d8ea8359e0bfe7b8              3047632
# 1  acccdab7b5c416d0cb08cd3a454c133c              3052718
# 2  4dea96f8099eb6899778d359f0181aba              3006601
# 3  9ef8fb82ea20dc287ed1ebebb20de60e              3070234
# 4  7728d88555ea4a62cd09d1269e727e4c              3026926
# 5  b19d9c7759ec8df17aa2b9a261efc09e              3027418
# 6  2a96e6d6c5b8e32ac127ae8aeb94a596              3038051
# 7  e54f087c7f4ed83cd6ae2da9ce86dd01              3013244
# 8  4e948b323a1eb20998aafc5ac91850cb              3007700
# 9  df689924893e875ae12af8b7471f4a3c              3023434
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 358076 entries, 0 to 358075
# Data columns (total 5 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   shape_id             358076 non-null  int32
#  1   shape_pt_sequence    358076 non-null  int64
#  2   shape_osm_node_id    358076 non-null  int64
#  3   shape_shst_node_id   356632 non-null  object
#  4   shape_model_node_id  358076 non-null  int64
# dtypes: int32(1), int64(3), object(1)
# memory usage: 15.0+ MB

# %%
def write_out_transit_standard(trip, stop, shape_point, freq, stop_times, routes, trips, rail_node = None):
    
    shape_point_df = shape_point.copy()
    trip_df = trip.copy()
        
    trip_df = trip_df[~ trip_df.agency_raw_name.isin(["Petaluma_2016_5_22", "WestCAT_2016_5_26", "GGFerries_2017_3_18"])].copy()
    
    trip_df["shape_id"] = trip_df["shape_id"].astype(int)
    
    trip_df = trip_df[trip_df.shape_id.isin(shape_point_df.shape_id.unique().tolist())]
    
    final_trip_list = trip_df.trip_id.unique().tolist()
    
    freq_df = freq.copy()
    freq_df = freq_df[freq_df.trip_id.isin(final_trip_list)]
    
    stop_df = stop.copy()
    
    if len(rail_node) > 0:
        rail_node_df = rail_node.copy()
        rail_node_dict = dict(zip(rail_node_df.stop_id, rail_node_df.model_node_id))
        
        stop_df['model_node_id'] = stop_df.apply(lambda x: rail_node_dict[x.stop_id] 
                                               if x.stop_id in rail_node_df.stop_id.tolist() 
                                               else x.model_node_id,
                                                axis = 1)
        stop_df['osm_node_id'] = stop_df.apply(lambda x: ""
                                                if x.stop_id in rail_node_df.stop_id.tolist() 
                                                else x.osm_node_id,
                                                axis = 1)
        stop_df['shst_node_id'] = stop_df.apply(lambda x: '' 
                                                if x.stop_id in rail_node_df.stop_id.tolist() 
                                                else x.shst_node_id,
                                                axis = 1)
    

    stop_times_df = stop_times.copy()
    stop_times_df = stop_times_df[stop_times_df.trip_id.isin(final_trip_list)]
    
    # update time to relative time for frequency based transit system
    stop_times_df['first_arrival'] = stop_times_df.groupby(['trip_id'])['arrival_time'].transform(min)
    stop_times_df['arrival_time'] = stop_times_df['arrival_time'] - stop_times_df['first_arrival']
    stop_times_df['departure_time'] = stop_times_df['departure_time'] - stop_times_df['first_arrival']
    
    stop_times_df['arrival_time'] = stop_times_df['arrival_time'].apply(
        lambda x : time.strftime('%H:%M:%S', time.gmtime(x)) if ~np.isnan(x) else x)
    stop_times_df['departure_time'] = stop_times_df['departure_time'].apply(
        lambda x : time.strftime('%H:%M:%S', time.gmtime(x)) if ~np.isnan(x) else x)

    
    stop_times_df.drop(['first_arrival'], axis = 1, inplace = True)
    
    route_df = routes.copy()
    route_df = route_df[route_df.route_id.isin(trip_df.route_id.tolist())]
    
    route_df.to_csv(output_folder + "routes.txt", 
                    index = False, 
                    sep = ',')
   
    shape_point_df.to_csv(output_folder + "shapes.txt", 
                          index = False, 
                          sep = ',')
  
    trip_df[trips.columns.values].to_csv(output_folder + "trips.txt", 
                                              index = False, 
                                              sep = ',')
  
    freq_df[['trip_id', 'headway_secs', 'start_time', 'end_time']].to_csv(output_folder + "frequencies.txt", 
                                                index = False, 
                                                sep = ',')
    
    stop_df.to_csv(output_folder + "stops.txt", 
                   index = False, 
                   sep = ',')
   
    stop_times_df.to_csv(output_folder + "stop_times.txt", 
                         index = False, 
                         sep = ',')

# %%
write_out_transit_standard(trip_df, 
                           stop_df, 
                           shape_point_df, 
                           freq_df, 
                           all_stop_times_df,
                           all_routes_df,
                           all_trips_df,
                           unique_rail_node_gdf)

# %% [markdown]
# # create rail-walk access links and add to the network

# %%
def create_transit_access_link(all_link, all_node, all_shape):
    
    """
    create rail walk access/egress links
    """
    
    tran_node_df = all_node[all_node.rail_only == 1].copy()
    walk_node_df = all_node[(all_node.walk_access == 1) & (all_node.rail_only == 0)].copy().reset_index(drop = True)
    
    walk_node_df = walk_node_df.to_crs({'init' : 'epsg:26915'})
    walk_node_df['X'] = walk_node_df.geometry.map(lambda g:g.x)
    walk_node_df['Y'] = walk_node_df.geometry.map(lambda g:g.y)
    inventory_node_ref = walk_node_df[['X', 'Y']].values
    tree = cKDTree(inventory_node_ref)
    
    tran_node_df = tran_node_df.to_crs({'init' : 'epsg:26915'})
    tran_node_df['X'] = tran_node_df.geometry.map(lambda g:g.x)
    tran_node_df['Y'] = tran_node_df.geometry.map(lambda g:g.y)
    
    for i in range(len(tran_node_df)):
        point = tran_node_df.iloc[i][['X', 'Y']].values
        dd, ii = tree.query(point, k = 1)
        add_node_gdf = gpd.GeoDataFrame(walk_node_df.iloc[ii]).transpose().reset_index(drop = True)
        add_node_gdf['tran_node'] = tran_node_df.iloc[i].model_node_id
        add_node_gdf['geometry_tran'] = tran_node_df.iloc[i].geometry
        
        if i == 0:
            rail_access_gdf = add_node_gdf.copy()
        else:
            rail_access_gdf = rail_access_gdf.append(add_node_gdf, ignore_index=True, sort=False)
    
    rail_access_gdf.rename(columns = {'geometry' : "geometry_walk"}, inplace = True)

    
    rail_access_gdf['geometry'] = [LineString(xy) for xy in zip(rail_access_gdf['geometry_walk'], 
                                                                rail_access_gdf['geometry_tran'])]
    
    # fake rail link shst geom id
    rail_access_gdf['shstGeometryId'] = range(1, 
                                     1 + len(rail_access_gdf))
    
    rail_access_gdf['shstGeometryId'] = rail_access_gdf.shstGeometryId.apply(lambda x:'walktorail'+str(x))
    rail_access_gdf['id'] = rail_access_gdf['shstGeometryId']
    
    rail_access_gdf["fromIntersectionId"] = rail_access_gdf.shst_node_id

    rail_access_gdf_copy = rail_access_gdf.copy()
    rail_access_gdf.rename(columns = {'model_node_id' : 'A', 'tran_node' : 'B'}, inplace = True)
    
    rail_access_gdf_copy.rename(columns = {'tran_node' : 'A', 'model_node_id' : 'B'}, inplace = True)
    
    rail_access_gdf = pd.concat(
                            [rail_access_gdf[['A', 'B', 'geometry', 'shstGeometryId', "id", "fromIntersectionId"]],
                            rail_access_gdf_copy[['A', 'B', 'geometry','shstGeometryId', "id", "fromIntersectionId"]]],
                               ignore_index = True,
                               sort = False)
    
    rail_access_gdf = gpd.GeoDataFrame(rail_access_gdf)
    rail_access_gdf.crs = {'init' : 'epsg:26915'}
    rail_access_gdf = rail_access_gdf.to_crs(all_node.crs)
    
    rail_access_gdf['walk_access'] = 1
    
    rail_access_link_columns = ["A", "B", "shstGeometryId", "walk_access", "id"]
    rail_access_shape_columns = ["id", "fromIntersectionId", "geometry"]
    
    all_link_df = all_link.copy()
    all_shape_gdf = all_shape.copy()
    
        
    all_shape_gdf = pd.concat([
                                all_shape_gdf,
                                rail_access_gdf[rail_access_shape_columns].drop_duplicates(
                                                                        subset = ["id"])
                              ],
                             sort = False,
                             ignore_index= True)

    
    all_link_df = pd.concat([all_link_df, 
                             rail_access_gdf[rail_access_link_columns]], 
                            ignore_index = True, 
                            sort = False)
    
    all_link_gdf = pd.merge(all_link_df,
                           all_shape_gdf,
                           how = "left",
                           left_on = "shstGeometryId",
                           right_on = "id")
    
    geom_length = gpd.GeoDataFrame(all_link_gdf[['geometry']])
    geom_length.crs = all_node.crs
    geom_length = geom_length.to_crs(epsg = 26915)
    geom_length["length"] = geom_length.length

    all_link_df["length"] = geom_length["length"]

    return all_link_df, all_shape_gdf

# %%
# %%time
all_link_df, all_shape_gdf = create_transit_access_link(roadway_and_rail_link_df, 
                                                        roadway_and_rail_node_gdf,
                                                        roadway_and_rail_shape_gdf)
# Out:
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# Wall time: 3min 1s

# %%
print('before adding rail walk access links, the network has {} links, with {} shapes'.format(
        roadway_and_rail_link_df.shape[0],
        roadway_and_rail_shape_gdf.shape[0]))
print('after adding rail walk access links, the network has {} links, with {} shapes'.format(
        all_link_df.shape[0],
        all_shape_gdf.shape[0]))
# Out:
# before adding rail walk access links, the network has 1633452 links, with 869317 shapes
# after adding rail walk access links, the network has 1634790 links, with 869986 shapes

# %%
# use nearest to get county match for rail walk access links
node_county_matched_gdf = node_gdf.copy()

node_county_matched_gdf = node_county_matched_gdf.to_crs(epsg = 26915)
node_county_matched_gdf['X'] = node_county_matched_gdf.geometry.map(lambda g:g.x)
node_county_matched_gdf['Y'] = node_county_matched_gdf.geometry.map(lambda g:g.y)

node_matched_inventory_ref = node_county_matched_gdf[['X', 'Y']].values
node_matched_tree = cKDTree(node_matched_inventory_ref)

link_county_unmatched_gdf = all_link_df[all_link_df.model_link_id.isnull()].copy()
link_county_unmatched_gdf = pd.merge(link_county_unmatched_gdf, all_shape_gdf[["id", "geometry"]], how = "left", on = "id")
link_county_unmatched_gdf = gpd.GeoDataFrame(link_county_unmatched_gdf, 
                                             geometry = link_county_unmatched_gdf.geometry, 
                                             crs = all_shape_gdf.crs)

link_county_unmatched_gdf = link_county_unmatched_gdf.to_crs({'init' : 'epsg:26915'})
link_county_unmatched_gdf['X'] = link_county_unmatched_gdf['geometry'].apply(lambda p: p.centroid.x)
link_county_unmatched_gdf['Y'] = link_county_unmatched_gdf['geometry'].apply(lambda p: p.centroid.y)

link_county_rematch_gdf = pd.DataFrame()

for i in range(len(link_county_unmatched_gdf)):
    point = link_county_unmatched_gdf.iloc[i][['X', 'Y']].values
    dd, ii = node_matched_tree.query(point, k = 1)
    add_snap_gdf = gpd.GeoDataFrame(node_county_matched_gdf.iloc[ii][["county"]]).transpose().reset_index(drop = True)
    
    add_snap_gdf = pd.concat([add_snap_gdf,
                              link_county_unmatched_gdf.drop("county", axis = 1).iloc[[i]].reset_index(drop = True)], 
                               axis = 1) 
    
    if i == 0:
        link_county_rematch_gdf = add_snap_gdf.copy()
    else:
        link_county_rematch_gdf = link_county_rematch_gdf.append(add_snap_gdf, ignore_index=True, sort=False)

link_county_rematch_gdf.crs = link_county_unmatched_gdf.crs
link_county_rematch_gdf = link_county_rematch_gdf.to_crs(node_gdf.crs)
# Out:
# C:\Users\lzorn\.conda\envs\tm2_network_dev\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
link_county_rematch_gdf.info()
link_county_rematch_gdf.county.value_counts()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 41 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   county                  1338 non-null   object
#  1   access                  0 non-null      object
#  2   area                    0 non-null      object
#  3   bike_access             0 non-null      float64
#  4   bridge                  0 non-null      object
#  5   drive_access            0 non-null      float64
#  6   est_width               0 non-null      object
#  7   fromIntersectionId      0 non-null      object
#  8   highway                 0 non-null      object
#  9   id                      1338 non-null   object
#  10  junction                0 non-null      object
#  11  key                     0 non-null      object
#  12  landuse                 0 non-null      object
#  13  lanes                   0 non-null      object
#  14  link                    0 non-null      object
#  15  maxspeed                0 non-null      object
#  16  name                    0 non-null      object
#  17  oneWay                  0 non-null      object
#  18  ref                     0 non-null      object
#  19  roadway                 0 non-null      object
#  20  roundabout              0 non-null      object
#  21  service                 0 non-null      object
#  22  shstGeometryId          1338 non-null   object
#  23  shstReferenceId         0 non-null      object
#  24  toIntersectionId        0 non-null      object
#  25  tunnel                  0 non-null      object
#  26  u                       0 non-null      float64
#  27  v                       0 non-null      float64
#  28  walk_access             1338 non-null   float64
#  29  wayId                   0 non-null      object
#  30  width                   0 non-null      object
#  31  length                  1338 non-null   float64
#  32  model_link_id           0 non-null      float64
#  33  county_numbering_start  0 non-null      float64
#  34  A                       1338 non-null   object
#  35  B                       1338 non-null   object
#  36  rail_traveltime         0 non-null      float64
#  37  rail_only               0 non-null      float64
#  38  geometry                1338 non-null   geometry
#  39  X                       1338 non-null   float64
#  40  Y                       1338 non-null   float64
# dtypes: float64(12), geometry(1), object(28)
# memory usage: 428.7+ KB
# San Francisco    866
# Santa Clara      300
# Alameda           70
# San Mateo         58
# Contra Costa      28
# Marin             10
# Solano             6
# Name: county, dtype: int64

# %%
# assign model_link_id to train-walk access links

# get the last link number of counties
county_last_link_id_df = roadway_and_rail_link_df.groupby("county")["model_link_id"].max().reset_index().rename(
    columns = {"model_link_id" : "county_last_id"})

link_county_rematch_gdf = pd.merge(
    link_county_rematch_gdf,
    county_last_link_id_df,
    how = "left",
    on = "county"
)

# assign model_link_id
link_county_rematch_gdf["model_link_id"] = link_county_rematch_gdf.groupby(["county"]).cumcount() + 1
link_county_rematch_gdf["model_link_id"] = link_county_rematch_gdf["model_link_id"] + link_county_rematch_gdf["county_last_id"]

# %%
# combine rail+roadway links and rail-walk access links

all_link_df = roadway_and_rail_link_df.append(link_county_rematch_gdf, 
                                              ignore_index = True, 
                                              sort = False)

# %%
# double check total number of links
all_link_df.model_link_id.nunique()
# Out:
# 1634790

# %%
# number geometry increse should be the number of transit nodes: 664+5
print(roadway_and_rail_link_df.shstGeometryId.nunique())
print(roadway_and_rail_shape_gdf.id.nunique())
print(roadway_and_rail_shape_gdf.shape)
print(all_shape_gdf.id.nunique())
print(all_shape_gdf.shape)
print(all_link_df.shstGeometryId.nunique())
# Out:
# 869317
# 869317
# (869317, 6)
# 869986
# (869986, 6)
# 869986

# %%
# number of link increase should be 2 times of transit nodes : 1328+10

print(roadway_and_rail_link_df.shape)
print(all_link_df.shape)
# Out:
# (1633452, 38)
# (1634790, 42)

# %%
# check number of links and model_link_id by county
print(all_link_df.county.value_counts(dropna=False))
print()
print(all_link_df.groupby("county")["model_link_id"].max())
# Out:
# Santa Clara      517014
# Alameda          315462
# Contra Costa     237498
# San Mateo        141024
# Sonoma           135042
# Solano           117114
# San Francisco     74758
# Marin             63198
# Napa              33680
# Name: county, dtype: int64
#
# county
# Alameda          3315461
# Contra Costa     4237497
# Marin            8063197
# Napa             6033679
# San Francisco      74758
# San Mateo        1141023
# Santa Clara      2517013
# Solano           5117113
# Sonoma           7135041
# Name: model_link_id, dtype: int64

# %% [markdown]
# # write out network standard with rail nodes and links

# %%
# clean up
all_shape_gdf = fill_na(all_shape_gdf)

int_col = ["bike_access", "walk_access", "drive_access", "rail_only"]
for c in int_col:
    all_link_df[c] = all_link_df[c].fillna(0).astype(np.int64)
    
int_col = ["bike_access", "walk_access", "drive_access", "rail_only"]
for c in int_col:
    roadway_and_rail_node_gdf[c] = roadway_and_rail_node_gdf[c].fillna(0).astype(np.int64)
# Out:
# numeric columns:  []
# str columns:  ['id', 'fromIntersectionId', 'toIntersectionId', 'forwardReferenceId', 'backReferenceId']

# %%
# files to write out
all_link_df.info()
all_shape_gdf.info()
roadway_and_rail_node_gdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1634790 entries, 0 to 1634789
# Data columns (total 42 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   access                  1632702 non-null  object
#  1   area                    1632702 non-null  object
#  2   bike_access             1634790 non-null  int64
#  3   bridge                  1632702 non-null  object
#  4   drive_access            1634790 non-null  int64
#  5   est_width               1632702 non-null  object
#  6   fromIntersectionId      1632702 non-null  object
#  7   highway                 1632702 non-null  object
#  8   id                      1634790 non-null  object
#  9   junction                1632702 non-null  object
#  10  key                     1632702 non-null  object
#  11  landuse                 1632702 non-null  object
#  12  lanes                   1632702 non-null  object
#  13  link                    1632702 non-null  object
#  14  maxspeed                1632702 non-null  object
#  15  name                    1632702 non-null  object
#  16  oneWay                  1632702 non-null  object
#  17  ref                     1632702 non-null  object
#  18  roadway                 1632702 non-null  object
#  19  roundabout              1632702 non-null  object
#  20  service                 1632702 non-null  object
#  21  shstGeometryId          1634790 non-null  object
#  22  shstReferenceId         1632702 non-null  object
#  23  toIntersectionId        1632702 non-null  object
#  24  tunnel                  1632702 non-null  object
#  25  u                       1632702 non-null  float64
#  26  v                       1632702 non-null  float64
#  27  walk_access             1634790 non-null  int64
#  28  wayId                   1632702 non-null  object
#  29  width                   1632702 non-null  object
#  30  county                  1634790 non-null  object
#  31  length                  1634040 non-null  float64
#  32  model_link_id           1634790 non-null  int64
#  33  county_numbering_start  1632702 non-null  float64
#  34  A                       1634790 non-null  object
#  35  B                       1634790 non-null  object
#  36  rail_traveltime         613 non-null      float64
#  37  rail_only               1634790 non-null  int64
#  38  geometry                1338 non-null     geometry
#  39  X                       1338 non-null     float64
#  40  Y                       1338 non-null     float64
#  41  county_last_id          1338 non-null     float64
# dtypes: float64(8), geometry(1), int64(5), object(28)
# memory usage: 523.8+ MB
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 869986 entries, 0 to 869985
# Data columns (total 6 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  869986 non-null  object
#  1   fromIntersectionId  869986 non-null  object
#  2   toIntersectionId    869986 non-null  object
#  3   forwardReferenceId  869986 non-null  object
#  4   backReferenceId     869986 non-null  object
#  5   geometry            869986 non-null  geometry
# dtypes: geometry(1), object(5)
# memory usage: 39.8+ MB
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 644480 entries, 0 to 644479
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   osm_node_id             643811 non-null  float64
#  1   shst_node_id            643811 non-null  object
#  2   county                  644480 non-null  object
#  3   drive_access            644480 non-null  int64
#  4   walk_access             644480 non-null  int64
#  5   bike_access             644480 non-null  int64
#  6   model_node_id           644480 non-null  int64
#  7   county_numbering_start  643811 non-null  float64
#  8   geometry                644480 non-null  geometry
#  9   rail_only               644480 non-null  int64
# dtypes: float64(2), geometry(1), int64(5), object(2)
# memory usage: 49.2+ MB

# %%
# %%time

print("-------write out link shape geojson---------")

shape_prop = ['id', 'fromIntersectionId', 'toIntersectionId', 'forwardReferenceId', 'backReferenceId']
shape_geojson = link_df_to_geojson(all_shape_gdf, shape_prop)

with open(os.path.join(output_data_version_dir, "shape.geojson"), "w") as f:
    json.dump(shape_geojson, f)
# Out:
# -------write out link shape geojson---------
# Wall time: 4min 35s

# %%
# %%time

# write out link variable json
# link unique handle "shstReferenceId" + "shstGeometryId"

print("-------write out link json---------")

link_prop = all_link_df.drop(["county_numbering_start", "X", "Y", "county_last_id", "geometry"], axis = 1).columns.tolist()

out = all_link_df[link_prop].to_json(orient = "records")

with open(os.path.join(output_data_version_dir, "link.json"), 'w') as f:
    f.write(out)
# Out:
# -------write out link json---------
# Wall time: 46.6 s

# %%
# %%time

print("-------write out node geojson---------")

node_prop = roadway_and_rail_node_gdf.drop(["geometry", "county_numbering_start"], axis = 1).columns.tolist()
node_geojson = point_df_to_geojson(roadway_and_rail_node_gdf, node_prop)

with open(os.path.join(output_data_version_dir, "node.geojson"), "w") as f:
    json.dump(node_geojson, f)
# Out:
# -------write out node geojson---------
# Wall time: 3min 10s

# %%
print("-------write out link feather---------")

link_feather = all_link_df.drop(["county_numbering_start", "X", "Y", "county_last_id", "geometry"], axis = 1).copy()

link_feather.to_feather(os.path.join(output_data_version_dir, 'link.feather'))
# Out:
# -------write out link feather---------

# %% [markdown]
# # write out to CUBE .lin

# %%
def prepare_df_for_cube(routes, mode_crosswalk, trip, bus_link, freq,
                        rail_link = pd.DataFrame(columns = ['shape_id'])):
    
    
    transit_link_gdf = pd.concat([bus_link[['shape_id']], rail_link[['shape_id']]], 
                                 sort = False, ignore_index = True)
    trip_df = trip.copy()
    
    trip_df = trip_df[trip_df.shape_id.isin(transit_link_gdf.shape_id.unique().tolist())]
    
    trip_df = pd.merge(trip_df.drop("agency_raw_name", axis = 1), routes, how = 'left', on = 'route_id')
    
    trip_df = trip_df[~ trip_df.agency_raw_name.isin(["Petaluma_2016_5_22", "WestCAT_2016_5_26", "GGFerries_2017_3_18"])].copy()
    
    trip_df = pd.merge(trip_df, freq[['trip_id','headway_secs']], how = 'left', on = 'trip_id')
    
    #trip_df['tod'] = np.where(trip_df.tod == 'peak', 'pk', 'op')
    
    trip_df['NAME'] = trip_df.apply(lambda x: str(x.agency_id) + '_' + str(x.route_id) + '_' 
                                    + str(x.route_short_name) 
                                    #+ '_'
                                    #+ x.tod 
                                    #+ str(x.direction_id)
                                    , 
                                    axis = 1)
    trip_df['LONGNAME'] = trip_df['route_long_name']
    trip_df['HEADWAY'] = (trip_df['headway_secs']/60).astype(int)
    
    """
    def mode_gtfs_to_muni(x):
        if x.route_type == 0:
            return 15
        elif x.route_type == 5:
   cube_trip_df = prepare_df_for_cube(all_routes_df, 
                                   gtfs_to_tm2_mode_crosswalk_df,
                                trip_df, 
                                bus_link_df, 
                                freq_df, 
                                rail_link_gdf)         return 14
        elif x.route_short_name[-1] in ["X", "R"]:
            return 12
        else:
            return 11
    
    trip_df['MODE'] = trip_df.apply(lambda x : mode_gtfs_to_muni(x),
                                   axis = 1)
    """
    
    trip_df = pd.merge(
        trip_df,
        mode_crosswalk.drop("agency_id", axis = 1),
        how = "left",
        on = ["agency_raw_name", "route_type"]
    )
    
    trip_df['TM2_mode'].fillna(11, inplace = True)
    trip_df['TM2_mode'] = trip_df['TM2_mode'].astype(int)
    
    trip_df['ONEWAY'] = 'T'
    
    return trip_df

# %%
# read gfts to TM2 mode crosswalk
gtfs_to_tm2_mode_crosswalk_df = pd.read_csv(os.path.join(input_data_interim_dir,"gtfs_to_tm2_mode_crosswalk.csv"))

gtfs_to_tm2_mode_crosswalk_df.drop_duplicates(subset = ["agency_raw_name", "route_type"], inplace = True)

# %%
cube_trip_df = prepare_df_for_cube(all_routes_df, 
                                   gtfs_to_tm2_mode_crosswalk_df,
                                   trip_df, 
                                   bus_link_df, 
                                   freq_df, 
                                   rail_link_gdf)

# %%
cube_trip_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4040 entries, 0 to 4039
# Data columns (total 78 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   service_id                    4040 non-null   object
#  1   trip_headsign                 3657 non-null   object
#  2   direction_id                  4040 non-null   float64
#  3   block_id                      2780 non-null   object
#  4   trip_short_name               363 non-null    object
#  5   wheelchair_accessible         105 non-null    float64
#  6   bikes_allowed                 703 non-null    float64
#  7   original_trip_id              147 non-null    object
#  8   trip_bikes_allowed            8 non-null      object
#  9   trip_type                     0 non-null      object
#  10  drt_max_travel_time           18 non-null     object
#  11  drt_avg_travel_time           18 non-null     object
#  12  drt_advance_book_min          18 non-null     object
#  13  drt_pickup_message            0 non-null      object
#  14  drt_drop_off_message          0 non-null      object
#  15  continuous_pickup_message     0 non-null      object
#  16  continuous_drop_off_message   0 non-null      object
#  17  route_id                      4040 non-null   int32
#  18  trip_id                       4040 non-null   int32
#  19  shape_id                      4040 non-null   int32
#  20  arrival_time                  4039 non-null   float64
#  21  departure_time                4039 non-null   float64
#  22  stop_sequence                 4040 non-null   int64
#  23  pickup_type                   1277 non-null   float64
#  24  drop_off_type                 1863 non-null   object
#  25  stop_headsign                 944 non-null    object
#  26  shape_dist_traveled           914 non-null    float64
#  27  timepoint                     332 non-null    float64
#  28  last_stop_on_trip             0 non-null      object
#  29  start_service_area_id         0 non-null      object
#  30  end_service_area_id           0 non-null      object
#  31  start_service_area_radius     0 non-null      object
#  32  end_service_area_radius       0 non-null      object
#  33  continuous_pickup_x           18 non-null     object
#  34  continuous_drop_off_x         18 non-null     object
#  35  pickup_area_id                0 non-null      object
#  36  drop_off_area_id              0 non-null      object
#  37  pickup_service_area_radius    0 non-null      object
#  38  drop_off_service_area_radius  0 non-null      object
#  39  *shape_id                     49 non-null     object
#  40  *seq#                         49 non-null     object
#  41  *Dist(m)                      49 non-null     object
#  42  *Comment                      0 non-null      object
#  43  stop_id                       4040 non-null   int32
#  44  arrival_h                     4039 non-null   float64
#  45  arrival_m                     4039 non-null   float64
#  46  departure_h                   4039 non-null   float64
#  47  departure_m                   4039 non-null   float64
#  48  tod                           4040 non-null   object
#  49  trip_num_x                    4040 non-null   int64
#  50  trip_num_y                    1041 non-null   float64
#  51  trip_num                      4040 non-null   float64
#  52  route_id_original             4040 non-null   object
#  53  agency_id                     3540 non-null   object
#  54  route_short_name              3781 non-null   object
#  55  route_long_name               3940 non-null   object
#  56  route_type                    4040 non-null   int64
#  57  route_color                   1912 non-null   object
#  58  route_text_color              1806 non-null   object
#  59  agency_raw_name               4040 non-null   object
#  60  route_desc                    685 non-null    object
#  61  route_url                     1747 non-null   object
#  62  route_sort_order              590 non-null    object
#  63  min_headway_minutes           291 non-null    object
#  64  eligibility_restricted        18 non-null     object
#  65  continuous_pickup_y           18 non-null     object
#  66  continuous_drop_off_y         18 non-null     object
#  67  headway_secs                  4040 non-null   int64
#  68  NAME                          4040 non-null   object
#  69  LONGNAME                      3940 non-null   object
#  70  HEADWAY                       4040 non-null   int32
#  71  agency_name                   3898 non-null   object
#  72  TM2_operator                  3898 non-null   float64
#  73  TM2_mode                      4040 non-null   int32
#  74  TM2_line_haul_name            3898 non-null   object
#  75  TM2_faresystem                3898 non-null   float64
#  76  is_express_bus                3898 non-null   float64
#  77  ONEWAY                        4040 non-null   object
# dtypes: float64(17), int32(6), int64(4), object(51)
# memory usage: 2.3+ MB

# %%
def node_list(cube_trip_dict, trip_df, stop_df, bus_link, stop_times, node_gdf, link_gdf,
              rail_link, rail_node_df, transit_lin_f):
    """ lmz: This really needs some documentation. It's poorly named as well.
    """            
    rail_link_df = rail_link.copy()
    rail_link_df = pd.merge(trip_df[['trip_id', 'shape_id']],
                            rail_link_df,
                           how = 'right',
                           on = 'shape_id')
    
    transit_link_gdf = pd.concat([bus_link[['u', 'v', 'shape_id', 'trip_id' , "A", "B"]], 
                                  rail_link_df[['shape_id', 'trip_id', "A", "B"]]], 
                                 sort = False, 
                                 ignore_index = True)
    
    """transit_link_gdf = pd.merge(transit_link_gdf,
                               link_gdf[['LINK_ID',"u","v"]],
                               how = "left",
                               on = ["u","v"])"""
   
    stop_times_df = stop_times.copy()
    stop_id_list = stop_times_df[stop_times_df.trip_id == cube_trip_dict['trip_id']]['stop_id'].tolist()
    stop_node_list = stop_df[stop_df['stop_id'].isin(stop_id_list)]['model_node_id'].tolist()
    
    #print(stop_node_list)
    
    node_list = transit_link_gdf[transit_link_gdf['trip_id'] == cube_trip_dict['trip_id']]['A'].tolist() + \
                    [transit_link_gdf[transit_link_gdf['trip_id'] == cube_trip_dict['trip_id']]['B'].iloc[-1]]
    
    #osmid_N_dict = dict(zip(node_gdf.OSMID, node_gdf.N))
    
    #node_list = list(map(osmid_N_dict.get, node_list))
    
    s = '\nLINE NAME=\"%s\",' % (cube_trip_dict['NAME'],)
    
    #line attribtes
    s += '\n LONGNAME=\"%s",' % (cube_trip_dict['LONGNAME'],)
    s += '\n USERA1=\"%s",' % (cube_trip_dict['agency_id'],)
    s += '\n USERA2=\"%s",' % (cube_trip_dict['TM2_line_haul_name'],)
    if cube_trip_dict['tod'] == 'AM':
        s += '\n HEADWAY[2]=%s,' % (cube_trip_dict['HEADWAY'],)
    elif cube_trip_dict['tod'] == "MD":
        s += '\n HEADWAY[3]=%s,' % (cube_trip_dict['HEADWAY'],)
    elif cube_trip_dict['tod'] == "PM":
        s += '\n HEADWAY[4]=%s,' % (cube_trip_dict['HEADWAY'],)
    elif cube_trip_dict['tod'] == "NT":
        s += '\n HEADWAY[5]=%s,' % (cube_trip_dict['HEADWAY'],)
    elif cube_trip_dict['tod'] == "EA":
        s += '\n HEADWAY[1]=%s,' % (cube_trip_dict['HEADWAY'],)
    s += '\n MODE=%s,' % (cube_trip_dict['TM2_mode'],)
    s += '\n ONEWAY=%s,' % (cube_trip_dict['ONEWAY'],)
    s += '\n OPERATOR=%s,' % (cube_trip_dict['agency_id'],)
    s += '\n SHORTNAME=%s,' % (cube_trip_dict['route_short_name'],)
    s += '\nN='
    
    circular = 0
    #node list
    trip_stop_list = []
    for nodeIdx in range(len(node_list)):
        # added condition to make sure stops only get stopped once
        if (node_list[nodeIdx] in stop_node_list) & (node_list[nodeIdx] not in trip_stop_list):
            s += '\n %s' % (node_list[nodeIdx])
            trip_stop_list += [node_list[nodeIdx]]
            if nodeIdx < (len(node_list)-1):
                s += ','
        else:
            s += '\n -%s' % (node_list[nodeIdx])
            if nodeIdx < (len(node_list)-1):
                s += ','
            if (node_list[nodeIdx] in trip_stop_list):
                circular = 1
    
    #if circular == 1:
    #    s += ','
    #    s += '\n CIRCULAR=T'                
            
    transit_lin_f.write(s)
    transit_lin_f.write('\n')

# %%
cube_trip_dict_list = cube_trip_df.to_dict(orient='records')
print(cube_trip_dict_list[0])
# Out:
# {'service_id': '72777', 'trip_headsign': 'San Jose', 'direction_id': 0.0, 'block_id': nan, 'trip_short_name': 'ACE 1', 'wheelchair_accessible': nan, 'bikes_allowed': nan, 'original_trip_id': nan, 'trip_bikes_allowed': nan, 'trip_type': nan, 'drt_max_travel_time': nan, 'drt_avg_travel_time': nan, 'drt_advance_book_min': nan, 'drt_pickup_message': nan, 'drt_drop_off_message': nan, 'continuous_pickup_message': nan, 'continuous_drop_off_message': nan, 'route_id': 1, 'trip_id': 1, 'shape_id': 1, 'arrival_time': 15600.0, 'departure_time': 15600.0, 'stop_sequence': 1, 'pickup_type': nan, 'drop_off_type': nan, 'stop_headsign': nan, 'shape_dist_traveled': nan, 'timepoint': nan, 'last_stop_on_trip': nan, 'start_service_area_id': nan, 'end_service_area_id': nan, 'start_service_area_radius': nan, 'end_service_area_radius': nan, 'continuous_pickup_x': nan, 'continuous_drop_off_x': nan, 'pickup_area_id': nan, 'drop_off_area_id': nan, 'pickup_service_area_radius': nan, 'drop_off_service_area_radius': nan, '*shape_id': nan, '*seq#': nan, '*Dist(m)': nan, '*Comment': nan, 'stop_id': 1, 'arrival_h': 4.0, 'arrival_m': 20.0, 'departure_h': 4.0, 'departure_m': 20.0, 'tod': 'EA', 'trip_num_x': 2, 'trip_num_y': 1.0, 'trip_num': 1.0, 'route_id_original': 'ACE', 'agency_id': 'CE', 'route_short_name': 'ACE', 'route_long_name': nan, 'route_type': 2, 'route_color': nan, 'route_text_color': nan, 'agency_raw_name': 'ACE_2017_3_20', 'route_desc': nan, 'route_url': nan, 'route_sort_order': nan, 'min_headway_minutes': nan, 'eligibility_restricted': nan, 'continuous_pickup_y': nan, 'continuous_drop_off_y': nan, 'headway_secs': 3600, 'NAME': 'CE_1_ACE', 'LONGNAME': nan, 'HEADWAY': 60, 'agency_name': 'ACE Altamont Corridor Express', 'TM2_operator': 5.0, 'TM2_mode': 133, 'TM2_line_haul_name': 'Commuter rail', 'TM2_faresystem': 44.0, 'is_express_bus': 0.0, 'ONEWAY': 'T'}

# %%
unique_rail_node_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 669 entries, 0 to 1433
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   node_id              669 non-null    int64
#  1   shape_pt_lat         669 non-null    float64
#  2   shape_pt_lon         669 non-null    float64
#  3   shape_pt_sequence    669 non-null    object
#  4   shape_dist_traveled  559 non-null    float64
#  5   shape_id             669 non-null    int32
#  6   is_stop              669 non-null    int64
#  7   stop_id              669 non-null    float64
#  8   model_node_id        669 non-null    int64
#  9   geometry             669 non-null    geometry
#  10  rail_only            669 non-null    int64
#  11  walk_access          669 non-null    int64
#  12  county               669 non-null    object
# dtypes: float64(4), geometry(1), int32(1), int64(5), object(2)
# memory usage: 70.6+ KB

# %%
stop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22402 entries, 0 to 22401
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   stop_name            22402 non-null  object
#  1   stop_lat             22402 non-null  float64
#  2   stop_lon             22402 non-null  float64
#  3   zone_id              12516 non-null  object
#  4   agency_raw_name      22402 non-null  object
#  5   stop_code            15737 non-null  object
#  6   location_type        5807 non-null   float64
#  7   parent_station       620 non-null    object
#  8   stop_desc            4492 non-null   object
#  9   stop_url             4168 non-null   object
#  10  stop_timezone        137 non-null    object
#  11  wheelchair_boarding  388 non-null    float64
#  12  platform_code        58 non-null     object
#  13  position             0 non-null      object
#  14  direction            0 non-null      object
#  15  * used by routes     125 non-null    object
#  16  stop_id              22402 non-null  int32
#  17  osm_node_id          22402 non-null  object
#  18  shst_node_id         22402 non-null  object
#  19  model_node_id        22402 non-null  object
# dtypes: float64(4), int32(1), object(15)
# memory usage: 3.5+ MB

# %%
# update stop_df to use model_node_id from unique_rail_node_dict 
stop_df = pd.merge(left=stop_df, right=unique_rail_node_gdf[['stop_id','model_node_id']],
                   how='left', on='stop_id', suffixes=['','_rail'])
stop_df.loc[stop_df['model_node_id_rail'].notnull(), 'model_node_id'] = stop_df.model_node_id_rail
stop_df.drop(columns='model_node_id_rail', inplace=True)
stop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22402 entries, 0 to 22401
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   stop_name            22402 non-null  object
#  1   stop_lat             22402 non-null  float64
#  2   stop_lon             22402 non-null  float64
#  3   zone_id              12516 non-null  object
#  4   agency_raw_name      22402 non-null  object
#  5   stop_code            15737 non-null  object
#  6   location_type        5807 non-null   float64
#  7   parent_station       620 non-null    object
#  8   stop_desc            4492 non-null   object
#  9   stop_url             4168 non-null   object
#  10  stop_timezone        137 non-null    object
#  11  wheelchair_boarding  388 non-null    float64
#  12  platform_code        58 non-null     object
#  13  position             0 non-null      object
#  14  direction            0 non-null      object
#  15  * used by routes     125 non-null    object
#  16  stop_id              22402 non-null  int32
#  17  osm_node_id          22402 non-null  object
#  18  shst_node_id         22402 non-null  object
#  19  model_node_id        22402 non-null  object
# dtypes: float64(4), int32(1), object(15)
# memory usage: 4.1+ MB

# %%
# %%time
# this takes ~30min
# the process has a lot of memory used up by this time which is probably not helping

transit_lin_file = os.path.join(output_folder, "transit.lin")
transit_lin_f    = open(transit_lin_file, 'w')

transit_lin_f.write(';;<<PT>><<LINE>>;;\n')

print("Writing to {}".format(transit_lin_file))
print("Writing record 0 of {}".format(len(cube_trip_dict_list)),end='')
for i in range(len(cube_trip_dict_list)):
    print("\rWriting record {} of {}".format(i, len(cube_trip_dict_list)),end='')
    node_list(cube_trip_dict_list[i],
              trip_df,
              stop_df, 
              bus_link_df,
              all_stop_times_df,
              roadway_and_rail_node_gdf,
              roadway_and_rail_link_df,
              rail_link_gdf,
              unique_rail_node_gdf,
              transit_lin_f # output file
             )
print("")
# Out:
# Writing to C:\Users\lzorn\Documents\scratch\tm2_network_building\processed\version_12\\transit.lin
# Writing record 4039 of 4040
# Wall time: 26min 59s

# %% [markdown]
# # write out quick QA/QC transit route true shape

# %%
# true shapes for line record

from shapely import ops, geometry

def get_true_line_shape(trip_df, bus_link, roadway_and_rail_shape,
                        rail_link = pd.DataFrame(columns = ['LINK_ID','shape_id', 'u', 'v'])):
    
    """
    write out true shape for each trip
    """
    
    rail_link_df = rail_link.copy()
    rail_link_df = pd.merge(trip_df[['trip_id', 'shape_id']],
                            rail_link_df,
                           how = 'right',
                           on = 'shape_id')
    
    transit_link_gdf = pd.concat([bus_link[['shape_id', 'trip_id', "shstGeometryId"]], 
                                  rail_link_df[['shape_id', 'trip_id', "shstGeometryId"]]], 
                                 sort = False, ignore_index = True)
    
    transit_link_gdf = pd.merge(transit_link_gdf,
                                roadway_and_rail_shape[['id', 'geometry']],
                                how = 'left',
                                left_on = 'shstGeometryId',
                               right_on = "id")
    
    true_line_shape_df = transit_link_gdf.groupby(['trip_id', 'shape_id'])['geometry'].agg(
                                                                lambda x: 
                                                                ops.linemerge(geometry.MultiLineString(x.tolist())))\
                                        .reset_index()
    
    """true_line_shape_df = pd.merge(true_line_shape_df, 
                                  cube,
                                 how = 'left',
                                 on = ['shape_id', 'trip_id'])"""
    
    true_line_shape_gdf = gpd.GeoDataFrame(true_line_shape_df, 
                                           crs = roadway_and_rail_shape.crs, 
                                           geometry = 'geometry')
    
    return true_line_shape_gdf

# %%
true_line_shape_gdf = get_true_line_shape(trip_df,
                                          bus_link_df, 
                                          roadway_and_rail_shape_gdf,
                                          rail_link_gdf)

true_line_shape_gdf.to_file(os.path.join(input_data_interim_dir, "transit_route.geojson"),
                            driver = "GeoJSON")
